# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

out_channels = 100
window_width = [3, 4, 5]
embedding_dimensions = 300
n_steps = 250
n_fc1 = 300
n_fc2 = 100
n_output = 1

activation_fn = tf.nn.relu
init_W_CL_3 = np.random.randn(window_width[0],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_3 = np.random.randn(1,1,1,out_channels).astype(np.float32)
init_W_CL_4 = np.random.randn(window_width[1],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_4 = np.random.randn(1,1,1,out_channels).astype(np.float32)
init_W_CL_5 = np.random.randn(window_width[2],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_5 = np.random.randn(1,1,1,out_channels).astype(np.float32)

learning_rate = tf.placeholder(tf.float32)

X = tf.placeholder(tf.int32, [None, n_steps], name="X") #m * n_steps
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=True)# n_words * embedding_dimensions
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X) # m * n_steps * embedding_dimensions

with tf.name_scope("CNN_3"):
    W_CL_3 = tf.Variable(initial_value=init_W_CL_3)
    b_CL_3 = tf.Variable(initial_value=init_b_CL_3)
    CL_3 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_3, strides=[1,1,1,1], padding="VALID")# m * n_steps - 3 + 1 *1 * out_channels 
    activated_CL_3 = activation_fn(tf.add(CL_3,b_CL_3)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_3 = tf.reshape(tf.math.reduce_max(activated_CL_3,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_4"):
    W_CL_4 = tf.Variable(initial_value=init_W_CL_4)
    b_CL_4 = tf.Variable(initial_value=init_b_CL_4)
    CL_4 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_4, strides=[1,1,1,1], padding="VALID")# m * n_steps - 4 + 1 *1 * out_channels 
    activated_CL_4 = activation_fn(tf.add(CL_4,b_CL_4)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_4 = tf.reshape(tf.math.reduce_max(activated_CL_4,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_5"):
    W_CL_5 = tf.Variable(initial_value=init_W_CL_5)
    b_CL_5 = tf.Variable(initial_value=init_b_CL_5)
    CL_5 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_5, strides=[1,1,1,1], padding="VALID")# m * n_steps - 5 + 1 *1 * out_channels 
    activated_CL_5 = activation_fn(tf.add(CL_5,b_CL_5)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_5 = tf.reshape(tf.math.reduce_max(activated_CL_5,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels

with tf.name_scope("Max_pool"):
    MAXPOOL = tf.concat([MAXPOOL_3,MAXPOOL_4,MAXPOOL_5], axis=1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(MAXPOOL, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc2, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 100

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 6

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model4.1/QIQC_model4.1.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

#file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

t_init = time.time()
lr = 1e-12
lr_stop = 1
lr_stack = []
loss_stack = []
step_stack = []
f1_stack = []
min_lr = 0.003
max_lr = 0.008
lr = min_lr

with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):            
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, learning_rate: lr})
            
            step = epoch * QIQC.nr_batches + iteration
            cycle = np.floor(1 + step/(2 * QIQC.nr_batches))
            pattern = np.absolute(step/QIQC.nr_batches - 2*cycle + 1)
            lr = min_lr + (max_lr - min_lr) * (1-pattern)
            
            if step % 50 ==0:
              f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
              step_stack.append(step)
              loss_stack.append(loss_dev)
              f1_stack.append(f1_dev)
            """
            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)
            """
            if iteration % 10000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 500 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch})
                #f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
                t_1 = time.time()
                t_delta = t_1 - t_0
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/500
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/6; It. 0/13041; Runtime 11.41 s; Remaining runtime 0h29min45s; f1_train nan; f1_dev nan; loss_train 10.2333; loss_dev 8.0967
# Ep. 1/6; It. 500/13041; Runtime 41.80 s; Remaining runtime 1h48min20s; f1_train 0.7273; f1_dev 0.5455; loss_train 0.0643; loss_dev 0.1330
# Ep. 1/6; It. 1000/13041; Runtime 41.76 s; Remaining runtime 1h47min31s; f1_train 0.6667; f1_dev 0.5773; loss_train 0.0488; loss_dev 0.1112
# Ep. 1/6; It. 1500/13041; Runtime 41.82 s; Remaining runtime 1h46min59s; f1_train 0.2857; f1_dev 0.3377; loss_train 0.1126; loss_dev 0.1355
# Ep. 1/6; It. 2000/13041; Runtime 41.85 s; Remaining runtime 1h46min22s; f1_train 0.7273; f1_dev 0.4719; loss_train 0.0491; loss_dev 0.1146
# Ep. 1/6; It. 2500/13041; Runtime 41.90 s; Remaining runtime 1h45min47s; f1_train 0.6667; f1_dev 0.6218; loss_train 0.1106; loss_dev 0.1135
# Ep. 1/6; It. 3000/13041; Runtime 41.91 s; Remaining runtime 1h45min6s; f1_train 0.8571; f1_dev 0.5169; loss_train 0.0769; loss_dev 0.1102
# Ep. 1/6; It. 3500/13041; Runtime 41.90 s; Remaining runtime 1h44min23s; f1_train 0.3333; f1_dev 0.6667; loss_train 0.1202; loss_dev 0.1050
# Ep. 1/6; It. 4000/13041; Runtime 41.92 s; Remaining runtime 1h43min44s; f1_train 0.9091; f1_dev 0.6667; loss_train 0.0444; loss_dev 0.1004
# Ep. 1/6; It. 4500/13041; Runtime 41.89 s; Remaining runtime 1h42min57s; f1_train 0.6667; f1_dev 0.4762; loss_train 0.0754; loss_dev 0.1048
# Ep. 1/6; It. 5000/13041; Runtime 41.95 s; Remaining runtime 1h42min25s; f1_train 0.5000; f1_dev 0.5556; loss_train 0.0655; loss_dev 0.1016
# Ep. 1/6; It. 5500/13041; Runtime 41.93 s; Remaining runtime 1h41min39s; f1_train 0.5714; f1_dev 0.5319; loss_train 0.0678; loss_dev 0.1135
# Ep. 1/6; It. 6000/13041; Runtime 41.93 s; Remaining runtime 1h40min57s; f1_train 0.8333; f1_dev 0.5743; loss_train 0.1095; loss_dev 0.1076
# Ep. 1/6; It. 6500/13041; Runtime 41.92 s; Remaining runtime 1h40min15s; f1_train 0.6667; f1_dev 0.5652; loss_train 0.1113; loss_dev 0.1040
# Ep. 1/6; It. 7000/13041; Runtime 41.88 s; Remaining runtime 1h39min27s; f1_train 0.6667; f1_dev 0.6263; loss_train 0.1520; loss_dev 0.1333
# Ep. 1/6; It. 7500/13041; Runtime 41.90 s; Remaining runtime 1h38min48s; f1_train 0.6000; f1_dev 0.6891; loss_train 0.0738; loss_dev 0.0948
# Ep. 1/6; It. 8000/13041; Runtime 41.82 s; Remaining runtime 1h37min55s; f1_train 1.0000; f1_dev 0.6435; loss_train 0.0288; loss_dev 0.1118
# Ep. 1/6; It. 8500/13041; Runtime 41.80 s; Remaining runtime 1h37min11s; f1_train 0.7692; f1_dev 0.6346; loss_train 0.0709; loss_dev 0.1045
# Ep. 1/6; It. 9000/13041; Runtime 41.78 s; Remaining runtime 1h36min26s; f1_train 0.8000; f1_dev 0.6606; loss_train 0.0567; loss_dev 0.1086
# Ep. 1/6; It. 9500/13041; Runtime 41.71 s; Remaining runtime 1h35min35s; f1_train 0.7273; f1_dev 0.6609; loss_train 0.0863; loss_dev 0.1062
# Ep. 1/6; It. 10000/13041; Runtime 48.48 s; Remaining runtime 1h50min17s; f1_train 0.7500; f1_dev 0.6195; loss_train 0.0806; loss_dev 0.1063
# Ep. 1/6; It. 10500/13041; Runtime 41.87 s; Remaining runtime 1h34min32s; f1_train nan; f1_dev nan; loss_train 0.1259; loss_dev 0.1310
# Ep. 1/6; It. 11000/13041; Runtime 41.69 s; Remaining runtime 1h33min26s; f1_train 0.5455; f1_dev 0.6486; loss_train 0.1129; loss_dev 0.1058
# Ep. 1/6; It. 11500/13041; Runtime 41.64 s; Remaining runtime 1h32min38s; f1_train 0.7273; f1_dev 0.6667; loss_train 0.1029; loss_dev 0.1080
# Ep. 1/6; It. 12000/13041; Runtime 41.64 s; Remaining runtime 1h31min57s; f1_train 0.5000; f1_dev 0.6531; loss_train 0.1144; loss_dev 0.1157
# Ep. 1/6; It. 12500/13041; Runtime 41.67 s; Remaining runtime 1h31min19s; f1_train 0.6667; f1_dev 0.6667; loss_train 0.0859; loss_dev 0.1067
# Ep. 1/6; It. 13000/13041; Runtime 41.64 s; Remaining runtime 1h30min34s; f1_train 0.7500; f1_dev 0.5979; loss_train 0.1056; loss_dev 0.1155
# Ep. 2/6; It. 0/13041; Runtime 13.04 s; Remaining runtime 0h28min20s; f1_train 0.6667; f1_dev 0.5979; loss_train 0.0945; loss_dev 0.1155
# Ep. 2/6; It. 500/13041; Runtime 41.80 s; Remaining runtime 1h30min8s; f1_train 1.0000; f1_dev 0.6000; loss_train 0.0332; loss_dev 0.1102
# Ep. 2/6; It. 1000/13041; Runtime 41.64 s; Remaining runtime 1h29min6s; f1_train 0.7692; f1_dev 0.6346; loss_train 0.1282; loss_dev 0.1208
# Ep. 2/6; It. 1500/13041; Runtime 41.65 s; Remaining runtime 1h28min27s; f1_train 0.8571; f1_dev 0.6000; loss_train 0.0765; loss_dev 0.1208
# Ep. 2/6; It. 2000/13041; Runtime 41.64 s; Remaining runtime 1h27min43s; f1_train 0.8462; f1_dev 0.6182; loss_train 0.1141; loss_dev 0.1221
# Ep. 2/6; It. 2500/13041; Runtime 41.64 s; Remaining runtime 1h27min2s; f1_train 0.6667; f1_dev 0.6182; loss_train 0.0422; loss_dev 0.1157
# Ep. 2/6; It. 3000/13041; Runtime 41.65 s; Remaining runtime 1h26min21s; f1_train 0.8889; f1_dev 0.6154; loss_train 0.0392; loss_dev 0.1226
# Ep. 2/6; It. 3500/13041; Runtime 41.63 s; Remaining runtime 1h25min37s; f1_train 0.4444; f1_dev 0.6337; loss_train 0.0751; loss_dev 0.1085
# Ep. 2/6; It. 4000/13041; Runtime 41.65 s; Remaining runtime 1h24min58s; f1_train 0.4615; f1_dev 0.6200; loss_train 0.1714; loss_dev 0.1187
# Ep. 2/6; It. 4500/13041; Runtime 41.62 s; Remaining runtime 1h24min12s; f1_train 0.8235; f1_dev 0.6545; loss_train 0.1042; loss_dev 0.1093
# Ep. 2/6; It. 5000/13041; Runtime 41.59 s; Remaining runtime 1h23min28s; f1_train 0.7143; f1_dev 0.6727; loss_train 0.1043; loss_dev 0.1172
# Ep. 2/6; It. 5500/13041; Runtime 41.61 s; Remaining runtime 1h22min48s; f1_train 0.7692; f1_dev 0.6226; loss_train 0.0836; loss_dev 0.1100
# Ep. 2/6; It. 6000/13041; Runtime 41.64 s; Remaining runtime 1h22min10s; f1_train 0.6667; f1_dev 0.6452; loss_train 0.0428; loss_dev 0.1124
# Ep. 2/6; It. 6500/13041; Runtime 41.62 s; Remaining runtime 1h21min26s; f1_train 0.6667; f1_dev 0.6609; loss_train 0.0741; loss_dev 0.1066
# Ep. 2/6; It. 7000/13041; Runtime 41.61 s; Remaining runtime 1h20min43s; f1_train 0.8000; f1_dev 0.6271; loss_train 0.0929; loss_dev 0.1088
# Ep. 2/6; It. 7500/13041; Runtime 41.64 s; Remaining runtime 1h20min5s; f1_train 0.5455; f1_dev 0.6422; loss_train 0.0753; loss_dev 0.1044
# Ep. 2/6; It. 8000/13041; Runtime 41.64 s; Remaining runtime 1h19min23s; f1_train 0.6667; f1_dev 0.6667; loss_train 0.1039; loss_dev 0.1046
# Ep. 2/6; It. 8500/13041; Runtime 41.61 s; Remaining runtime 1h18min38s; f1_train 0.5000; f1_dev 0.6491; loss_train 0.1453; loss_dev 0.1127
# Ep. 2/6; It. 9000/13041; Runtime 41.68 s; Remaining runtime 1h18min5s; f1_train 0.7500; f1_dev 0.5524; loss_train 0.0467; loss_dev 0.1122
# Ep. 2/6; It. 9500/13041; Runtime 41.61 s; Remaining runtime 1h17min15s; f1_train 0.6667; f1_dev 0.5495; loss_train 0.1058; loss_dev 0.1089
# Ep. 2/6; It. 10000/13041; Runtime 47.77 s; Remaining runtime 1h27min54s; f1_train 0.8333; f1_dev 0.5773; loss_train 0.1298; loss_dev 0.1114
# Ep. 2/6; It. 10500/13041; Runtime 41.79 s; Remaining runtime 1h16min11s; f1_train 0.6667; f1_dev 0.5806; loss_train 0.1195; loss_dev 0.1075
# Ep. 2/6; It. 11000/13041; Runtime 41.63 s; Remaining runtime 1h15min13s; f1_train 0.3077; f1_dev 0.6838; loss_train 0.1849; loss_dev 0.1061
# Ep. 2/6; It. 11500/13041; Runtime 41.69 s; Remaining runtime 1h14min37s; f1_train 0.7619; f1_dev 0.6614; loss_train 0.1692; loss_dev 0.1060
# Ep. 2/6; It. 12000/13041; Runtime 41.65 s; Remaining runtime 1h13min52s; f1_train 0.5000; f1_dev 0.6609; loss_train 0.0563; loss_dev 0.1032
# Ep. 2/6; It. 12500/13041; Runtime 41.64 s; Remaining runtime 1h13min9s; f1_train 0.6667; f1_dev 0.6604; loss_train 0.0493; loss_dev 0.1056
# Ep. 2/6; It. 13000/13041; Runtime 41.67 s; Remaining runtime 1h12min30s; f1_train 0.5714; f1_dev 0.6263; loss_train 0.2078; loss_dev 0.1050
# Ep. 3/6; It. 0/13041; Runtime 13.44 s; Remaining runtime 0h23min21s; f1_train 0.8696; f1_dev 0.6612; loss_train 0.0792; loss_dev 0.1021
# Ep. 3/6; It. 500/13041; Runtime 41.70 s; Remaining runtime 1h11min48s; f1_train 0.9091; f1_dev 0.6306; loss_train 0.0326; loss_dev 0.1372
# Ep. 3/6; It. 1000/13041; Runtime 41.69 s; Remaining runtime 1h11min5s; f1_train 0.8000; f1_dev 0.6316; loss_train 0.0991; loss_dev 0.1453
# Ep. 3/6; It. 1500/13041; Runtime 41.70 s; Remaining runtime 1h10min25s; f1_train 0.6667; f1_dev 0.6154; loss_train 0.0421; loss_dev 0.1212
# Ep. 3/6; It. 2000/13041; Runtime 41.71 s; Remaining runtime 1h9min45s; f1_train 1.0000; f1_dev 0.6422; loss_train 0.0191; loss_dev 0.1283
# Ep. 3/6; It. 2500/13041; Runtime 41.64 s; Remaining runtime 1h8min55s; f1_train 0.7692; f1_dev 0.6214; loss_train 0.1067; loss_dev 0.1316
# Ep. 3/6; It. 3000/13041; Runtime 41.64 s; Remaining runtime 1h8min14s; f1_train 0.7273; f1_dev 0.6613; loss_train 0.0416; loss_dev 0.1180
# Ep. 3/6; It. 3500/13041; Runtime 41.68 s; Remaining runtime 1h7min36s; f1_train 0.8889; f1_dev 0.6140; loss_train 0.0339; loss_dev 0.1280
# Ep. 3/6; It. 4000/13041; Runtime 41.63 s; Remaining runtime 1h6min50s; f1_train 0.9474; f1_dev 0.6612; loss_train 0.0437; loss_dev 0.1265
# Ep. 3/6; It. 4500/13041; Runtime 41.68 s; Remaining runtime 1h6min13s; f1_train 0.8235; f1_dev 0.6418; loss_train 0.0612; loss_dev 0.1218
# Ep. 3/6; It. 5000/13041; Runtime 41.65 s; Remaining runtime 1h5min29s; f1_train 0.8333; f1_dev 0.6269; loss_train 0.0504; loss_dev 0.1546
# Ep. 3/6; It. 5500/13041; Runtime 41.66 s; Remaining runtime 1h4min47s; f1_train 0.9231; f1_dev 0.6131; loss_train 0.0260; loss_dev 0.1357
# Ep. 3/6; It. 6000/13041; Runtime 41.65 s; Remaining runtime 1h4min5s; f1_train 0.8333; f1_dev 0.6446; loss_train 0.0672; loss_dev 0.1293
# Ep. 3/6; It. 6500/13041; Runtime 41.65 s; Remaining runtime 1h3min23s; f1_train 0.8571; f1_dev 0.6230; loss_train 0.0773; loss_dev 0.1416
# Ep. 3/6; It. 7000/13041; Runtime 41.65 s; Remaining runtime 1h2min42s; f1_train 0.7500; f1_dev 0.6034; loss_train 0.0428; loss_dev 0.1462
# Ep. 3/6; It. 7500/13041; Runtime 41.62 s; Remaining runtime 1h1min58s; f1_train 1.0000; f1_dev 0.6154; loss_train 0.0177; loss_dev 0.1312
# Ep. 3/6; It. 8000/13041; Runtime 41.68 s; Remaining runtime 1h1min21s; f1_train 0.7059; f1_dev 0.6116; loss_train 0.1663; loss_dev 0.1214
# Ep. 3/6; It. 8500/13041; Runtime 41.64 s; Remaining runtime 1h0min36s; f1_train 0.9091; f1_dev 0.6202; loss_train 0.0349; loss_dev 0.1192
# Ep. 3/6; It. 9000/13041; Runtime 41.67 s; Remaining runtime 0h59min56s; f1_train 0.7692; f1_dev 0.6167; loss_train 0.0773; loss_dev 0.1123
# Ep. 3/6; It. 9500/13041; Runtime 41.69 s; Remaining runtime 0h59min17s; f1_train 0.6250; f1_dev 0.5890; loss_train 0.1183; loss_dev 0.1505
# Ep. 3/6; It. 10000/13041; Runtime 48.30 s; Remaining runtime 1h7min52s; f1_train 0.8000; f1_dev 0.5872; loss_train 0.0937; loss_dev 0.1211
# Ep. 3/6; It. 10500/13041; Runtime 41.79 s; Remaining runtime 0h58min2s; f1_train 0.8889; f1_dev 0.6372; loss_train 0.1107; loss_dev 0.1508
# Ep. 3/6; It. 11000/13041; Runtime 41.64 s; Remaining runtime 0h57min8s; f1_train 0.9091; f1_dev 0.5909; loss_train 0.0371; loss_dev 0.1311
# Ep. 3/6; It. 11500/13041; Runtime 41.67 s; Remaining runtime 0h56min28s; f1_train 0.7273; f1_dev 0.6935; loss_train 0.1502; loss_dev 0.1255
# Ep. 3/6; It. 12000/13041; Runtime 41.67 s; Remaining runtime 0h55min47s; f1_train 0.8750; f1_dev 0.6609; loss_train 0.1206; loss_dev 0.1311
# Ep. 3/6; It. 12500/13041; Runtime 41.67 s; Remaining runtime 0h55min5s; f1_train 0.6667; f1_dev 0.6179; loss_train 0.0479; loss_dev 0.1264
# Ep. 3/6; It. 13000/13041; Runtime 41.67 s; Remaining runtime 0h54min24s; f1_train 0.8889; f1_dev 0.6226; loss_train 0.0427; loss_dev 0.1143
# Ep. 4/6; It. 0/13041; Runtime 12.92 s; Remaining runtime 0h16min50s; f1_train 0.7500; f1_dev 0.5169; loss_train 0.0302; loss_dev 0.1443
# Ep. 4/6; It. 500/13041; Runtime 41.77 s; Remaining runtime 0h53min46s; f1_train 0.9474; f1_dev 0.6071; loss_train 0.0405; loss_dev 0.1262
# Ep. 4/6; It. 1000/13041; Runtime 41.66 s; Remaining runtime 0h52min56s; f1_train 0.8000; f1_dev 0.6481; loss_train 0.0677; loss_dev 0.2130
# Ep. 4/6; It. 1500/13041; Runtime 41.63 s; Remaining runtime 0h52min12s; f1_train 0.9524; f1_dev 0.4270; loss_train 0.0496; loss_dev 0.1416
# Ep. 4/6; It. 2000/13041; Runtime 41.65 s; Remaining runtime 0h51min32s; f1_train 0.8333; f1_dev 0.5565; loss_train 0.0387; loss_dev 0.1497
# Ep. 4/6; It. 2500/13041; Runtime 41.66 s; Remaining runtime 0h50min51s; f1_train 0.8235; f1_dev 0.5667; loss_train 0.1293; loss_dev 0.1410
# Ep. 4/6; It. 3000/13041; Runtime 41.66 s; Remaining runtime 0h50min10s; f1_train 0.8421; f1_dev 0.5645; loss_train 0.0900; loss_dev 0.1498
# Ep. 4/6; It. 3500/13041; Runtime 41.68 s; Remaining runtime 0h49min29s; f1_train 1.0000; f1_dev 0.5669; loss_train 0.0208; loss_dev 0.1615
# Ep. 4/6; It. 4000/13041; Runtime 41.63 s; Remaining runtime 0h48min44s; f1_train 0.6667; f1_dev 0.5806; loss_train 0.0493; loss_dev 0.1368
# Ep. 4/6; It. 4500/13041; Runtime 41.66 s; Remaining runtime 0h48min4s; f1_train 1.0000; f1_dev 0.6000; loss_train 0.0112; loss_dev 0.1872
# Ep. 4/6; It. 5000/13041; Runtime 41.72 s; Remaining runtime 0h47min27s; f1_train 0.8571; f1_dev 0.6182; loss_train 0.0680; loss_dev 0.1554
# Ep. 4/6; It. 5500/13041; Runtime 41.67 s; Remaining runtime 0h46min42s; f1_train 0.8000; f1_dev 0.6316; loss_train 0.0265; loss_dev 0.1856
# Ep. 4/6; It. 6000/13041; Runtime 41.67 s; Remaining runtime 0h46min0s; f1_train 0.8750; f1_dev 0.6250; loss_train 0.0549; loss_dev 0.2115
# Ep. 4/6; It. 6500/13041; Runtime 41.68 s; Remaining runtime 0h45min19s; f1_train 0.8889; f1_dev 0.6018; loss_train 0.0549; loss_dev 0.1533
# Ep. 4/6; It. 7000/13041; Runtime 41.66 s; Remaining runtime 0h44min36s; f1_train 0.8000; f1_dev 0.6195; loss_train 0.0758; loss_dev 0.1409
# Ep. 4/6; It. 7500/13041; Runtime 41.65 s; Remaining runtime 0h43min54s; f1_train 0.8333; f1_dev 0.6018; loss_train 0.0545; loss_dev 0.1415
# Ep. 4/6; It. 8000/13041; Runtime 41.66 s; Remaining runtime 0h43min12s; f1_train 0.7500; f1_dev 0.6129; loss_train 0.0436; loss_dev 0.1366
# Ep. 4/6; It. 8500/13041; Runtime 41.66 s; Remaining runtime 0h42min31s; f1_train 1.0000; f1_dev 0.5950; loss_train 0.0116; loss_dev 0.1485
# Ep. 4/6; It. 9000/13041; Runtime 41.68 s; Remaining runtime 0h41min51s; f1_train 0.8333; f1_dev 0.5981; loss_train 0.0624; loss_dev 0.1212
# Ep. 4/6; It. 9500/13041; Runtime 41.66 s; Remaining runtime 0h41min7s; f1_train 0.7500; f1_dev 0.5950; loss_train 0.0438; loss_dev 0.1426
# Ep. 4/6; It. 10000/13041; Runtime 47.94 s; Remaining runtime 0h46min32s; f1_train 0.5714; f1_dev 0.6019; loss_train 0.0729; loss_dev 0.1384
# Ep. 4/6; It. 10500/13041; Runtime 41.81 s; Remaining runtime 0h39min53s; f1_train 0.8889; f1_dev 0.6154; loss_train 0.0563; loss_dev 0.1482
# Ep. 4/6; It. 11000/13041; Runtime 41.68 s; Remaining runtime 0h39min4s; f1_train 0.8000; f1_dev 0.6050; loss_train 0.0500; loss_dev 0.1537
# Ep. 4/6; It. 11500/13041; Runtime 41.65 s; Remaining runtime 0h38min20s; f1_train 1.0000; f1_dev 0.6333; loss_train 0.0281; loss_dev 0.1462
# Ep. 4/6; It. 12000/13041; Runtime 41.66 s; Remaining runtime 0h37min39s; f1_train 0.9412; f1_dev 0.6552; loss_train 0.0387; loss_dev 0.1457
# Ep. 4/6; It. 12500/13041; Runtime 41.62 s; Remaining runtime 0h36min55s; f1_train 1.0000; f1_dev 0.6316; loss_train 0.0172; loss_dev 0.1495
# Ep. 4/6; It. 13000/13041; Runtime 41.64 s; Remaining runtime 0h36min15s; f1_train 0.8000; f1_dev 0.6207; loss_train 0.0463; loss_dev 0.1659
# Ep. 5/6; It. 0/13041; Runtime 12.98 s; Remaining runtime 0h11min17s; f1_train 1.0000; f1_dev 0.6207; loss_train 0.0091; loss_dev 0.1445
# Ep. 5/6; It. 500/13041; Runtime 41.76 s; Remaining runtime 0h35min36s; f1_train 0.9091; f1_dev 0.5556; loss_train 0.0326; loss_dev 0.2150
# Ep. 5/6; It. 1000/13041; Runtime 41.64 s; Remaining runtime 0h34min48s; f1_train 0.8000; f1_dev 0.5714; loss_train 0.0102; loss_dev 0.4453
# Ep. 5/6; It. 1500/13041; Runtime 41.70 s; Remaining runtime 0h34min10s; f1_train 0.9231; f1_dev 0.5806; loss_train 0.0299; loss_dev 0.1717
# Ep. 5/6; It. 2000/13041; Runtime 41.67 s; Remaining runtime 0h33min26s; f1_train 0.7778; f1_dev 0.5891; loss_train 0.0769; loss_dev 0.1940
# Ep. 5/6; It. 2500/13041; Runtime 41.70 s; Remaining runtime 0h32min46s; f1_train 0.9091; f1_dev 0.5891; loss_train 0.0616; loss_dev 0.1827
# Ep. 5/6; It. 3000/13041; Runtime 41.61 s; Remaining runtime 0h32min0s; f1_train 0.8889; f1_dev 0.5950; loss_train 0.0330; loss_dev 0.2163
# Ep. 5/6; It. 3500/13041; Runtime 41.63 s; Remaining runtime 0h31min20s; f1_train 0.9474; f1_dev 0.5488; loss_train 0.0299; loss_dev 0.1808
# Ep. 5/6; It. 4000/13041; Runtime 41.65 s; Remaining runtime 0h30min39s; f1_train 1.0000; f1_dev 0.6080; loss_train 0.0095; loss_dev 0.2109
# Ep. 5/6; It. 4500/13041; Runtime 41.63 s; Remaining runtime 0h29min56s; f1_train 0.9231; f1_dev 0.5564; loss_train 0.0318; loss_dev 0.1827
# Ep. 5/6; It. 5000/13041; Runtime 41.67 s; Remaining runtime 0h29min17s; f1_train 1.0000; f1_dev 0.5954; loss_train 0.0076; loss_dev 0.1583
# Ep. 5/6; It. 5500/13041; Runtime 41.64 s; Remaining runtime 0h28min34s; f1_train 0.8571; f1_dev 0.6207; loss_train 0.0327; loss_dev 0.1799
# Ep. 5/6; It. 6000/13041; Runtime 41.65 s; Remaining runtime 0h27min52s; f1_train 0.9333; f1_dev 0.6142; loss_train 0.0516; loss_dev 0.1704
# Ep. 5/6; It. 6500/13041; Runtime 41.63 s; Remaining runtime 0h27min10s; f1_train 1.0000; f1_dev 0.5970; loss_train 0.0174; loss_dev 0.1750
# Ep. 5/6; It. 7000/13041; Runtime 41.63 s; Remaining runtime 0h26min28s; f1_train 0.9167; f1_dev 0.6140; loss_train 0.0702; loss_dev 0.1848
# Ep. 5/6; It. 7500/13041; Runtime 41.61 s; Remaining runtime 0h25min46s; f1_train 1.0000; f1_dev 0.5538; loss_train 0.0123; loss_dev 0.1812
# Ep. 5/6; It. 8000/13041; Runtime 41.61 s; Remaining runtime 0h25min4s; f1_train 0.7692; f1_dev 0.5950; loss_train 0.0776; loss_dev 0.2099
# Ep. 5/6; It. 8500/13041; Runtime 41.62 s; Remaining runtime 0h24min23s; f1_train 0.9000; f1_dev 0.5862; loss_train 0.0565; loss_dev 0.1490
# Ep. 5/6; It. 9000/13041; Runtime 41.65 s; Remaining runtime 0h23min42s; f1_train 0.7500; f1_dev 0.5891; loss_train 0.0471; loss_dev 0.1859
# Ep. 5/6; It. 9500/13041; Runtime 41.66 s; Remaining runtime 0h23min1s; f1_train 0.8571; f1_dev 0.5588; loss_train 0.0561; loss_dev 0.1908
# Ep. 5/6; It. 10000/13041; Runtime 47.70 s; Remaining runtime 0h25min34s; f1_train 0.9333; f1_dev 0.6015; loss_train 0.0336; loss_dev 0.1772
# Ep. 5/6; It. 10500/13041; Runtime 41.77 s; Remaining runtime 0h21min41s; f1_train 0.4000; f1_dev 0.6000; loss_train 0.1036; loss_dev 0.1676
# Ep. 5/6; It. 11000/13041; Runtime 41.65 s; Remaining runtime 0h20min56s; f1_train 0.8889; f1_dev 0.5735; loss_train 0.0255; loss_dev 0.1711
# Ep. 5/6; It. 11500/13041; Runtime 41.60 s; Remaining runtime 0h20min13s; f1_train 0.8235; f1_dev 0.5692; loss_train 0.0688; loss_dev 0.1607
# Ep. 5/6; It. 12000/13041; Runtime 41.60 s; Remaining runtime 0h19min31s; f1_train 1.0000; f1_dev 0.6050; loss_train 0.0162; loss_dev 0.1984
# Ep. 5/6; It. 12500/13041; Runtime 41.63 s; Remaining runtime 0h18min50s; f1_train 0.9091; f1_dev 0.5490; loss_train 0.0290; loss_dev 0.2076
# Ep. 5/6; It. 13000/13041; Runtime 41.62 s; Remaining runtime 0h18min8s; f1_train 0.9231; f1_dev 0.6129; loss_train 0.0327; loss_dev 0.1480
# Ep. 6/6; It. 0/13041; Runtime 13.09 s; Remaining runtime 0h5min41s; f1_train 0.9091; f1_dev 0.5926; loss_train 0.0475; loss_dev 0.1525
# Ep. 6/6; It. 500/13041; Runtime 41.71 s; Remaining runtime 0h17min26s; f1_train 0.5714; f1_dev 0.5714; loss_train 0.0566; loss_dev 0.2481
# Ep. 6/6; It. 1000/13041; Runtime 41.59 s; Remaining runtime 0h16min41s; f1_train 0.6667; f1_dev 0.5738; loss_train 0.0984; loss_dev 0.1968
# Ep. 6/6; It. 1500/13041; Runtime 41.60 s; Remaining runtime 0h16min0s; f1_train 0.7500; f1_dev 0.5692; loss_train 0.0368; loss_dev 0.3654
# Ep. 6/6; It. 2000/13041; Runtime 41.62 s; Remaining runtime 0h15min18s; f1_train 0.8696; f1_dev 0.5797; loss_train 0.0745; loss_dev 0.2408
# Ep. 6/6; It. 2500/13041; Runtime 41.62 s; Remaining runtime 0h14min37s; f1_train 1.0000; f1_dev 0.5882; loss_train 0.0115; loss_dev 0.2112
# Ep. 6/6; It. 3000/13041; Runtime 41.64 s; Remaining runtime 0h13min56s; f1_train 0.8000; f1_dev 0.5827; loss_train 0.0386; loss_dev 0.1641
# Ep. 6/6; It. 3500/13041; Runtime 41.59 s; Remaining runtime 0h13min13s; f1_train 0.9091; f1_dev 0.5968; loss_train 0.0363; loss_dev 0.1702
# Ep. 6/6; It. 4000/13041; Runtime 41.62 s; Remaining runtime 0h12min32s; f1_train 0.7778; f1_dev 0.6000; loss_train 0.0715; loss_dev 0.2047
# Ep. 6/6; It. 4500/13041; Runtime 41.58 s; Remaining runtime 0h11min50s; f1_train 1.0000; f1_dev 0.4396; loss_train 0.0551; loss_dev 0.3403
# Ep. 6/6; It. 5000/13041; Runtime 41.62 s; Remaining runtime 0h11min9s; f1_train 0.9412; f1_dev 0.5667; loss_train 0.0398; loss_dev 0.2047
# Ep. 6/6; It. 5500/13041; Runtime 41.60 s; Remaining runtime 0h10min27s; f1_train 0.9474; f1_dev 0.5854; loss_train 0.0347; loss_dev 0.1745
# Ep. 6/6; It. 6000/13041; Runtime 41.61 s; Remaining runtime 0h9min45s; f1_train 0.8571; f1_dev 0.5714; loss_train 0.0517; loss_dev 0.2341
# Ep. 6/6; It. 6500/13041; Runtime 41.61 s; Remaining runtime 0h9min4s; f1_train 0.9474; f1_dev 0.5738; loss_train 0.0324; loss_dev 0.1735
# Ep. 6/6; It. 7000/13041; Runtime 41.62 s; Remaining runtime 0h8min22s; f1_train 0.5000; f1_dev 0.6080; loss_train 0.0651; loss_dev 0.1949
# Ep. 6/6; It. 7500/13041; Runtime 41.60 s; Remaining runtime 0h7min40s; f1_train 1.0000; f1_dev 0.5564; loss_train 0.0163; loss_dev 0.1834
# Ep. 6/6; It. 8000/13041; Runtime 41.68 s; Remaining runtime 0h7min0s; f1_train 1.0000; f1_dev 0.5692; loss_train 0.0227; loss_dev 0.1750
# Ep. 6/6; It. 8500/13041; Runtime 41.66 s; Remaining runtime 0h6min18s; f1_train 1.0000; f1_dev 0.5734; loss_train 0.0229; loss_dev 0.1622
# Ep. 6/6; It. 9000/13041; Runtime 41.61 s; Remaining runtime 0h5min36s; f1_train 0.8333; f1_dev 0.5714; loss_train 0.0383; loss_dev 0.1838
# Ep. 6/6; It. 9500/13041; Runtime 41.60 s; Remaining runtime 0h4min54s; f1_train 0.8000; f1_dev 0.5185; loss_train 0.0290; loss_dev 0.1924
# Ep. 6/6; It. 10000/13041; Runtime 47.71 s; Remaining runtime 0h4min50s; f1_train 0.8750; f1_dev 0.5271; loss_train 0.0423; loss_dev 0.1701
# Ep. 6/6; It. 10500/13041; Runtime 41.78 s; Remaining runtime 0h3min32s; f1_train 0.7778; f1_dev 0.5693; loss_train 0.0733; loss_dev 0.1620
# Ep. 6/6; It. 11000/13041; Runtime 41.61 s; Remaining runtime 0h2min49s; f1_train 0.8000; f1_dev 0.5778; loss_train 0.0291; loss_dev 0.1869
# Ep. 6/6; It. 11500/13041; Runtime 41.60 s; Remaining runtime 0h2min8s; f1_train 0.9231; f1_dev 0.6107; loss_train 0.0217; loss_dev 0.1712
# Ep. 6/6; It. 12000/13041; Runtime 41.59 s; Remaining runtime 0h1min26s; f1_train 1.0000; f1_dev 0.5694; loss_train 0.0174; loss_dev 0.1937
# Ep. 6/6; It. 12500/13041; Runtime 41.62 s; Remaining runtime 0h0min45s; f1_train 0.8333; f1_dev 0.6078; loss_train 0.0468; loss_dev 0.1679
# Ep. 6/6; It. 13000/13041; Runtime 41.67 s; Remaining runtime 0h0min3s; f1_train 0.9231; f1_dev 0.5984; loss_train 0.0319; loss_dev 0.1807
# Total actual runtime: 1 hours 50 min 32 sec

# %%
plt.figure(figsize = (20, 8))
plt.subplot(121) 
plt.plot(step_stack, loss_stack)
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
#plt.xlim([0.001,0.008])
plt.ylim([0,0.3])
plt.subplot(122)
plt.plot(step_stack, f1_stack)
#plt.xlim([0.001,0.008])
plt.ylim([0,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1")

plt.show()

# %%
MODELS_FILE = "models/model4.1/QIQC_model4.1.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model4.1/QIQC_model4.1.ckpt
# cross val f1 63.57%, dev f1 61.29%
