# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

def numpy_ewma_vectorized(data, alpha):
    alpha_ = 1-alpha
    D = pd.DataFrame(data)
    M = D.ewm(alpha=alpha_).mean()
    out = M.values
    return out

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

out_channels = 100
window_width = [3, 4, 5]
embedding_dimensions = 300
n_steps = 250
n_fc1 = 300
n_fc2 = 100
n_output = 1

activation_fn = tf.nn.relu
init_W_CL_3 = np.random.randn(window_width[0],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_3 = np.random.randn(1,1,1,out_channels).astype(np.float32)
init_W_CL_4 = np.random.randn(window_width[1],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_4 = np.random.randn(1,1,1,out_channels).astype(np.float32)
init_W_CL_5 = np.random.randn(window_width[2],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_5 = np.random.randn(1,1,1,out_channels).astype(np.float32)

learning_rate = tf.placeholder(tf.float32)

X = tf.placeholder(tf.int32, [None, n_steps], name="X") #m * n_steps
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)# n_words * embedding_dimensions
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X) # m * n_steps * embedding_dimensions

with tf.name_scope("CNN_3"):
    W_CL_3 = tf.Variable(initial_value=init_W_CL_3)
    b_CL_3 = tf.Variable(initial_value=init_b_CL_3)
    CL_3 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_3, strides=[1,1,1,1], padding="VALID")# m * n_steps - 3 + 1 *1 * out_channels 
    activated_CL_3 = activation_fn(tf.add(CL_3,b_CL_3)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_3 = tf.reshape(tf.math.reduce_max(activated_CL_3,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_4"):
    W_CL_4 = tf.Variable(initial_value=init_W_CL_4)
    b_CL_4 = tf.Variable(initial_value=init_b_CL_4)
    CL_4 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_4, strides=[1,1,1,1], padding="VALID")# m * n_steps - 4 + 1 *1 * out_channels 
    activated_CL_4 = activation_fn(tf.add(CL_4,b_CL_4)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_4 = tf.reshape(tf.math.reduce_max(activated_CL_4,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_5"):
    W_CL_5 = tf.Variable(initial_value=init_W_CL_5)
    b_CL_5 = tf.Variable(initial_value=init_b_CL_5)
    CL_5 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_5, strides=[1,1,1,1], padding="VALID")# m * n_steps - 5 + 1 *1 * out_channels 
    activated_CL_5 = activation_fn(tf.add(CL_5,b_CL_5)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_5 = tf.reshape(tf.math.reduce_max(activated_CL_5,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels

with tf.name_scope("Max_pool"):
    MAXPOOL = tf.concat([MAXPOOL_3,MAXPOOL_4,MAXPOOL_5], axis=1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(MAXPOOL, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc1, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 8

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model4/QIQC_model4.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

t_init = time.time()
lr_stack = []
loss_stack = []
step_stack = []
f1_stack = []
loss_train_stack = []
f1_train_stack = []
lr = 0.004

with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):    
            if epoch % 2 == 0 and epoch != 0 :
              lr = lr/2
              
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, learning_rate: lr})
            step = epoch * QIQC.nr_batches + iteration
            
            if step % 20 ==0:
              f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
              f1_train, loss_train = sess.run([f1, loss], feed_dict = {X : X_batch, y : y_batch})
              step_stack.append(step)
              loss_stack.append(loss_dev)
              f1_stack.append(f1_dev)
              loss_train_stack.append(loss_train)
              f1_train_stack.append(f1_train)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                t_1 = time.time()
                t_delta = t_1 - t_0
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/8; It. 0/2608; Runtime 5.02 s; Remaining runtime 0h17min28s; f1_train nan; f1_dev nan; loss_train 11.3990; loss_dev 10.3892
# Ep. 1/8; It. 100/2608; Runtime 26.27 s; Remaining runtime 1h30min54s; f1_train 0.2439; f1_dev 0.4040; loss_train 0.1405; loss_dev 0.1910
# Ep. 1/8; It. 200/2608; Runtime 26.30 s; Remaining runtime 1h30min34s; f1_train 0.4615; f1_dev 0.2632; loss_train 0.1429; loss_dev 0.1743
# Ep. 1/8; It. 300/2608; Runtime 26.28 s; Remaining runtime 1h30min4s; f1_train 0.3529; f1_dev 0.3810; loss_train 0.1266; loss_dev 0.1511
# Ep. 1/8; It. 400/2608; Runtime 26.27 s; Remaining runtime 1h29min36s; f1_train 0.5333; f1_dev 0.4536; loss_train 0.1532; loss_dev 0.1401
# Ep. 1/8; It. 500/2608; Runtime 26.25 s; Remaining runtime 1h29min5s; f1_train 0.5098; f1_dev 0.5000; loss_train 0.1395; loss_dev 0.1434
# Ep. 1/8; It. 600/2608; Runtime 26.23 s; Remaining runtime 1h28min34s; f1_train 0.5070; f1_dev 0.4318; loss_train 0.1760; loss_dev 0.1325
# Ep. 1/8; It. 700/2608; Runtime 26.19 s; Remaining runtime 1h28min0s; f1_train 0.5000; f1_dev 0.5102; loss_train 0.1470; loss_dev 0.1242
# Ep. 1/8; It. 800/2608; Runtime 26.23 s; Remaining runtime 1h27min42s; f1_train 0.6154; f1_dev 0.5620; loss_train 0.1161; loss_dev 0.1315
# Ep. 1/8; It. 900/2608; Runtime 26.26 s; Remaining runtime 1h27min23s; f1_train 0.6667; f1_dev 0.5200; loss_train 0.1081; loss_dev 0.1211
# Ep. 1/8; It. 1000/2608; Runtime 30.16 s; Remaining runtime 1h39min51s; f1_train 0.4186; f1_dev 0.3636; loss_train 0.1305; loss_dev 0.1269
# Ep. 1/8; It. 1100/2608; Runtime 26.27 s; Remaining runtime 1h26min32s; f1_train 0.4000; f1_dev 0.3636; loss_train 0.1153; loss_dev 0.1284
# Ep. 1/8; It. 1200/2608; Runtime 26.22 s; Remaining runtime 1h25min54s; f1_train 0.4737; f1_dev 0.4719; loss_train 0.1042; loss_dev 0.1185
# Ep. 1/8; It. 1300/2608; Runtime 26.23 s; Remaining runtime 1h25min32s; f1_train 0.6667; f1_dev 0.5766; loss_train 0.1124; loss_dev 0.1149
# Ep. 1/8; It. 1400/2608; Runtime 26.24 s; Remaining runtime 1h25min8s; f1_train 0.5500; f1_dev 0.4000; loss_train 0.0977; loss_dev 0.1219
# Ep. 1/8; It. 1500/2608; Runtime 26.23 s; Remaining runtime 1h24min40s; f1_train 0.3556; f1_dev 0.4681; loss_train 0.1229; loss_dev 0.1089
# Ep. 1/8; It. 1600/2608; Runtime 26.21 s; Remaining runtime 1h24min8s; f1_train 0.7429; f1_dev 0.5794; loss_train 0.1044; loss_dev 0.1105
# Ep. 1/8; It. 1700/2608; Runtime 26.22 s; Remaining runtime 1h23min45s; f1_train 0.6269; f1_dev 0.5825; loss_train 0.1116; loss_dev 0.1077
# Ep. 1/8; It. 1800/2608; Runtime 26.23 s; Remaining runtime 1h23min20s; f1_train 0.5902; f1_dev 0.4146; loss_train 0.1320; loss_dev 0.1136
# Ep. 1/8; It. 1900/2608; Runtime 26.20 s; Remaining runtime 1h22min48s; f1_train 0.4444; f1_dev 0.4667; loss_train 0.1147; loss_dev 0.1142
# Ep. 1/8; It. 2000/2608; Runtime 29.46 s; Remaining runtime 1h32min37s; f1_train 0.4878; f1_dev 0.4471; loss_train 0.1234; loss_dev 0.1153
# Ep. 1/8; It. 2100/2608; Runtime 26.29 s; Remaining runtime 1h22min13s; f1_train 0.6061; f1_dev 0.5905; loss_train 0.1230; loss_dev 0.1084
# Ep. 1/8; It. 2200/2608; Runtime 26.24 s; Remaining runtime 1h21min36s; f1_train 0.4571; f1_dev 0.5545; loss_train 0.0858; loss_dev 0.1047
# Ep. 1/8; It. 2300/2608; Runtime 26.22 s; Remaining runtime 1h21min7s; f1_train 0.6875; f1_dev 0.6393; loss_train 0.1037; loss_dev 0.1106
# Ep. 1/8; It. 2400/2608; Runtime 26.22 s; Remaining runtime 1h20min41s; f1_train 0.6122; f1_dev 0.5905; loss_train 0.1010; loss_dev 0.1051
# Ep. 1/8; It. 2500/2608; Runtime 26.22 s; Remaining runtime 1h20min15s; f1_train 0.7037; f1_dev 0.6230; loss_train 0.1020; loss_dev 0.1121
# Ep. 1/8; It. 2600/2608; Runtime 26.23 s; Remaining runtime 1h19min51s; f1_train 0.5714; f1_dev 0.5055; loss_train 0.1219; loss_dev 0.1067
# Ep. 2/8; It. 0/2608; Runtime 7.08 s; Remaining runtime 0h21min33s; f1_train 0.5714; f1_dev 0.5055; loss_train 0.1219; loss_dev 0.1067
# Ep. 2/8; It. 100/2608; Runtime 26.31 s; Remaining runtime 1h19min36s; f1_train 0.6757; f1_dev 0.6000; loss_train 0.1248; loss_dev 0.1036
# Ep. 2/8; It. 200/2608; Runtime 26.21 s; Remaining runtime 1h18min52s; f1_train 0.6333; f1_dev 0.5743; loss_train 0.1206; loss_dev 0.1051
# Ep. 2/8; It. 300/2608; Runtime 26.23 s; Remaining runtime 1h18min29s; f1_train 0.6087; f1_dev 0.4884; loss_train 0.0978; loss_dev 0.1122
# Ep. 2/8; It. 400/2608; Runtime 26.27 s; Remaining runtime 1h18min10s; f1_train 0.7778; f1_dev 0.6406; loss_train 0.0798; loss_dev 0.1076
# Ep. 2/8; It. 500/2608; Runtime 26.23 s; Remaining runtime 1h17min37s; f1_train 0.5185; f1_dev 0.6000; loss_train 0.1071; loss_dev 0.0996
# Ep. 2/8; It. 600/2608; Runtime 26.22 s; Remaining runtime 1h17min9s; f1_train 0.6557; f1_dev 0.5567; loss_train 0.1116; loss_dev 0.1023
# Ep. 2/8; It. 700/2608; Runtime 26.22 s; Remaining runtime 1h16min42s; f1_train 0.6207; f1_dev 0.5600; loss_train 0.0983; loss_dev 0.1034
# Ep. 2/8; It. 800/2608; Runtime 26.24 s; Remaining runtime 1h16min20s; f1_train 0.6182; f1_dev 0.6667; loss_train 0.1149; loss_dev 0.1020
# Ep. 2/8; It. 900/2608; Runtime 26.24 s; Remaining runtime 1h15min54s; f1_train 0.5405; f1_dev 0.5055; loss_train 0.0905; loss_dev 0.1111
# Ep. 2/8; It. 1000/2608; Runtime 28.73 s; Remaining runtime 1h22min37s; f1_train 0.7353; f1_dev 0.6552; loss_train 0.1053; loss_dev 0.1004
# Ep. 2/8; It. 1100/2608; Runtime 26.19 s; Remaining runtime 1h14min53s; f1_train 0.6000; f1_dev 0.5591; loss_train 0.1058; loss_dev 0.1002
# Ep. 2/8; It. 1200/2608; Runtime 26.22 s; Remaining runtime 1h14min32s; f1_train 0.5882; f1_dev 0.5053; loss_train 0.0852; loss_dev 0.1030
# Ep. 2/8; It. 1300/2608; Runtime 26.26 s; Remaining runtime 1h14min12s; f1_train 0.5000; f1_dev 0.5743; loss_train 0.1077; loss_dev 0.0994
# Ep. 2/8; It. 1400/2608; Runtime 26.24 s; Remaining runtime 1h13min42s; f1_train 0.6909; f1_dev 0.6379; loss_train 0.1137; loss_dev 0.1005
# Ep. 2/8; It. 1500/2608; Runtime 26.19 s; Remaining runtime 1h13min7s; f1_train 0.6000; f1_dev 0.5849; loss_train 0.1095; loss_dev 0.0982
# Ep. 2/8; It. 1600/2608; Runtime 26.23 s; Remaining runtime 1h12min48s; f1_train 0.6786; f1_dev 0.6095; loss_train 0.0917; loss_dev 0.0980
# Ep. 2/8; It. 1700/2608; Runtime 26.22 s; Remaining runtime 1h12min20s; f1_train 0.7761; f1_dev 0.6372; loss_train 0.0899; loss_dev 0.1034
# Ep. 2/8; It. 1800/2608; Runtime 26.21 s; Remaining runtime 1h11min53s; f1_train 0.6769; f1_dev 0.6772; loss_train 0.0858; loss_dev 0.1072
# Ep. 2/8; It. 1900/2608; Runtime 26.23 s; Remaining runtime 1h11min30s; f1_train 0.7059; f1_dev 0.6095; loss_train 0.0812; loss_dev 0.0984
# Ep. 2/8; It. 2000/2608; Runtime 29.26 s; Remaining runtime 1h19min15s; f1_train 0.5500; f1_dev 0.5376; loss_train 0.0967; loss_dev 0.1047
# Ep. 2/8; It. 2100/2608; Runtime 26.30 s; Remaining runtime 1h10min49s; f1_train 0.6667; f1_dev 0.5474; loss_train 0.1044; loss_dev 0.1033
# Ep. 2/8; It. 2200/2608; Runtime 26.24 s; Remaining runtime 1h10min12s; f1_train 0.5283; f1_dev 0.6111; loss_train 0.1233; loss_dev 0.0988
# Ep. 2/8; It. 2300/2608; Runtime 26.24 s; Remaining runtime 1h9min46s; f1_train 0.7037; f1_dev 0.5981; loss_train 0.0966; loss_dev 0.0986
# Ep. 2/8; It. 2400/2608; Runtime 26.24 s; Remaining runtime 1h9min20s; f1_train 0.7077; f1_dev 0.6441; loss_train 0.1041; loss_dev 0.1023
# Ep. 2/8; It. 2500/2608; Runtime 26.23 s; Remaining runtime 1h8min53s; f1_train 0.6923; f1_dev 0.6610; loss_train 0.0812; loss_dev 0.0991
# Ep. 2/8; It. 2600/2608; Runtime 26.23 s; Remaining runtime 1h8min26s; f1_train 0.6415; f1_dev 0.6545; loss_train 0.1006; loss_dev 0.0981
# Ep. 3/8; It. 0/2608; Runtime 6.11 s; Remaining runtime 0h15min55s; f1_train 0.6415; f1_dev 0.6545; loss_train 0.1006; loss_dev 0.0981
# Ep. 3/8; It. 100/2608; Runtime 26.21 s; Remaining runtime 1h7min54s; f1_train 0.7458; f1_dev 0.6226; loss_train 0.0844; loss_dev 0.0975
# Ep. 3/8; It. 200/2608; Runtime 26.22 s; Remaining runtime 1h7min30s; f1_train 0.6885; f1_dev 0.6226; loss_train 0.0821; loss_dev 0.0975
# Ep. 3/8; It. 300/2608; Runtime 26.22 s; Remaining runtime 1h7min3s; f1_train 0.7037; f1_dev 0.6226; loss_train 0.0782; loss_dev 0.0975
# Ep. 3/8; It. 400/2608; Runtime 26.26 s; Remaining runtime 1h6min44s; f1_train 0.6087; f1_dev 0.6226; loss_train 0.0895; loss_dev 0.0975
# Ep. 3/8; It. 500/2608; Runtime 26.26 s; Remaining runtime 1h6min17s; f1_train 0.5818; f1_dev 0.6226; loss_train 0.1005; loss_dev 0.0975
# Ep. 3/8; It. 600/2608; Runtime 26.21 s; Remaining runtime 1h5min43s; f1_train 0.6230; f1_dev 0.6226; loss_train 0.1318; loss_dev 0.0975
# Ep. 3/8; It. 700/2608; Runtime 26.21 s; Remaining runtime 1h5min17s; f1_train 0.7234; f1_dev 0.6226; loss_train 0.0905; loss_dev 0.0975
# Ep. 3/8; It. 800/2608; Runtime 26.23 s; Remaining runtime 1h4min54s; f1_train 0.6400; f1_dev 0.6226; loss_train 0.0857; loss_dev 0.0975
# Ep. 3/8; It. 900/2608; Runtime 26.26 s; Remaining runtime 1h4min33s; f1_train 0.4800; f1_dev 0.6226; loss_train 0.1064; loss_dev 0.0975
# Ep. 3/8; It. 1000/2608; Runtime 28.63 s; Remaining runtime 1h9min53s; f1_train 0.5185; f1_dev 0.6226; loss_train 0.0996; loss_dev 0.0975
# Ep. 3/8; It. 1100/2608; Runtime 26.21 s; Remaining runtime 1h3min32s; f1_train 0.7532; f1_dev 0.6226; loss_train 0.1150; loss_dev 0.0975
# Ep. 3/8; It. 1200/2608; Runtime 26.23 s; Remaining runtime 1h3min9s; f1_train 0.5909; f1_dev 0.6226; loss_train 0.0679; loss_dev 0.0975
# Ep. 3/8; It. 1300/2608; Runtime 26.23 s; Remaining runtime 1h2min43s; f1_train 0.5909; f1_dev 0.6226; loss_train 0.0812; loss_dev 0.0975
# Ep. 3/8; It. 1400/2608; Runtime 26.20 s; Remaining runtime 1h2min13s; f1_train 0.6129; f1_dev 0.6226; loss_train 0.1516; loss_dev 0.0975
# Ep. 3/8; It. 1500/2608; Runtime 26.22 s; Remaining runtime 1h1min49s; f1_train 0.6296; f1_dev 0.6226; loss_train 0.1112; loss_dev 0.0975
# Ep. 3/8; It. 1600/2608; Runtime 26.20 s; Remaining runtime 1h1min21s; f1_train 0.5455; f1_dev 0.6226; loss_train 0.1018; loss_dev 0.0975
# Ep. 3/8; It. 1700/2608; Runtime 26.19 s; Remaining runtime 1h0min52s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.0927; loss_dev 0.0975
# Ep. 3/8; It. 1800/2608; Runtime 26.22 s; Remaining runtime 1h0min30s; f1_train 0.6957; f1_dev 0.6226; loss_train 0.0804; loss_dev 0.0975
# Ep. 3/8; It. 1900/2608; Runtime 26.25 s; Remaining runtime 1h0min8s; f1_train 0.6038; f1_dev 0.6226; loss_train 0.0996; loss_dev 0.0975
# Ep. 3/8; It. 2000/2608; Runtime 28.63 s; Remaining runtime 1h5min7s; f1_train 0.6552; f1_dev 0.6226; loss_train 0.0920; loss_dev 0.0975
# Ep. 3/8; It. 2100/2608; Runtime 26.23 s; Remaining runtime 0h59min13s; f1_train 0.7234; f1_dev 0.6226; loss_train 0.1101; loss_dev 0.0975
# Ep. 3/8; It. 2200/2608; Runtime 26.20 s; Remaining runtime 0h58min43s; f1_train 0.5714; f1_dev 0.6226; loss_train 0.1517; loss_dev 0.0975
# Ep. 3/8; It. 2300/2608; Runtime 26.21 s; Remaining runtime 0h58min18s; f1_train 0.6410; f1_dev 0.6226; loss_train 0.1446; loss_dev 0.0975
# Ep. 3/8; It. 2400/2608; Runtime 26.21 s; Remaining runtime 0h57min51s; f1_train 0.5000; f1_dev 0.6226; loss_train 0.0950; loss_dev 0.0975
# Ep. 3/8; It. 2500/2608; Runtime 26.23 s; Remaining runtime 0h57min29s; f1_train 0.6885; f1_dev 0.6226; loss_train 0.0979; loss_dev 0.0975
# Ep. 3/8; It. 2600/2608; Runtime 26.24 s; Remaining runtime 0h57min4s; f1_train 0.6111; f1_dev 0.6226; loss_train 0.0811; loss_dev 0.0975
# Ep. 4/8; It. 0/2608; Runtime 6.33 s; Remaining runtime 0h13min45s; f1_train 0.7143; f1_dev 0.6226; loss_train 0.0976; loss_dev 0.0975
# Ep. 4/8; It. 100/2608; Runtime 26.26 s; Remaining runtime 0h56min37s; f1_train 0.5833; f1_dev 0.6226; loss_train 0.0893; loss_dev 0.0975
# Ep. 4/8; It. 200/2608; Runtime 26.21 s; Remaining runtime 0h56min5s; f1_train 0.6538; f1_dev 0.6226; loss_train 0.0838; loss_dev 0.0975
# Ep. 4/8; It. 300/2608; Runtime 26.21 s; Remaining runtime 0h55min39s; f1_train 0.7037; f1_dev 0.6226; loss_train 0.0935; loss_dev 0.0975
# Ep. 4/8; It. 400/2608; Runtime 26.23 s; Remaining runtime 0h55min14s; f1_train 0.7143; f1_dev 0.6226; loss_train 0.0819; loss_dev 0.0975
# Ep. 4/8; It. 500/2608; Runtime 26.24 s; Remaining runtime 0h54min50s; f1_train 0.6154; f1_dev 0.6226; loss_train 0.1008; loss_dev 0.0975
# Ep. 4/8; It. 600/2608; Runtime 26.20 s; Remaining runtime 0h54min19s; f1_train 0.5957; f1_dev 0.6226; loss_train 0.0971; loss_dev 0.0975
# Ep. 4/8; It. 700/2608; Runtime 26.23 s; Remaining runtime 0h53min56s; f1_train 0.6557; f1_dev 0.6226; loss_train 0.1239; loss_dev 0.0975
# Ep. 4/8; It. 800/2608; Runtime 26.21 s; Remaining runtime 0h53min27s; f1_train 0.5806; f1_dev 0.6226; loss_train 0.1080; loss_dev 0.0975
# Ep. 4/8; It. 900/2608; Runtime 26.24 s; Remaining runtime 0h53min5s; f1_train 0.7692; f1_dev 0.6226; loss_train 0.0678; loss_dev 0.0975
# Ep. 4/8; It. 1000/2608; Runtime 28.83 s; Remaining runtime 0h57min50s; f1_train 0.6087; f1_dev 0.6226; loss_train 0.0929; loss_dev 0.0975
# Ep. 4/8; It. 1100/2608; Runtime 26.23 s; Remaining runtime 0h52min11s; f1_train 0.7451; f1_dev 0.6226; loss_train 0.0691; loss_dev 0.0975
# Ep. 4/8; It. 1200/2608; Runtime 26.21 s; Remaining runtime 0h51min43s; f1_train 0.6875; f1_dev 0.6226; loss_train 0.0869; loss_dev 0.0975
# Ep. 4/8; It. 1300/2608; Runtime 26.22 s; Remaining runtime 0h51min18s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.0842; loss_dev 0.0975
# Ep. 4/8; It. 1400/2608; Runtime 26.25 s; Remaining runtime 0h50min55s; f1_train 0.6129; f1_dev 0.6226; loss_train 0.1183; loss_dev 0.0975
# Ep. 4/8; It. 1500/2608; Runtime 26.22 s; Remaining runtime 0h50min25s; f1_train 0.6800; f1_dev 0.6226; loss_train 0.0970; loss_dev 0.0975
# Ep. 4/8; It. 1600/2608; Runtime 26.20 s; Remaining runtime 0h49min56s; f1_train 0.7188; f1_dev 0.6226; loss_train 0.0897; loss_dev 0.0975
# Ep. 4/8; It. 1700/2608; Runtime 26.20 s; Remaining runtime 0h49min30s; f1_train 0.6154; f1_dev 0.6226; loss_train 0.0881; loss_dev 0.0975
# Ep. 4/8; It. 1800/2608; Runtime 26.24 s; Remaining runtime 0h49min8s; f1_train 0.7619; f1_dev 0.6226; loss_train 0.0836; loss_dev 0.0975
# Ep. 4/8; It. 1900/2608; Runtime 26.22 s; Remaining runtime 0h48min40s; f1_train 0.5818; f1_dev 0.6226; loss_train 0.1066; loss_dev 0.0975
# Ep. 4/8; It. 2000/2608; Runtime 28.44 s; Remaining runtime 0h52min20s; f1_train 0.5789; f1_dev 0.6226; loss_train 0.0572; loss_dev 0.0975
# Ep. 4/8; It. 2100/2608; Runtime 26.24 s; Remaining runtime 0h47min51s; f1_train 0.5085; f1_dev 0.6226; loss_train 0.1130; loss_dev 0.0975
# Ep. 4/8; It. 2200/2608; Runtime 26.24 s; Remaining runtime 0h47min24s; f1_train 0.6032; f1_dev 0.6226; loss_train 0.1183; loss_dev 0.0975
# Ep. 4/8; It. 2300/2608; Runtime 26.21 s; Remaining runtime 0h46min54s; f1_train 0.6182; f1_dev 0.6226; loss_train 0.1078; loss_dev 0.0975
# Ep. 4/8; It. 2400/2608; Runtime 26.21 s; Remaining runtime 0h46min28s; f1_train 0.5862; f1_dev 0.6226; loss_train 0.1267; loss_dev 0.0975
# Ep. 4/8; It. 2500/2608; Runtime 26.23 s; Remaining runtime 0h46min4s; f1_train 0.7164; f1_dev 0.6226; loss_train 0.1061; loss_dev 0.0975
# Ep. 4/8; It. 2600/2608; Runtime 26.24 s; Remaining runtime 0h45min39s; f1_train 0.6970; f1_dev 0.6226; loss_train 0.1123; loss_dev 0.0975
# Ep. 5/8; It. 0/2608; Runtime 6.01 s; Remaining runtime 0h10min27s; f1_train 0.6970; f1_dev 0.6226; loss_train 0.1123; loss_dev 0.0975
# Ep. 5/8; It. 100/2608; Runtime 26.24 s; Remaining runtime 0h45min11s; f1_train 0.6250; f1_dev 0.6226; loss_train 0.1013; loss_dev 0.0975
# Ep. 5/8; It. 200/2608; Runtime 26.27 s; Remaining runtime 0h44min47s; f1_train 0.5600; f1_dev 0.6226; loss_train 0.0961; loss_dev 0.0975
# Ep. 5/8; It. 300/2608; Runtime 26.21 s; Remaining runtime 0h44min15s; f1_train 0.6316; f1_dev 0.6226; loss_train 0.0873; loss_dev 0.0975
# Ep. 5/8; It. 400/2608; Runtime 26.20 s; Remaining runtime 0h43min48s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.0987; loss_dev 0.0975
# Ep. 5/8; It. 500/2608; Runtime 26.21 s; Remaining runtime 0h43min23s; f1_train 0.7333; f1_dev 0.6226; loss_train 0.0975; loss_dev 0.0975
# Ep. 5/8; It. 600/2608; Runtime 26.23 s; Remaining runtime 0h42min59s; f1_train 0.6780; f1_dev 0.6226; loss_train 0.0972; loss_dev 0.0975
# Ep. 5/8; It. 700/2608; Runtime 26.20 s; Remaining runtime 0h42min29s; f1_train 0.6154; f1_dev 0.6226; loss_train 0.0863; loss_dev 0.0975
# Ep. 5/8; It. 800/2608; Runtime 26.21 s; Remaining runtime 0h42min4s; f1_train 0.6545; f1_dev 0.6226; loss_train 0.0866; loss_dev 0.0975
# Ep. 5/8; It. 900/2608; Runtime 26.22 s; Remaining runtime 0h41min39s; f1_train 0.6071; f1_dev 0.6226; loss_train 0.0900; loss_dev 0.0975
# Ep. 5/8; It. 1000/2608; Runtime 28.56 s; Remaining runtime 0h44min53s; f1_train 0.5397; f1_dev 0.6226; loss_train 0.1336; loss_dev 0.0975
# Ep. 5/8; It. 1100/2608; Runtime 26.21 s; Remaining runtime 0h40min45s; f1_train 0.7385; f1_dev 0.6226; loss_train 0.1118; loss_dev 0.0975
# Ep. 5/8; It. 1200/2608; Runtime 26.23 s; Remaining runtime 0h40min21s; f1_train 0.7077; f1_dev 0.6226; loss_train 0.1116; loss_dev 0.0975
# Ep. 5/8; It. 1300/2608; Runtime 26.23 s; Remaining runtime 0h39min55s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.1109; loss_dev 0.0975
# Ep. 5/8; It. 1400/2608; Runtime 26.23 s; Remaining runtime 0h39min29s; f1_train 0.7200; f1_dev 0.6226; loss_train 0.0771; loss_dev 0.0975
# Ep. 5/8; It. 1500/2608; Runtime 26.24 s; Remaining runtime 0h39min3s; f1_train 0.7111; f1_dev 0.6226; loss_train 0.0902; loss_dev 0.0975
# Ep. 5/8; It. 1600/2608; Runtime 26.26 s; Remaining runtime 0h38min39s; f1_train 0.6957; f1_dev 0.6226; loss_train 0.1107; loss_dev 0.0975
# Ep. 5/8; It. 1700/2608; Runtime 26.20 s; Remaining runtime 0h38min7s; f1_train 0.5263; f1_dev 0.6226; loss_train 0.0820; loss_dev 0.0975
# Ep. 5/8; It. 1800/2608; Runtime 26.22 s; Remaining runtime 0h37min42s; f1_train 0.6047; f1_dev 0.6226; loss_train 0.0875; loss_dev 0.0975
# Ep. 5/8; It. 1900/2608; Runtime 26.25 s; Remaining runtime 0h37min19s; f1_train 0.6545; f1_dev 0.6226; loss_train 0.1247; loss_dev 0.0975
# Ep. 5/8; It. 2000/2608; Runtime 28.47 s; Remaining runtime 0h40min0s; f1_train 0.6545; f1_dev 0.6226; loss_train 0.0867; loss_dev 0.0975
# Ep. 5/8; It. 2100/2608; Runtime 26.25 s; Remaining runtime 0h36min27s; f1_train 0.6585; f1_dev 0.6226; loss_train 0.1455; loss_dev 0.0975
# Ep. 5/8; It. 2200/2608; Runtime 26.22 s; Remaining runtime 0h35min58s; f1_train 0.5714; f1_dev 0.6226; loss_train 0.1250; loss_dev 0.0975
# Ep. 5/8; It. 2300/2608; Runtime 26.22 s; Remaining runtime 0h35min32s; f1_train 0.6400; f1_dev 0.6226; loss_train 0.0824; loss_dev 0.0975
# Ep. 5/8; It. 2400/2608; Runtime 26.25 s; Remaining runtime 0h35min8s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.0990; loss_dev 0.0975
# Ep. 5/8; It. 2500/2608; Runtime 26.25 s; Remaining runtime 0h34min42s; f1_train 0.6000; f1_dev 0.6226; loss_train 0.1014; loss_dev 0.0975
# Ep. 5/8; It. 2600/2608; Runtime 26.21 s; Remaining runtime 0h34min12s; f1_train 0.6545; f1_dev 0.6226; loss_train 0.0796; loss_dev 0.0975
# Ep. 6/8; It. 0/2608; Runtime 5.96 s; Remaining runtime 0h7min46s; f1_train 0.5926; f1_dev 0.6226; loss_train 0.1126; loss_dev 0.0975
# Ep. 6/8; It. 100/2608; Runtime 26.24 s; Remaining runtime 0h33min47s; f1_train 0.5116; f1_dev 0.6226; loss_train 0.0830; loss_dev 0.0975
# Ep. 6/8; It. 200/2608; Runtime 26.24 s; Remaining runtime 0h33min20s; f1_train 0.7000; f1_dev 0.6226; loss_train 0.0967; loss_dev 0.0975
# Ep. 6/8; It. 300/2608; Runtime 26.24 s; Remaining runtime 0h32min54s; f1_train 0.6102; f1_dev 0.6226; loss_train 0.1053; loss_dev 0.0975
# Ep. 6/8; It. 400/2608; Runtime 26.23 s; Remaining runtime 0h32min27s; f1_train 0.6471; f1_dev 0.6226; loss_train 0.1069; loss_dev 0.0975
# Ep. 6/8; It. 500/2608; Runtime 26.22 s; Remaining runtime 0h32min0s; f1_train 0.6154; f1_dev 0.6226; loss_train 0.1053; loss_dev 0.0975
# Ep. 6/8; It. 600/2608; Runtime 26.24 s; Remaining runtime 0h31min35s; f1_train 0.4255; f1_dev 0.6226; loss_train 0.1200; loss_dev 0.0975
# Ep. 6/8; It. 700/2608; Runtime 26.25 s; Remaining runtime 0h31min9s; f1_train 0.6792; f1_dev 0.6226; loss_train 0.0994; loss_dev 0.0975
# Ep. 6/8; It. 800/2608; Runtime 26.24 s; Remaining runtime 0h30min43s; f1_train 0.5758; f1_dev 0.6226; loss_train 0.1267; loss_dev 0.0975
# Ep. 6/8; It. 900/2608; Runtime 26.20 s; Remaining runtime 0h30min14s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.0844; loss_dev 0.0975
# Ep. 6/8; It. 1000/2608; Runtime 28.46 s; Remaining runtime 0h32min21s; f1_train 0.7077; f1_dev 0.6226; loss_train 0.1054; loss_dev 0.0975
# Ep. 6/8; It. 1100/2608; Runtime 26.23 s; Remaining runtime 0h29min24s; f1_train 0.7385; f1_dev 0.6226; loss_train 0.0877; loss_dev 0.0975
# Ep. 6/8; It. 1200/2608; Runtime 26.23 s; Remaining runtime 0h28min57s; f1_train 0.6552; f1_dev 0.6226; loss_train 0.1054; loss_dev 0.0975
# Ep. 6/8; It. 1300/2608; Runtime 26.19 s; Remaining runtime 0h28min28s; f1_train 0.7018; f1_dev 0.6226; loss_train 0.0968; loss_dev 0.0975
# Ep. 6/8; It. 1400/2608; Runtime 26.24 s; Remaining runtime 0h28min5s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.1005; loss_dev 0.0975
# Ep. 6/8; It. 1500/2608; Runtime 26.26 s; Remaining runtime 0h27min40s; f1_train 0.7692; f1_dev 0.6226; loss_train 0.0733; loss_dev 0.0975
# Ep. 6/8; It. 1600/2608; Runtime 26.22 s; Remaining runtime 0h27min11s; f1_train 0.6538; f1_dev 0.6226; loss_train 0.0843; loss_dev 0.0975
# Ep. 6/8; It. 1700/2608; Runtime 26.21 s; Remaining runtime 0h26min44s; f1_train 0.5854; f1_dev 0.6226; loss_train 0.0861; loss_dev 0.0975
# Ep. 6/8; It. 1800/2608; Runtime 26.21 s; Remaining runtime 0h26min18s; f1_train 0.4615; f1_dev 0.6226; loss_train 0.0839; loss_dev 0.0975
# Ep. 6/8; It. 1900/2608; Runtime 26.23 s; Remaining runtime 0h25min53s; f1_train 0.6122; f1_dev 0.6226; loss_train 0.0897; loss_dev 0.0975
# Ep. 6/8; It. 2000/2608; Runtime 28.47 s; Remaining runtime 0h27min38s; f1_train 0.5714; f1_dev 0.6226; loss_train 0.1107; loss_dev 0.0975
# Ep. 6/8; It. 2100/2608; Runtime 26.21 s; Remaining runtime 0h25min0s; f1_train 0.6452; f1_dev 0.6226; loss_train 0.1035; loss_dev 0.0975
# Ep. 6/8; It. 2200/2608; Runtime 26.23 s; Remaining runtime 0h24min34s; f1_train 0.6275; f1_dev 0.6226; loss_train 0.0778; loss_dev 0.0975
# Ep. 6/8; It. 2300/2608; Runtime 26.25 s; Remaining runtime 0h24min10s; f1_train 0.5926; f1_dev 0.6226; loss_train 0.0972; loss_dev 0.0975
# Ep. 6/8; It. 2400/2608; Runtime 26.25 s; Remaining runtime 0h23min43s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.0790; loss_dev 0.0975
# Ep. 6/8; It. 2500/2608; Runtime 26.22 s; Remaining runtime 0h23min15s; f1_train 0.7333; f1_dev 0.6226; loss_train 0.0894; loss_dev 0.0975
# Ep. 6/8; It. 2600/2608; Runtime 26.22 s; Remaining runtime 0h22min49s; f1_train 0.6557; f1_dev 0.6226; loss_train 0.1175; loss_dev 0.0975
# Ep. 7/8; It. 0/2608; Runtime 6.16 s; Remaining runtime 0h5min21s; f1_train 0.6557; f1_dev 0.6226; loss_train 0.1175; loss_dev 0.0975
# Ep. 7/8; It. 100/2608; Runtime 26.24 s; Remaining runtime 0h22min22s; f1_train 0.5000; f1_dev 0.6226; loss_train 0.0884; loss_dev 0.0975
# Ep. 7/8; It. 200/2608; Runtime 26.22 s; Remaining runtime 0h21min54s; f1_train 0.5614; f1_dev 0.6226; loss_train 0.1027; loss_dev 0.0975
# Ep. 7/8; It. 300/2608; Runtime 26.20 s; Remaining runtime 0h21min28s; f1_train 0.7547; f1_dev 0.6226; loss_train 0.0781; loss_dev 0.0975
# Ep. 7/8; It. 400/2608; Runtime 26.21 s; Remaining runtime 0h21min2s; f1_train 0.6250; f1_dev 0.6226; loss_train 0.1285; loss_dev 0.0975
# Ep. 7/8; It. 500/2608; Runtime 26.26 s; Remaining runtime 0h20min38s; f1_train 0.6471; f1_dev 0.6226; loss_train 0.1194; loss_dev 0.0975
# Ep. 7/8; It. 600/2608; Runtime 26.25 s; Remaining runtime 0h20min11s; f1_train 0.6452; f1_dev 0.6226; loss_train 0.1302; loss_dev 0.0975
# Ep. 7/8; It. 700/2608; Runtime 26.20 s; Remaining runtime 0h19min43s; f1_train 0.7143; f1_dev 0.6226; loss_train 0.0987; loss_dev 0.0975
# Ep. 7/8; It. 800/2608; Runtime 26.20 s; Remaining runtime 0h19min17s; f1_train 0.5833; f1_dev 0.6226; loss_train 0.1130; loss_dev 0.0975
# Ep. 7/8; It. 900/2608; Runtime 26.25 s; Remaining runtime 0h18min52s; f1_train 0.7000; f1_dev 0.6226; loss_train 0.1174; loss_dev 0.0975
# Ep. 7/8; It. 1000/2608; Runtime 28.46 s; Remaining runtime 0h19min59s; f1_train 0.6400; f1_dev 0.6226; loss_train 0.0982; loss_dev 0.0975
# Ep. 7/8; It. 1100/2608; Runtime 26.20 s; Remaining runtime 0h17min58s; f1_train 0.6129; f1_dev 0.6226; loss_train 0.1217; loss_dev 0.0975
# Ep. 7/8; It. 1200/2608; Runtime 26.23 s; Remaining runtime 0h17min33s; f1_train 0.6377; f1_dev 0.6226; loss_train 0.1105; loss_dev 0.0975
# Ep. 7/8; It. 1300/2608; Runtime 26.24 s; Remaining runtime 0h17min7s; f1_train 0.6786; f1_dev 0.6226; loss_train 0.0801; loss_dev 0.0975
# Ep. 7/8; It. 1400/2608; Runtime 26.24 s; Remaining runtime 0h16min41s; f1_train 0.6000; f1_dev 0.6226; loss_train 0.0941; loss_dev 0.0975
# Ep. 7/8; It. 1500/2608; Runtime 26.22 s; Remaining runtime 0h16min14s; f1_train 0.7368; f1_dev 0.6226; loss_train 0.0903; loss_dev 0.0975
# Ep. 7/8; It. 1600/2608; Runtime 26.21 s; Remaining runtime 0h15min47s; f1_train 0.5778; f1_dev 0.6226; loss_train 0.0874; loss_dev 0.0975
# Ep. 7/8; It. 1700/2608; Runtime 26.23 s; Remaining runtime 0h15min22s; f1_train 0.6538; f1_dev 0.6226; loss_train 0.0894; loss_dev 0.0975
# Ep. 7/8; It. 1800/2608; Runtime 26.25 s; Remaining runtime 0h14min56s; f1_train 0.6071; f1_dev 0.6226; loss_train 0.1019; loss_dev 0.0975
# Ep. 7/8; It. 1900/2608; Runtime 26.20 s; Remaining runtime 0h14min28s; f1_train 0.6364; f1_dev 0.6226; loss_train 0.0821; loss_dev 0.0975
# Ep. 7/8; It. 2000/2608; Runtime 28.44 s; Remaining runtime 0h15min14s; f1_train 0.5366; f1_dev 0.6226; loss_train 0.0750; loss_dev 0.0975
# Ep. 7/8; It. 2100/2608; Runtime 26.23 s; Remaining runtime 0h13min37s; f1_train 0.7213; f1_dev 0.6226; loss_train 0.0903; loss_dev 0.0975
# Ep. 7/8; It. 2200/2608; Runtime 26.22 s; Remaining runtime 0h13min10s; f1_train 0.6286; f1_dev 0.6226; loss_train 0.1065; loss_dev 0.0975
# Ep. 7/8; It. 2300/2608; Runtime 26.20 s; Remaining runtime 0h12min44s; f1_train 0.5714; f1_dev 0.6226; loss_train 0.1025; loss_dev 0.0975
# Ep. 7/8; It. 2400/2608; Runtime 26.20 s; Remaining runtime 0h12min17s; f1_train 0.7179; f1_dev 0.6226; loss_train 0.0628; loss_dev 0.0975
# Ep. 7/8; It. 2500/2608; Runtime 26.23 s; Remaining runtime 0h11min52s; f1_train 0.7170; f1_dev 0.6226; loss_train 0.0797; loss_dev 0.0975
# Ep. 7/8; It. 2600/2608; Runtime 26.23 s; Remaining runtime 0h11min26s; f1_train 0.7143; f1_dev 0.6226; loss_train 0.0879; loss_dev 0.0975
# Ep. 8/8; It. 0/2608; Runtime 5.67 s; Remaining runtime 0h2min27s; f1_train 0.7143; f1_dev 0.6226; loss_train 0.0879; loss_dev 0.0975
# Ep. 8/8; It. 100/2608; Runtime 26.21 s; Remaining runtime 0h10min57s; f1_train 0.6897; f1_dev 0.6226; loss_train 0.0990; loss_dev 0.0975
# Ep. 8/8; It. 200/2608; Runtime 26.25 s; Remaining runtime 0h10min32s; f1_train 0.7111; f1_dev 0.6226; loss_train 0.0735; loss_dev 0.0975
# Ep. 8/8; It. 300/2608; Runtime 26.25 s; Remaining runtime 0h10min5s; f1_train 0.6792; f1_dev 0.6226; loss_train 0.0800; loss_dev 0.0975
# Ep. 8/8; It. 400/2608; Runtime 26.18 s; Remaining runtime 0h9min38s; f1_train 0.5667; f1_dev 0.6226; loss_train 0.1172; loss_dev 0.0975
# Ep. 8/8; It. 500/2608; Runtime 26.20 s; Remaining runtime 0h9min12s; f1_train 0.6538; f1_dev 0.6226; loss_train 0.1012; loss_dev 0.0975
# Ep. 8/8; It. 600/2608; Runtime 26.24 s; Remaining runtime 0h8min46s; f1_train 0.6182; f1_dev 0.6226; loss_train 0.0977; loss_dev 0.0975
# Ep. 8/8; It. 700/2608; Runtime 26.22 s; Remaining runtime 0h8min20s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.1023; loss_dev 0.0975
# Ep. 8/8; It. 800/2608; Runtime 26.19 s; Remaining runtime 0h7min53s; f1_train 0.6552; f1_dev 0.6226; loss_train 0.1027; loss_dev 0.0975
# Ep. 8/8; It. 900/2608; Runtime 26.21 s; Remaining runtime 0h7min27s; f1_train 0.4912; f1_dev 0.6226; loss_train 0.1107; loss_dev 0.0975
# Ep. 8/8; It. 1000/2608; Runtime 28.44 s; Remaining runtime 0h7min37s; f1_train 0.7797; f1_dev 0.6226; loss_train 0.0879; loss_dev 0.0975
# Ep. 8/8; It. 1100/2608; Runtime 26.19 s; Remaining runtime 0h6min34s; f1_train 0.5818; f1_dev 0.6226; loss_train 0.1030; loss_dev 0.0975
# Ep. 8/8; It. 1200/2608; Runtime 26.22 s; Remaining runtime 0h6min9s; f1_train 0.5357; f1_dev 0.6226; loss_train 0.1148; loss_dev 0.0975
# Ep. 8/8; It. 1300/2608; Runtime 26.24 s; Remaining runtime 0h5min43s; f1_train 0.7541; f1_dev 0.6226; loss_train 0.0755; loss_dev 0.0975
# Ep. 8/8; It. 1400/2608; Runtime 26.21 s; Remaining runtime 0h5min16s; f1_train 0.6154; f1_dev 0.6226; loss_train 0.1121; loss_dev 0.0975
# Ep. 8/8; It. 1500/2608; Runtime 26.20 s; Remaining runtime 0h4min50s; f1_train 0.7742; f1_dev 0.6226; loss_train 0.0754; loss_dev 0.0975
# Ep. 8/8; It. 1600/2608; Runtime 26.23 s; Remaining runtime 0h4min24s; f1_train 0.7333; f1_dev 0.6226; loss_train 0.1062; loss_dev 0.0975
# Ep. 8/8; It. 1700/2608; Runtime 26.21 s; Remaining runtime 0h3min57s; f1_train 0.7636; f1_dev 0.6226; loss_train 0.0665; loss_dev 0.0975
# Ep. 8/8; It. 1800/2608; Runtime 26.20 s; Remaining runtime 0h3min31s; f1_train 0.6296; f1_dev 0.6226; loss_train 0.1020; loss_dev 0.0975
# Ep. 8/8; It. 1900/2608; Runtime 26.22 s; Remaining runtime 0h3min5s; f1_train 0.5937; f1_dev 0.6226; loss_train 0.1294; loss_dev 0.0975
# Ep. 8/8; It. 2000/2608; Runtime 28.78 s; Remaining runtime 0h2min54s; f1_train 0.6769; f1_dev 0.6226; loss_train 0.1175; loss_dev 0.0975
# Ep. 8/8; It. 2100/2608; Runtime 26.21 s; Remaining runtime 0h2min13s; f1_train 0.5385; f1_dev 0.6226; loss_train 0.1104; loss_dev 0.0975
# Ep. 8/8; It. 2200/2608; Runtime 26.22 s; Remaining runtime 0h1min46s; f1_train 0.6667; f1_dev 0.6226; loss_train 0.1317; loss_dev 0.0975
# Ep. 8/8; It. 2300/2608; Runtime 26.20 s; Remaining runtime 0h1min20s; f1_train 0.5909; f1_dev 0.6226; loss_train 0.0892; loss_dev 0.0975
# Ep. 8/8; It. 2400/2608; Runtime 26.24 s; Remaining runtime 0h0min54s; f1_train 0.7308; f1_dev 0.6226; loss_train 0.0891; loss_dev 0.0975
# Ep. 8/8; It. 2500/2608; Runtime 26.24 s; Remaining runtime 0h0min28s; f1_train 0.6341; f1_dev 0.6226; loss_train 0.0882; loss_dev 0.0975
# Ep. 8/8; It. 2600/2608; Runtime 26.20 s; Remaining runtime 0h0min2s; f1_train 0.6275; f1_dev 0.6226; loss_train 0.0955; loss_dev 0.0975
# Total actual runtime: 1 hours 32 min 31 sec

# %%
alpha = 0.1
ewma_loss_dev = numpy_ewma_vectorized(loss_stack, alpha)
ewma_f1_dev = numpy_ewma_vectorized(f1_stack, alpha)
ewma_loss_train = numpy_ewma_vectorized(loss_train_stack, alpha)
ewma_f1_train = numpy_ewma_vectorized(f1_train_stack, alpha)

plt.figure(figsize = (20, 16))
plt.subplot(221) 
plt.plot(step_stack, ewma_loss_dev)
plt.xlabel("Learning Rate")
plt.ylabel("Loss dev")
#plt.xlim([0.001,0.008])
plt.ylim([0,.3])
plt.subplot(222)
plt.plot(step_stack, ewma_f1_dev)
#plt.xlim([0.001,0.008])
#plt.ylim([0.55,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1 dev")

plt.subplot(223) 
plt.plot(step_stack, ewma_loss_train)
plt.xlabel("Learning Rate")
plt.ylabel("Loss Train")
#plt.xlim([0.001,0.008])
plt.ylim([0,0.3])
plt.subplot(224)
plt.plot(step_stack, ewma_f1_train)
#plt.xlim([0.001,0.008])
#plt.ylim([0.55,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1 Train")

plt.show()

# %%
MODELS_FILE = "models/model4/QIQC_model4.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model4/QIQC_model4.ckpt
# cross val f1 62.50%, dev f1 62.26%
