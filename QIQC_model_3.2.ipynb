# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_neurons = [500, 500, 500, 500]
n_fc1 = 1500
n_fc2 = 600
n_fc3 = 200
n_output = 1
learning_rate = tf.placeholder(tf.float32)
activation_fn = tf.nn.elu

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = [tf.contrib.rnn.LSTMCell(num_units=n, name="LSTM") for n in n_neurons]
    multi_lstm_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    h_states, out_states = tf.nn.dynamic_rnn(multi_lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len) #state = 3 * 2 * m * 500
    states = tf.concat([out_states[0][0],out_states[1][0],out_states[2][0], out_states[3][0]], axis = 1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2, n_fc3, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc3, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
"""
QIQC.reset()
with tf.Session() as sess:
    init.run()
    loss_hist = []
    lr_hist = []
    iter_hist = []
    lr = 0
    t_0 = time.time()
    for iteration in range(QIQC.nr_batches):  
        lr = (iteration + 1)/QIQC.nr_batches * 10 # 1.008188^85 = 2
        X_lengths, X_batch, y_batch = QIQC.next_batch()
        _, run_loss = sess.run([training_op, loss], feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate:lr})

        loss_hist.append(run_loss)
        iter_hist.append(iteration)
        lr_hist.append(lr)
        if iteration % 100 == 0:
            t_1 = time.time()
            t_delta = t_1 - t_0
            expected_runtime = t_delta * (QIQC.nr_batches - iteration)/100
            expected_runtime_h = int(expected_runtime//3600)
            expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
            expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
            t_0 = t_1
            print("It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s".format(iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec))
    
"""
# Out:
# '\nQIQC.reset()\nwith tf.Session() as sess:\n    init.run()\n    loss_hist = []\n    lr_hist = []\n    iter_hist = []\n    lr = 0\n    t_0 = time.time()\n    for iteration in range(QIQC.nr_batches):  \n        lr = (iteration + 1)/QIQC.nr_batches * 10 # 1.008188^85 = 2\n        X_lengths, X_batch, y_batch = QIQC.next_batch()\n        _, run_loss = sess.run([training_op, loss], feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate:lr})\n\n        loss_hist.append(run_loss)\n        iter_hist.append(iteration)\n        lr_hist.append(lr)\n        if iteration % 100 == 0:\n            t_1 = time.time()\n            t_delta = t_1 - t_0\n            expected_runtime = t_delta * (QIQC.nr_batches - iteration)/100\n            expected_runtime_h = int(expected_runtime//3600)\n            expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)\n            expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))\n            t_0 = t_1\n            print("It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s".format(iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec))\n    \n'

# %%
#plt.plot(np.log(lr_hist), loss_hist)
#plt.ylim((0,30))

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model3.2/QIQC_model3.2.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
total_deltas = 0
t_init = time.time()
min_lr = 0.0005
max_lr = 0.0015
with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    stepsize = QIQC.nr_batches
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            step = epoch * QIQC.nr_batches + iteration
            cycle = np.floor(1 + step/(2 * stepsize))
            pattern = np.absolute(step/stepsize - 2*cycle + 1)
            cycle_lr = min_lr + (max_lr - min_lr) * pattern
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate: cycle_lr})
            """
            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)
            """
            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                t_1 = time.time()
                t_delta = t_1 - t_0
                total_deltas += t_delta
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/5; It. 0/2608; Runtime 7.30 s; Remaining runtime 0h15min52s; f1_train nan; f1_dev nan; loss_train 1.2466; loss_dev 1.0744
# Ep. 1/5; It. 100/2608; Runtime 105.53 s; Remaining runtime 3h47min35s; f1_train 0.1333; f1_dev 0.2250; loss_train 0.1107; loss_dev 0.1390
# Ep. 1/5; It. 200/2608; Runtime 103.52 s; Remaining runtime 3h41min32s; f1_train 0.5238; f1_dev 0.3908; loss_train 0.1275; loss_dev 0.1242
# Ep. 1/5; It. 300/2608; Runtime 103.23 s; Remaining runtime 3h39min11s; f1_train 0.3529; f1_dev 0.2535; loss_train 0.1026; loss_dev 0.1287
# Ep. 1/5; It. 400/2608; Runtime 104.33 s; Remaining runtime 3h39min47s; f1_train 0.5797; f1_dev 0.6126; loss_train 0.1503; loss_dev 0.1138
# Ep. 1/5; It. 500/2608; Runtime 103.55 s; Remaining runtime 3h36min24s; f1_train 0.3750; f1_dev 0.3902; loss_train 0.1084; loss_dev 0.1183
# Ep. 1/5; It. 600/2608; Runtime 101.89 s; Remaining runtime 3h31min15s; f1_train 0.5897; f1_dev 0.5859; loss_train 0.1673; loss_dev 0.1085
# Ep. 1/5; It. 700/2608; Runtime 107.82 s; Remaining runtime 3h41min45s; f1_train 0.5507; f1_dev 0.6195; loss_train 0.1371; loss_dev 0.1146
# Ep. 1/5; It. 800/2608; Runtime 104.11 s; Remaining runtime 3h32min23s; f1_train 0.7826; f1_dev 0.5882; loss_train 0.0784; loss_dev 0.1072
# Ep. 1/5; It. 900/2608; Runtime 105.02 s; Remaining runtime 3h32min29s; f1_train 0.5357; f1_dev 0.6261; loss_train 0.1106; loss_dev 0.1089
# Ep. 1/5; It. 1000/2608; Runtime 108.06 s; Remaining runtime 3h36min50s; f1_train 0.6038; f1_dev 0.6095; loss_train 0.1029; loss_dev 0.1027
# Ep. 1/5; It. 1100/2608; Runtime 104.54 s; Remaining runtime 3h28min2s; f1_train 0.6222; f1_dev 0.6095; loss_train 0.0892; loss_dev 0.1025
# Ep. 1/5; It. 1200/2608; Runtime 104.77 s; Remaining runtime 3h26min45s; f1_train 0.5957; f1_dev 0.6000; loss_train 0.0968; loss_dev 0.0994
# Ep. 1/5; It. 1300/2608; Runtime 104.38 s; Remaining runtime 3h24min14s; f1_train 0.6122; f1_dev 0.5714; loss_train 0.1109; loss_dev 0.1051
# Ep. 1/5; It. 1400/2608; Runtime 103.30 s; Remaining runtime 3h20min24s; f1_train 0.6667; f1_dev 0.6154; loss_train 0.0872; loss_dev 0.0981
# Ep. 1/5; It. 1500/2608; Runtime 104.22 s; Remaining runtime 3h20min27s; f1_train 0.5200; f1_dev 0.6481; loss_train 0.1010; loss_dev 0.1002
# Ep. 1/5; It. 1600/2608; Runtime 104.77 s; Remaining runtime 3h19min45s; f1_train 0.8533; f1_dev 0.6667; loss_train 0.0807; loss_dev 0.0998
# Ep. 1/5; It. 1700/2608; Runtime 103.67 s; Remaining runtime 3h15min56s; f1_train 0.6667; f1_dev 0.5773; loss_train 0.0982; loss_dev 0.1008
# Ep. 1/5; It. 1800/2608; Runtime 103.71 s; Remaining runtime 3h14min17s; f1_train 0.7042; f1_dev 0.6200; loss_train 0.1108; loss_dev 0.1006
# Ep. 1/5; It. 1900/2608; Runtime 103.60 s; Remaining runtime 3h12min20s; f1_train 0.6571; f1_dev 0.6610; loss_train 0.1220; loss_dev 0.1051
# Ep. 1/5; It. 2000/2608; Runtime 105.51 s; Remaining runtime 3h14min8s; f1_train 0.6296; f1_dev 0.6964; loss_train 0.0987; loss_dev 0.0978
# Ep. 1/5; It. 2100/2608; Runtime 104.86 s; Remaining runtime 3h11min11s; f1_train 0.4528; f1_dev 0.5652; loss_train 0.1187; loss_dev 0.1045
# Ep. 1/5; It. 2200/2608; Runtime 107.60 s; Remaining runtime 3h14min23s; f1_train 0.4762; f1_dev 0.6154; loss_train 0.0895; loss_dev 0.0947
# Ep. 1/5; It. 2300/2608; Runtime 103.48 s; Remaining runtime 3h5min13s; f1_train 0.7463; f1_dev 0.6508; loss_train 0.0965; loss_dev 0.1029
# Ep. 1/5; It. 2400/2608; Runtime 103.96 s; Remaining runtime 3h4min21s; f1_train 0.6316; f1_dev 0.6168; loss_train 0.0961; loss_dev 0.0994
# Ep. 1/5; It. 2500/2608; Runtime 104.06 s; Remaining runtime 3h2min47s; f1_train 0.6250; f1_dev 0.6055; loss_train 0.1017; loss_dev 0.0983
# Ep. 1/5; It. 2600/2608; Runtime 103.78 s; Remaining runtime 3h0min34s; f1_train 0.6667; f1_dev 0.5833; loss_train 0.1017; loss_dev 0.1018
# Ep. 2/5; It. 0/2608; Runtime 16.96 s; Remaining runtime 0h29min29s; f1_train 0.7500; f1_dev 0.6095; loss_train 0.0813; loss_dev 0.0993
# Ep. 2/5; It. 100/2608; Runtime 104.37 s; Remaining runtime 2h59min43s; f1_train 0.5778; f1_dev 0.6154; loss_train 0.0844; loss_dev 0.0983
# Ep. 2/5; It. 200/2608; Runtime 104.54 s; Remaining runtime 2h58min16s; f1_train 0.7059; f1_dev 0.5825; loss_train 0.0965; loss_dev 0.0993
# Ep. 2/5; It. 300/2608; Runtime 104.47 s; Remaining runtime 2h56min24s; f1_train 0.5000; f1_dev 0.5773; loss_train 0.0843; loss_dev 0.0988
# Ep. 2/5; It. 400/2608; Runtime 104.64 s; Remaining runtime 2h54min57s; f1_train 0.6897; f1_dev 0.6038; loss_train 0.0990; loss_dev 0.0997
# Ep. 2/5; It. 500/2608; Runtime 103.87 s; Remaining runtime 2h51min56s; f1_train 0.6984; f1_dev 0.6422; loss_train 0.1116; loss_dev 0.0964
# Ep. 2/5; It. 600/2608; Runtime 103.92 s; Remaining runtime 2h50min17s; f1_train 0.6792; f1_dev 0.5800; loss_train 0.0910; loss_dev 0.1017
# Ep. 2/5; It. 700/2608; Runtime 103.62 s; Remaining runtime 2h48min4s; f1_train 0.6275; f1_dev 0.6182; loss_train 0.0815; loss_dev 0.0989
# Ep. 2/5; It. 800/2608; Runtime 104.65 s; Remaining runtime 2h47min59s; f1_train 0.4783; f1_dev 0.5745; loss_train 0.1325; loss_dev 0.1071
# Ep. 2/5; It. 900/2608; Runtime 106.37 s; Remaining runtime 2h48min58s; f1_train 0.7500; f1_dev 0.6364; loss_train 0.1070; loss_dev 0.1015
# Ep. 2/5; It. 1000/2608; Runtime 108.85 s; Remaining runtime 2h51min7s; f1_train 0.5714; f1_dev 0.5652; loss_train 0.1252; loss_dev 0.1029
# Ep. 2/5; It. 1100/2608; Runtime 102.50 s; Remaining runtime 2h39min25s; f1_train 0.8219; f1_dev 0.6316; loss_train 0.0743; loss_dev 0.0964
# Ep. 2/5; It. 1200/2608; Runtime 103.18 s; Remaining runtime 2h38min45s; f1_train 0.6316; f1_dev 0.6168; loss_train 0.1085; loss_dev 0.0973
# Ep. 2/5; It. 1300/2608; Runtime 103.81 s; Remaining runtime 2h37min59s; f1_train 0.6296; f1_dev 0.5745; loss_train 0.0878; loss_dev 0.0985
# Ep. 2/5; It. 1400/2608; Runtime 103.55 s; Remaining runtime 2h35min52s; f1_train 0.7463; f1_dev 0.6111; loss_train 0.0919; loss_dev 0.0969
# Ep. 2/5; It. 1500/2608; Runtime 102.17 s; Remaining runtime 2h32min6s; f1_train 0.5373; f1_dev 0.6667; loss_train 0.1605; loss_dev 0.0973
# Ep. 2/5; It. 1600/2608; Runtime 105.88 s; Remaining runtime 2h35min51s; f1_train 0.6914; f1_dev 0.6491; loss_train 0.1112; loss_dev 0.0952
# Ep. 2/5; It. 1700/2608; Runtime 105.63 s; Remaining runtime 2h33min43s; f1_train 0.6800; f1_dev 0.6250; loss_train 0.0848; loss_dev 0.0996
# Ep. 2/5; It. 1800/2608; Runtime 103.48 s; Remaining runtime 2h28min52s; f1_train 0.6471; f1_dev 0.6214; loss_train 0.1025; loss_dev 0.0958
# Ep. 2/5; It. 1900/2608; Runtime 106.88 s; Remaining runtime 2h31min58s; f1_train 0.7000; f1_dev 0.5417; loss_train 0.0954; loss_dev 0.1049
# Ep. 2/5; It. 2000/2608; Runtime 110.05 s; Remaining runtime 2h34min39s; f1_train 0.6545; f1_dev 0.6239; loss_train 0.0910; loss_dev 0.0947
# Ep. 2/5; It. 2100/2608; Runtime 102.58 s; Remaining runtime 2h22min27s; f1_train 0.5769; f1_dev 0.6019; loss_train 0.1032; loss_dev 0.0942
# Ep. 2/5; It. 2200/2608; Runtime 105.66 s; Remaining runtime 2h24min57s; f1_train 0.5882; f1_dev 0.6545; loss_train 0.1176; loss_dev 0.0916
# Ep. 2/5; It. 2300/2608; Runtime 103.01 s; Remaining runtime 2h19min37s; f1_train 0.5970; f1_dev 0.6435; loss_train 0.1409; loss_dev 0.0944
# Ep. 2/5; It. 2400/2608; Runtime 105.04 s; Remaining runtime 2h20min36s; f1_train 0.4889; f1_dev 0.6549; loss_train 0.1021; loss_dev 0.1013
# Ep. 2/5; It. 2500/2608; Runtime 104.50 s; Remaining runtime 2h18min8s; f1_train 0.6250; f1_dev 0.5979; loss_train 0.0839; loss_dev 0.0989
# Ep. 2/5; It. 2600/2608; Runtime 103.11 s; Remaining runtime 2h14min35s; f1_train 0.6349; f1_dev 0.5510; loss_train 0.1305; loss_dev 0.0961
# Ep. 3/5; It. 0/2608; Runtime 16.90 s; Remaining runtime 0h22min2s; f1_train 0.6780; f1_dev 0.6078; loss_train 0.0889; loss_dev 0.0953
# Ep. 3/5; It. 100/2608; Runtime 105.01 s; Remaining runtime 2h15min10s; f1_train 0.6552; f1_dev 0.5743; loss_train 0.0852; loss_dev 0.0947
# Ep. 3/5; It. 200/2608; Runtime 103.37 s; Remaining runtime 2h11min21s; f1_train 0.6364; f1_dev 0.6833; loss_train 0.1360; loss_dev 0.0939
# Ep. 3/5; It. 300/2608; Runtime 106.23 s; Remaining runtime 2h13min12s; f1_train 0.7273; f1_dev 0.6139; loss_train 0.0674; loss_dev 0.0958
# Ep. 3/5; It. 400/2608; Runtime 104.87 s; Remaining runtime 2h9min45s; f1_train 0.8197; f1_dev 0.6195; loss_train 0.0711; loss_dev 0.0934
# Ep. 3/5; It. 500/2608; Runtime 103.06 s; Remaining runtime 2h5min47s; f1_train 0.7188; f1_dev 0.6555; loss_train 0.0957; loss_dev 0.0935
# Ep. 3/5; It. 600/2608; Runtime 104.41 s; Remaining runtime 2h5min42s; f1_train 0.6538; f1_dev 0.6667; loss_train 0.0939; loss_dev 0.0959
# Ep. 3/5; It. 700/2608; Runtime 104.75 s; Remaining runtime 2h4min22s; f1_train 0.6809; f1_dev 0.6355; loss_train 0.0922; loss_dev 0.0972
# Ep. 3/5; It. 800/2608; Runtime 103.56 s; Remaining runtime 2h1min13s; f1_train 0.7719; f1_dev 0.6786; loss_train 0.0763; loss_dev 0.0989
# Ep. 3/5; It. 900/2608; Runtime 103.65 s; Remaining runtime 1h59min36s; f1_train 0.7600; f1_dev 0.6139; loss_train 0.0485; loss_dev 0.0966
# Ep. 3/5; It. 1000/2608; Runtime 110.08 s; Remaining runtime 2h5min11s; f1_train 0.5778; f1_dev 0.6139; loss_train 0.0857; loss_dev 0.0939
# Ep. 3/5; It. 1100/2608; Runtime 104.97 s; Remaining runtime 1h57min38s; f1_train 0.7647; f1_dev 0.6842; loss_train 0.0812; loss_dev 0.0937
# Ep. 3/5; It. 1200/2608; Runtime 104.93 s; Remaining runtime 1h55min50s; f1_train 0.6818; f1_dev 0.6667; loss_train 0.0679; loss_dev 0.0973
# Ep. 3/5; It. 1300/2608; Runtime 103.60 s; Remaining runtime 1h52min38s; f1_train 0.6441; f1_dev 0.6306; loss_train 0.0818; loss_dev 0.0960
# Ep. 3/5; It. 1400/2608; Runtime 104.70 s; Remaining runtime 1h52min6s; f1_train 0.5417; f1_dev 0.6667; loss_train 0.1069; loss_dev 0.0906
# Ep. 3/5; It. 1500/2608; Runtime 103.17 s; Remaining runtime 1h48min44s; f1_train 0.7119; f1_dev 0.6667; loss_train 0.0888; loss_dev 0.0902
# Ep. 3/5; It. 1600/2608; Runtime 104.42 s; Remaining runtime 1h48min19s; f1_train 0.6780; f1_dev 0.6780; loss_train 0.1147; loss_dev 0.0884
# Ep. 3/5; It. 1700/2608; Runtime 106.09 s; Remaining runtime 1h48min17s; f1_train 0.6809; f1_dev 0.6122; loss_train 0.0706; loss_dev 0.0991
# Ep. 3/5; It. 1800/2608; Runtime 103.66 s; Remaining runtime 1h44min4s; f1_train 0.6512; f1_dev 0.6346; loss_train 0.0791; loss_dev 0.0953
# Ep. 3/5; It. 1900/2608; Runtime 102.91 s; Remaining runtime 1h41min36s; f1_train 0.6038; f1_dev 0.6214; loss_train 0.0894; loss_dev 0.0943
# Ep. 3/5; It. 2000/2608; Runtime 109.06 s; Remaining runtime 1h45min51s; f1_train 0.5417; f1_dev 0.6667; loss_train 0.1024; loss_dev 0.0930
# Ep. 3/5; It. 2100/2608; Runtime 104.43 s; Remaining runtime 1h39min37s; f1_train 0.6970; f1_dev 0.6545; loss_train 0.1110; loss_dev 0.0915
# Ep. 3/5; It. 2200/2608; Runtime 105.30 s; Remaining runtime 1h38min41s; f1_train 0.6061; f1_dev 0.6372; loss_train 0.1244; loss_dev 0.0922
# Ep. 3/5; It. 2300/2608; Runtime 104.77 s; Remaining runtime 1h36min27s; f1_train 0.7297; f1_dev 0.6019; loss_train 0.1030; loss_dev 0.0928
# Ep. 3/5; It. 2400/2608; Runtime 105.21 s; Remaining runtime 1h35min6s; f1_train 0.7188; f1_dev 0.6727; loss_train 0.1065; loss_dev 0.0912
# Ep. 3/5; It. 2500/2608; Runtime 104.58 s; Remaining runtime 1h32min48s; f1_train 0.7200; f1_dev 0.6408; loss_train 0.0820; loss_dev 0.0961
# Ep. 3/5; It. 2600/2608; Runtime 104.13 s; Remaining runtime 1h30min39s; f1_train 0.6977; f1_dev 0.6542; loss_train 0.0712; loss_dev 0.0921
# Ep. 4/5; It. 0/2608; Runtime 16.85 s; Remaining runtime 0h14min38s; f1_train 0.7500; f1_dev 0.6122; loss_train 0.0890; loss_dev 0.0963
# Ep. 4/5; It. 100/2608; Runtime 103.17 s; Remaining runtime 1h27min58s; f1_train 0.6494; f1_dev 0.6415; loss_train 0.1053; loss_dev 0.0944
# Ep. 4/5; It. 200/2608; Runtime 105.26 s; Remaining runtime 1h27min59s; f1_train 0.7714; f1_dev 0.6168; loss_train 0.0874; loss_dev 0.0963
# Ep. 4/5; It. 300/2608; Runtime 105.87 s; Remaining runtime 1h26min44s; f1_train 0.6939; f1_dev 0.6239; loss_train 0.0842; loss_dev 0.0971
# Ep. 4/5; It. 400/2608; Runtime 103.91 s; Remaining runtime 1h23min24s; f1_train 0.8136; f1_dev 0.6481; loss_train 0.0580; loss_dev 0.0938
# Ep. 4/5; It. 500/2608; Runtime 104.35 s; Remaining runtime 1h22min1s; f1_train 0.6462; f1_dev 0.6838; loss_train 0.1092; loss_dev 0.0961
# Ep. 4/5; It. 600/2608; Runtime 104.33 s; Remaining runtime 1h20min16s; f1_train 0.7179; f1_dev 0.6614; loss_train 0.1130; loss_dev 0.0981
# Ep. 4/5; It. 700/2608; Runtime 102.06 s; Remaining runtime 1h16min48s; f1_train 0.7917; f1_dev 0.6545; loss_train 0.0524; loss_dev 0.0962
# Ep. 4/5; It. 800/2608; Runtime 104.04 s; Remaining runtime 1h16min34s; f1_train 0.7170; f1_dev 0.6607; loss_train 0.0798; loss_dev 0.0981
# Ep. 4/5; It. 900/2608; Runtime 104.28 s; Remaining runtime 1h15min0s; f1_train 0.6667; f1_dev 0.6842; loss_train 0.1124; loss_dev 0.0970
# Ep. 4/5; It. 1000/2608; Runtime 106.89 s; Remaining runtime 1h15min6s; f1_train 0.7188; f1_dev 0.6847; loss_train 0.0836; loss_dev 0.0950
# Ep. 4/5; It. 1100/2608; Runtime 104.84 s; Remaining runtime 1h11min55s; f1_train 0.7660; f1_dev 0.6609; loss_train 0.0504; loss_dev 0.0967
# Ep. 4/5; It. 1200/2608; Runtime 105.51 s; Remaining runtime 1h10min37s; f1_train 0.8358; f1_dev 0.6726; loss_train 0.0780; loss_dev 0.1045
# Ep. 4/5; It. 1300/2608; Runtime 104.80 s; Remaining runtime 1h8min24s; f1_train 0.5614; f1_dev 0.6481; loss_train 0.1071; loss_dev 0.0977
# Ep. 4/5; It. 1400/2608; Runtime 104.36 s; Remaining runtime 1h6min22s; f1_train 0.6667; f1_dev 0.6214; loss_train 0.0710; loss_dev 0.0992
# Ep. 4/5; It. 1500/2608; Runtime 103.80 s; Remaining runtime 1h4min17s; f1_train 0.6984; f1_dev 0.6286; loss_train 0.0740; loss_dev 0.0978
# Ep. 4/5; It. 1600/2608; Runtime 102.94 s; Remaining runtime 1h2min2s; f1_train 0.5641; f1_dev 0.6226; loss_train 0.0742; loss_dev 0.0999
# Ep. 4/5; It. 1700/2608; Runtime 104.39 s; Remaining runtime 1h1min10s; f1_train 0.7037; f1_dev 0.6286; loss_train 0.0759; loss_dev 0.0984
# Ep. 4/5; It. 1800/2608; Runtime 105.73 s; Remaining runtime 1h0min11s; f1_train 0.7119; f1_dev 0.5825; loss_train 0.0916; loss_dev 0.0929
# Ep. 4/5; It. 1900/2608; Runtime 104.67 s; Remaining runtime 0h57min50s; f1_train 0.7407; f1_dev 0.6168; loss_train 0.0679; loss_dev 0.0940
# Ep. 4/5; It. 2000/2608; Runtime 109.20 s; Remaining runtime 0h58min31s; f1_train 0.6122; f1_dev 0.6415; loss_train 0.0820; loss_dev 0.0976
# Ep. 4/5; It. 2100/2608; Runtime 106.14 s; Remaining runtime 0h55min7s; f1_train 0.7333; f1_dev 0.6000; loss_train 0.0683; loss_dev 0.0986
# Ep. 4/5; It. 2200/2608; Runtime 103.24 s; Remaining runtime 0h51min53s; f1_train 0.6230; f1_dev 0.6435; loss_train 0.0945; loss_dev 0.0937
# Ep. 4/5; It. 2300/2608; Runtime 103.79 s; Remaining runtime 0h50min26s; f1_train 0.8254; f1_dev 0.6154; loss_train 0.0647; loss_dev 0.0926
# Ep. 4/5; It. 2400/2608; Runtime 103.45 s; Remaining runtime 0h48min33s; f1_train 0.7500; f1_dev 0.6078; loss_train 0.0973; loss_dev 0.0975
# Ep. 4/5; It. 2500/2608; Runtime 105.83 s; Remaining runtime 0h47min54s; f1_train 0.7692; f1_dev 0.5962; loss_train 0.0701; loss_dev 0.0936
# Ep. 4/5; It. 2600/2608; Runtime 103.95 s; Remaining runtime 0h45min19s; f1_train 0.8000; f1_dev 0.5825; loss_train 0.0666; loss_dev 0.0961
# Ep. 5/5; It. 0/2608; Runtime 17.13 s; Remaining runtime 0h7min26s; f1_train 0.6786; f1_dev 0.5905; loss_train 0.0850; loss_dev 0.1001
# Ep. 5/5; It. 100/2608; Runtime 103.49 s; Remaining runtime 0h43min15s; f1_train 0.7742; f1_dev 0.6496; loss_train 0.0698; loss_dev 0.0970
# Ep. 5/5; It. 200/2608; Runtime 104.53 s; Remaining runtime 0h41min57s; f1_train 0.7556; f1_dev 0.6364; loss_train 0.0576; loss_dev 0.0987
# Ep. 5/5; It. 300/2608; Runtime 104.01 s; Remaining runtime 0h40min0s; f1_train 0.6400; f1_dev 0.6422; loss_train 0.0935; loss_dev 0.0967
# Ep. 5/5; It. 400/2608; Runtime 105.41 s; Remaining runtime 0h38min47s; f1_train 0.6154; f1_dev 0.5684; loss_train 0.0936; loss_dev 0.1007
# Ep. 5/5; It. 500/2608; Runtime 104.00 s; Remaining runtime 0h36min32s; f1_train 0.8205; f1_dev 0.6168; loss_train 0.1014; loss_dev 0.1001
# Ep. 5/5; It. 600/2608; Runtime 105.00 s; Remaining runtime 0h35min8s; f1_train 0.6667; f1_dev 0.6491; loss_train 0.0987; loss_dev 0.0962
# Ep. 5/5; It. 700/2608; Runtime 104.22 s; Remaining runtime 0h33min8s; f1_train 0.6939; f1_dev 0.6481; loss_train 0.0729; loss_dev 0.0952
# Ep. 5/5; It. 800/2608; Runtime 103.99 s; Remaining runtime 0h31min20s; f1_train 0.7059; f1_dev 0.5743; loss_train 0.0767; loss_dev 0.0991
# Ep. 5/5; It. 900/2608; Runtime 102.10 s; Remaining runtime 0h29min3s; f1_train 0.7647; f1_dev 0.6296; loss_train 0.0822; loss_dev 0.0928
# Ep. 5/5; It. 1000/2608; Runtime 109.93 s; Remaining runtime 0h29min27s; f1_train 0.6780; f1_dev 0.6286; loss_train 0.0731; loss_dev 0.0942
# Ep. 5/5; It. 1100/2608; Runtime 105.06 s; Remaining runtime 0h26min24s; f1_train 0.8421; f1_dev 0.5825; loss_train 0.0548; loss_dev 0.0969
# Ep. 5/5; It. 1200/2608; Runtime 103.61 s; Remaining runtime 0h24min18s; f1_train 0.6923; f1_dev 0.5962; loss_train 0.0780; loss_dev 0.0981
# Ep. 5/5; It. 1300/2608; Runtime 103.19 s; Remaining runtime 0h22min29s; f1_train 0.6667; f1_dev 0.6538; loss_train 0.0972; loss_dev 0.0920
# Ep. 5/5; It. 1400/2608; Runtime 102.65 s; Remaining runtime 0h20min39s; f1_train 0.7692; f1_dev 0.6355; loss_train 0.0894; loss_dev 0.0986
# Ep. 5/5; It. 1500/2608; Runtime 103.06 s; Remaining runtime 0h19min1s; f1_train 0.8214; f1_dev 0.6609; loss_train 0.0574; loss_dev 0.0939
# Ep. 5/5; It. 1600/2608; Runtime 104.66 s; Remaining runtime 0h17min35s; f1_train 0.6452; f1_dev 0.6727; loss_train 0.1048; loss_dev 0.0934
# Ep. 5/5; It. 1700/2608; Runtime 103.81 s; Remaining runtime 0h15min42s; f1_train 0.6944; f1_dev 0.6019; loss_train 0.1101; loss_dev 0.0987
# Ep. 5/5; It. 1800/2608; Runtime 103.33 s; Remaining runtime 0h13min54s; f1_train 0.7500; f1_dev 0.6296; loss_train 0.0643; loss_dev 0.0952
# Ep. 5/5; It. 1900/2608; Runtime 104.42 s; Remaining runtime 0h12min19s; f1_train 0.7200; f1_dev 0.6964; loss_train 0.0800; loss_dev 0.0920
# Ep. 5/5; It. 2000/2608; Runtime 108.54 s; Remaining runtime 0h10min59s; f1_train 0.8406; f1_dev 0.6724; loss_train 0.0726; loss_dev 0.0953
# Ep. 5/5; It. 2100/2608; Runtime 107.30 s; Remaining runtime 0h9min5s; f1_train 0.7429; f1_dev 0.7080; loss_train 0.0929; loss_dev 0.0978
# Ep. 5/5; It. 2200/2608; Runtime 103.73 s; Remaining runtime 0h7min3s; f1_train 0.8060; f1_dev 0.6481; loss_train 0.0706; loss_dev 0.0980
# Ep. 5/5; It. 2300/2608; Runtime 104.68 s; Remaining runtime 0h5min22s; f1_train 0.7419; f1_dev 0.6545; loss_train 0.0944; loss_dev 0.1001
# Ep. 5/5; It. 2400/2608; Runtime 104.85 s; Remaining runtime 0h3min38s; f1_train 0.7059; f1_dev 0.6095; loss_train 0.1009; loss_dev 0.0982
# Ep. 5/5; It. 2500/2608; Runtime 105.01 s; Remaining runtime 0h1min53s; f1_train 0.6122; f1_dev 0.6286; loss_train 0.0777; loss_dev 0.0974
# Ep. 5/5; It. 2600/2608; Runtime 104.31 s; Remaining runtime 0h0min8s; f1_train 0.7719; f1_dev 0.6435; loss_train 0.0771; loss_dev 0.0964
# Total actual runtime: 3 hours 48 min 14 sec

# %%
MODELS_FILE = "models/model3.2/QIQC_model3.2.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set, seq_len: X_cv_lengths})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model3.2/QIQC_model3.2.ckpt
# cross val f1 63.25%, dev f1 63.46%
