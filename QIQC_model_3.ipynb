# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_neurons = [500, 500, 500]
n_fc1 = 1500
n_fc2 = 500
n_fc3 = 100
n_output = 1
learning_rate = 0.001
activation_fn = tf.nn.elu

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = [tf.contrib.rnn.LSTMCell(num_units=n, name="LSTM") for n in n_neurons]
    multi_lstm_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    h_states, out_states = tf.nn.dynamic_rnn(multi_lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len) #state = 3 * 2 * m * 500
    states = tf.concat([out_states[0][0],out_states[1][0],out_states[2][0]], axis = 1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2, n_fc3, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc3, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model3/QIQC_model3.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
total_deltas = 0
t_init = time.time()
with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths})

            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                step = epoch * QIQC.nr_batches + iteration
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                t_1 = time.time()
                t_delta = t_1 - t_0
                total_deltas += t_delta
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))

t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/5; It. 0/2608; Runtime 8.67 s; Remaining runtime 0h18min50s; f1_train nan; f1_dev nan; loss_train 0.7402; loss_dev 0.6292
# Ep. 1/5; It. 100/2608; Runtime 83.59 s; Remaining runtime 3h0min16s; f1_train 0.4091; f1_dev 0.5524; loss_train 0.1047; loss_dev 0.1273
# Ep. 1/5; It. 200/2608; Runtime 81.53 s; Remaining runtime 2h54min28s; f1_train 0.6939; f1_dev 0.5208; loss_train 0.1269; loss_dev 0.1210
# Ep. 1/5; It. 300/2608; Runtime 82.05 s; Remaining runtime 2h54min12s; f1_train 0.4865; f1_dev 0.3590; loss_train 0.1012; loss_dev 0.1317
# Ep. 1/5; It. 400/2608; Runtime 82.13 s; Remaining runtime 2h53min1s; f1_train 0.6269; f1_dev 0.6126; loss_train 0.1542; loss_dev 0.1209
# Ep. 1/5; It. 500/2608; Runtime 81.52 s; Remaining runtime 2h50min22s; f1_train 0.4375; f1_dev 0.3810; loss_train 0.1076; loss_dev 0.1192
# Ep. 1/5; It. 600/2608; Runtime 81.01 s; Remaining runtime 2h47min58s; f1_train 0.5789; f1_dev 0.5800; loss_train 0.1650; loss_dev 0.1110
# Ep. 1/5; It. 700/2608; Runtime 84.93 s; Remaining runtime 2h54min40s; f1_train 0.5507; f1_dev 0.6018; loss_train 0.1391; loss_dev 0.1139
# Ep. 1/5; It. 800/2608; Runtime 81.90 s; Remaining runtime 2h47min4s; f1_train 0.7660; f1_dev 0.5941; loss_train 0.0813; loss_dev 0.1076
# Ep. 1/5; It. 900/2608; Runtime 83.48 s; Remaining runtime 2h48min53s; f1_train 0.5769; f1_dev 0.6261; loss_train 0.1092; loss_dev 0.1124
# Ep. 1/5; It. 1000/2608; Runtime 86.27 s; Remaining runtime 2h53min7s; f1_train 0.6429; f1_dev 0.6226; loss_train 0.1046; loss_dev 0.1039
# Ep. 1/5; It. 1100/2608; Runtime 82.22 s; Remaining runtime 2h43min37s; f1_train 0.6250; f1_dev 0.6095; loss_train 0.0927; loss_dev 0.1039
# Ep. 1/5; It. 1200/2608; Runtime 83.32 s; Remaining runtime 2h44min25s; f1_train 0.5532; f1_dev 0.5625; loss_train 0.0973; loss_dev 0.1027
# Ep. 1/5; It. 1300/2608; Runtime 82.09 s; Remaining runtime 2h40min37s; f1_train 0.5333; f1_dev 0.5652; loss_train 0.1116; loss_dev 0.1044
# Ep. 1/5; It. 1400/2608; Runtime 81.16 s; Remaining runtime 2h37min27s; f1_train 0.7200; f1_dev 0.6122; loss_train 0.0863; loss_dev 0.1010
# Ep. 1/5; It. 1500/2608; Runtime 82.67 s; Remaining runtime 2h39min0s; f1_train 0.6557; f1_dev 0.6549; loss_train 0.1025; loss_dev 0.1025
# Ep. 1/5; It. 1600/2608; Runtime 82.35 s; Remaining runtime 2h37min1s; f1_train 0.8421; f1_dev 0.6429; loss_train 0.0809; loss_dev 0.1008
# Ep. 1/5; It. 1700/2608; Runtime 81.68 s; Remaining runtime 2h34min22s; f1_train 0.6000; f1_dev 0.5169; loss_train 0.1042; loss_dev 0.1024
# Ep. 1/5; It. 1800/2608; Runtime 82.42 s; Remaining runtime 2h34min23s; f1_train 0.7200; f1_dev 0.6545; loss_train 0.1085; loss_dev 0.1011
# Ep. 1/5; It. 1900/2608; Runtime 81.35 s; Remaining runtime 2h31min2s; f1_train 0.5667; f1_dev 0.6154; loss_train 0.1168; loss_dev 0.1030
# Ep. 1/5; It. 2000/2608; Runtime 83.52 s; Remaining runtime 2h33min40s; f1_train 0.6296; f1_dev 0.6909; loss_train 0.0969; loss_dev 0.0987
# Ep. 1/5; It. 2100/2608; Runtime 83.46 s; Remaining runtime 2h32min10s; f1_train 0.4615; f1_dev 0.5714; loss_train 0.1169; loss_dev 0.1059
# Ep. 1/5; It. 2200/2608; Runtime 84.45 s; Remaining runtime 2h32min34s; f1_train 0.5000; f1_dev 0.5657; loss_train 0.0878; loss_dev 0.0955
# Ep. 1/5; It. 2300/2608; Runtime 81.41 s; Remaining runtime 2h25min42s; f1_train 0.7164; f1_dev 0.6349; loss_train 0.1041; loss_dev 0.1045
# Ep. 1/5; It. 2400/2608; Runtime 82.71 s; Remaining runtime 2h26min40s; f1_train 0.6545; f1_dev 0.6296; loss_train 0.0970; loss_dev 0.1006
# Ep. 1/5; It. 2500/2608; Runtime 81.90 s; Remaining runtime 2h23min52s; f1_train 0.6667; f1_dev 0.6139; loss_train 0.0966; loss_dev 0.0984
# Ep. 1/5; It. 2600/2608; Runtime 81.66 s; Remaining runtime 2h22min5s; f1_train 0.6557; f1_dev 0.5714; loss_train 0.0964; loss_dev 0.1019
# Ep. 2/5; It. 0/2608; Runtime 15.50 s; Remaining runtime 0h26min56s; f1_train 0.7273; f1_dev 0.5567; loss_train 0.0779; loss_dev 0.1010
# Ep. 2/5; It. 100/2608; Runtime 82.30 s; Remaining runtime 2h21min43s; f1_train 0.6190; f1_dev 0.5859; loss_train 0.0796; loss_dev 0.0964
# Ep. 2/5; It. 200/2608; Runtime 82.48 s; Remaining runtime 2h20min38s; f1_train 0.7385; f1_dev 0.5773; loss_train 0.0957; loss_dev 0.1007
# Ep. 2/5; It. 300/2608; Runtime 83.16 s; Remaining runtime 2h20min26s; f1_train 0.4390; f1_dev 0.5800; loss_train 0.0902; loss_dev 0.0994
# Ep. 2/5; It. 400/2608; Runtime 82.33 s; Remaining runtime 2h17min39s; f1_train 0.6667; f1_dev 0.5849; loss_train 0.1005; loss_dev 0.1000
# Ep. 2/5; It. 500/2608; Runtime 81.88 s; Remaining runtime 2h15min32s; f1_train 0.7576; f1_dev 0.6364; loss_train 0.1075; loss_dev 0.0968
# Ep. 2/5; It. 600/2608; Runtime 82.65 s; Remaining runtime 2h15min26s; f1_train 0.6667; f1_dev 0.5474; loss_train 0.0915; loss_dev 0.1031
# Ep. 2/5; It. 700/2608; Runtime 81.32 s; Remaining runtime 2h11min53s; f1_train 0.6667; f1_dev 0.5769; loss_train 0.0836; loss_dev 0.0980
# Ep. 2/5; It. 800/2608; Runtime 81.85 s; Remaining runtime 2h11min23s; f1_train 0.4444; f1_dev 0.5745; loss_train 0.1303; loss_dev 0.1062
# Ep. 2/5; It. 900/2608; Runtime 84.00 s; Remaining runtime 2h13min26s; f1_train 0.7324; f1_dev 0.6316; loss_train 0.1026; loss_dev 0.0996
# Ep. 2/5; It. 1000/2608; Runtime 86.01 s; Remaining runtime 2h15min12s; f1_train 0.5581; f1_dev 0.5591; loss_train 0.1233; loss_dev 0.0985
# Ep. 2/5; It. 1100/2608; Runtime 80.48 s; Remaining runtime 2h5min10s; f1_train 0.8108; f1_dev 0.6429; loss_train 0.0755; loss_dev 0.0970
# Ep. 2/5; It. 1200/2608; Runtime 81.56 s; Remaining runtime 2h5min29s; f1_train 0.6071; f1_dev 0.6355; loss_train 0.1064; loss_dev 0.0975
# Ep. 2/5; It. 1300/2608; Runtime 81.44 s; Remaining runtime 2h3min57s; f1_train 0.6122; f1_dev 0.6042; loss_train 0.0804; loss_dev 0.0964
# Ep. 2/5; It. 1400/2608; Runtime 81.25 s; Remaining runtime 2h2min18s; f1_train 0.6970; f1_dev 0.6154; loss_train 0.0958; loss_dev 0.0975
# Ep. 2/5; It. 1500/2608; Runtime 81.01 s; Remaining runtime 2h0min36s; f1_train 0.4912; f1_dev 0.5510; loss_train 0.1580; loss_dev 0.0959
# Ep. 2/5; It. 1600/2608; Runtime 82.96 s; Remaining runtime 2h2min7s; f1_train 0.7073; f1_dev 0.6393; loss_train 0.1112; loss_dev 0.0983
# Ep. 2/5; It. 1700/2608; Runtime 82.86 s; Remaining runtime 2h0min35s; f1_train 0.6923; f1_dev 0.6429; loss_train 0.0787; loss_dev 0.0953
# Ep. 2/5; It. 1800/2608; Runtime 81.85 s; Remaining runtime 1h57min45s; f1_train 0.6765; f1_dev 0.6000; loss_train 0.1015; loss_dev 0.0955
# Ep. 2/5; It. 1900/2608; Runtime 83.57 s; Remaining runtime 1h58min49s; f1_train 0.6552; f1_dev 0.5556; loss_train 0.0962; loss_dev 0.1041
# Ep. 2/5; It. 2000/2608; Runtime 85.97 s; Remaining runtime 2h0min48s; f1_train 0.6984; f1_dev 0.6822; loss_train 0.0935; loss_dev 0.0961
# Ep. 2/5; It. 2100/2608; Runtime 81.36 s; Remaining runtime 1h52min58s; f1_train 0.6667; f1_dev 0.5882; loss_train 0.0960; loss_dev 0.0930
# Ep. 2/5; It. 2200/2608; Runtime 82.88 s; Remaining runtime 1h53min42s; f1_train 0.6377; f1_dev 0.6296; loss_train 0.1175; loss_dev 0.0901
# Ep. 2/5; It. 2300/2608; Runtime 80.92 s; Remaining runtime 1h49min40s; f1_train 0.5970; f1_dev 0.6549; loss_train 0.1351; loss_dev 0.0939
# Ep. 2/5; It. 2400/2608; Runtime 83.14 s; Remaining runtime 1h51min17s; f1_train 0.4651; f1_dev 0.5567; loss_train 0.1010; loss_dev 0.0980
# Ep. 2/5; It. 2500/2608; Runtime 81.85 s; Remaining runtime 1h48min12s; f1_train 0.7037; f1_dev 0.6415; loss_train 0.0785; loss_dev 0.0954
# Ep. 2/5; It. 2600/2608; Runtime 80.82 s; Remaining runtime 1h45min29s; f1_train 0.6761; f1_dev 0.6286; loss_train 0.1138; loss_dev 0.0923
# Ep. 3/5; It. 0/2608; Runtime 13.65 s; Remaining runtime 0h17min47s; f1_train 0.6552; f1_dev 0.6154; loss_train 0.0829; loss_dev 0.0923
# Ep. 3/5; It. 100/2608; Runtime 82.72 s; Remaining runtime 1h46min28s; f1_train 0.6667; f1_dev 0.5495; loss_train 0.0897; loss_dev 0.0962
# Ep. 3/5; It. 200/2608; Runtime 81.28 s; Remaining runtime 1h43min16s; f1_train 0.6333; f1_dev 0.6486; loss_train 0.1291; loss_dev 0.0900
# Ep. 3/5; It. 300/2608; Runtime 84.31 s; Remaining runtime 1h45min43s; f1_train 0.6452; f1_dev 0.5979; loss_train 0.0648; loss_dev 0.0947
# Ep. 3/5; It. 400/2608; Runtime 82.37 s; Remaining runtime 1h41min55s; f1_train 0.8475; f1_dev 0.6429; loss_train 0.0662; loss_dev 0.0933
# Ep. 3/5; It. 500/2608; Runtime 81.05 s; Remaining runtime 1h38min55s; f1_train 0.7000; f1_dev 0.6429; loss_train 0.0923; loss_dev 0.0928
# Ep. 3/5; It. 600/2608; Runtime 82.79 s; Remaining runtime 1h39min40s; f1_train 0.5882; f1_dev 0.6400; loss_train 0.0959; loss_dev 0.1007
# Ep. 3/5; It. 700/2608; Runtime 82.16 s; Remaining runtime 1h37min32s; f1_train 0.6667; f1_dev 0.6214; loss_train 0.0858; loss_dev 0.0944
# Ep. 3/5; It. 800/2608; Runtime 81.40 s; Remaining runtime 1h35min17s; f1_train 0.7500; f1_dev 0.6476; loss_train 0.0735; loss_dev 0.0996
# Ep. 3/5; It. 900/2608; Runtime 82.18 s; Remaining runtime 1h34min50s; f1_train 0.7442; f1_dev 0.5979; loss_train 0.0501; loss_dev 0.0964
# Ep. 3/5; It. 1000/2608; Runtime 87.81 s; Remaining runtime 1h39min52s; f1_train 0.5957; f1_dev 0.5979; loss_train 0.0823; loss_dev 0.0964
# Ep. 3/5; It. 1100/2608; Runtime 82.49 s; Remaining runtime 1h32min26s; f1_train 0.7606; f1_dev 0.6481; loss_train 0.0781; loss_dev 0.0942
# Ep. 3/5; It. 1200/2608; Runtime 83.27 s; Remaining runtime 1h31min55s; f1_train 0.6818; f1_dev 0.6000; loss_train 0.0690; loss_dev 0.0972
# Ep. 3/5; It. 1300/2608; Runtime 81.45 s; Remaining runtime 1h28min33s; f1_train 0.6984; f1_dev 0.6422; loss_train 0.0826; loss_dev 0.0957
# Ep. 3/5; It. 1400/2608; Runtime 82.23 s; Remaining runtime 1h28min2s; f1_train 0.6415; f1_dev 0.6481; loss_train 0.1061; loss_dev 0.0900
# Ep. 3/5; It. 1500/2608; Runtime 81.97 s; Remaining runtime 1h26min23s; f1_train 0.6667; f1_dev 0.6602; loss_train 0.0884; loss_dev 0.0884
# Ep. 3/5; It. 1600/2608; Runtime 82.04 s; Remaining runtime 1h25min6s; f1_train 0.6333; f1_dev 0.6491; loss_train 0.1097; loss_dev 0.0901
# Ep. 3/5; It. 1700/2608; Runtime 83.40 s; Remaining runtime 1h25min7s; f1_train 0.6809; f1_dev 0.6535; loss_train 0.0699; loss_dev 0.0958
# Ep. 3/5; It. 1800/2608; Runtime 82.30 s; Remaining runtime 1h22min37s; f1_train 0.6047; f1_dev 0.6355; loss_train 0.0766; loss_dev 0.0952
# Ep. 3/5; It. 1900/2608; Runtime 80.80 s; Remaining runtime 1h19min46s; f1_train 0.5833; f1_dev 0.6061; loss_train 0.0847; loss_dev 0.0950
# Ep. 3/5; It. 2000/2608; Runtime 85.67 s; Remaining runtime 1h23min9s; f1_train 0.5532; f1_dev 0.6408; loss_train 0.1005; loss_dev 0.0970
# Ep. 3/5; It. 2100/2608; Runtime 83.11 s; Remaining runtime 1h19min17s; f1_train 0.6970; f1_dev 0.6168; loss_train 0.1057; loss_dev 0.0932
# Ep. 3/5; It. 2200/2608; Runtime 82.66 s; Remaining runtime 1h17min28s; f1_train 0.5714; f1_dev 0.6355; loss_train 0.1189; loss_dev 0.0910
# Ep. 3/5; It. 2300/2608; Runtime 82.25 s; Remaining runtime 1h15min43s; f1_train 0.7949; f1_dev 0.6140; loss_train 0.0978; loss_dev 0.0970
# Ep. 3/5; It. 2400/2608; Runtime 83.47 s; Remaining runtime 1h15min27s; f1_train 0.7541; f1_dev 0.6481; loss_train 0.1109; loss_dev 0.0919
# Ep. 3/5; It. 2500/2608; Runtime 82.30 s; Remaining runtime 1h13min1s; f1_train 0.6792; f1_dev 0.5981; loss_train 0.0863; loss_dev 0.0971
# Ep. 3/5; It. 2600/2608; Runtime 81.93 s; Remaining runtime 1h11min19s; f1_train 0.6486; f1_dev 0.6602; loss_train 0.0677; loss_dev 0.0928
# Ep. 4/5; It. 0/2608; Runtime 13.85 s; Remaining runtime 0h12min2s; f1_train 0.7797; f1_dev 0.5833; loss_train 0.0886; loss_dev 0.0977
# Ep. 4/5; It. 100/2608; Runtime 81.32 s; Remaining runtime 1h9min20s; f1_train 0.7532; f1_dev 0.5800; loss_train 0.0922; loss_dev 0.1001
# Ep. 4/5; It. 200/2608; Runtime 82.75 s; Remaining runtime 1h9min10s; f1_train 0.7385; f1_dev 0.5895; loss_train 0.0838; loss_dev 0.1054
# Ep. 4/5; It. 300/2608; Runtime 84.02 s; Remaining runtime 1h8min50s; f1_train 0.7200; f1_dev 0.6275; loss_train 0.0762; loss_dev 0.0982
# Ep. 4/5; It. 400/2608; Runtime 81.68 s; Remaining runtime 1h5min33s; f1_train 0.8333; f1_dev 0.6154; loss_train 0.0551; loss_dev 0.0994
# Ep. 4/5; It. 500/2608; Runtime 82.03 s; Remaining runtime 1h4min28s; f1_train 0.5902; f1_dev 0.6481; loss_train 0.1073; loss_dev 0.0978
# Ep. 4/5; It. 600/2608; Runtime 82.80 s; Remaining runtime 1h3min42s; f1_train 0.7000; f1_dev 0.7049; loss_train 0.1207; loss_dev 0.1015
# Ep. 4/5; It. 700/2608; Runtime 80.29 s; Remaining runtime 1h0min25s; f1_train 0.8261; f1_dev 0.6286; loss_train 0.0497; loss_dev 0.0981
# Ep. 4/5; It. 800/2608; Runtime 81.79 s; Remaining runtime 1h0min11s; f1_train 0.6792; f1_dev 0.6346; loss_train 0.0838; loss_dev 0.1023
# Ep. 4/5; It. 900/2608; Runtime 82.77 s; Remaining runtime 0h59min32s; f1_train 0.6230; f1_dev 0.6095; loss_train 0.1123; loss_dev 0.0996
# Ep. 4/5; It. 1000/2608; Runtime 83.71 s; Remaining runtime 0h58min49s; f1_train 0.6866; f1_dev 0.6942; loss_train 0.0971; loss_dev 0.1007
# Ep. 4/5; It. 1100/2608; Runtime 82.67 s; Remaining runtime 0h56min42s; f1_train 0.7692; f1_dev 0.6486; loss_train 0.0489; loss_dev 0.0985
# Ep. 4/5; It. 1200/2608; Runtime 84.36 s; Remaining runtime 0h56min27s; f1_train 0.7692; f1_dev 0.6549; loss_train 0.0827; loss_dev 0.1022
# Ep. 4/5; It. 1300/2608; Runtime 82.75 s; Remaining runtime 0h54min0s; f1_train 0.6000; f1_dev 0.5962; loss_train 0.1102; loss_dev 0.0938
# Ep. 4/5; It. 1400/2608; Runtime 82.22 s; Remaining runtime 0h52min17s; f1_train 0.6984; f1_dev 0.5743; loss_train 0.0781; loss_dev 0.0913
# Ep. 4/5; It. 1500/2608; Runtime 82.54 s; Remaining runtime 0h51min7s; f1_train 0.6667; f1_dev 0.5833; loss_train 0.0779; loss_dev 0.0957
# Ep. 4/5; It. 1600/2608; Runtime 81.05 s; Remaining runtime 0h48min50s; f1_train 0.5946; f1_dev 0.6038; loss_train 0.0811; loss_dev 0.0950
# Ep. 4/5; It. 1700/2608; Runtime 82.06 s; Remaining runtime 0h48min5s; f1_train 0.6786; f1_dev 0.6486; loss_train 0.0776; loss_dev 0.0965
# Ep. 4/5; It. 1800/2608; Runtime 83.89 s; Remaining runtime 0h47min45s; f1_train 0.7368; f1_dev 0.5800; loss_train 0.0872; loss_dev 0.0970
# Ep. 4/5; It. 1900/2608; Runtime 82.37 s; Remaining runtime 0h45min31s; f1_train 0.7660; f1_dev 0.5714; loss_train 0.0632; loss_dev 0.0994
# Ep. 4/5; It. 2000/2608; Runtime 85.36 s; Remaining runtime 0h45min45s; f1_train 0.6800; f1_dev 0.6000; loss_train 0.0818; loss_dev 0.1012
# Ep. 4/5; It. 2100/2608; Runtime 84.49 s; Remaining runtime 0h43min52s; f1_train 0.7937; f1_dev 0.6286; loss_train 0.0654; loss_dev 0.0974
# Ep. 4/5; It. 2200/2608; Runtime 81.25 s; Remaining runtime 0h40min50s; f1_train 0.6774; f1_dev 0.6476; loss_train 0.0953; loss_dev 0.0977
# Ep. 4/5; It. 2300/2608; Runtime 81.70 s; Remaining runtime 0h39min42s; f1_train 0.7812; f1_dev 0.6000; loss_train 0.0647; loss_dev 0.0967
# Ep. 4/5; It. 2400/2608; Runtime 82.22 s; Remaining runtime 0h38min35s; f1_train 0.7297; f1_dev 0.6154; loss_train 0.0911; loss_dev 0.0971
# Ep. 4/5; It. 2500/2608; Runtime 83.06 s; Remaining runtime 0h37min36s; f1_train 0.7843; f1_dev 0.6286; loss_train 0.0600; loss_dev 0.0998
# Ep. 4/5; It. 2600/2608; Runtime 81.61 s; Remaining runtime 0h35min34s; f1_train 0.8000; f1_dev 0.5962; loss_train 0.0646; loss_dev 0.0962
# Ep. 5/5; It. 0/2608; Runtime 12.97 s; Remaining runtime 0h5min38s; f1_train 0.7541; f1_dev 0.6111; loss_train 0.0869; loss_dev 0.0956
# Ep. 5/5; It. 100/2608; Runtime 81.63 s; Remaining runtime 0h34min7s; f1_train 0.7547; f1_dev 0.6078; loss_train 0.0632; loss_dev 0.1016
# Ep. 5/5; It. 200/2608; Runtime 82.16 s; Remaining runtime 0h32min58s; f1_train 0.7317; f1_dev 0.6545; loss_train 0.0652; loss_dev 0.0978
# Ep. 5/5; It. 300/2608; Runtime 82.49 s; Remaining runtime 0h31min43s; f1_train 0.4898; f1_dev 0.6095; loss_train 0.1032; loss_dev 0.1006
# Ep. 5/5; It. 400/2608; Runtime 82.96 s; Remaining runtime 0h30min31s; f1_train 0.7273; f1_dev 0.5714; loss_train 0.0769; loss_dev 0.1049
# Ep. 5/5; It. 500/2608; Runtime 81.77 s; Remaining runtime 0h28min43s; f1_train 0.8205; f1_dev 0.6226; loss_train 0.0802; loss_dev 0.1046
# Ep. 5/5; It. 600/2608; Runtime 83.42 s; Remaining runtime 0h27min55s; f1_train 0.6769; f1_dev 0.6296; loss_train 0.0966; loss_dev 0.1029
# Ep. 5/5; It. 700/2608; Runtime 81.88 s; Remaining runtime 0h26min2s; f1_train 0.7059; f1_dev 0.6306; loss_train 0.0694; loss_dev 0.0978
# Ep. 5/5; It. 800/2608; Runtime 81.71 s; Remaining runtime 0h24min37s; f1_train 0.7931; f1_dev 0.6364; loss_train 0.0695; loss_dev 0.1000
# Ep. 5/5; It. 900/2608; Runtime 81.11 s; Remaining runtime 0h23min5s; f1_train 0.8000; f1_dev 0.6607; loss_train 0.0785; loss_dev 0.1011
# Ep. 5/5; It. 1000/2608; Runtime 86.47 s; Remaining runtime 0h23min10s; f1_train 0.7213; f1_dev 0.6481; loss_train 0.0728; loss_dev 0.1014
# Ep. 5/5; It. 1100/2608; Runtime 82.54 s; Remaining runtime 0h20min44s; f1_train 0.8214; f1_dev 0.6286; loss_train 0.0569; loss_dev 0.0981
# Ep. 5/5; It. 1200/2608; Runtime 82.29 s; Remaining runtime 0h19min18s; f1_train 0.6909; f1_dev 0.6126; loss_train 0.0740; loss_dev 0.1032
# Ep. 5/5; It. 1300/2608; Runtime 81.22 s; Remaining runtime 0h17min42s; f1_train 0.6667; f1_dev 0.6408; loss_train 0.0908; loss_dev 0.0983
# Ep. 5/5; It. 1400/2608; Runtime 80.66 s; Remaining runtime 0h16min14s; f1_train 0.7595; f1_dev 0.5905; loss_train 0.0942; loss_dev 0.1067
# Ep. 5/5; It. 1500/2608; Runtime 81.89 s; Remaining runtime 0h15min7s; f1_train 0.8000; f1_dev 0.6355; loss_train 0.0478; loss_dev 0.1051
# Ep. 5/5; It. 1600/2608; Runtime 82.39 s; Remaining runtime 0h13min50s; f1_train 0.6000; f1_dev 0.6372; loss_train 0.1005; loss_dev 0.0991
# Ep. 5/5; It. 1700/2608; Runtime 81.58 s; Remaining runtime 0h12min20s; f1_train 0.6364; f1_dev 0.5941; loss_train 0.1162; loss_dev 0.1013
# Ep. 5/5; It. 1800/2608; Runtime 82.05 s; Remaining runtime 0h11min2s; f1_train 0.8000; f1_dev 0.6296; loss_train 0.0628; loss_dev 0.1022
# Ep. 5/5; It. 1900/2608; Runtime 82.11 s; Remaining runtime 0h9min41s; f1_train 0.6531; f1_dev 0.6429; loss_train 0.0746; loss_dev 0.0985
# Ep. 5/5; It. 2000/2608; Runtime 85.28 s; Remaining runtime 0h8min38s; f1_train 0.8182; f1_dev 0.6724; loss_train 0.0626; loss_dev 0.1044
# Ep. 5/5; It. 2100/2608; Runtime 85.11 s; Remaining runtime 0h7min12s; f1_train 0.7397; f1_dev 0.6422; loss_train 0.0990; loss_dev 0.1038
# Ep. 5/5; It. 2200/2608; Runtime 81.66 s; Remaining runtime 0h5min33s; f1_train 0.8125; f1_dev 0.6286; loss_train 0.0695; loss_dev 0.1067
# Ep. 5/5; It. 2300/2608; Runtime 82.24 s; Remaining runtime 0h4min13s; f1_train 0.7302; f1_dev 0.6140; loss_train 0.0859; loss_dev 0.1034
# Ep. 5/5; It. 2400/2608; Runtime 83.26 s; Remaining runtime 0h2min53s; f1_train 0.6452; f1_dev 0.6200; loss_train 0.1007; loss_dev 0.1019
# Ep. 5/5; It. 2500/2608; Runtime 82.54 s; Remaining runtime 0h1min29s; f1_train 0.6667; f1_dev 0.6055; loss_train 0.0758; loss_dev 0.0977
# Ep. 5/5; It. 2600/2608; Runtime 82.00 s; Remaining runtime 0h0min6s; f1_train 0.7937; f1_dev 0.6557; loss_train 0.0802; loss_dev 0.1004
# Total actual runtime: 3 hours 0 min 4 sec

# %%
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set, seq_len: X_cv_lengths})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model3/QIQC_model3.ckpt
# cross val f1 67.16%, dev f1 67.24%
