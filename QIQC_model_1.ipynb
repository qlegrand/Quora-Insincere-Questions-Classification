# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_inputs = 300
n_neurons = 500
n_fc1 = 500
n_fc2 = 200
n_output = 1
learning_rate = 0.001
activation_fn = tf.nn.elu
k_initializer = tf.contrib.layers.variance_scaling_initializer

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = tf.contrib.rnn.LSTMCell(num_units=n_neurons, name="LSTM")
    h_states, states = tf.nn.dynamic_rnn(lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len)

with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states[0], n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc2, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs//run-{}//".format(now)
MODELS_FILE = "models/model1/QIQC_model1.ckpt"
MODELS_INDEX = "models/model1/QIQC_model1.ckpt.index"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
modind = os.path.join(DRIVE_PATH,MODELS_INDEX)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

with tf.Session() as sess:
    #if os.path.isfile(modind):
    #    saver.restore(sess, modfil)
    #else:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths})
            
            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                step = epoch * QIQC.nr_batches + iteration
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                t_1 = time.time()
                t_delta = t_1 - t_0
                t_0 = t_1
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                print("Epoch {}/{}; iteration {}/{}; runtime {:2f} sec, f1_train {:4f}; f1_dev {:4f}; loss_train {:4f}; loss_dev {:4f}".format(epoch, n_epoch, iteration, QIQC.nr_batches, t_delta,f1_train,f1_dev,loss_train,loss_dev))
# Out:
# Epoch 0/5; iteration 0/2608; runtime 5.514426 sec, f1_train  nan; f1_dev  nan; loss_train 0.408455; loss_dev 0.348088
# Epoch 0/5; iteration 100/2608; runtime 26.996230 sec, f1_train 0.368421; f1_dev 0.464646; loss_train 0.103457; loss_dev 0.124984
# Epoch 0/5; iteration 200/2608; runtime 25.577585 sec, f1_train 0.523810; f1_dev 0.439560; loss_train 0.125422; loss_dev 0.121066
# Epoch 0/5; iteration 300/2608; runtime 25.794161 sec, f1_train 0.444444; f1_dev 0.337662; loss_train 0.102346; loss_dev 0.128438
# Epoch 0/5; iteration 400/2608; runtime 26.177999 sec, f1_train 0.584615; f1_dev 0.579439; loss_train 0.151896; loss_dev 0.118315
# Epoch 0/5; iteration 500/2608; runtime 25.995084 sec, f1_train 0.451613; f1_dev 0.315789; loss_train 0.109725; loss_dev 0.122416
# Epoch 0/5; iteration 600/2608; runtime 25.627789 sec, f1_train 0.520548; f1_dev 0.606061; loss_train 0.167968; loss_dev 0.110033
# Epoch 0/5; iteration 700/2608; runtime 26.807061 sec, f1_train 0.537313; f1_dev 0.607143; loss_train 0.135404; loss_dev 0.108485
# Epoch 0/5; iteration 800/2608; runtime 25.904326 sec, f1_train 0.765957; f1_dev 0.607843; loss_train 0.080090; loss_dev 0.107484
# Epoch 0/5; iteration 900/2608; runtime 26.248100 sec, f1_train 0.588235; f1_dev 0.625000; loss_train 0.108564; loss_dev 0.108383
# Epoch 0/5; iteration 1000/2608; runtime 29.703866 sec, f1_train 0.618182; f1_dev 0.585859; loss_train 0.105103; loss_dev 0.103572
# Epoch 0/5; iteration 1100/2608; runtime 26.267508 sec, f1_train 0.680851; f1_dev 0.545455; loss_train 0.093370; loss_dev 0.102139
# Epoch 0/5; iteration 1200/2608; runtime 26.185698 sec, f1_train 0.595745; f1_dev 0.556701; loss_train 0.098101; loss_dev 0.101314
# Epoch 0/5; iteration 1300/2608; runtime 25.739715 sec, f1_train 0.565217; f1_dev 0.580645; loss_train 0.112199; loss_dev 0.105092
# Epoch 0/5; iteration 1400/2608; runtime 25.471687 sec, f1_train 0.693878; f1_dev 0.612245; loss_train 0.083767; loss_dev 0.100169
# Epoch 0/5; iteration 1500/2608; runtime 26.295580 sec, f1_train 0.592593; f1_dev 0.636364; loss_train 0.103967; loss_dev 0.100616
# Epoch 0/5; iteration 1600/2608; runtime 26.166178 sec, f1_train 0.821918; f1_dev 0.605505; loss_train 0.079308; loss_dev 0.102489
# Epoch 0/5; iteration 1700/2608; runtime 25.767740 sec, f1_train 0.676923; f1_dev 0.577320; loss_train 0.097980; loss_dev 0.101933
# Epoch 0/5; iteration 1800/2608; runtime 26.204014 sec, f1_train 0.702703; f1_dev 0.621359; loss_train 0.107903; loss_dev 0.100877
# Epoch 0/5; iteration 1900/2608; runtime 25.474934 sec, f1_train 0.655172; f1_dev 0.600000; loss_train 0.113217; loss_dev 0.105315
# Epoch 0/5; iteration 2000/2608; runtime 27.922157 sec, f1_train 0.618182; f1_dev 0.660714; loss_train 0.096478; loss_dev 0.097901
# Epoch 0/5; iteration 2100/2608; runtime 26.537896 sec, f1_train 0.509091; f1_dev 0.565217; loss_train 0.116472; loss_dev 0.106469
# Epoch 0/5; iteration 2200/2608; runtime 26.449299 sec, f1_train 0.487805; f1_dev 0.612245; loss_train 0.086504; loss_dev 0.097214
# Epoch 0/5; iteration 2300/2608; runtime 25.671554 sec, f1_train 0.760563; f1_dev 0.671875; loss_train 0.103061; loss_dev 0.105907
# Epoch 0/5; iteration 2400/2608; runtime 26.335167 sec, f1_train 0.631579; f1_dev 0.616822; loss_train 0.098614; loss_dev 0.101908
# Epoch 0/5; iteration 2500/2608; runtime 25.622094 sec, f1_train 0.583333; f1_dev 0.630631; loss_train 0.099150; loss_dev 0.097480
# Epoch 0/5; iteration 2600/2608; runtime 25.591227 sec, f1_train 0.634921; f1_dev 0.607843; loss_train 0.096975; loss_dev 0.103919
# Epoch 1/5; iteration 0/2608; runtime 9.849458 sec, f1_train 0.703704; f1_dev 0.597938; loss_train 0.077405; loss_dev 0.104343
# Epoch 1/5; iteration 100/2608; runtime 26.157063 sec, f1_train 0.619048; f1_dev 0.596154; loss_train 0.076718; loss_dev 0.101682
# Epoch 1/5; iteration 200/2608; runtime 25.770205 sec, f1_train 0.705882; f1_dev 0.606061; loss_train 0.092241; loss_dev 0.103351
# Epoch 1/5; iteration 300/2608; runtime 26.137065 sec, f1_train 0.577778; f1_dev 0.601942; loss_train 0.086318; loss_dev 0.101864
# Epoch 1/5; iteration 400/2608; runtime 25.838730 sec, f1_train 0.666667; f1_dev 0.603774; loss_train 0.097359; loss_dev 0.102030
# Epoch 1/5; iteration 500/2608; runtime 25.605556 sec, f1_train 0.735294; f1_dev 0.630631; loss_train 0.111287; loss_dev 0.100622
# Epoch 1/5; iteration 600/2608; runtime 25.921672 sec, f1_train 0.716981; f1_dev 0.583333; loss_train 0.084047; loss_dev 0.106564
# Epoch 1/5; iteration 700/2608; runtime 25.547916 sec, f1_train 0.679245; f1_dev 0.582524; loss_train 0.078652; loss_dev 0.100907
# Epoch 1/5; iteration 800/2608; runtime 25.731145 sec, f1_train 0.520000; f1_dev 0.583333; loss_train 0.126559; loss_dev 0.104216
# Epoch 1/5; iteration 900/2608; runtime 26.415468 sec, f1_train 0.732394; f1_dev 0.626087; loss_train 0.101424; loss_dev 0.103345
# Epoch 1/5; iteration 1000/2608; runtime 29.062656 sec, f1_train 0.545455; f1_dev 0.521739; loss_train 0.121791; loss_dev 0.106452
# Epoch 1/5; iteration 1100/2608; runtime 25.699993 sec, f1_train 0.849315; f1_dev 0.611111; loss_train 0.072853; loss_dev 0.101274
# Epoch 1/5; iteration 1200/2608; runtime 25.795779 sec, f1_train 0.620690; f1_dev 0.609524; loss_train 0.104693; loss_dev 0.098228
# Epoch 1/5; iteration 1300/2608; runtime 25.797385 sec, f1_train 0.653846; f1_dev 0.606061; loss_train 0.082839; loss_dev 0.102421
# Epoch 1/5; iteration 1400/2608; runtime 25.725249 sec, f1_train 0.716418; f1_dev 0.609524; loss_train 0.089271; loss_dev 0.100738
# Epoch 1/5; iteration 1500/2608; runtime 25.687273 sec, f1_train 0.516129; f1_dev 0.580000; loss_train 0.158283; loss_dev 0.096361
# Epoch 1/5; iteration 1600/2608; runtime 26.141731 sec, f1_train 0.666667; f1_dev 0.627119; loss_train 0.112353; loss_dev 0.102080
# Epoch 1/5; iteration 1700/2608; runtime 26.193409 sec, f1_train 0.727273; f1_dev 0.618182; loss_train 0.080325; loss_dev 0.099667
# Epoch 1/5; iteration 1800/2608; runtime 25.937458 sec, f1_train 0.676471; f1_dev 0.592593; loss_train 0.099813; loss_dev 0.097856
# Epoch 1/5; iteration 1900/2608; runtime 26.385997 sec, f1_train 0.607143; f1_dev 0.555556; loss_train 0.100183; loss_dev 0.107627
# Epoch 1/5; iteration 2000/2608; runtime 28.719702 sec, f1_train 0.700000; f1_dev 0.634921; loss_train 0.088912; loss_dev 0.100036
# Epoch 1/5; iteration 2100/2608; runtime 26.357388 sec, f1_train 0.701754; f1_dev 0.603774; loss_train 0.092926; loss_dev 0.094474
# Epoch 1/5; iteration 2200/2608; runtime 26.162638 sec, f1_train 0.591549; f1_dev 0.625000; loss_train 0.118058; loss_dev 0.093168
# Epoch 1/5; iteration 2300/2608; runtime 25.621389 sec, f1_train 0.597015; f1_dev 0.666667; loss_train 0.131172; loss_dev 0.096588
# Epoch 1/5; iteration 2400/2608; runtime 26.325959 sec, f1_train 0.536585; f1_dev 0.582524; loss_train 0.093767; loss_dev 0.101483
# Epoch 1/5; iteration 2500/2608; runtime 25.909208 sec, f1_train 0.703704; f1_dev 0.619469; loss_train 0.074995; loss_dev 0.099749
# Epoch 1/5; iteration 2600/2608; runtime 25.603958 sec, f1_train 0.666667; f1_dev 0.590476; loss_train 0.118001; loss_dev 0.095997
# Epoch 2/5; iteration 0/2608; runtime 9.625619 sec, f1_train 0.688525; f1_dev 0.611111; loss_train 0.081341; loss_dev 0.095964
# Epoch 2/5; iteration 100/2608; runtime 26.339226 sec, f1_train 0.689655; f1_dev 0.541667; loss_train 0.088718; loss_dev 0.098688
# Epoch 2/5; iteration 200/2608; runtime 25.651257 sec, f1_train 0.677419; f1_dev 0.644068; loss_train 0.119331; loss_dev 0.091023
# Epoch 2/5; iteration 300/2608; runtime 26.494732 sec, f1_train 0.647059; f1_dev 0.577320; loss_train 0.067481; loss_dev 0.093154
# Epoch 2/5; iteration 400/2608; runtime 25.963675 sec, f1_train 0.793651; f1_dev 0.636364; loss_train 0.065646; loss_dev 0.097447
# Epoch 2/5; iteration 500/2608; runtime 25.512790 sec, f1_train 0.718750; f1_dev 0.631579; loss_train 0.092175; loss_dev 0.094114
# Epoch 2/5; iteration 600/2608; runtime 26.099488 sec, f1_train 0.653846; f1_dev 0.629630; loss_train 0.089302; loss_dev 0.103669
# Epoch 2/5; iteration 700/2608; runtime 25.962074 sec, f1_train 0.625000; f1_dev 0.648148; loss_train 0.084558; loss_dev 0.098494
# Epoch 2/5; iteration 800/2608; runtime 25.634496 sec, f1_train 0.745763; f1_dev 0.678571; loss_train 0.071527; loss_dev 0.098736
# Epoch 2/5; iteration 900/2608; runtime 25.878307 sec, f1_train 0.727273; f1_dev 0.568421; loss_train 0.051403; loss_dev 0.099414
# Epoch 2/5; iteration 1000/2608; runtime 29.894310 sec, f1_train 0.608696; f1_dev 0.609524; loss_train 0.082183; loss_dev 0.097705
# Epoch 2/5; iteration 1100/2608; runtime 26.498013 sec, f1_train 0.810811; f1_dev 0.642857; loss_train 0.077875; loss_dev 0.095965
# Epoch 2/5; iteration 1200/2608; runtime 26.322511 sec, f1_train 0.711111; f1_dev 0.627451; loss_train 0.069690; loss_dev 0.099242
# Epoch 2/5; iteration 1300/2608; runtime 25.684032 sec, f1_train 0.677419; f1_dev 0.660870; loss_train 0.082222; loss_dev 0.095373
# Epoch 2/5; iteration 1400/2608; runtime 25.860431 sec, f1_train 0.653846; f1_dev 0.616822; loss_train 0.089722; loss_dev 0.092813
# Epoch 2/5; iteration 1500/2608; runtime 25.800051 sec, f1_train 0.701754; f1_dev 0.678899; loss_train 0.078480; loss_dev 0.093957
# Epoch 2/5; iteration 1600/2608; runtime 25.807473 sec, f1_train 0.600000; f1_dev 0.643478; loss_train 0.111014; loss_dev 0.091713
# Epoch 2/5; iteration 1700/2608; runtime 26.214343 sec, f1_train 0.708333; f1_dev 0.574257; loss_train 0.062495; loss_dev 0.102192
# Epoch 2/5; iteration 1800/2608; runtime 25.922354 sec, f1_train 0.585366; f1_dev 0.660550; loss_train 0.079114; loss_dev 0.098162
# Epoch 2/5; iteration 1900/2608; runtime 25.490609 sec, f1_train 0.625000; f1_dev 0.607843; loss_train 0.085713; loss_dev 0.101342
# Epoch 2/5; iteration 2000/2608; runtime 28.802047 sec, f1_train 0.612245; f1_dev 0.672727; loss_train 0.096160; loss_dev 0.092898
# Epoch 2/5; iteration 2100/2608; runtime 26.650054 sec, f1_train 0.666667; f1_dev 0.654545; loss_train 0.103846; loss_dev 0.092805
# Epoch 2/5; iteration 2200/2608; runtime 26.148498 sec, f1_train 0.575758; f1_dev 0.678261; loss_train 0.111956; loss_dev 0.093552
# Epoch 2/5; iteration 2300/2608; runtime 25.950336 sec, f1_train 0.729730; f1_dev 0.623853; loss_train 0.098515; loss_dev 0.098097
# Epoch 2/5; iteration 2400/2608; runtime 26.296615 sec, f1_train 0.761905; f1_dev 0.672566; loss_train 0.102164; loss_dev 0.096073
# Epoch 2/5; iteration 2500/2608; runtime 25.903790 sec, f1_train 0.640000; f1_dev 0.642202; loss_train 0.078421; loss_dev 0.100178
# Epoch 2/5; iteration 2600/2608; runtime 25.811154 sec, f1_train 0.634146; f1_dev 0.654545; loss_train 0.069797; loss_dev 0.096199
# Epoch 3/5; iteration 0/2608; runtime 10.431554 sec, f1_train 0.800000; f1_dev 0.600000; loss_train 0.086861; loss_dev 0.100964
# Epoch 3/5; iteration 100/2608; runtime 25.970775 sec, f1_train 0.773333; f1_dev 0.598131; loss_train 0.097117; loss_dev 0.101728
# Epoch 3/5; iteration 200/2608; runtime 26.006423 sec, f1_train 0.757576; f1_dev 0.613861; loss_train 0.080138; loss_dev 0.108321
# Epoch 3/5; iteration 300/2608; runtime 26.497684 sec, f1_train 0.754717; f1_dev 0.603774; loss_train 0.073000; loss_dev 0.109393
# Epoch 3/5; iteration 400/2608; runtime 25.749854 sec, f1_train 0.825397; f1_dev 0.623853; loss_train 0.057288; loss_dev 0.100979
# Epoch 3/5; iteration 500/2608; runtime 25.773160 sec, f1_train 0.612903; f1_dev 0.618182; loss_train 0.103435; loss_dev 0.099595
# Epoch 3/5; iteration 600/2608; runtime 26.116720 sec, f1_train 0.666667; f1_dev 0.649573; loss_train 0.105902; loss_dev 0.098827
# Epoch 3/5; iteration 700/2608; runtime 25.330467 sec, f1_train 0.791667; f1_dev 0.648148; loss_train 0.045144; loss_dev 0.096823
# Epoch 3/5; iteration 800/2608; runtime 25.861877 sec, f1_train 0.727273; f1_dev 0.621849; loss_train 0.070032; loss_dev 0.098737
# Epoch 3/5; iteration 900/2608; runtime 26.142491 sec, f1_train 0.655172; f1_dev 0.684211; loss_train 0.098112; loss_dev 0.098382
# Epoch 3/5; iteration 1000/2608; runtime 28.912973 sec, f1_train 0.704225; f1_dev 0.672269; loss_train 0.082043; loss_dev 0.094720
# Epoch 3/5; iteration 1100/2608; runtime 26.445529 sec, f1_train 0.784314; f1_dev 0.643478; loss_train 0.052806; loss_dev 0.095899
# Epoch 3/5; iteration 1200/2608; runtime 26.680607 sec, f1_train 0.840580; f1_dev 0.672414; loss_train 0.078070; loss_dev 0.100030
# Epoch 3/5; iteration 1300/2608; runtime 26.020028 sec, f1_train 0.622951; f1_dev 0.618182; loss_train 0.099119; loss_dev 0.104444
# Epoch 3/5; iteration 1400/2608; runtime 25.871291 sec, f1_train 0.738462; f1_dev 0.648649; loss_train 0.078888; loss_dev 0.097020
# Epoch 3/5; iteration 1500/2608; runtime 26.114154 sec, f1_train 0.750000; f1_dev 0.618182; loss_train 0.070515; loss_dev 0.102739
# Epoch 3/5; iteration 1600/2608; runtime 25.551359 sec, f1_train 0.631579; f1_dev 0.630631; loss_train 0.067111; loss_dev 0.108278
# Epoch 3/5; iteration 1700/2608; runtime 25.861043 sec, f1_train 0.763636; f1_dev 0.672727; loss_train 0.071534; loss_dev 0.101053
# Epoch 3/5; iteration 1800/2608; runtime 26.441364 sec, f1_train 0.666667; f1_dev 0.603774; loss_train 0.090625; loss_dev 0.095420
# Epoch 3/5; iteration 1900/2608; runtime 25.886444 sec, f1_train 0.680000; f1_dev 0.600000; loss_train 0.067354; loss_dev 0.101161
# Epoch 3/5; iteration 2000/2608; runtime 28.631829 sec, f1_train 0.640000; f1_dev 0.616822; loss_train 0.080053; loss_dev 0.102722
# Epoch 3/5; iteration 2100/2608; runtime 27.166083 sec, f1_train 0.781250; f1_dev 0.660714; loss_train 0.066157; loss_dev 0.096737
# Epoch 3/5; iteration 2200/2608; runtime 25.603147 sec, f1_train 0.700000; f1_dev 0.648649; loss_train 0.078369; loss_dev 0.095030
# Epoch 3/5; iteration 2300/2608; runtime 25.684322 sec, f1_train 0.861538; f1_dev 0.618182; loss_train 0.060369; loss_dev 0.093731
# Epoch 3/5; iteration 2400/2608; runtime 25.862589 sec, f1_train 0.780488; f1_dev 0.642202; loss_train 0.084031; loss_dev 0.092789
# Epoch 3/5; iteration 2500/2608; runtime 26.123845 sec, f1_train 0.821429; f1_dev 0.666667; loss_train 0.055455; loss_dev 0.094424
# Epoch 3/5; iteration 2600/2608; runtime 25.783140 sec, f1_train 0.800000; f1_dev 0.636364; loss_train 0.058129; loss_dev 0.097970
# Epoch 4/5; iteration 0/2608; runtime 9.351597 sec, f1_train 0.781250; f1_dev 0.642857; loss_train 0.074726; loss_dev 0.095859
# Epoch 4/5; iteration 100/2608; runtime 26.025359 sec, f1_train 0.785714; f1_dev 0.596154; loss_train 0.055990; loss_dev 0.109399
# Epoch 4/5; iteration 200/2608; runtime 25.983639 sec, f1_train 0.800000; f1_dev 0.700855; loss_train 0.052061; loss_dev 0.101685
# Epoch 4/5; iteration 300/2608; runtime 26.032798 sec, f1_train 0.666667; f1_dev 0.672566; loss_train 0.072126; loss_dev 0.097040
# Epoch 4/5; iteration 400/2608; runtime 26.142073 sec, f1_train 0.724138; f1_dev 0.648148; loss_train 0.065504; loss_dev 0.103404
# Epoch 4/5; iteration 500/2608; runtime 25.828071 sec, f1_train 0.825000; f1_dev 0.678571; loss_train 0.070957; loss_dev 0.106433
# Epoch 4/5; iteration 600/2608; runtime 26.325944 sec, f1_train 0.767123; f1_dev 0.637931; loss_train 0.076607; loss_dev 0.106786
# Epoch 4/5; iteration 700/2608; runtime 25.868575 sec, f1_train 0.777778; f1_dev 0.661017; loss_train 0.062361; loss_dev 0.102661
# Epoch 4/5; iteration 800/2608; runtime 25.734147 sec, f1_train 0.821429; f1_dev 0.644068; loss_train 0.061136; loss_dev 0.105223
# Epoch 4/5; iteration 900/2608; runtime 25.611049 sec, f1_train 0.805970; f1_dev 0.642857; loss_train 0.066042; loss_dev 0.107568
# Epoch 4/5; iteration 1000/2608; runtime 29.403755 sec, f1_train 0.800000; f1_dev 0.655172; loss_train 0.062336; loss_dev 0.105580
# Epoch 4/5; iteration 1100/2608; runtime 26.480383 sec, f1_train 0.881356; f1_dev 0.642857; loss_train 0.045534; loss_dev 0.112051
# Epoch 4/5; iteration 1200/2608; runtime 26.035207 sec, f1_train 0.703704; f1_dev 0.628571; loss_train 0.065550; loss_dev 0.107478
# Epoch 4/5; iteration 1300/2608; runtime 25.655679 sec, f1_train 0.800000; f1_dev 0.678899; loss_train 0.073905; loss_dev 0.099759
# Epoch 4/5; iteration 1400/2608; runtime 25.507841 sec, f1_train 0.800000; f1_dev 0.623853; loss_train 0.076591; loss_dev 0.110234
# Epoch 4/5; iteration 1500/2608; runtime 25.880506 sec, f1_train 0.862069; f1_dev 0.689655; loss_train 0.043940; loss_dev 0.105181
# Epoch 4/5; iteration 1600/2608; runtime 26.024836 sec, f1_train 0.655172; f1_dev 0.631579; loss_train 0.083283; loss_dev 0.102876
# Epoch 4/5; iteration 1700/2608; runtime 25.709755 sec, f1_train 0.763158; f1_dev 0.628571; loss_train 0.088715; loss_dev 0.099238
# Epoch 4/5; iteration 1800/2608; runtime 25.939719 sec, f1_train 0.814815; f1_dev 0.660714; loss_train 0.049013; loss_dev 0.102237
# Epoch 4/5; iteration 1900/2608; runtime 25.914607 sec, f1_train 0.777778; f1_dev 0.694915; loss_train 0.063449; loss_dev 0.101111
# Epoch 4/5; iteration 2000/2608; runtime 28.468621 sec, f1_train 0.840580; f1_dev 0.688525; loss_train 0.056751; loss_dev 0.104935
# Epoch 4/5; iteration 2100/2608; runtime 27.293833 sec, f1_train 0.771429; f1_dev 0.684685; loss_train 0.077342; loss_dev 0.106806
# Epoch 4/5; iteration 2200/2608; runtime 25.685307 sec, f1_train 0.843750; f1_dev 0.637931; loss_train 0.060761; loss_dev 0.103956
# Epoch 4/5; iteration 2300/2608; runtime 25.990794 sec, f1_train 0.806452; f1_dev 0.642857; loss_train 0.062199; loss_dev 0.104556
# Epoch 4/5; iteration 2400/2608; runtime 26.101134 sec, f1_train 0.782609; f1_dev 0.634615; loss_train 0.085836; loss_dev 0.105081
# Epoch 4/5; iteration 2500/2608; runtime 25.984232 sec, f1_train 0.785714; f1_dev 0.642857; loss_train 0.066925; loss_dev 0.105426
# Epoch 4/5; iteration 2600/2608; runtime 25.851734 sec, f1_train 0.774194; f1_dev 0.672269; loss_train 0.068026; loss_dev 0.102670
