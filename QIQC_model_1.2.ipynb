# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_inputs = 300
n_neurons = 1000
n_fc1 = 1000
n_fc2 = 500
n_output = 1
learning_rate = 0.01
activation_fn = tf.nn.elu
k_initializer = tf.contrib.layers.variance_scaling_initializer

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = tf.contrib.rnn.LSTMCell(num_units=n_neurons, name="LSTM")
    h_states, states = tf.nn.dynamic_rnn(lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len)

with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states[0], n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc2, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs//run-{}//".format(now)
MODELS_FILE = "models/model1.2/QIQC_model1.2.ckpt"
MODELS_INDEX = "models/model1.2/QIQC_model1.2.ckpt.index"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
modind = os.path.join(DRIVE_PATH,MODELS_INDEX)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

with tf.Session() as sess:
    #if os.path.isfile(modind):
    #    saver.restore(sess, modfil)
    #else:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths})

            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                step = epoch * QIQC.nr_batches + iteration
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                t_1 = time.time()
                t_delta = t_1 - t_0
                t_0 = t_1
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                print("Epoch {}/{}; iteration {}/{}; runtime {:2f} sec, f1_train {:4f}; f1_dev {:4f}; loss_train {:4f}; loss_dev {:4f}".format(epoch, n_epoch, iteration, QIQC.nr_batches, t_delta,f1_train,f1_dev,loss_train,loss_dev))
# Out:
# Epoch 0/5; iteration 0/2608; runtime 6.660501 sec, f1_train  nan; f1_dev  nan; loss_train 70.589867; loss_dev 71.454887
# Epoch 0/5; iteration 100/2608; runtime 61.819350 sec, f1_train 0.117647; f1_dev 0.129870; loss_train 0.210219; loss_dev 0.228703
# Epoch 0/5; iteration 200/2608; runtime 59.328079 sec, f1_train  nan; f1_dev  nan; loss_train 0.209844; loss_dev 0.212270
# Epoch 0/5; iteration 300/2608; runtime 59.542238 sec, f1_train  nan; f1_dev  nan; loss_train 0.191791; loss_dev 0.206446
# Epoch 0/5; iteration 400/2608; runtime 59.574251 sec, f1_train 0.181818; f1_dev 0.084507; loss_train 0.238146; loss_dev 0.204085
# Epoch 0/5; iteration 500/2608; runtime 60.047210 sec, f1_train 0.148148; f1_dev 0.090909; loss_train 0.182543; loss_dev 0.185381
# Epoch 0/5; iteration 600/2608; runtime 59.410520 sec, f1_train  nan; f1_dev  nan; loss_train 0.300713; loss_dev 0.197094
# Epoch 0/5; iteration 700/2608; runtime 61.686570 sec, f1_train 0.153846; f1_dev 0.092308; loss_train 0.189124; loss_dev 0.172590
# Epoch 0/5; iteration 800/2608; runtime 60.131930 sec, f1_train 0.275862; f1_dev 0.032258; loss_train 0.130005; loss_dev 0.175468
# Epoch 0/5; iteration 900/2608; runtime 61.352591 sec, f1_train 0.400000; f1_dev 0.115942; loss_train 0.145577; loss_dev 0.170534
# Epoch 0/5; iteration 1000/2608; runtime 63.561357 sec, f1_train 0.060606; f1_dev 0.090909; loss_train 0.168089; loss_dev 0.179173
# Epoch 0/5; iteration 1100/2608; runtime 60.476273 sec, f1_train 0.307692; f1_dev 0.365591; loss_train 0.161415; loss_dev 0.164170
# Epoch 0/5; iteration 1200/2608; runtime 61.051041 sec, f1_train 0.333333; f1_dev 0.236842; loss_train 0.143939; loss_dev 0.144134
# Epoch 0/5; iteration 1300/2608; runtime 59.582375 sec, f1_train 0.500000; f1_dev 0.428571; loss_train 0.146291; loss_dev 0.142970
# Epoch 0/5; iteration 1400/2608; runtime 58.879854 sec, f1_train 0.473684; f1_dev 0.243902; loss_train 0.114797; loss_dev 0.137235
# Epoch 0/5; iteration 1500/2608; runtime 60.553656 sec, f1_train 0.500000; f1_dev 0.367816; loss_train 0.129629; loss_dev 0.133659
# Epoch 0/5; iteration 1600/2608; runtime 60.505092 sec, f1_train 0.355556; f1_dev 0.090909; loss_train 0.136129; loss_dev 0.156754
# Epoch 0/5; iteration 1700/2608; runtime 59.342298 sec, f1_train 0.440000; f1_dev 0.303797; loss_train 0.135489; loss_dev 0.130766
# Epoch 0/5; iteration 1800/2608; runtime 59.624901 sec, f1_train 0.407407; f1_dev 0.191781; loss_train 0.147449; loss_dev 0.136312
# Epoch 0/5; iteration 1900/2608; runtime 59.138336 sec, f1_train 0.553191; f1_dev 0.352941; loss_train 0.128554; loss_dev 0.129446
# Epoch 0/5; iteration 2000/2608; runtime 61.555033 sec, f1_train 0.171429; f1_dev 0.171429; loss_train 0.133149; loss_dev 0.131782
# Epoch 0/5; iteration 2100/2608; runtime 61.294472 sec, f1_train 0.048780; f1_dev 0.230769; loss_train 0.147038; loss_dev 0.128314
# Epoch 0/5; iteration 2200/2608; runtime 61.740208 sec, f1_train 0.296296; f1_dev 0.142857; loss_train 0.095715; loss_dev 0.137563
# Epoch 0/5; iteration 2300/2608; runtime 59.046715 sec, f1_train 0.518519; f1_dev 0.468085; loss_train 0.118448; loss_dev 0.126784
# Epoch 0/5; iteration 2400/2608; runtime 59.907202 sec, f1_train 0.378378; f1_dev 0.213333; loss_train 0.123665; loss_dev 0.141777
# Epoch 0/5; iteration 2500/2608; runtime 60.253789 sec, f1_train 0.250000; f1_dev 0.194444; loss_train 0.114883; loss_dev 0.128677
# Epoch 0/5; iteration 2600/2608; runtime 60.136750 sec, f1_train 0.500000; f1_dev 0.282051; loss_train 0.131347; loss_dev 0.131012
# Epoch 1/5; iteration 0/2608; runtime 13.334669 sec, f1_train 0.400000; f1_dev 0.386364; loss_train 0.096058; loss_dev 0.133538
# Epoch 1/5; iteration 100/2608; runtime 59.852495 sec, f1_train 0.465116; f1_dev 0.468085; loss_train 0.106303; loss_dev 0.122471
# Epoch 1/5; iteration 200/2608; runtime 59.661825 sec, f1_train 0.638889; f1_dev 0.533333; loss_train 0.139727; loss_dev 0.131441
# Epoch 1/5; iteration 300/2608; runtime 61.128210 sec, f1_train 0.368421; f1_dev 0.430108; loss_train 0.126978; loss_dev 0.127524
# Epoch 1/5; iteration 400/2608; runtime 60.669115 sec, f1_train 0.300000; f1_dev 0.303797; loss_train 0.128048; loss_dev 0.137382
# Epoch 1/5; iteration 500/2608; runtime 59.297165 sec, f1_train 0.588235; f1_dev 0.367816; loss_train 0.143150; loss_dev 0.135532
# Epoch 1/5; iteration 600/2608; runtime 59.888351 sec, f1_train 0.307692; f1_dev 0.337349; loss_train 0.147007; loss_dev 0.125861
# Epoch 1/5; iteration 700/2608; runtime 59.483963 sec, f1_train 0.476190; f1_dev 0.361446; loss_train 0.114595; loss_dev 0.138030
# Epoch 1/5; iteration 800/2608; runtime 60.921704 sec, f1_train  nan; f1_dev 0.121212; loss_train 0.148827; loss_dev 0.129867
# Epoch 1/5; iteration 900/2608; runtime 61.468855 sec, f1_train 0.638889; f1_dev 0.540541; loss_train 0.166302; loss_dev 0.156604
# Epoch 1/5; iteration 1000/2608; runtime 62.957564 sec, f1_train 0.358974; f1_dev 0.380952; loss_train 0.154556; loss_dev 0.189937
# Epoch 1/5; iteration 1100/2608; runtime 58.618819 sec, f1_train 0.468085; f1_dev 0.380952; loss_train 0.114088; loss_dev 0.138248
# Epoch 1/5; iteration 1200/2608; runtime 60.195621 sec, f1_train 0.363636; f1_dev 0.464646; loss_train 0.115146; loss_dev 0.128271
# Epoch 1/5; iteration 1300/2608; runtime 60.420536 sec, f1_train 0.560000; f1_dev 0.448980; loss_train 0.114996; loss_dev 0.130154
# Epoch 1/5; iteration 1400/2608; runtime 59.224910 sec, f1_train 0.603175; f1_dev 0.500000; loss_train 0.119755; loss_dev 0.135663
# Epoch 1/5; iteration 1500/2608; runtime 58.867350 sec, f1_train 0.290909; f1_dev 0.390805; loss_train 0.190671; loss_dev 0.127094
# Epoch 1/5; iteration 1600/2608; runtime 60.239202 sec, f1_train 0.657895; f1_dev 0.504348; loss_train 0.144959; loss_dev 0.138469
# Epoch 1/5; iteration 1700/2608; runtime 61.242095 sec, f1_train 0.608696; f1_dev 0.380952; loss_train 0.105780; loss_dev 0.129069
# Epoch 1/5; iteration 1800/2608; runtime 60.136405 sec, f1_train 0.537313; f1_dev 0.542056; loss_train 0.138355; loss_dev 0.129551
# Epoch 1/5; iteration 1900/2608; runtime 60.827818 sec, f1_train 0.655738; f1_dev 0.404494; loss_train 0.113127; loss_dev 0.126327
# Epoch 1/5; iteration 2000/2608; runtime 63.910974 sec, f1_train 0.517241; f1_dev 0.557377; loss_train 0.126023; loss_dev 0.135452
# Epoch 1/5; iteration 2100/2608; runtime 60.627228 sec, f1_train 0.576923; f1_dev 0.422222; loss_train 0.111249; loss_dev 0.124813
# Epoch 1/5; iteration 2200/2608; runtime 60.378027 sec, f1_train 0.597403; f1_dev 0.556522; loss_train 0.158706; loss_dev 0.138706
# Epoch 1/5; iteration 2300/2608; runtime 58.877569 sec, f1_train 0.500000; f1_dev 0.469388; loss_train 0.153309; loss_dev 0.121410
# Epoch 1/5; iteration 2400/2608; runtime 60.901554 sec, f1_train 0.545455; f1_dev 0.515464; loss_train 0.138369; loss_dev 0.124248
# Epoch 1/5; iteration 2500/2608; runtime 60.299543 sec, f1_train 0.577778; f1_dev 0.446809; loss_train 0.098763; loss_dev 0.123151
# Epoch 1/5; iteration 2600/2608; runtime 59.700789 sec, f1_train 0.533333; f1_dev 0.509804; loss_train 0.148090; loss_dev 0.116171
# Epoch 2/5; iteration 0/2608; runtime 12.168842 sec, f1_train 0.561404; f1_dev 0.547170; loss_train 0.130023; loss_dev 0.128992
# Epoch 2/5; iteration 100/2608; runtime 60.077477 sec, f1_train 0.052632; f1_dev 0.092308; loss_train 0.163644; loss_dev 0.140525
# Epoch 2/5; iteration 200/2608; runtime 58.841626 sec, f1_train 0.210526; f1_dev 0.191781; loss_train 0.187104; loss_dev 0.144774
# Epoch 2/5; iteration 300/2608; runtime 61.593783 sec, f1_train 0.095238; f1_dev 0.171429; loss_train 0.087257; loss_dev 0.137569
# Epoch 2/5; iteration 400/2608; runtime 60.950569 sec, f1_train 0.428571; f1_dev 0.307692; loss_train 0.106849; loss_dev 0.134445
# Epoch 2/5; iteration 500/2608; runtime 59.080947 sec, f1_train 0.468085; f1_dev 0.409091; loss_train 0.112720; loss_dev 0.123598
# Epoch 2/5; iteration 600/2608; runtime 60.003943 sec, f1_train  nan; f1_dev 0.149254; loss_train 0.124464; loss_dev 0.133505
# Epoch 2/5; iteration 700/2608; runtime 59.870866 sec, f1_train 0.400000; f1_dev 0.390244; loss_train 0.113588; loss_dev 0.124229
# Epoch 2/5; iteration 800/2608; runtime 59.985626 sec, f1_train 0.324324; f1_dev 0.354430; loss_train 0.113253; loss_dev 0.127589
# Epoch 2/5; iteration 900/2608; runtime 60.867182 sec, f1_train 0.611111; f1_dev 0.370370; loss_train 0.080663; loss_dev 0.120368
# Epoch 2/5; iteration 1000/2608; runtime 63.982025 sec, f1_train 0.294118; f1_dev 0.222222; loss_train 0.117813; loss_dev 0.128225
# Epoch 2/5; iteration 1100/2608; runtime 59.857299 sec, f1_train 0.705882; f1_dev 0.563107; loss_train 0.126878; loss_dev 0.126021
# Epoch 2/5; iteration 1200/2608; runtime 60.651075 sec, f1_train 0.611111; f1_dev 0.434783; loss_train 0.080699; loss_dev 0.119418
# Epoch 2/5; iteration 1300/2608; runtime 60.287347 sec, f1_train 0.408163; f1_dev 0.463158; loss_train 0.117185; loss_dev 0.119104
# Epoch 2/5; iteration 1400/2608; runtime 60.066460 sec, f1_train 0.333333; f1_dev 0.354430; loss_train 0.116489; loss_dev 0.118759
# Epoch 2/5; iteration 1500/2608; runtime 59.423558 sec, f1_train 0.610169; f1_dev 0.566372; loss_train 0.124756; loss_dev 0.122309
# Epoch 2/5; iteration 1600/2608; runtime 59.426261 sec, f1_train 0.575758; f1_dev 0.580645; loss_train 0.131723; loss_dev 0.121805
# Epoch 2/5; iteration 1700/2608; runtime 60.633978 sec, f1_train 0.594595; f1_dev 0.613333; loss_train 0.127806; loss_dev 0.152270
# Epoch 2/5; iteration 1800/2608; runtime 60.929821 sec, f1_train 0.450000; f1_dev 0.574257; loss_train 0.101180; loss_dev 0.112401
# Epoch 2/5; iteration 1900/2608; runtime 59.055809 sec, f1_train 0.576271; f1_dev 0.615385; loss_train 0.120893; loss_dev 0.113200
# Epoch 2/5; iteration 2000/2608; runtime 62.911099 sec, f1_train 0.390244; f1_dev 0.563107; loss_train 0.123475; loss_dev 0.112774
# Epoch 2/5; iteration 2100/2608; runtime 60.801101 sec, f1_train 0.645161; f1_dev 0.571429; loss_train 0.128391; loss_dev 0.111105
# Epoch 2/5; iteration 2200/2608; runtime 61.159950 sec, f1_train 0.205128; f1_dev 0.385542; loss_train 0.133952; loss_dev 0.119461
# Epoch 2/5; iteration 2300/2608; runtime 60.379245 sec, f1_train 0.734177; f1_dev 0.600000; loss_train 0.124823; loss_dev 0.133096
# Epoch 2/5; iteration 2400/2608; runtime 60.549397 sec, f1_train 0.444444; f1_dev 0.483516; loss_train 0.133646; loss_dev 0.119822
# Epoch 2/5; iteration 2500/2608; runtime 60.035161 sec, f1_train 0.410256; f1_dev 0.500000; loss_train 0.109577; loss_dev 0.124925
# Epoch 2/5; iteration 2600/2608; runtime 60.754211 sec, f1_train 0.413793; f1_dev 0.414634; loss_train 0.098098; loss_dev 0.126267
# Epoch 3/5; iteration 0/2608; runtime 12.909400 sec, f1_train 0.560000; f1_dev 0.426966; loss_train 0.117836; loss_dev 0.130395
# Epoch 3/5; iteration 100/2608; runtime 59.232251 sec, f1_train 0.507463; f1_dev 0.560000; loss_train 0.150767; loss_dev 0.116658
# Epoch 3/5; iteration 200/2608; runtime 60.068034 sec, f1_train 0.528302; f1_dev 0.423529; loss_train 0.109425; loss_dev 0.116619
# Epoch 3/5; iteration 300/2608; runtime 60.952546 sec, f1_train 0.461538; f1_dev 0.534653; loss_train 0.096363; loss_dev 0.107595
# Epoch 3/5; iteration 400/2608; runtime 60.102489 sec, f1_train 0.615385; f1_dev 0.560000; loss_train 0.089448; loss_dev 0.115319
# Epoch 3/5; iteration 500/2608; runtime 60.268251 sec, f1_train 0.597015; f1_dev 0.634921; loss_train 0.150408; loss_dev 0.129384
# Epoch 3/5; iteration 600/2608; runtime 60.178722 sec, f1_train 0.575758; f1_dev 0.614035; loss_train 0.132136; loss_dev 0.117136
# Epoch 3/5; iteration 700/2608; runtime 58.307649 sec, f1_train 0.514286; f1_dev 0.452381; loss_train 0.077191; loss_dev 0.121010
# Epoch 3/5; iteration 800/2608; runtime 59.688528 sec, f1_train 0.600000; f1_dev 0.555556; loss_train 0.101645; loss_dev 0.116562
# Epoch 3/5; iteration 900/2608; runtime 61.026593 sec, f1_train 0.586207; f1_dev 0.626087; loss_train 0.131924; loss_dev 0.113535
# Epoch 3/5; iteration 1000/2608; runtime 62.944711 sec, f1_train 0.566038; f1_dev 0.483516; loss_train 0.126234; loss_dev 0.110921
# Epoch 3/5; iteration 1100/2608; runtime 60.069782 sec, f1_train 0.571429; f1_dev 0.395062; loss_train 0.075298; loss_dev 0.130613
# Epoch 3/5; iteration 1200/2608; runtime 61.221069 sec, f1_train 0.800000; f1_dev 0.563636; loss_train 0.090260; loss_dev 0.115742
# Epoch 3/5; iteration 1300/2608; runtime 60.458244 sec, f1_train 0.408163; f1_dev 0.568421; loss_train 0.134907; loss_dev 0.114255
# Epoch 3/5; iteration 1400/2608; runtime 60.462361 sec, f1_train 0.489796; f1_dev 0.505747; loss_train 0.087028; loss_dev 0.118808
# Epoch 3/5; iteration 1500/2608; runtime 60.325630 sec, f1_train 0.545455; f1_dev 0.358974; loss_train 0.096857; loss_dev 0.118070
# Epoch 3/5; iteration 1600/2608; runtime 58.909926 sec, f1_train 0.600000; f1_dev 0.565657; loss_train 0.090037; loss_dev 0.108097
# Epoch 3/5; iteration 1700/2608; runtime 59.596738 sec, f1_train 0.679245; f1_dev 0.584906; loss_train 0.089757; loss_dev 0.109558
# Epoch 3/5; iteration 1800/2608; runtime 61.790956 sec, f1_train 0.590909; f1_dev 0.465116; loss_train 0.104598; loss_dev 0.113968
# Epoch 3/5; iteration 1900/2608; runtime 60.990994 sec, f1_train 0.074074; f1_dev 0.093750; loss_train 0.106010; loss_dev 0.128638
# Epoch 3/5; iteration 2000/2608; runtime 62.875535 sec, f1_train 0.550000; f1_dev 0.488889; loss_train 0.092275; loss_dev 0.112372
# Epoch 3/5; iteration 2100/2608; runtime 61.578448 sec, f1_train 0.760563; f1_dev 0.627119; loss_train 0.089473; loss_dev 0.111220
# Epoch 3/5; iteration 2200/2608; runtime 59.323895 sec, f1_train 0.584615; f1_dev 0.579439; loss_train 0.131700; loss_dev 0.111555
# Epoch 3/5; iteration 2300/2608; runtime 60.036270 sec, f1_train 0.057143; f1_dev 0.032258; loss_train 0.152473; loss_dev 0.183943
# Epoch 3/5; iteration 2400/2608; runtime 60.422568 sec, f1_train 0.731707; f1_dev 0.628099; loss_train 0.116564; loss_dev 0.112388
# Epoch 3/5; iteration 2500/2608; runtime 60.367345 sec, f1_train 0.242424; f1_dev 0.092308; loss_train 0.134081; loss_dev 0.169297
# Epoch 3/5; iteration 2600/2608; runtime 59.292410 sec, f1_train 0.705882; f1_dev 0.556701; loss_train 0.083484; loss_dev 0.113034
# Epoch 4/5; iteration 0/2608; runtime 12.892187 sec, f1_train 0.615385; f1_dev 0.594595; loss_train 0.114611; loss_dev 0.111268
# Epoch 4/5; iteration 100/2608; runtime 60.194709 sec, f1_train 0.487805; f1_dev 0.375000; loss_train 0.097076; loss_dev 0.114264
# Epoch 4/5; iteration 200/2608; runtime 60.969021 sec, f1_train 0.558140; f1_dev 0.631579; loss_train 0.111082; loss_dev 0.107398
# Epoch 4/5; iteration 300/2608; runtime 59.964200 sec, f1_train 0.584615; f1_dev 0.671875; loss_train 0.125909; loss_dev 0.110761
# Epoch 4/5; iteration 400/2608; runtime 60.279322 sec, f1_train 0.600000; f1_dev 0.635514; loss_train 0.104707; loss_dev 0.106929
# Epoch 4/5; iteration 500/2608; runtime 59.754971 sec, f1_train 0.783784; f1_dev 0.605505; loss_train 0.112980; loss_dev 0.106072
# Epoch 4/5; iteration 600/2608; runtime 62.047720 sec, f1_train 0.611111; f1_dev 0.612903; loss_train 0.140048; loss_dev 0.114036
# Epoch 4/5; iteration 700/2608; runtime 59.969913 sec, f1_train 0.486486; f1_dev 0.543478; loss_train 0.104379; loss_dev 0.112403
# Epoch 4/5; iteration 800/2608; runtime 59.425790 sec, f1_train 0.677966; f1_dev 0.635659; loss_train 0.107589; loss_dev 0.113281
# Epoch 4/5; iteration 900/2608; runtime 59.083913 sec, f1_train 0.703704; f1_dev 0.471910; loss_train 0.113893; loss_dev 0.112442
# Epoch 4/5; iteration 1000/2608; runtime 64.712952 sec, f1_train 0.444444; f1_dev 0.494382; loss_train 0.111773; loss_dev 0.117006
# Epoch 4/5; iteration 1100/2608; runtime 61.042670 sec, f1_train 0.450000; f1_dev 0.147059; loss_train 0.090257; loss_dev 0.113210
# Epoch 4/5; iteration 1200/2608; runtime 59.864879 sec, f1_train 0.465116; f1_dev 0.549451; loss_train 0.095389; loss_dev 0.111579
# Epoch 4/5; iteration 1300/2608; runtime 58.995319 sec, f1_train 0.594595; f1_dev 0.596491; loss_train 0.139076; loss_dev 0.110961
# Epoch 4/5; iteration 1400/2608; runtime 59.003240 sec, f1_train 0.647887; f1_dev 0.576923; loss_train 0.118812; loss_dev 0.108002
# Epoch 4/5; iteration 1500/2608; runtime 60.244506 sec, f1_train 0.711111; f1_dev 0.574468; loss_train 0.092692; loss_dev 0.103503
# Epoch 4/5; iteration 1600/2608; runtime 60.432233 sec, f1_train 0.474576; f1_dev 0.655462; loss_train 0.150645; loss_dev 0.107948
# Epoch 4/5; iteration 1700/2608; runtime 59.149771 sec, f1_train 0.567164; f1_dev 0.531915; loss_train 0.137505; loss_dev 0.110341
# Epoch 4/5; iteration 1800/2608; runtime 59.647444 sec, f1_train 0.734694; f1_dev 0.629630; loss_train 0.068244; loss_dev 0.104616
# Epoch 4/5; iteration 1900/2608; runtime 60.493636 sec, f1_train 0.689655; f1_dev 0.645669; loss_train 0.099277; loss_dev 0.103840
# Epoch 4/5; iteration 2000/2608; runtime 63.285336 sec, f1_train 0.760563; f1_dev 0.661871; loss_train 0.101012; loss_dev 0.122068
# Epoch 4/5; iteration 2100/2608; runtime 61.978836 sec, f1_train 0.464286; f1_dev 0.568421; loss_train 0.138727; loss_dev 0.102586
# Epoch 4/5; iteration 2200/2608; runtime 59.298595 sec, f1_train 0.633333; f1_dev 0.576923; loss_train 0.087263; loss_dev 0.109244
# Epoch 4/5; iteration 2300/2608; runtime 59.699333 sec, f1_train 0.657895; f1_dev 0.623188; loss_train 0.123307; loss_dev 0.119969
# Epoch 4/5; iteration 2400/2608; runtime 61.084363 sec, f1_train 0.561404; f1_dev 0.562500; loss_train 0.123997; loss_dev 0.104044
# Epoch 4/5; iteration 2500/2608; runtime 60.584075 sec, f1_train 0.558824; f1_dev 0.642857; loss_train 0.140603; loss_dev 0.112825
# Epoch 4/5; iteration 2600/2608; runtime 59.682280 sec, f1_train 0.716418; f1_dev 0.666667; loss_train 0.129511; loss_dev 0.132809
