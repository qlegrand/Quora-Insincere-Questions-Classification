# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_neurons = [500, 500, 500, 500]
n_fc1 = 500
n_fc2 = 500
n_fc3 = 500
n_fc4 = 500
n_fc5 = 250
n_output = 1
learning_rate = tf.placeholder(tf.float32)
activation_fn = tf.nn.elu

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    #embedded_sentences = tf.transpose(tf.nn.embedding_lookup(word_embeddings, X),perm = [1,0,2])
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    #lstm_cell = tf.contrib.cudnn_rnn.CudnnLSTM(4, 500)
    #h_states, out_states = lstm_cell(embedded_sentences)
    lstm_cell = [tf.contrib.rnn.LSTMCell(num_units=n, name="LSTM") for n in n_neurons]
    multi_lstm_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    h_states, out_states = tf.nn.dynamic_rnn(multi_lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len) #state = 3 * 2 * m * 500

    
with tf.name_scope("fully_connected_layers"):
    #fc1 = tf.contrib.layers.fully_connected(tf.transpose(out_states[1], perm=[1,0,2]), n_fc1, activation_fn=activation_fn)
    fc1 = tf.contrib.layers.fully_connected(out_states[3][0], n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2, n_fc3, activation_fn=activation_fn)
    fc4 = tf.contrib.layers.fully_connected(fc3, n_fc4, activation_fn=activation_fn)
    fc5 = tf.contrib.layers.fully_connected(fc4, n_fc5, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc5, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model3.2.1/QIQC_model3.2.1.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
total_deltas = 0
t_init = time.time()
min_lr = 0.0005
max_lr = 0.0015
with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    stepsize = QIQC.nr_batches
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            step = epoch * QIQC.nr_batches + iteration
            cycle = np.floor(1 + step/(2 * stepsize))
            pattern = np.absolute(step/stepsize - 2*cycle + 1)
            cycle_lr = min_lr + (max_lr - min_lr) * pattern
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate: cycle_lr})
            """
            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)
            """
            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                t_1 = time.time()
                t_delta = t_1 - t_0
                total_deltas += t_delta
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/5; It. 0/2608; Runtime 7.85 s; Remaining runtime 0h17min4s; f1_train nan; f1_dev nan; loss_train 0.3775; loss_dev 0.3561
# Ep. 1/5; It. 100/2608; Runtime 104.16 s; Remaining runtime 3h44min37s; f1_train nan; f1_dev nan; loss_train 0.2047; loss_dev 0.2172
# Ep. 1/5; It. 200/2608; Runtime 101.87 s; Remaining runtime 3h38min0s; f1_train nan; f1_dev nan; loss_train 0.2056; loss_dev 0.2137
# Ep. 1/5; It. 300/2608; Runtime 101.73 s; Remaining runtime 3h36min0s; f1_train nan; f1_dev nan; loss_train 0.1930; loss_dev 0.2143
# Ep. 1/5; It. 400/2608; Runtime 102.70 s; Remaining runtime 3h36min21s; f1_train nan; f1_dev nan; loss_train 0.2442; loss_dev 0.2117
# Ep. 1/5; It. 500/2608; Runtime 101.91 s; Remaining runtime 3h32min59s; f1_train nan; f1_dev nan; loss_train 0.2088; loss_dev 0.2306
# Ep. 1/5; It. 600/2608; Runtime 100.08 s; Remaining runtime 3h27min30s; f1_train nan; f1_dev nan; loss_train 0.3123; loss_dev 0.2108
# Ep. 1/5; It. 700/2608; Runtime 106.46 s; Remaining runtime 3h38min56s; f1_train 0.3600; f1_dev 0.4091; loss_train 0.1712; loss_dev 0.1394
# Ep. 1/5; It. 800/2608; Runtime 102.64 s; Remaining runtime 3h29min23s; f1_train 0.4706; f1_dev 0.3243; loss_train 0.0945; loss_dev 0.1308
# Ep. 1/5; It. 900/2608; Runtime 103.65 s; Remaining runtime 3h29min43s; f1_train 0.5000; f1_dev 0.5577; loss_train 0.1089; loss_dev 0.1209
# Ep. 1/5; It. 1000/2608; Runtime 106.02 s; Remaining runtime 3h32min45s; f1_train 0.5763; f1_dev 0.6168; loss_train 0.1105; loss_dev 0.1126
# Ep. 1/5; It. 1100/2608; Runtime 102.96 s; Remaining runtime 3h24min53s; f1_train 0.5882; f1_dev 0.6218; loss_train 0.0989; loss_dev 0.1057
# Ep. 1/5; It. 1200/2608; Runtime 103.26 s; Remaining runtime 3h23min45s; f1_train 0.5000; f1_dev 0.5495; loss_train 0.1037; loss_dev 0.1087
# Ep. 1/5; It. 1300/2608; Runtime 102.70 s; Remaining runtime 3h20min56s; f1_train 0.5417; f1_dev 0.5918; loss_train 0.1171; loss_dev 0.1035
# Ep. 1/5; It. 1400/2608; Runtime 101.65 s; Remaining runtime 3h17min11s; f1_train 0.5714; f1_dev 0.6296; loss_train 0.0952; loss_dev 0.0984
# Ep. 1/5; It. 1500/2608; Runtime 102.59 s; Remaining runtime 3h17min19s; f1_train 0.5970; f1_dev 0.6614; loss_train 0.1134; loss_dev 0.1088
# Ep. 1/5; It. 1600/2608; Runtime 103.11 s; Remaining runtime 3h16min36s; f1_train 0.8267; f1_dev 0.6724; loss_train 0.0807; loss_dev 0.1007
# Ep. 1/5; It. 1700/2608; Runtime 102.20 s; Remaining runtime 3h13min9s; f1_train 0.5938; f1_dev 0.5714; loss_train 0.1066; loss_dev 0.0989
# Ep. 1/5; It. 1800/2608; Runtime 102.15 s; Remaining runtime 3h11min21s; f1_train 0.7436; f1_dev 0.6903; loss_train 0.1129; loss_dev 0.1007
# Ep. 1/5; It. 1900/2608; Runtime 101.81 s; Remaining runtime 3h9min1s; f1_train 0.6984; f1_dev 0.6154; loss_train 0.1129; loss_dev 0.1024
# Ep. 1/5; It. 2000/2608; Runtime 104.03 s; Remaining runtime 3h11min24s; f1_train 0.6182; f1_dev 0.6909; loss_train 0.1051; loss_dev 0.0978
# Ep. 1/5; It. 2100/2608; Runtime 103.02 s; Remaining runtime 3h7min50s; f1_train 0.5714; f1_dev 0.5684; loss_train 0.1197; loss_dev 0.1028
# Ep. 1/5; It. 2200/2608; Runtime 105.52 s; Remaining runtime 3h10min37s; f1_train 0.4444; f1_dev 0.5275; loss_train 0.0859; loss_dev 0.0987
# Ep. 1/5; It. 2300/2608; Runtime 101.42 s; Remaining runtime 3h1min32s; f1_train 0.7143; f1_dev 0.7077; loss_train 0.1107; loss_dev 0.1049
# Ep. 1/5; It. 2400/2608; Runtime 102.31 s; Remaining runtime 3h1min25s; f1_train 0.6207; f1_dev 0.6364; loss_train 0.1019; loss_dev 0.1011
# Ep. 1/5; It. 2500/2608; Runtime 102.50 s; Remaining runtime 3h0min3s; f1_train 0.6383; f1_dev 0.5962; loss_train 0.1003; loss_dev 0.1004
# Ep. 1/5; It. 2600/2608; Runtime 102.13 s; Remaining runtime 2h57min42s; f1_train 0.6984; f1_dev 0.6061; loss_train 0.1044; loss_dev 0.1013
# Ep. 2/5; It. 0/2608; Runtime 15.45 s; Remaining runtime 0h26min51s; f1_train 0.7273; f1_dev 0.6200; loss_train 0.0822; loss_dev 0.1046
# Ep. 2/5; It. 100/2608; Runtime 102.56 s; Remaining runtime 2h56min36s; f1_train 0.6047; f1_dev 0.5941; loss_train 0.0828; loss_dev 0.1006
# Ep. 2/5; It. 200/2608; Runtime 102.83 s; Remaining runtime 2h55min21s; f1_train 0.7042; f1_dev 0.6000; loss_train 0.1040; loss_dev 0.1037
# Ep. 2/5; It. 300/2608; Runtime 102.86 s; Remaining runtime 2h53min41s; f1_train 0.4444; f1_dev 0.5918; loss_train 0.0858; loss_dev 0.1008
# Ep. 2/5; It. 400/2608; Runtime 103.04 s; Remaining runtime 2h52min16s; f1_train 0.6545; f1_dev 0.5833; loss_train 0.1055; loss_dev 0.1027
# Ep. 2/5; It. 500/2608; Runtime 102.16 s; Remaining runtime 2h49min6s; f1_train 0.7164; f1_dev 0.6226; loss_train 0.1096; loss_dev 0.0977
# Ep. 2/5; It. 600/2608; Runtime 102.28 s; Remaining runtime 2h47min35s; f1_train 0.7170; f1_dev 0.5918; loss_train 0.0957; loss_dev 0.1050
# Ep. 2/5; It. 700/2608; Runtime 102.03 s; Remaining runtime 2h45min29s; f1_train 0.6538; f1_dev 0.6111; loss_train 0.0852; loss_dev 0.0990
# Ep. 2/5; It. 800/2608; Runtime 102.96 s; Remaining runtime 2h45min16s; f1_train 0.4091; f1_dev 0.5169; loss_train 0.1391; loss_dev 0.1152
# Ep. 2/5; It. 900/2608; Runtime 104.78 s; Remaining runtime 2h46min27s; f1_train 0.6765; f1_dev 0.6078; loss_train 0.1105; loss_dev 0.1034
# Ep. 2/5; It. 1000/2608; Runtime 106.07 s; Remaining runtime 2h46min44s; f1_train 0.5238; f1_dev 0.5275; loss_train 0.1246; loss_dev 0.1033
# Ep. 2/5; It. 1100/2608; Runtime 100.82 s; Remaining runtime 2h36min48s; f1_train 0.7887; f1_dev 0.6071; loss_train 0.0761; loss_dev 0.0991
# Ep. 2/5; It. 1200/2608; Runtime 101.67 s; Remaining runtime 2h36min26s; f1_train 0.5818; f1_dev 0.6038; loss_train 0.1090; loss_dev 0.0964
# Ep. 2/5; It. 1300/2608; Runtime 102.51 s; Remaining runtime 2h36min0s; f1_train 0.7018; f1_dev 0.6139; loss_train 0.0841; loss_dev 0.1007
# Ep. 2/5; It. 1400/2608; Runtime 101.81 s; Remaining runtime 2h33min15s; f1_train 0.7692; f1_dev 0.6168; loss_train 0.0886; loss_dev 0.0990
# Ep. 2/5; It. 1500/2608; Runtime 100.38 s; Remaining runtime 2h29min26s; f1_train 0.5538; f1_dev 0.6154; loss_train 0.1553; loss_dev 0.0994
# Ep. 2/5; It. 1600/2608; Runtime 104.34 s; Remaining runtime 2h33min35s; f1_train 0.6757; f1_dev 0.6126; loss_train 0.1090; loss_dev 0.0993
# Ep. 2/5; It. 1700/2608; Runtime 104.02 s; Remaining runtime 2h31min22s; f1_train 0.6923; f1_dev 0.6122; loss_train 0.0929; loss_dev 0.1064
# Ep. 2/5; It. 1800/2608; Runtime 101.69 s; Remaining runtime 2h26min17s; f1_train 0.7042; f1_dev 0.6182; loss_train 0.1069; loss_dev 0.0950
# Ep. 2/5; It. 1900/2608; Runtime 105.03 s; Remaining runtime 2h29min20s; f1_train 0.6452; f1_dev 0.5833; loss_train 0.0968; loss_dev 0.1058
# Ep. 2/5; It. 2000/2608; Runtime 106.56 s; Remaining runtime 2h29min44s; f1_train 0.6780; f1_dev 0.6435; loss_train 0.0884; loss_dev 0.0989
# Ep. 2/5; It. 2100/2608; Runtime 101.00 s; Remaining runtime 2h20min15s; f1_train 0.5600; f1_dev 0.5714; loss_train 0.0983; loss_dev 0.0974
# Ep. 2/5; It. 2200/2608; Runtime 103.99 s; Remaining runtime 2h22min40s; f1_train 0.5938; f1_dev 0.6476; loss_train 0.1145; loss_dev 0.0916
# Ep. 2/5; It. 2300/2608; Runtime 101.32 s; Remaining runtime 2h17min19s; f1_train 0.5714; f1_dev 0.6606; loss_train 0.1333; loss_dev 0.0928
# Ep. 2/5; It. 2400/2608; Runtime 103.42 s; Remaining runtime 2h18min26s; f1_train 0.5652; f1_dev 0.6609; loss_train 0.1050; loss_dev 0.1032
# Ep. 2/5; It. 2500/2608; Runtime 102.82 s; Remaining runtime 2h15min55s; f1_train 0.6923; f1_dev 0.6408; loss_train 0.0762; loss_dev 0.0982
# Ep. 2/5; It. 2600/2608; Runtime 101.44 s; Remaining runtime 2h12min24s; f1_train 0.6563; f1_dev 0.5981; loss_train 0.1275; loss_dev 0.0959
# Ep. 3/5; It. 0/2608; Runtime 13.60 s; Remaining runtime 0h17min44s; f1_train 0.6038; f1_dev 0.5773; loss_train 0.0868; loss_dev 0.0950
# Ep. 3/5; It. 100/2608; Runtime 103.38 s; Remaining runtime 2h13min5s; f1_train 0.6780; f1_dev 0.5625; loss_train 0.0966; loss_dev 0.0962
# Ep. 3/5; It. 200/2608; Runtime 101.69 s; Remaining runtime 2h9min13s; f1_train 0.6667; f1_dev 0.6491; loss_train 0.1300; loss_dev 0.0956
# Ep. 3/5; It. 300/2608; Runtime 104.48 s; Remaining runtime 2h11min1s; f1_train 0.6000; f1_dev 0.5684; loss_train 0.0704; loss_dev 0.0989
# Ep. 3/5; It. 400/2608; Runtime 103.00 s; Remaining runtime 2h7min27s; f1_train 0.8475; f1_dev 0.6667; loss_train 0.0648; loss_dev 0.0969
# Ep. 3/5; It. 500/2608; Runtime 101.21 s; Remaining runtime 2h3min32s; f1_train 0.6875; f1_dev 0.6609; loss_train 0.0930; loss_dev 0.0971
# Ep. 3/5; It. 600/2608; Runtime 102.50 s; Remaining runtime 2h3min24s; f1_train 0.6531; f1_dev 0.6667; loss_train 0.0951; loss_dev 0.0965
# Ep. 3/5; It. 700/2608; Runtime 103.02 s; Remaining runtime 2h2min18s; f1_train 0.6522; f1_dev 0.6286; loss_train 0.0934; loss_dev 0.0975
# Ep. 3/5; It. 800/2608; Runtime 101.85 s; Remaining runtime 1h59min13s; f1_train 0.7500; f1_dev 0.6604; loss_train 0.0762; loss_dev 0.0969
# Ep. 3/5; It. 900/2608; Runtime 101.76 s; Remaining runtime 1h57min26s; f1_train 0.7234; f1_dev 0.5657; loss_train 0.0508; loss_dev 0.0983
# Ep. 3/5; It. 1000/2608; Runtime 107.01 s; Remaining runtime 2h1min42s; f1_train 0.6250; f1_dev 0.6019; loss_train 0.0849; loss_dev 0.0956
# Ep. 3/5; It. 1100/2608; Runtime 103.08 s; Remaining runtime 1h55min31s; f1_train 0.7778; f1_dev 0.6296; loss_train 0.0798; loss_dev 0.0963
# Ep. 3/5; It. 1200/2608; Runtime 102.89 s; Remaining runtime 1h53min35s; f1_train 0.7556; f1_dev 0.6545; loss_train 0.0708; loss_dev 0.1040
# Ep. 3/5; It. 1300/2608; Runtime 101.70 s; Remaining runtime 1h50min34s; f1_train 0.5517; f1_dev 0.6296; loss_train 0.0893; loss_dev 0.1009
# Ep. 3/5; It. 1400/2608; Runtime 102.82 s; Remaining runtime 1h50min5s; f1_train 0.5714; f1_dev 0.6476; loss_train 0.1033; loss_dev 0.0926
# Ep. 3/5; It. 1500/2608; Runtime 101.21 s; Remaining runtime 1h46min40s; f1_train 0.5769; f1_dev 0.6471; loss_train 0.0989; loss_dev 0.0953
# Ep. 3/5; It. 1600/2608; Runtime 102.61 s; Remaining runtime 1h46min26s; f1_train 0.6552; f1_dev 0.6549; loss_train 0.1074; loss_dev 0.0924
# Ep. 3/5; It. 1700/2608; Runtime 104.27 s; Remaining runtime 1h46min25s; f1_train 0.7347; f1_dev 0.6226; loss_train 0.0667; loss_dev 0.0985
# Ep. 3/5; It. 1800/2608; Runtime 101.70 s; Remaining runtime 1h42min6s; f1_train 0.6250; f1_dev 0.6545; loss_train 0.0808; loss_dev 0.0972
# Ep. 3/5; It. 1900/2608; Runtime 101.06 s; Remaining runtime 1h39min46s; f1_train 0.5714; f1_dev 0.5657; loss_train 0.0931; loss_dev 0.0976
# Ep. 3/5; It. 2000/2608; Runtime 106.24 s; Remaining runtime 1h43min7s; f1_train 0.5882; f1_dev 0.6095; loss_train 0.0963; loss_dev 0.0974
# Ep. 3/5; It. 2100/2608; Runtime 102.66 s; Remaining runtime 1h37min56s; f1_train 0.6567; f1_dev 0.6609; loss_train 0.1084; loss_dev 0.0953
# Ep. 3/5; It. 2200/2608; Runtime 103.58 s; Remaining runtime 1h37min5s; f1_train 0.6471; f1_dev 0.6239; loss_train 0.1248; loss_dev 0.0954
# Ep. 3/5; It. 2300/2608; Runtime 103.00 s; Remaining runtime 1h34min49s; f1_train 0.7568; f1_dev 0.6415; loss_train 0.1058; loss_dev 0.0969
# Ep. 3/5; It. 2400/2608; Runtime 103.33 s; Remaining runtime 1h33min24s; f1_train 0.7463; f1_dev 0.6441; loss_train 0.1159; loss_dev 0.0948
# Ep. 3/5; It. 2500/2608; Runtime 102.91 s; Remaining runtime 1h31min19s; f1_train 0.7083; f1_dev 0.6226; loss_train 0.0828; loss_dev 0.0991
# Ep. 3/5; It. 2600/2608; Runtime 102.52 s; Remaining runtime 1h29min15s; f1_train 0.6500; f1_dev 0.6355; loss_train 0.0728; loss_dev 0.0949
# Ep. 4/5; It. 0/2608; Runtime 13.52 s; Remaining runtime 0h11min45s; f1_train 0.7500; f1_dev 0.6061; loss_train 0.0881; loss_dev 0.0979
# Ep. 4/5; It. 100/2608; Runtime 101.44 s; Remaining runtime 1h26min29s; f1_train 0.6753; f1_dev 0.6078; loss_train 0.1043; loss_dev 0.1018
# Ep. 4/5; It. 200/2608; Runtime 103.50 s; Remaining runtime 1h26min31s; f1_train 0.7692; f1_dev 0.6061; loss_train 0.0772; loss_dev 0.1007
# Ep. 4/5; It. 300/2608; Runtime 104.01 s; Remaining runtime 1h25min12s; f1_train 0.6538; f1_dev 0.6195; loss_train 0.0822; loss_dev 0.0998
# Ep. 4/5; It. 400/2608; Runtime 102.03 s; Remaining runtime 1h21min53s; f1_train 0.8000; f1_dev 0.5926; loss_train 0.0600; loss_dev 0.1015
# Ep. 4/5; It. 500/2608; Runtime 102.71 s; Remaining runtime 1h20min43s; f1_train 0.5902; f1_dev 0.6126; loss_train 0.1105; loss_dev 0.0977
# Ep. 4/5; It. 600/2608; Runtime 102.67 s; Remaining runtime 1h18min59s; f1_train 0.7317; f1_dev 0.6718; loss_train 0.1027; loss_dev 0.1008
# Ep. 4/5; It. 700/2608; Runtime 100.25 s; Remaining runtime 1h15min27s; f1_train 0.7391; f1_dev 0.6372; loss_train 0.0492; loss_dev 0.0968
# Ep. 4/5; It. 800/2608; Runtime 102.35 s; Remaining runtime 1h15min19s; f1_train 0.6800; f1_dev 0.5981; loss_train 0.0713; loss_dev 0.1003
# Ep. 4/5; It. 900/2608; Runtime 102.78 s; Remaining runtime 1h13min56s; f1_train 0.6441; f1_dev 0.6195; loss_train 0.1074; loss_dev 0.1011
# Ep. 4/5; It. 1000/2608; Runtime 104.03 s; Remaining runtime 1h13min6s; f1_train 0.6567; f1_dev 0.6833; loss_train 0.0931; loss_dev 0.0998
# Ep. 4/5; It. 1100/2608; Runtime 103.38 s; Remaining runtime 1h10min55s; f1_train 0.7931; f1_dev 0.6261; loss_train 0.0540; loss_dev 0.0993
# Ep. 4/5; It. 1200/2608; Runtime 104.04 s; Remaining runtime 1h9min38s; f1_train 0.8358; f1_dev 0.6071; loss_train 0.0755; loss_dev 0.1024
# Ep. 4/5; It. 1300/2608; Runtime 103.25 s; Remaining runtime 1h7min23s; f1_train 0.5517; f1_dev 0.6038; loss_train 0.1080; loss_dev 0.0982
# Ep. 4/5; It. 1400/2608; Runtime 102.70 s; Remaining runtime 1h5min19s; f1_train 0.6316; f1_dev 0.6139; loss_train 0.0797; loss_dev 0.0942
# Ep. 4/5; It. 1500/2608; Runtime 102.29 s; Remaining runtime 1h3min21s; f1_train 0.6667; f1_dev 0.5962; loss_train 0.0747; loss_dev 0.0974
# Ep. 4/5; It. 1600/2608; Runtime 101.18 s; Remaining runtime 1h0min58s; f1_train 0.5946; f1_dev 0.6286; loss_train 0.0733; loss_dev 0.1018
# Ep. 4/5; It. 1700/2608; Runtime 102.75 s; Remaining runtime 1h0min12s; f1_train 0.7170; f1_dev 0.6078; loss_train 0.0737; loss_dev 0.1020
# Ep. 4/5; It. 1800/2608; Runtime 104.14 s; Remaining runtime 0h59min17s; f1_train 0.7368; f1_dev 0.6355; loss_train 0.0889; loss_dev 0.0957
# Ep. 4/5; It. 1900/2608; Runtime 103.06 s; Remaining runtime 0h56min57s; f1_train 0.7586; f1_dev 0.6239; loss_train 0.0743; loss_dev 0.0941
# Ep. 4/5; It. 2000/2608; Runtime 106.02 s; Remaining runtime 0h56min49s; f1_train 0.6000; f1_dev 0.6214; loss_train 0.0877; loss_dev 0.1052
# Ep. 4/5; It. 2100/2608; Runtime 104.58 s; Remaining runtime 0h54min18s; f1_train 0.7879; f1_dev 0.6261; loss_train 0.0680; loss_dev 0.1064
# Ep. 4/5; It. 2200/2608; Runtime 101.43 s; Remaining runtime 0h50min59s; f1_train 0.6557; f1_dev 0.6429; loss_train 0.0843; loss_dev 0.0975
# Ep. 4/5; It. 2300/2608; Runtime 101.99 s; Remaining runtime 0h49min34s; f1_train 0.7812; f1_dev 0.6379; loss_train 0.0702; loss_dev 0.0992
# Ep. 4/5; It. 2400/2608; Runtime 101.76 s; Remaining runtime 0h47min45s; f1_train 0.7949; f1_dev 0.6481; loss_train 0.0836; loss_dev 0.1017
# Ep. 4/5; It. 2500/2608; Runtime 103.85 s; Remaining runtime 0h47min0s; f1_train 0.7636; f1_dev 0.6422; loss_train 0.0700; loss_dev 0.0945
# Ep. 4/5; It. 2600/2608; Runtime 102.21 s; Remaining runtime 0h44min33s; f1_train 0.7636; f1_dev 0.6182; loss_train 0.0660; loss_dev 0.0962
# Ep. 5/5; It. 0/2608; Runtime 14.50 s; Remaining runtime 0h6min18s; f1_train 0.7647; f1_dev 0.6387; loss_train 0.0843; loss_dev 0.1004
# Ep. 5/5; It. 100/2608; Runtime 101.89 s; Remaining runtime 0h42min35s; f1_train 0.7586; f1_dev 0.6306; loss_train 0.0643; loss_dev 0.1001
# Ep. 5/5; It. 200/2608; Runtime 102.75 s; Remaining runtime 0h41min14s; f1_train 0.7619; f1_dev 0.6783; loss_train 0.0613; loss_dev 0.1052
# Ep. 5/5; It. 300/2608; Runtime 102.28 s; Remaining runtime 0h39min20s; f1_train 0.6792; f1_dev 0.6609; loss_train 0.0873; loss_dev 0.1001
# Ep. 5/5; It. 400/2608; Runtime 103.73 s; Remaining runtime 0h38min10s; f1_train 0.7541; f1_dev 0.6226; loss_train 0.0753; loss_dev 0.1020
# Ep. 5/5; It. 500/2608; Runtime 101.99 s; Remaining runtime 0h35min50s; f1_train 0.8158; f1_dev 0.6372; loss_train 0.0887; loss_dev 0.1069
# Ep. 5/5; It. 600/2608; Runtime 103.16 s; Remaining runtime 0h34min31s; f1_train 0.7647; f1_dev 0.6126; loss_train 0.0899; loss_dev 0.1069
# Ep. 5/5; It. 700/2608; Runtime 102.68 s; Remaining runtime 0h32min39s; f1_train 0.7059; f1_dev 0.6545; loss_train 0.0719; loss_dev 0.1018
# Ep. 5/5; It. 800/2608; Runtime 102.29 s; Remaining runtime 0h30min49s; f1_train 0.8621; f1_dev 0.6019; loss_train 0.0696; loss_dev 0.1047
# Ep. 5/5; It. 900/2608; Runtime 100.46 s; Remaining runtime 0h28min35s; f1_train 0.7941; f1_dev 0.6261; loss_train 0.0765; loss_dev 0.1041
# Ep. 5/5; It. 1000/2608; Runtime 108.49 s; Remaining runtime 0h29min4s; f1_train 0.7458; f1_dev 0.6364; loss_train 0.0757; loss_dev 0.0974
# Ep. 5/5; It. 1100/2608; Runtime 103.41 s; Remaining runtime 0h25min59s; f1_train 0.7451; f1_dev 0.6226; loss_train 0.0566; loss_dev 0.1048
# Ep. 5/5; It. 1200/2608; Runtime 102.16 s; Remaining runtime 0h23min58s; f1_train 0.6552; f1_dev 0.6372; loss_train 0.0712; loss_dev 0.0983
# Ep. 5/5; It. 1300/2608; Runtime 101.65 s; Remaining runtime 0h22min9s; f1_train 0.7143; f1_dev 0.6038; loss_train 0.1019; loss_dev 0.0937
# Ep. 5/5; It. 1400/2608; Runtime 101.07 s; Remaining runtime 0h20min20s; f1_train 0.7500; f1_dev 0.5741; loss_train 0.0959; loss_dev 0.1082
# Ep. 5/5; It. 1500/2608; Runtime 101.50 s; Remaining runtime 0h18min44s; f1_train 0.8889; f1_dev 0.5714; loss_train 0.0519; loss_dev 0.1010
# Ep. 5/5; It. 1600/2608; Runtime 103.20 s; Remaining runtime 0h17min20s; f1_train 0.7000; f1_dev 0.5862; loss_train 0.0951; loss_dev 0.0986
# Ep. 5/5; It. 1700/2608; Runtime 102.06 s; Remaining runtime 0h15min26s; f1_train 0.7222; f1_dev 0.5825; loss_train 0.1023; loss_dev 0.0989
# Ep. 5/5; It. 1800/2608; Runtime 101.76 s; Remaining runtime 0h13min42s; f1_train 0.7692; f1_dev 0.6549; loss_train 0.0612; loss_dev 0.0977
# Ep. 5/5; It. 1900/2608; Runtime 102.75 s; Remaining runtime 0h12min7s; f1_train 0.6792; f1_dev 0.6555; loss_train 0.0846; loss_dev 0.0979
# Ep. 5/5; It. 2000/2608; Runtime 105.59 s; Remaining runtime 0h10min41s; f1_train 0.8529; f1_dev 0.6500; loss_train 0.0648; loss_dev 0.1036
# Ep. 5/5; It. 2100/2608; Runtime 105.76 s; Remaining runtime 0h8min57s; f1_train 0.7463; f1_dev 0.6296; loss_train 0.0843; loss_dev 0.0978
# Ep. 5/5; It. 2200/2608; Runtime 102.20 s; Remaining runtime 0h6min56s; f1_train 0.7667; f1_dev 0.6261; loss_train 0.0736; loss_dev 0.1002
# Ep. 5/5; It. 2300/2608; Runtime 102.99 s; Remaining runtime 0h5min17s; f1_train 0.8125; f1_dev 0.6607; loss_train 0.0739; loss_dev 0.0963
# Ep. 5/5; It. 2400/2608; Runtime 103.31 s; Remaining runtime 0h3min34s; f1_train 0.7671; f1_dev 0.5849; loss_train 0.0881; loss_dev 0.1045
# Ep. 5/5; It. 2500/2608; Runtime 103.17 s; Remaining runtime 0h1min51s; f1_train 0.7143; f1_dev 0.6207; loss_train 0.0792; loss_dev 0.1002
# Ep. 5/5; It. 2600/2608; Runtime 102.45 s; Remaining runtime 0h0min8s; f1_train 0.7213; f1_dev 0.6557; loss_train 0.0765; loss_dev 0.0973
# Total actual runtime: 3 hours 44 min 13 sec

# %%
MODELS_FILE = "models/model3.2.1/QIQC_model3.2.1.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set, seq_len: X_cv_lengths})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model3.2.1/QIQC_model3.2.1.ckpt
# cross val f1 59.68%, dev f1 61.11%
