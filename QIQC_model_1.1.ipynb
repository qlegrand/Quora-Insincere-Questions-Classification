# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_inputs = 300
n_neurons = 500
n_fc1 = 500
n_fc2 = 200
n_output = 1
learning_rate = 0.01
activation_fn = tf.nn.elu
k_initializer = tf.contrib.layers.variance_scaling_initializer

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = tf.contrib.rnn.LSTMCell(num_units=n_neurons, name="LSTM")
    h_states, states = tf.nn.dynamic_rnn(lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len)

with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states[0], n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc2, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs//run-{}//".format(now)
MODELS_FILE = "models/model1.1/QIQC_model1.1.ckpt"
MODELS_INDEX = "models/model1.1/QIQC_model1.1.ckpt.index"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
modind = os.path.join(DRIVE_PATH,MODELS_INDEX)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

with tf.Session() as sess:
    #if os.path.isfile(modind):
    #    saver.restore(sess, modfil)
    #else:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths})

            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                step = epoch * QIQC.nr_batches + iteration
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                t_1 = time.time()
                t_delta = t_1 - t_0
                t_0 = t_1
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                print("Epoch {}/{}; iteration {}/{}; runtime {:2f} sec, f1_train {:4f}; f1_dev {:4f}; loss_train {:4f}; loss_dev {:4f}".format(epoch, n_epoch, iteration, QIQC.nr_batches, t_delta,f1_train,f1_dev,loss_train,loss_dev))
# Out:
# Epoch 0/5; iteration 0/2608; runtime 5.765893 sec, f1_train  nan; f1_dev  nan; loss_train 6.336743; loss_dev 5.759160
# Epoch 0/5; iteration 100/2608; runtime 26.775103 sec, f1_train 0.074074; f1_dev 0.117647; loss_train 0.162849; loss_dev 0.189683
# Epoch 0/5; iteration 200/2608; runtime 25.689469 sec, f1_train 0.432432; f1_dev 0.282051; loss_train 0.137160; loss_dev 0.129796
# Epoch 0/5; iteration 300/2608; runtime 25.976440 sec, f1_train 0.258065; f1_dev 0.093750; loss_train 0.118102; loss_dev 0.141942
# Epoch 0/5; iteration 400/2608; runtime 25.990555 sec, f1_train 0.571429; f1_dev 0.518519; loss_train 0.152548; loss_dev 0.123310
# Epoch 0/5; iteration 500/2608; runtime 25.921961 sec, f1_train 0.206897; f1_dev 0.285714; loss_train 0.120788; loss_dev 0.129297
# Epoch 0/5; iteration 600/2608; runtime 25.602930 sec, f1_train 0.506667; f1_dev 0.458333; loss_train 0.177273; loss_dev 0.118795
# Epoch 0/5; iteration 700/2608; runtime 26.865388 sec, f1_train 0.461538; f1_dev 0.525253; loss_train 0.143785; loss_dev 0.115395
# Epoch 0/5; iteration 800/2608; runtime 25.837809 sec, f1_train 0.555556; f1_dev 0.370370; loss_train 0.084162; loss_dev 0.121929
# Epoch 0/5; iteration 900/2608; runtime 26.335323 sec, f1_train 0.421053; f1_dev 0.423529; loss_train 0.107392; loss_dev 0.121792
# Epoch 0/5; iteration 1000/2608; runtime 29.546500 sec, f1_train 0.380952; f1_dev 0.488889; loss_train 0.113318; loss_dev 0.121291
# Epoch 0/5; iteration 1100/2608; runtime 26.605150 sec, f1_train 0.277778; f1_dev 0.404762; loss_train 0.111011; loss_dev 0.126629
# Epoch 0/5; iteration 1200/2608; runtime 26.164274 sec, f1_train 0.545455; f1_dev 0.510638; loss_train 0.104189; loss_dev 0.114708
# Epoch 0/5; iteration 1300/2608; runtime 25.803604 sec, f1_train 0.610169; f1_dev 0.561983; loss_train 0.123980; loss_dev 0.121265
# Epoch 0/5; iteration 1400/2608; runtime 25.615186 sec, f1_train 0.553191; f1_dev 0.536082; loss_train 0.104894; loss_dev 0.120591
# Epoch 0/5; iteration 1500/2608; runtime 26.059605 sec, f1_train 0.553191; f1_dev 0.494845; loss_train 0.118250; loss_dev 0.111986
# Epoch 0/5; iteration 1600/2608; runtime 25.970166 sec, f1_train 0.760563; f1_dev 0.558559; loss_train 0.093062; loss_dev 0.111942
# Epoch 0/5; iteration 1700/2608; runtime 25.720790 sec, f1_train 0.531250; f1_dev 0.545455; loss_train 0.114863; loss_dev 0.109776
# Epoch 0/5; iteration 1800/2608; runtime 25.972008 sec, f1_train 0.656250; f1_dev 0.409639; loss_train 0.129680; loss_dev 0.114401
# Epoch 0/5; iteration 1900/2608; runtime 25.697367 sec, f1_train 0.689655; f1_dev 0.571429; loss_train 0.115675; loss_dev 0.112192
# Epoch 0/5; iteration 2000/2608; runtime 28.371576 sec, f1_train 0.277778; f1_dev 0.297297; loss_train 0.132736; loss_dev 0.117102
# Epoch 0/5; iteration 2100/2608; runtime 26.766827 sec, f1_train 0.575342; f1_dev 0.610169; loss_train 0.133459; loss_dev 0.114914
# Epoch 0/5; iteration 2200/2608; runtime 26.602782 sec, f1_train 0.387097; f1_dev 0.409639; loss_train 0.080025; loss_dev 0.111679
# Epoch 0/5; iteration 2300/2608; runtime 25.772865 sec, f1_train 0.677419; f1_dev 0.631579; loss_train 0.099555; loss_dev 0.108512
# Epoch 0/5; iteration 2400/2608; runtime 26.130991 sec, f1_train 0.603774; f1_dev 0.623853; loss_train 0.104639; loss_dev 0.107406
# Epoch 0/5; iteration 2500/2608; runtime 25.773677 sec, f1_train 0.595745; f1_dev 0.557692; loss_train 0.103490; loss_dev 0.105475
# Epoch 0/5; iteration 2600/2608; runtime 25.644151 sec, f1_train 0.526316; f1_dev 0.516854; loss_train 0.125456; loss_dev 0.113056
# Epoch 1/5; iteration 0/2608; runtime 8.384248 sec, f1_train 0.653061; f1_dev 0.500000; loss_train 0.078031; loss_dev 0.111019
# Epoch 1/5; iteration 100/2608; runtime 26.266072 sec, f1_train 0.625000; f1_dev 0.596154; loss_train 0.094318; loss_dev 0.107248
# Epoch 1/5; iteration 200/2608; runtime 25.857217 sec, f1_train 0.567164; f1_dev 0.582524; loss_train 0.110591; loss_dev 0.106891
# Epoch 1/5; iteration 300/2608; runtime 26.083427 sec, f1_train 0.230769; f1_dev 0.228571; loss_train 0.105548; loss_dev 0.136734
# Epoch 1/5; iteration 400/2608; runtime 25.902311 sec, f1_train 0.629630; f1_dev 0.612613; loss_train 0.111086; loss_dev 0.109337
# Epoch 1/5; iteration 500/2608; runtime 25.693381 sec, f1_train 0.561404; f1_dev 0.648148; loss_train 0.115542; loss_dev 0.102977
# Epoch 1/5; iteration 600/2608; runtime 26.005121 sec, f1_train 0.615385; f1_dev 0.627451; loss_train 0.111738; loss_dev 0.103551
# Epoch 1/5; iteration 700/2608; runtime 25.642708 sec, f1_train 0.627451; f1_dev 0.555556; loss_train 0.097451; loss_dev 0.110424
# Epoch 1/5; iteration 800/2608; runtime 25.854789 sec, f1_train 0.400000; f1_dev 0.556701; loss_train 0.144009; loss_dev 0.111934
# Epoch 1/5; iteration 900/2608; runtime 26.637956 sec, f1_train 0.704225; f1_dev 0.591837; loss_train 0.111676; loss_dev 0.107468
# Epoch 1/5; iteration 1000/2608; runtime 29.638297 sec, f1_train 0.545455; f1_dev 0.661290; loss_train 0.130243; loss_dev 0.104207
# Epoch 1/5; iteration 1100/2608; runtime 25.849123 sec, f1_train 0.787879; f1_dev 0.605505; loss_train 0.081556; loss_dev 0.102961
# Epoch 1/5; iteration 1200/2608; runtime 25.892358 sec, f1_train 0.324324; f1_dev 0.320000; loss_train 0.119838; loss_dev 0.112059
# Epoch 1/5; iteration 1300/2608; runtime 25.816503 sec, f1_train 0.703704; f1_dev 0.585859; loss_train 0.091201; loss_dev 0.104572
# Epoch 1/5; iteration 1400/2608; runtime 25.663779 sec, f1_train 0.735294; f1_dev 0.626087; loss_train 0.105656; loss_dev 0.103101
# Epoch 1/5; iteration 1500/2608; runtime 25.558159 sec, f1_train 0.461538; f1_dev 0.637168; loss_train 0.175151; loss_dev 0.106450
# Epoch 1/5; iteration 1600/2608; runtime 26.121261 sec, f1_train 0.666667; f1_dev 0.642202; loss_train 0.110433; loss_dev 0.098823
# Epoch 1/5; iteration 1700/2608; runtime 26.057225 sec, f1_train 0.629630; f1_dev 0.603448; loss_train 0.105066; loss_dev 0.116470
# Epoch 1/5; iteration 1800/2608; runtime 25.864222 sec, f1_train 0.646154; f1_dev 0.582524; loss_train 0.111320; loss_dev 0.099596
# Epoch 1/5; iteration 1900/2608; runtime 26.362970 sec, f1_train 0.727273; f1_dev 0.629630; loss_train 0.095307; loss_dev 0.103281
# Epoch 1/5; iteration 2000/2608; runtime 29.016056 sec, f1_train 0.677966; f1_dev 0.648148; loss_train 0.085832; loss_dev 0.099633
# Epoch 1/5; iteration 2100/2608; runtime 26.268054 sec, f1_train 0.583333; f1_dev 0.580645; loss_train 0.104436; loss_dev 0.106343
# Epoch 1/5; iteration 2200/2608; runtime 26.147546 sec, f1_train 0.582278; f1_dev 0.666667; loss_train 0.133118; loss_dev 0.105173
# Epoch 1/5; iteration 2300/2608; runtime 25.528126 sec, f1_train 0.591549; f1_dev 0.661157; loss_train 0.144837; loss_dev 0.098391
# Epoch 1/5; iteration 2400/2608; runtime 26.421825 sec, f1_train 0.533333; f1_dev 0.660550; loss_train 0.106785; loss_dev 0.097205
# Epoch 1/5; iteration 2500/2608; runtime 25.862406 sec, f1_train 0.690909; f1_dev 0.611111; loss_train 0.087050; loss_dev 0.099465
# Epoch 1/5; iteration 2600/2608; runtime 25.490388 sec, f1_train 0.676471; f1_dev 0.611111; loss_train 0.122831; loss_dev 0.101485
# Epoch 2/5; iteration 0/2608; runtime 6.380990 sec, f1_train 0.656716; f1_dev 0.636364; loss_train 0.108196; loss_dev 0.101913
# Epoch 2/5; iteration 100/2608; runtime 26.397871 sec, f1_train 0.644068; f1_dev 0.591837; loss_train 0.100028; loss_dev 0.094728
# Epoch 2/5; iteration 200/2608; runtime 25.622110 sec, f1_train 0.566667; f1_dev 0.613861; loss_train 0.161190; loss_dev 0.097437
# Epoch 2/5; iteration 300/2608; runtime 26.471145 sec, f1_train 0.705882; f1_dev 0.612245; loss_train 0.076189; loss_dev 0.102770
# Epoch 2/5; iteration 400/2608; runtime 25.921852 sec, f1_train 0.771930; f1_dev 0.607843; loss_train 0.073800; loss_dev 0.115430
# Epoch 2/5; iteration 500/2608; runtime 25.455798 sec, f1_train 0.684932; f1_dev 0.639344; loss_train 0.122624; loss_dev 0.113178
# Epoch 2/5; iteration 600/2608; runtime 26.129058 sec, f1_train 0.550000; f1_dev 0.452381; loss_train 0.104293; loss_dev 0.118973
# Epoch 2/5; iteration 700/2608; runtime 25.802088 sec, f1_train 0.512821; f1_dev 0.549451; loss_train 0.106932; loss_dev 0.106803
# Epoch 2/5; iteration 800/2608; runtime 25.607605 sec, f1_train 0.758621; f1_dev 0.605505; loss_train 0.079034; loss_dev 0.103462
# Epoch 2/5; iteration 900/2608; runtime 25.948254 sec, f1_train 0.588235; f1_dev 0.405063; loss_train 0.067316; loss_dev 0.117181
# Epoch 2/5; iteration 1000/2608; runtime 28.916295 sec, f1_train 0.432432; f1_dev 0.470588; loss_train 0.110156; loss_dev 0.120818
# Epoch 2/5; iteration 1100/2608; runtime 26.482606 sec, f1_train 0.740741; f1_dev 0.641791; loss_train 0.113417; loss_dev 0.117533
# Epoch 2/5; iteration 1200/2608; runtime 26.245168 sec, f1_train 0.648649; f1_dev 0.559140; loss_train 0.073433; loss_dev 0.101997
# Epoch 2/5; iteration 1300/2608; runtime 25.653337 sec, f1_train 0.634921; f1_dev 0.690909; loss_train 0.095364; loss_dev 0.096091
# Epoch 2/5; iteration 1400/2608; runtime 25.960123 sec, f1_train 0.590164; f1_dev 0.588235; loss_train 0.123158; loss_dev 0.113616
# Epoch 2/5; iteration 1500/2608; runtime 25.847603 sec, f1_train 0.677419; f1_dev 0.654867; loss_train 0.103332; loss_dev 0.100614
# Epoch 2/5; iteration 1600/2608; runtime 25.843383 sec, f1_train 0.615385; f1_dev 0.630631; loss_train 0.112048; loss_dev 0.101243
# Epoch 2/5; iteration 1700/2608; runtime 26.219526 sec, f1_train 0.708333; f1_dev 0.616822; loss_train 0.070112; loss_dev 0.101978
# Epoch 2/5; iteration 1800/2608; runtime 25.995798 sec, f1_train 0.565217; f1_dev 0.601942; loss_train 0.094900; loss_dev 0.107502
# Epoch 2/5; iteration 1900/2608; runtime 25.490977 sec, f1_train 0.653061; f1_dev 0.627451; loss_train 0.096138; loss_dev 0.100659
# Epoch 2/5; iteration 2000/2608; runtime 28.426674 sec, f1_train 0.528302; f1_dev 0.661157; loss_train 0.114087; loss_dev 0.105898
# Epoch 2/5; iteration 2100/2608; runtime 26.633861 sec, f1_train 0.730159; f1_dev 0.642202; loss_train 0.107836; loss_dev 0.094477
# Epoch 2/5; iteration 2200/2608; runtime 26.044694 sec, f1_train 0.391304; f1_dev 0.444444; loss_train 0.122705; loss_dev 0.110431
# Epoch 2/5; iteration 2300/2608; runtime 25.919288 sec, f1_train 0.761905; f1_dev 0.606061; loss_train 0.108169; loss_dev 0.111538
# Epoch 2/5; iteration 2400/2608; runtime 26.297449 sec, f1_train 0.641509; f1_dev 0.600000; loss_train 0.118857; loss_dev 0.106543
# Epoch 2/5; iteration 2500/2608; runtime 25.921628 sec, f1_train 0.693878; f1_dev 0.600000; loss_train 0.092416; loss_dev 0.102936
# Epoch 2/5; iteration 2600/2608; runtime 25.771461 sec, f1_train 0.615385; f1_dev 0.628571; loss_train 0.071948; loss_dev 0.098880
# Epoch 3/5; iteration 0/2608; runtime 7.496289 sec, f1_train 0.698413; f1_dev 0.649123; loss_train 0.100857; loss_dev 0.098985
# Epoch 3/5; iteration 100/2608; runtime 26.192702 sec, f1_train 0.734177; f1_dev 0.618182; loss_train 0.113644; loss_dev 0.098779
# Epoch 3/5; iteration 200/2608; runtime 26.039538 sec, f1_train 0.738095; f1_dev 0.620155; loss_train 0.102648; loss_dev 0.106704
# Epoch 3/5; iteration 300/2608; runtime 26.486545 sec, f1_train 0.603774; f1_dev 0.635514; loss_train 0.082001; loss_dev 0.101442
# Epoch 3/5; iteration 400/2608; runtime 25.768367 sec, f1_train 0.758621; f1_dev 0.613861; loss_train 0.068634; loss_dev 0.101145
# Epoch 3/5; iteration 500/2608; runtime 25.817564 sec, f1_train 0.562500; f1_dev 0.623853; loss_train 0.121136; loss_dev 0.100155
# Epoch 3/5; iteration 600/2608; runtime 26.111921 sec, f1_train 0.600000; f1_dev 0.649573; loss_train 0.117683; loss_dev 0.097175
# Epoch 3/5; iteration 700/2608; runtime 25.399994 sec, f1_train 0.631579; f1_dev 0.627451; loss_train 0.058338; loss_dev 0.100792
# Epoch 3/5; iteration 800/2608; runtime 25.787772 sec, f1_train 0.653061; f1_dev 0.672727; loss_train 0.085233; loss_dev 0.103947
# Epoch 3/5; iteration 900/2608; runtime 26.101383 sec, f1_train 0.679245; f1_dev 0.642202; loss_train 0.111936; loss_dev 0.099394
# Epoch 3/5; iteration 1000/2608; runtime 27.915110 sec, f1_train 0.634921; f1_dev 0.644628; loss_train 0.103594; loss_dev 0.101423
# Epoch 3/5; iteration 1100/2608; runtime 26.506009 sec, f1_train 0.690909; f1_dev 0.661017; loss_train 0.060414; loss_dev 0.100403
# Epoch 3/5; iteration 1200/2608; runtime 26.577277 sec, f1_train 0.812500; f1_dev 0.615385; loss_train 0.078590; loss_dev 0.108109
# Epoch 3/5; iteration 1300/2608; runtime 26.061838 sec, f1_train 0.452830; f1_dev 0.585859; loss_train 0.110934; loss_dev 0.104028
# Epoch 3/5; iteration 1400/2608; runtime 25.908314 sec, f1_train 0.500000; f1_dev 0.405063; loss_train 0.084140; loss_dev 0.106392
# Epoch 3/5; iteration 1500/2608; runtime 26.114181 sec, f1_train 0.638298; f1_dev 0.597938; loss_train 0.084081; loss_dev 0.105962
# Epoch 3/5; iteration 1600/2608; runtime 25.600293 sec, f1_train 0.666667; f1_dev 0.539326; loss_train 0.075129; loss_dev 0.105861
# Epoch 3/5; iteration 1700/2608; runtime 25.846574 sec, f1_train 0.641509; f1_dev 0.597938; loss_train 0.090845; loss_dev 0.109628
# Epoch 3/5; iteration 1800/2608; runtime 26.490945 sec, f1_train 0.718750; f1_dev 0.637168; loss_train 0.092283; loss_dev 0.103730
# Epoch 3/5; iteration 1900/2608; runtime 25.914842 sec, f1_train 0.553191; f1_dev 0.565657; loss_train 0.078736; loss_dev 0.105655
# Epoch 3/5; iteration 2000/2608; runtime 28.193818 sec, f1_train 0.627451; f1_dev 0.574074; loss_train 0.089227; loss_dev 0.100267
# Epoch 3/5; iteration 2100/2608; runtime 26.974353 sec, f1_train 0.736842; f1_dev 0.590476; loss_train 0.077635; loss_dev 0.101417
# Epoch 3/5; iteration 2200/2608; runtime 25.587936 sec, f1_train 0.588235; f1_dev 0.601626; loss_train 0.113343; loss_dev 0.103745
# Epoch 3/5; iteration 2300/2608; runtime 25.646334 sec, f1_train 0.703704; f1_dev 0.537634; loss_train 0.069990; loss_dev 0.108131
# Epoch 3/5; iteration 2400/2608; runtime 25.890815 sec, f1_train 0.508475; f1_dev 0.516854; loss_train 0.104027; loss_dev 0.109454
# Epoch 3/5; iteration 2500/2608; runtime 26.152966 sec, f1_train 0.368421; f1_dev 0.400000; loss_train 0.084028; loss_dev 0.114600
# Epoch 3/5; iteration 2600/2608; runtime 25.714659 sec, f1_train 0.754717; f1_dev 0.601942; loss_train 0.071350; loss_dev 0.095268
# Epoch 4/5; iteration 0/2608; runtime 7.088278 sec, f1_train 0.581818; f1_dev 0.607843; loss_train 0.097002; loss_dev 0.095744
# Epoch 4/5; iteration 100/2608; runtime 26.327087 sec, f1_train 0.716981; f1_dev 0.562500; loss_train 0.076133; loss_dev 0.100960
# Epoch 4/5; iteration 200/2608; runtime 25.930360 sec, f1_train 0.558140; f1_dev 0.608696; loss_train 0.087102; loss_dev 0.099697
# Epoch 4/5; iteration 300/2608; runtime 26.044979 sec, f1_train 0.608696; f1_dev 0.626263; loss_train 0.098727; loss_dev 0.102114
# Epoch 4/5; iteration 400/2608; runtime 26.116727 sec, f1_train 0.553191; f1_dev 0.517647; loss_train 0.093769; loss_dev 0.110366
# Epoch 4/5; iteration 500/2608; runtime 25.784324 sec, f1_train 0.789474; f1_dev 0.590476; loss_train 0.097475; loss_dev 0.103977
# Epoch 4/5; iteration 600/2608; runtime 26.305027 sec, f1_train 0.600000; f1_dev 0.594059; loss_train 0.117400; loss_dev 0.108759
# Epoch 4/5; iteration 700/2608; runtime 25.815868 sec, f1_train 0.564103; f1_dev 0.482759; loss_train 0.075833; loss_dev 0.113902
# Epoch 4/5; iteration 800/2608; runtime 25.784052 sec, f1_train 0.777778; f1_dev 0.598131; loss_train 0.085188; loss_dev 0.101948
# Epoch 4/5; iteration 900/2608; runtime 25.644563 sec, f1_train 0.774194; f1_dev 0.615385; loss_train 0.085848; loss_dev 0.099317
# Epoch 4/5; iteration 1000/2608; runtime 28.384427 sec, f1_train 0.724138; f1_dev 0.603774; loss_train 0.082535; loss_dev 0.099420
# Epoch 4/5; iteration 1100/2608; runtime 26.370523 sec, f1_train 0.793651; f1_dev 0.629032; loss_train 0.070263; loss_dev 0.103516
# Epoch 4/5; iteration 1200/2608; runtime 25.966403 sec, f1_train 0.666667; f1_dev 0.633333; loss_train 0.091593; loss_dev 0.104338
# Epoch 4/5; iteration 1300/2608; runtime 25.655305 sec, f1_train 0.407407; f1_dev 0.522727; loss_train 0.119421; loss_dev 0.106712
# Epoch 4/5; iteration 1400/2608; runtime 25.451192 sec, f1_train 0.739726; f1_dev 0.616822; loss_train 0.116131; loss_dev 0.100567
# Epoch 4/5; iteration 1500/2608; runtime 25.860622 sec, f1_train 0.666667; f1_dev 0.603774; loss_train 0.081714; loss_dev 0.096307
# Epoch 4/5; iteration 1600/2608; runtime 25.880326 sec, f1_train 0.628571; f1_dev 0.641221; loss_train 0.130648; loss_dev 0.110190
# Epoch 4/5; iteration 1700/2608; runtime 25.615961 sec, f1_train 0.746988; f1_dev 0.649573; loss_train 0.111267; loss_dev 0.096075
# Epoch 4/5; iteration 1800/2608; runtime 25.857645 sec, f1_train 0.695652; f1_dev 0.636364; loss_train 0.061040; loss_dev 0.098945
# Epoch 4/5; iteration 1900/2608; runtime 25.897052 sec, f1_train 0.734694; f1_dev 0.618182; loss_train 0.084756; loss_dev 0.099053
# Epoch 4/5; iteration 2000/2608; runtime 27.964583 sec, f1_train 0.688525; f1_dev 0.660714; loss_train 0.075283; loss_dev 0.097448
# Epoch 4/5; iteration 2100/2608; runtime 27.219033 sec, f1_train 0.682927; f1_dev 0.656716; loss_train 0.137479; loss_dev 0.110187
# Epoch 4/5; iteration 2200/2608; runtime 25.730781 sec, f1_train 0.642857; f1_dev 0.574468; loss_train 0.083299; loss_dev 0.106694
# Epoch 4/5; iteration 2300/2608; runtime 25.876887 sec, f1_train 0.631579; f1_dev 0.641509; loss_train 0.098446; loss_dev 0.108383
# Epoch 4/5; iteration 2400/2608; runtime 26.235065 sec, f1_train 0.384615; f1_dev 0.414634; loss_train 0.128100; loss_dev 0.118697
# Epoch 4/5; iteration 2500/2608; runtime 25.985917 sec, f1_train 0.571429; f1_dev 0.589474; loss_train 0.098819; loss_dev 0.103565
# Epoch 4/5; iteration 2600/2608; runtime 25.827144 sec, f1_train 0.530612; f1_dev 0.607843; loss_train 0.099734; loss_dev 0.105218
