# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

#n_inputs = 300
n_neurons = [500, 500, 500]
n_fc1 = 500
n_fc2 = 500
n_fc3 = 500
n_fc4 = 100
n_output = 1
learning_rate = 0.001
activation_fn = tf.nn.elu

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = [tf.contrib.rnn.LSTMCell(num_units=n, name="LSTM") for n in n_neurons]
    multi_lstm_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    h_states, states = tf.nn.dynamic_rnn(multi_lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len)

with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states[0][0], n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1 + states[1][0], n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2 + states[2][0], n_fc3, activation_fn=activation_fn)
    fc4 = tf.contrib.layers.fully_connected(fc3, n_fc4, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc4, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model2.1/QIQC_model2.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
total_deltas = 0
t_init = time.time()
with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths})

            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                step = epoch * QIQC.nr_batches + iteration
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                t_1 = time.time()
                t_delta = t_1 - t_0
                total_deltas += t_delta
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))

t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/5; It. 0/2608; Runtime 8.44 s; Remaining runtime 0h18min20s; f1_train nan; f1_dev nan; loss_train 0.6869; loss_dev 0.5859
# Ep. 1/5; It. 100/2608; Runtime 82.59 s; Remaining runtime 2h58min7s; f1_train 0.4000; f1_dev 0.5556; loss_train 0.1044; loss_dev 0.1291
# Ep. 1/5; It. 200/2608; Runtime 81.35 s; Remaining runtime 2h54min5s; f1_train 0.5909; f1_dev 0.4731; loss_train 0.1265; loss_dev 0.1221
# Ep. 1/5; It. 300/2608; Runtime 81.85 s; Remaining runtime 2h53min47s; f1_train 0.5128; f1_dev 0.4000; loss_train 0.0988; loss_dev 0.1296
# Ep. 1/5; It. 400/2608; Runtime 82.00 s; Remaining runtime 2h52min45s; f1_train 0.6087; f1_dev 0.5913; loss_train 0.1528; loss_dev 0.1171
# Ep. 1/5; It. 500/2608; Runtime 81.42 s; Remaining runtime 2h50min9s; f1_train 0.4242; f1_dev 0.3333; loss_train 0.1079; loss_dev 0.1201
# Ep. 1/5; It. 600/2608; Runtime 81.01 s; Remaining runtime 2h47min57s; f1_train 0.5479; f1_dev 0.5918; loss_train 0.1711; loss_dev 0.1100
# Ep. 1/5; It. 700/2608; Runtime 84.81 s; Remaining runtime 2h54min25s; f1_train 0.5231; f1_dev 0.6111; loss_train 0.1364; loss_dev 0.1094
# Ep. 1/5; It. 800/2608; Runtime 81.63 s; Remaining runtime 2h46min31s; f1_train 0.7660; f1_dev 0.6139; loss_train 0.0790; loss_dev 0.1055
# Ep. 1/5; It. 900/2608; Runtime 83.06 s; Remaining runtime 2h48min3s; f1_train 0.5614; f1_dev 0.6261; loss_train 0.1153; loss_dev 0.1116
# Ep. 1/5; It. 1000/2608; Runtime 85.78 s; Remaining runtime 2h52min8s; f1_train 0.6316; f1_dev 0.5657; loss_train 0.1070; loss_dev 0.1041
# Ep. 1/5; It. 1100/2608; Runtime 81.70 s; Remaining runtime 2h42min35s; f1_train 0.6222; f1_dev 0.6019; loss_train 0.0935; loss_dev 0.1043
# Ep. 1/5; It. 1200/2608; Runtime 82.83 s; Remaining runtime 2h43min26s; f1_train 0.5833; f1_dev 0.6000; loss_train 0.0992; loss_dev 0.1010
# Ep. 1/5; It. 1300/2608; Runtime 81.65 s; Remaining runtime 2h39min45s; f1_train 0.5652; f1_dev 0.5333; loss_train 0.1120; loss_dev 0.1045
# Ep. 1/5; It. 1400/2608; Runtime 80.79 s; Remaining runtime 2h36min43s; f1_train 0.7059; f1_dev 0.6122; loss_train 0.0879; loss_dev 0.0971
# Ep. 1/5; It. 1500/2608; Runtime 82.36 s; Remaining runtime 2h38min24s; f1_train 0.6296; f1_dev 0.6355; loss_train 0.1019; loss_dev 0.1002
# Ep. 1/5; It. 1600/2608; Runtime 82.07 s; Remaining runtime 2h36min29s; f1_train 0.8158; f1_dev 0.6783; loss_train 0.0794; loss_dev 0.1000
# Ep. 1/5; It. 1700/2608; Runtime 81.46 s; Remaining runtime 2h33min57s; f1_train 0.5763; f1_dev 0.5393; loss_train 0.1014; loss_dev 0.1029
# Ep. 1/5; It. 1800/2608; Runtime 82.35 s; Remaining runtime 2h34min16s; f1_train 0.6933; f1_dev 0.6667; loss_train 0.1069; loss_dev 0.1003
# Ep. 1/5; It. 1900/2608; Runtime 81.23 s; Remaining runtime 2h30min48s; f1_train 0.6875; f1_dev 0.6491; loss_train 0.1157; loss_dev 0.1054
# Ep. 1/5; It. 2000/2608; Runtime 82.95 s; Remaining runtime 2h32min37s; f1_train 0.6545; f1_dev 0.6727; loss_train 0.0980; loss_dev 0.0994
# Ep. 1/5; It. 2100/2608; Runtime 82.96 s; Remaining runtime 2h31min16s; f1_train 0.4815; f1_dev 0.5745; loss_train 0.1175; loss_dev 0.1046
# Ep. 1/5; It. 2200/2608; Runtime 83.97 s; Remaining runtime 2h31min42s; f1_train 0.3429; f1_dev 0.6042; loss_train 0.0859; loss_dev 0.0973
# Ep. 1/5; It. 2300/2608; Runtime 80.98 s; Remaining runtime 2h24min56s; f1_train 0.7059; f1_dev 0.6446; loss_train 0.1022; loss_dev 0.1062
# Ep. 1/5; It. 2400/2608; Runtime 82.46 s; Remaining runtime 2h26min13s; f1_train 0.6897; f1_dev 0.6126; loss_train 0.0964; loss_dev 0.1002
# Ep. 1/5; It. 2500/2608; Runtime 81.67 s; Remaining runtime 2h23min28s; f1_train 0.6250; f1_dev 0.6168; loss_train 0.0993; loss_dev 0.0976
# Ep. 1/5; It. 2600/2608; Runtime 81.46 s; Remaining runtime 2h21min44s; f1_train 0.6557; f1_dev 0.5510; loss_train 0.0979; loss_dev 0.1048
# Ep. 2/5; It. 0/2608; Runtime 14.88 s; Remaining runtime 0h25min52s; f1_train 0.7407; f1_dev 0.5657; loss_train 0.0787; loss_dev 0.1038
# Ep. 2/5; It. 100/2608; Runtime 82.06 s; Remaining runtime 2h21min18s; f1_train 0.5714; f1_dev 0.5882; loss_train 0.0814; loss_dev 0.0986
# Ep. 2/5; It. 200/2608; Runtime 82.21 s; Remaining runtime 2h20min12s; f1_train 0.7353; f1_dev 0.6078; loss_train 0.0983; loss_dev 0.1025
# Ep. 2/5; It. 300/2608; Runtime 82.77 s; Remaining runtime 2h19min46s; f1_train 0.5641; f1_dev 0.5882; loss_train 0.0841; loss_dev 0.0999
# Ep. 2/5; It. 400/2608; Runtime 82.01 s; Remaining runtime 2h17min7s; f1_train 0.6552; f1_dev 0.6000; loss_train 0.0974; loss_dev 0.0993
# Ep. 2/5; It. 500/2608; Runtime 81.40 s; Remaining runtime 2h14min44s; f1_train 0.7188; f1_dev 0.6422; loss_train 0.1023; loss_dev 0.0986
# Ep. 2/5; It. 600/2608; Runtime 82.16 s; Remaining runtime 2h14min37s; f1_train 0.7407; f1_dev 0.5567; loss_train 0.0902; loss_dev 0.1017
# Ep. 2/5; It. 700/2608; Runtime 81.07 s; Remaining runtime 2h11min29s; f1_train 0.6667; f1_dev 0.5825; loss_train 0.0806; loss_dev 0.0999
# Ep. 2/5; It. 800/2608; Runtime 81.91 s; Remaining runtime 2h11min29s; f1_train 0.5882; f1_dev 0.5745; loss_train 0.1233; loss_dev 0.1054
# Ep. 2/5; It. 900/2608; Runtime 84.36 s; Remaining runtime 2h14min1s; f1_train 0.7222; f1_dev 0.6154; loss_train 0.1054; loss_dev 0.1032
# Ep. 2/5; It. 1000/2608; Runtime 85.65 s; Remaining runtime 2h14min38s; f1_train 0.5909; f1_dev 0.5111; loss_train 0.1250; loss_dev 0.1037
# Ep. 2/5; It. 1100/2608; Runtime 80.86 s; Remaining runtime 2h5min46s; f1_train 0.8333; f1_dev 0.6261; loss_train 0.0727; loss_dev 0.1008
# Ep. 2/5; It. 1200/2608; Runtime 82.11 s; Remaining runtime 2h6min20s; f1_train 0.6071; f1_dev 0.6226; loss_train 0.1046; loss_dev 0.1011
# Ep. 2/5; It. 1300/2608; Runtime 82.12 s; Remaining runtime 2h4min59s; f1_train 0.6275; f1_dev 0.5918; loss_train 0.0860; loss_dev 0.0998
# Ep. 2/5; It. 1400/2608; Runtime 81.85 s; Remaining runtime 2h3min12s; f1_train 0.7077; f1_dev 0.6154; loss_train 0.0932; loss_dev 0.0999
# Ep. 2/5; It. 1500/2608; Runtime 81.60 s; Remaining runtime 2h1min28s; f1_train 0.5070; f1_dev 0.6325; loss_train 0.1633; loss_dev 0.1080
# Ep. 2/5; It. 1600/2608; Runtime 83.64 s; Remaining runtime 2h3min7s; f1_train 0.6835; f1_dev 0.6491; loss_train 0.1115; loss_dev 0.0996
# Ep. 2/5; It. 1700/2608; Runtime 83.45 s; Remaining runtime 2h1min26s; f1_train 0.7143; f1_dev 0.6306; loss_train 0.0826; loss_dev 0.0993
# Ep. 2/5; It. 1800/2608; Runtime 82.71 s; Remaining runtime 1h58min59s; f1_train 0.6567; f1_dev 0.5714; loss_train 0.1034; loss_dev 0.1029
# Ep. 2/5; It. 1900/2608; Runtime 84.48 s; Remaining runtime 2h0min8s; f1_train 0.7000; f1_dev 0.5495; loss_train 0.0947; loss_dev 0.1093
# Ep. 2/5; It. 2000/2608; Runtime 86.90 s; Remaining runtime 2h2min6s; f1_train 0.7188; f1_dev 0.6560; loss_train 0.0908; loss_dev 0.1011
# Ep. 2/5; It. 2100/2608; Runtime 82.29 s; Remaining runtime 1h54min16s; f1_train 0.7018; f1_dev 0.6019; loss_train 0.0893; loss_dev 0.0937
# Ep. 2/5; It. 2200/2608; Runtime 83.73 s; Remaining runtime 1h54min52s; f1_train 0.6061; f1_dev 0.6415; loss_train 0.1168; loss_dev 0.0958
# Ep. 2/5; It. 2300/2608; Runtime 81.61 s; Remaining runtime 1h50min36s; f1_train 0.6176; f1_dev 0.6491; loss_train 0.1401; loss_dev 0.0967
# Ep. 2/5; It. 2400/2608; Runtime 83.62 s; Remaining runtime 1h51min56s; f1_train 0.5238; f1_dev 0.5769; loss_train 0.0945; loss_dev 0.1021
# Ep. 2/5; It. 2500/2608; Runtime 82.30 s; Remaining runtime 1h48min47s; f1_train 0.7170; f1_dev 0.6296; loss_train 0.0777; loss_dev 0.0999
# Ep. 2/5; It. 2600/2608; Runtime 81.20 s; Remaining runtime 1h45min59s; f1_train 0.6567; f1_dev 0.5769; loss_train 0.1224; loss_dev 0.0965
# Ep. 3/5; It. 0/2608; Runtime 12.44 s; Remaining runtime 0h16min13s; f1_train 0.6667; f1_dev 0.6038; loss_train 0.0850; loss_dev 0.0975
# Ep. 3/5; It. 100/2608; Runtime 82.64 s; Remaining runtime 1h46min23s; f1_train 0.6429; f1_dev 0.5474; loss_train 0.0880; loss_dev 0.0996
# Ep. 3/5; It. 200/2608; Runtime 81.63 s; Remaining runtime 1h43min43s; f1_train 0.6774; f1_dev 0.6726; loss_train 0.1242; loss_dev 0.0936
# Ep. 3/5; It. 300/2608; Runtime 85.01 s; Remaining runtime 1h46min35s; f1_train 0.6500; f1_dev 0.6422; loss_train 0.0747; loss_dev 0.0914
# Ep. 3/5; It. 400/2608; Runtime 83.28 s; Remaining runtime 1h43min3s; f1_train 0.8065; f1_dev 0.6306; loss_train 0.0647; loss_dev 0.0978
# Ep. 3/5; It. 500/2608; Runtime 81.74 s; Remaining runtime 1h39min46s; f1_train 0.7213; f1_dev 0.6261; loss_train 0.0927; loss_dev 0.1008
# Ep. 3/5; It. 600/2608; Runtime 83.21 s; Remaining runtime 1h40min11s; f1_train 0.6923; f1_dev 0.6415; loss_train 0.0895; loss_dev 0.0990
# Ep. 3/5; It. 700/2608; Runtime 82.47 s; Remaining runtime 1h37min55s; f1_train 0.6087; f1_dev 0.6226; loss_train 0.0860; loss_dev 0.0973
# Ep. 3/5; It. 800/2608; Runtime 81.68 s; Remaining runtime 1h35min37s; f1_train 0.7931; f1_dev 0.6549; loss_train 0.0748; loss_dev 0.1068
# Ep. 3/5; It. 900/2608; Runtime 82.35 s; Remaining runtime 1h35min2s; f1_train 0.7442; f1_dev 0.6078; loss_train 0.0527; loss_dev 0.0994
# Ep. 3/5; It. 1000/2608; Runtime 85.86 s; Remaining runtime 1h37min39s; f1_train 0.5652; f1_dev 0.5800; loss_train 0.0852; loss_dev 0.1008
# Ep. 3/5; It. 1100/2608; Runtime 82.72 s; Remaining runtime 1h32min41s; f1_train 0.7671; f1_dev 0.6126; loss_train 0.0816; loss_dev 0.1004
# Ep. 3/5; It. 1200/2608; Runtime 83.45 s; Remaining runtime 1h32min7s; f1_train 0.7111; f1_dev 0.6154; loss_train 0.0687; loss_dev 0.1030
# Ep. 3/5; It. 1300/2608; Runtime 81.93 s; Remaining runtime 1h29min5s; f1_train 0.6885; f1_dev 0.6250; loss_train 0.0820; loss_dev 0.0991
# Ep. 3/5; It. 1400/2608; Runtime 82.62 s; Remaining runtime 1h28min27s; f1_train 0.5600; f1_dev 0.6364; loss_train 0.1023; loss_dev 0.0960
# Ep. 3/5; It. 1500/2608; Runtime 82.27 s; Remaining runtime 1h26min42s; f1_train 0.6667; f1_dev 0.6476; loss_train 0.0897; loss_dev 0.0932
# Ep. 3/5; It. 1600/2608; Runtime 82.52 s; Remaining runtime 1h25min36s; f1_train 0.6429; f1_dev 0.6435; loss_train 0.1080; loss_dev 0.0924
# Ep. 3/5; It. 1700/2608; Runtime 83.70 s; Remaining runtime 1h25min25s; f1_train 0.6800; f1_dev 0.6476; loss_train 0.0644; loss_dev 0.1022
# Ep. 3/5; It. 1800/2608; Runtime 82.28 s; Remaining runtime 1h22min36s; f1_train 0.5581; f1_dev 0.6111; loss_train 0.0809; loss_dev 0.1023
# Ep. 3/5; It. 1900/2608; Runtime 80.97 s; Remaining runtime 1h19min56s; f1_train 0.5957; f1_dev 0.6139; loss_train 0.0841; loss_dev 0.1019
# Ep. 3/5; It. 2000/2608; Runtime 86.82 s; Remaining runtime 1h24min16s; f1_train 0.5417; f1_dev 0.6095; loss_train 0.0977; loss_dev 0.0975
# Ep. 3/5; It. 2100/2608; Runtime 83.06 s; Remaining runtime 1h19min14s; f1_train 0.6875; f1_dev 0.6140; loss_train 0.1088; loss_dev 0.0967
# Ep. 3/5; It. 2200/2608; Runtime 83.07 s; Remaining runtime 1h17min51s; f1_train 0.5846; f1_dev 0.6306; loss_train 0.1214; loss_dev 0.0967
# Ep. 3/5; It. 2300/2608; Runtime 82.33 s; Remaining runtime 1h15min47s; f1_train 0.7792; f1_dev 0.6226; loss_train 0.0989; loss_dev 0.1013
# Ep. 3/5; It. 2400/2608; Runtime 83.77 s; Remaining runtime 1h15min43s; f1_train 0.7419; f1_dev 0.6481; loss_train 0.1093; loss_dev 0.0966
# Ep. 3/5; It. 2500/2608; Runtime 82.72 s; Remaining runtime 1h13min24s; f1_train 0.6538; f1_dev 0.6111; loss_train 0.0817; loss_dev 0.1022
# Ep. 3/5; It. 2600/2608; Runtime 82.12 s; Remaining runtime 1h11min30s; f1_train 0.6000; f1_dev 0.6415; loss_train 0.0753; loss_dev 0.0984
# Ep. 4/5; It. 0/2608; Runtime 14.72 s; Remaining runtime 0h12min47s; f1_train 0.7778; f1_dev 0.5941; loss_train 0.0895; loss_dev 0.1012
# Ep. 4/5; It. 100/2608; Runtime 81.37 s; Remaining runtime 1h9min22s; f1_train 0.7089; f1_dev 0.5437; loss_train 0.0929; loss_dev 0.1007
# Ep. 4/5; It. 200/2608; Runtime 83.11 s; Remaining runtime 1h9min28s; f1_train 0.7302; f1_dev 0.5567; loss_train 0.0813; loss_dev 0.1102
# Ep. 4/5; It. 300/2608; Runtime 84.33 s; Remaining runtime 1h9min5s; f1_train 0.7600; f1_dev 0.5962; loss_train 0.0734; loss_dev 0.1058
# Ep. 4/5; It. 400/2608; Runtime 82.09 s; Remaining runtime 1h5min53s; f1_train 0.8571; f1_dev 0.6168; loss_train 0.0519; loss_dev 0.1028
# Ep. 4/5; It. 500/2608; Runtime 82.48 s; Remaining runtime 1h4min49s; f1_train 0.6349; f1_dev 0.5926; loss_train 0.1101; loss_dev 0.0986
# Ep. 4/5; It. 600/2608; Runtime 83.26 s; Remaining runtime 1h4min3s; f1_train 0.6400; f1_dev 0.6723; loss_train 0.1085; loss_dev 0.1000
# Ep. 4/5; It. 700/2608; Runtime 80.34 s; Remaining runtime 1h0min27s; f1_train 0.7391; f1_dev 0.6435; loss_train 0.0510; loss_dev 0.0977
# Ep. 4/5; It. 800/2608; Runtime 82.01 s; Remaining runtime 1h0min21s; f1_train 0.7407; f1_dev 0.6111; loss_train 0.0757; loss_dev 0.1016
# Ep. 4/5; It. 900/2608; Runtime 83.00 s; Remaining runtime 0h59min42s; f1_train 0.6230; f1_dev 0.6435; loss_train 0.1118; loss_dev 0.0994
# Ep. 4/5; It. 1000/2608; Runtime 84.06 s; Remaining runtime 0h59min4s; f1_train 0.7059; f1_dev 0.6609; loss_train 0.0840; loss_dev 0.1027
# Ep. 4/5; It. 1100/2608; Runtime 83.04 s; Remaining runtime 0h56min58s; f1_train 0.7500; f1_dev 0.6491; loss_train 0.0552; loss_dev 0.1026
# Ep. 4/5; It. 1200/2608; Runtime 84.70 s; Remaining runtime 0h56min41s; f1_train 0.8438; f1_dev 0.6609; loss_train 0.0751; loss_dev 0.1077
# Ep. 4/5; It. 1300/2608; Runtime 83.16 s; Remaining runtime 0h54min16s; f1_train 0.6667; f1_dev 0.6296; loss_train 0.0987; loss_dev 0.1035
# Ep. 4/5; It. 1400/2608; Runtime 82.63 s; Remaining runtime 0h52min33s; f1_train 0.7419; f1_dev 0.5882; loss_train 0.0719; loss_dev 0.1015
# Ep. 4/5; It. 1500/2608; Runtime 82.92 s; Remaining runtime 0h51min21s; f1_train 0.7241; f1_dev 0.5743; loss_train 0.0700; loss_dev 0.1030
# Ep. 4/5; It. 1600/2608; Runtime 81.29 s; Remaining runtime 0h48min59s; f1_train 0.5641; f1_dev 0.5849; loss_train 0.0746; loss_dev 0.1059
# Ep. 4/5; It. 1700/2608; Runtime 82.46 s; Remaining runtime 0h48min19s; f1_train 0.7407; f1_dev 0.6168; loss_train 0.0718; loss_dev 0.0994
# Ep. 4/5; It. 1800/2608; Runtime 84.30 s; Remaining runtime 0h47min59s; f1_train 0.6909; f1_dev 0.6214; loss_train 0.0848; loss_dev 0.0928
# Ep. 4/5; It. 1900/2608; Runtime 82.74 s; Remaining runtime 0h45min43s; f1_train 0.7547; f1_dev 0.5859; loss_train 0.0605; loss_dev 0.1010
# Ep. 4/5; It. 2000/2608; Runtime 85.80 s; Remaining runtime 0h45min59s; f1_train 0.6667; f1_dev 0.6606; loss_train 0.0807; loss_dev 0.0982
# Ep. 4/5; It. 2100/2608; Runtime 85.59 s; Remaining runtime 0h44min27s; f1_train 0.8060; f1_dev 0.6422; loss_train 0.0696; loss_dev 0.0981
# Ep. 4/5; It. 2200/2608; Runtime 82.20 s; Remaining runtime 0h41min19s; f1_train 0.6780; f1_dev 0.6542; loss_train 0.0896; loss_dev 0.0925
# Ep. 4/5; It. 2300/2608; Runtime 82.05 s; Remaining runtime 0h39min52s; f1_train 0.8125; f1_dev 0.6095; loss_train 0.0613; loss_dev 0.0975
# Ep. 4/5; It. 2400/2608; Runtime 82.53 s; Remaining runtime 0h38min44s; f1_train 0.8158; f1_dev 0.6667; loss_train 0.0885; loss_dev 0.0960
# Ep. 4/5; It. 2500/2608; Runtime 83.48 s; Remaining runtime 0h37min47s; f1_train 0.7925; f1_dev 0.6364; loss_train 0.0668; loss_dev 0.0973
# Ep. 4/5; It. 2600/2608; Runtime 82.12 s; Remaining runtime 0h35min48s; f1_train 0.8000; f1_dev 0.6607; loss_train 0.0589; loss_dev 0.0956
# Ep. 5/5; It. 0/2608; Runtime 12.31 s; Remaining runtime 0h5min21s; f1_train 0.7188; f1_dev 0.6606; loss_train 0.0786; loss_dev 0.0959
# Ep. 5/5; It. 100/2608; Runtime 82.02 s; Remaining runtime 0h34min17s; f1_train 0.8148; f1_dev 0.5981; loss_train 0.0583; loss_dev 0.1092
# Ep. 5/5; It. 200/2608; Runtime 83.38 s; Remaining runtime 0h33min27s; f1_train 0.7727; f1_dev 0.6549; loss_train 0.0505; loss_dev 0.1035
# Ep. 5/5; It. 300/2608; Runtime 83.88 s; Remaining runtime 0h32min15s; f1_train 0.7170; f1_dev 0.6481; loss_train 0.0765; loss_dev 0.0977
# Ep. 5/5; It. 400/2608; Runtime 84.24 s; Remaining runtime 0h30min59s; f1_train 0.7586; f1_dev 0.6019; loss_train 0.0694; loss_dev 0.0999
# Ep. 5/5; It. 500/2608; Runtime 83.05 s; Remaining runtime 0h29min10s; f1_train 0.7429; f1_dev 0.5743; loss_train 0.1002; loss_dev 0.1067
# Ep. 5/5; It. 600/2608; Runtime 84.91 s; Remaining runtime 0h28min24s; f1_train 0.7246; f1_dev 0.6355; loss_train 0.0907; loss_dev 0.1048
# Ep. 5/5; It. 700/2608; Runtime 83.15 s; Remaining runtime 0h26min26s; f1_train 0.7170; f1_dev 0.6195; loss_train 0.0688; loss_dev 0.1018
# Ep. 5/5; It. 800/2608; Runtime 82.45 s; Remaining runtime 0h24min50s; f1_train 0.8333; f1_dev 0.6372; loss_train 0.0703; loss_dev 0.1023
# Ep. 5/5; It. 900/2608; Runtime 81.62 s; Remaining runtime 0h23min14s; f1_train 0.8000; f1_dev 0.6372; loss_train 0.0701; loss_dev 0.1010
# Ep. 5/5; It. 1000/2608; Runtime 86.16 s; Remaining runtime 0h23min5s; f1_train 0.7541; f1_dev 0.6355; loss_train 0.0689; loss_dev 0.1018
# Ep. 5/5; It. 1100/2608; Runtime 82.73 s; Remaining runtime 0h20min47s; f1_train 0.7692; f1_dev 0.6019; loss_train 0.0547; loss_dev 0.0996
# Ep. 5/5; It. 1200/2608; Runtime 82.56 s; Remaining runtime 0h19min22s; f1_train 0.7170; f1_dev 0.6095; loss_train 0.0698; loss_dev 0.1061
# Ep. 5/5; It. 1300/2608; Runtime 81.47 s; Remaining runtime 0h17min45s; f1_train 0.7042; f1_dev 0.6476; loss_train 0.0954; loss_dev 0.1013
# Ep. 5/5; It. 1400/2608; Runtime 80.96 s; Remaining runtime 0h16min18s; f1_train 0.7848; f1_dev 0.5794; loss_train 0.0813; loss_dev 0.1092
# Ep. 5/5; It. 1500/2608; Runtime 82.30 s; Remaining runtime 0h15min11s; f1_train 0.9020; f1_dev 0.6542; loss_train 0.0426; loss_dev 0.1055
# Ep. 5/5; It. 1600/2608; Runtime 82.70 s; Remaining runtime 0h13min53s; f1_train 0.6786; f1_dev 0.6168; loss_train 0.0937; loss_dev 0.1092
# Ep. 5/5; It. 1700/2608; Runtime 82.02 s; Remaining runtime 0h12min24s; f1_train 0.7895; f1_dev 0.6408; loss_train 0.0835; loss_dev 0.1041
# Ep. 5/5; It. 1800/2608; Runtime 82.36 s; Remaining runtime 0h11min5s; f1_train 0.7925; f1_dev 0.6239; loss_train 0.0592; loss_dev 0.1051
# Ep. 5/5; It. 1900/2608; Runtime 82.28 s; Remaining runtime 0h9min42s; f1_train 0.7451; f1_dev 0.6182; loss_train 0.0693; loss_dev 0.1019
# Ep. 5/5; It. 2000/2608; Runtime 85.08 s; Remaining runtime 0h8min37s; f1_train 0.8657; f1_dev 0.6780; loss_train 0.0581; loss_dev 0.1088
# Ep. 5/5; It. 2100/2608; Runtime 85.41 s; Remaining runtime 0h7min13s; f1_train 0.7536; f1_dev 0.6549; loss_train 0.0878; loss_dev 0.1060
# Ep. 5/5; It. 2200/2608; Runtime 82.02 s; Remaining runtime 0h5min34s; f1_train 0.7692; f1_dev 0.6604; loss_train 0.0686; loss_dev 0.1076
# Ep. 5/5; It. 2300/2608; Runtime 82.85 s; Remaining runtime 0h4min15s; f1_train 0.8000; f1_dev 0.6364; loss_train 0.0726; loss_dev 0.1064
# Ep. 5/5; It. 2400/2608; Runtime 83.70 s; Remaining runtime 0h2min54s; f1_train 0.7647; f1_dev 0.5941; loss_train 0.0884; loss_dev 0.1093
# Ep. 5/5; It. 2500/2608; Runtime 83.02 s; Remaining runtime 0h1min29s; f1_train 0.6275; f1_dev 0.6296; loss_train 0.0785; loss_dev 0.1004
# Ep. 5/5; It. 2600/2608; Runtime 82.30 s; Remaining runtime 0h0min6s; f1_train 0.8065; f1_dev 0.6333; loss_train 0.0699; loss_dev 0.1041
# Total actual runtime: 3 hours 0 min 33 sec

# %%
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()
MODELS_FILE = "models/model2.1/QIQC_model2.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set, seq_len: X_cv_lengths})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model2.1/QIQC_model2.ckpt
# cross val f1 61.76%, dev f1 67.80%
