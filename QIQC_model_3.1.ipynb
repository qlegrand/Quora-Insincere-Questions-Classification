# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_neurons = [500, 500, 500]
n_fc1 = 1500
n_fc2 = 500
n_fc3 = 100
n_output = 1
learning_rate = tf.placeholder(tf.float32)
activation_fn = tf.nn.elu

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = [tf.contrib.rnn.LSTMCell(num_units=n, name="LSTM") for n in n_neurons]
    multi_lstm_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    h_states, out_states = tf.nn.dynamic_rnn(multi_lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len) #state = 3 * 2 * m * 500
    states = tf.concat([out_states[0][0],out_states[1][0],out_states[2][0]], axis = 1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2, n_fc3, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc3, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
"""
QIQC.reset()
with tf.Session() as sess:
    init.run()
    loss_hist = []
    lr_hist = []
    iter_hist = []
    lr = 0
    t_0 = time.time()
    for iteration in range(QIQC.nr_batches):  
        lr = (iteration + 1)/QIQC.nr_batches * 10 # 1.008188^85 = 2
        X_lengths, X_batch, y_batch = QIQC.next_batch()
        _, run_loss = sess.run([training_op, loss], feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate:lr})

        loss_hist.append(run_loss)
        iter_hist.append(iteration)
        lr_hist.append(lr)
        if iteration % 100 == 0:
            t_1 = time.time()
            t_delta = t_1 - t_0
            expected_runtime = t_delta * (QIQC.nr_batches - iteration)/100
            expected_runtime_h = int(expected_runtime//3600)
            expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
            expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
            t_0 = t_1
            print("It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s".format(iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec))
    
"""
# Out:
# '\nQIQC.reset()\nwith tf.Session() as sess:\n    init.run()\n    loss_hist = []\n    lr_hist = []\n    iter_hist = []\n    lr = 0\n    t_0 = time.time()\n    for iteration in range(QIQC.nr_batches):  \n        lr = (iteration + 1)/QIQC.nr_batches * 10 # 1.008188^85 = 2\n        X_lengths, X_batch, y_batch = QIQC.next_batch()\n        _, run_loss = sess.run([training_op, loss], feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate:lr})\n\n        loss_hist.append(run_loss)\n        iter_hist.append(iteration)\n        lr_hist.append(lr)\n        if iteration % 100 == 0:\n            t_1 = time.time()\n            t_delta = t_1 - t_0\n            expected_runtime = t_delta * (QIQC.nr_batches - iteration)/100\n            expected_runtime_h = int(expected_runtime//3600)\n            expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)\n            expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))\n            t_0 = t_1\n            print("It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s".format(iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec))\n    \n'

# %%
#plt.plot(np.log(lr_hist), loss_hist)
#plt.ylim((0,30))

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model3.1/QIQC_model3.1.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
total_deltas = 0
t_init = time.time()
min_lr = 0.0005
max_lr = 0.0015
with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    stepsize = QIQC.nr_batches
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            step = epoch * QIQC.nr_batches + iteration
            cycle = np.floor(1 + step/(2 * stepsize))
            pattern = np.absolute(step/stepsize - 2*cycle + 1)
            cycle_lr = min_lr + (max_lr - min_lr) * pattern
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate: cycle_lr})

            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                t_1 = time.time()
                t_delta = t_1 - t_0
                total_deltas += t_delta
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/5; It. 0/2608; Runtime 7.26 s; Remaining runtime 0h15min46s; f1_train nan; f1_dev nan; loss_train 1.0092; loss_dev 1.0996
# Ep. 1/5; It. 100/2608; Runtime 79.99 s; Remaining runtime 2h52min30s; f1_train 0.0870; f1_dev 0.1918; loss_train 0.1050; loss_dev 0.1411
# Ep. 1/5; It. 200/2608; Runtime 80.05 s; Remaining runtime 2h51min18s; f1_train 0.6269; f1_dev 0.5524; loss_train 0.1286; loss_dev 0.1252
# Ep. 1/5; It. 300/2608; Runtime 80.85 s; Remaining runtime 2h51min40s; f1_train 0.2963; f1_dev 0.2000; loss_train 0.1185; loss_dev 0.1413
# Ep. 1/5; It. 400/2608; Runtime 80.15 s; Remaining runtime 2h48min51s; f1_train 0.6230; f1_dev 0.5913; loss_train 0.1250; loss_dev 0.1184
# Ep. 1/5; It. 500/2608; Runtime 79.58 s; Remaining runtime 2h46min18s; f1_train 0.6207; f1_dev 0.6168; loss_train 0.1178; loss_dev 0.1110
# Ep. 1/5; It. 600/2608; Runtime 80.37 s; Remaining runtime 2h46min37s; f1_train 0.6415; f1_dev 0.5905; loss_train 0.1182; loss_dev 0.1075
# Ep. 1/5; It. 700/2608; Runtime 79.30 s; Remaining runtime 2h43min5s; f1_train 0.6182; f1_dev 0.6372; loss_train 0.1025; loss_dev 0.1075
# Ep. 1/5; It. 800/2608; Runtime 80.02 s; Remaining runtime 2h43min14s; f1_train 0.3000; f1_dev 0.3750; loss_train 0.1558; loss_dev 0.1198
# Ep. 1/5; It. 900/2608; Runtime 82.11 s; Remaining runtime 2h46min8s; f1_train 0.7123; f1_dev 0.6111; loss_train 0.1216; loss_dev 0.1111
# Ep. 1/5; It. 1000/2608; Runtime 83.53 s; Remaining runtime 2h47min37s; f1_train 0.4103; f1_dev 0.4524; loss_train 0.1376; loss_dev 0.1092
# Ep. 1/5; It. 1100/2608; Runtime 78.46 s; Remaining runtime 2h36min7s; f1_train 0.7887; f1_dev 0.6140; loss_train 0.0830; loss_dev 0.1041
# Ep. 1/5; It. 1200/2608; Runtime 79.72 s; Remaining runtime 2h37min18s; f1_train 0.5926; f1_dev 0.6415; loss_train 0.1102; loss_dev 0.1021
# Ep. 1/5; It. 1300/2608; Runtime 79.59 s; Remaining runtime 2h35min44s; f1_train 0.6122; f1_dev 0.5957; loss_train 0.0942; loss_dev 0.1032
# Ep. 1/5; It. 1400/2608; Runtime 79.35 s; Remaining runtime 2h33min56s; f1_train 0.6970; f1_dev 0.5773; loss_train 0.1044; loss_dev 0.1027
# Ep. 1/5; It. 1500/2608; Runtime 79.15 s; Remaining runtime 2h32min13s; f1_train 0.4615; f1_dev 0.6214; loss_train 0.1659; loss_dev 0.0982
# Ep. 1/5; It. 1600/2608; Runtime 81.10 s; Remaining runtime 2h34min38s; f1_train 0.6923; f1_dev 0.6429; loss_train 0.1181; loss_dev 0.0977
# Ep. 1/5; It. 1700/2608; Runtime 80.98 s; Remaining runtime 2h33min2s; f1_train 0.7018; f1_dev 0.6316; loss_train 0.0827; loss_dev 0.1012
# Ep. 1/5; It. 1800/2608; Runtime 80.05 s; Remaining runtime 2h29min57s; f1_train 0.6761; f1_dev 0.6078; loss_train 0.1084; loss_dev 0.0986
# Ep. 1/5; It. 1900/2608; Runtime 81.79 s; Remaining runtime 2h31min51s; f1_train 0.6316; f1_dev 0.5455; loss_train 0.1020; loss_dev 0.1125
# Ep. 1/5; It. 2000/2608; Runtime 83.60 s; Remaining runtime 2h33min49s; f1_train 0.6774; f1_dev 0.6504; loss_train 0.0948; loss_dev 0.1031
# Ep. 1/5; It. 2100/2608; Runtime 79.54 s; Remaining runtime 2h25min1s; f1_train 0.5818; f1_dev 0.6214; loss_train 0.1029; loss_dev 0.0948
# Ep. 1/5; It. 2200/2608; Runtime 80.87 s; Remaining runtime 2h26min6s; f1_train 0.5970; f1_dev 0.6095; loss_train 0.1206; loss_dev 0.0963
# Ep. 1/5; It. 2300/2608; Runtime 79.02 s; Remaining runtime 2h21min27s; f1_train 0.5970; f1_dev 0.6306; loss_train 0.1443; loss_dev 0.0956
# Ep. 1/5; It. 2400/2608; Runtime 81.34 s; Remaining runtime 2h24min14s; f1_train 0.5000; f1_dev 0.6061; loss_train 0.1018; loss_dev 0.1018
# Ep. 1/5; It. 2500/2608; Runtime 80.04 s; Remaining runtime 2h20min36s; f1_train 0.6538; f1_dev 0.5631; loss_train 0.0866; loss_dev 0.0994
# Ep. 1/5; It. 2600/2608; Runtime 78.98 s; Remaining runtime 2h17min25s; f1_train 0.6970; f1_dev 0.5882; loss_train 0.1278; loss_dev 0.0973
# Ep. 2/5; It. 0/2608; Runtime 14.29 s; Remaining runtime 0h24min50s; f1_train 0.5965; f1_dev 0.5962; loss_train 0.0963; loss_dev 0.0973
# Ep. 2/5; It. 100/2608; Runtime 80.62 s; Remaining runtime 2h18min49s; f1_train 0.6429; f1_dev 0.5745; loss_train 0.1030; loss_dev 0.1020
# Ep. 2/5; It. 200/2608; Runtime 79.18 s; Remaining runtime 2h15min1s; f1_train 0.5614; f1_dev 0.6408; loss_train 0.1476; loss_dev 0.0931
# Ep. 2/5; It. 300/2608; Runtime 82.05 s; Remaining runtime 2h18min33s; f1_train 0.6486; f1_dev 0.6214; loss_train 0.0718; loss_dev 0.0958
# Ep. 2/5; It. 400/2608; Runtime 80.22 s; Remaining runtime 2h14min8s; f1_train 0.7797; f1_dev 0.6055; loss_train 0.0695; loss_dev 0.0978
# Ep. 2/5; It. 500/2608; Runtime 78.97 s; Remaining runtime 2h10min43s; f1_train 0.7097; f1_dev 0.6140; loss_train 0.0999; loss_dev 0.0955
# Ep. 2/5; It. 600/2608; Runtime 80.66 s; Remaining runtime 2h12min10s; f1_train 0.5833; f1_dev 0.6061; loss_train 0.1028; loss_dev 0.1004
# Ep. 2/5; It. 700/2608; Runtime 80.03 s; Remaining runtime 2h9min48s; f1_train 0.5366; f1_dev 0.5882; loss_train 0.0960; loss_dev 0.0984
# Ep. 2/5; It. 800/2608; Runtime 79.30 s; Remaining runtime 2h7min17s; f1_train 0.7541; f1_dev 0.6226; loss_train 0.0824; loss_dev 0.0993
# Ep. 2/5; It. 900/2608; Runtime 80.08 s; Remaining runtime 2h7min12s; f1_train 0.7234; f1_dev 0.6061; loss_train 0.0567; loss_dev 0.0983
# Ep. 2/5; It. 1000/2608; Runtime 84.57 s; Remaining runtime 2h12min56s; f1_train 0.6087; f1_dev 0.6078; loss_train 0.0890; loss_dev 0.1008
# Ep. 2/5; It. 1100/2608; Runtime 80.12 s; Remaining runtime 2h4min36s; f1_train 0.7714; f1_dev 0.6111; loss_train 0.0852; loss_dev 0.0997
# Ep. 2/5; It. 1200/2608; Runtime 81.06 s; Remaining runtime 2h4min43s; f1_train 0.6667; f1_dev 0.6346; loss_train 0.0719; loss_dev 0.0994
# Ep. 2/5; It. 1300/2608; Runtime 79.31 s; Remaining runtime 2h0min42s; f1_train 0.5902; f1_dev 0.6355; loss_train 0.0883; loss_dev 0.1018
# Ep. 2/5; It. 1400/2608; Runtime 80.04 s; Remaining runtime 2h0min28s; f1_train 0.5306; f1_dev 0.6422; loss_train 0.1170; loss_dev 0.0936
# Ep. 2/5; It. 1500/2608; Runtime 79.76 s; Remaining runtime 1h58min43s; f1_train 0.6296; f1_dev 0.6408; loss_train 0.1006; loss_dev 0.0961
# Ep. 2/5; It. 1600/2608; Runtime 79.87 s; Remaining runtime 1h57min34s; f1_train 0.5714; f1_dev 0.6122; loss_train 0.1149; loss_dev 0.0982
# Ep. 2/5; It. 1700/2608; Runtime 81.18 s; Remaining runtime 1h58min8s; f1_train 0.7547; f1_dev 0.6182; loss_train 0.0693; loss_dev 0.1017
# Ep. 2/5; It. 1800/2608; Runtime 80.06 s; Remaining runtime 1h55min10s; f1_train 0.7059; f1_dev 0.6355; loss_train 0.0958; loss_dev 0.1008
# Ep. 2/5; It. 1900/2608; Runtime 78.67 s; Remaining runtime 1h51min52s; f1_train 0.6000; f1_dev 0.5918; loss_train 0.0994; loss_dev 0.1054
# Ep. 2/5; It. 2000/2608; Runtime 83.55 s; Remaining runtime 1h57min25s; f1_train 0.5106; f1_dev 0.6038; loss_train 0.1082; loss_dev 0.0970
# Ep. 2/5; It. 2100/2608; Runtime 80.83 s; Remaining runtime 1h52min14s; f1_train 0.6780; f1_dev 0.5979; loss_train 0.1154; loss_dev 0.0974
# Ep. 2/5; It. 2200/2608; Runtime 80.64 s; Remaining runtime 1h50min38s; f1_train 0.5574; f1_dev 0.5745; loss_train 0.1271; loss_dev 0.0991
# Ep. 2/5; It. 2300/2608; Runtime 80.07 s; Remaining runtime 1h48min31s; f1_train 0.7123; f1_dev 0.6038; loss_train 0.1068; loss_dev 0.0993
# Ep. 2/5; It. 2400/2608; Runtime 81.33 s; Remaining runtime 1h48min52s; f1_train 0.6545; f1_dev 0.6337; loss_train 0.1201; loss_dev 0.0968
# Ep. 2/5; It. 2500/2608; Runtime 80.11 s; Remaining runtime 1h45min54s; f1_train 0.6531; f1_dev 0.5962; loss_train 0.0908; loss_dev 0.1014
# Ep. 2/5; It. 2600/2608; Runtime 79.69 s; Remaining runtime 1h44min1s; f1_train 0.5714; f1_dev 0.5946; loss_train 0.0763; loss_dev 0.1004
# Ep. 3/5; It. 0/2608; Runtime 15.04 s; Remaining runtime 0h19min36s; f1_train 0.7333; f1_dev 0.6154; loss_train 0.0989; loss_dev 0.0978
# Ep. 3/5; It. 100/2608; Runtime 79.02 s; Remaining runtime 1h41min43s; f1_train 0.6835; f1_dev 0.6000; loss_train 0.1171; loss_dev 0.1003
# Ep. 3/5; It. 200/2608; Runtime 80.51 s; Remaining runtime 1h42min18s; f1_train 0.5098; f1_dev 0.4884; loss_train 0.0960; loss_dev 0.1067
# Ep. 3/5; It. 300/2608; Runtime 81.75 s; Remaining runtime 1h42min30s; f1_train 0.6531; f1_dev 0.6364; loss_train 0.0923; loss_dev 0.0995
# Ep. 3/5; It. 400/2608; Runtime 79.52 s; Remaining runtime 1h38min23s; f1_train 0.7368; f1_dev 0.5800; loss_train 0.0764; loss_dev 0.1033
# Ep. 3/5; It. 500/2608; Runtime 79.97 s; Remaining runtime 1h37min37s; f1_train 0.5484; f1_dev 0.5926; loss_train 0.1310; loss_dev 0.0996
# Ep. 3/5; It. 600/2608; Runtime 80.75 s; Remaining runtime 1h37min13s; f1_train 0.6410; f1_dev 0.6230; loss_train 0.1283; loss_dev 0.1005
# Ep. 3/5; It. 700/2608; Runtime 78.22 s; Remaining runtime 1h32min52s; f1_train 0.6667; f1_dev 0.6168; loss_train 0.0621; loss_dev 0.0989
# Ep. 3/5; It. 800/2608; Runtime 79.65 s; Remaining runtime 1h33min14s; f1_train 0.6122; f1_dev 0.6038; loss_train 0.0852; loss_dev 0.1032
# Ep. 3/5; It. 900/2608; Runtime 80.65 s; Remaining runtime 1h33min4s; f1_train 0.6545; f1_dev 0.6306; loss_train 0.1208; loss_dev 0.1028
# Ep. 3/5; It. 1000/2608; Runtime 83.16 s; Remaining runtime 1h34min34s; f1_train 0.6462; f1_dev 0.6667; loss_train 0.1033; loss_dev 0.0979
# Ep. 3/5; It. 1100/2608; Runtime 80.49 s; Remaining runtime 1h30min11s; f1_train 0.7308; f1_dev 0.6422; loss_train 0.0539; loss_dev 0.0989
# Ep. 3/5; It. 1200/2608; Runtime 82.09 s; Remaining runtime 1h30min37s; f1_train 0.7879; f1_dev 0.6842; loss_train 0.0813; loss_dev 0.1025
# Ep. 3/5; It. 1300/2608; Runtime 80.48 s; Remaining runtime 1h27min30s; f1_train 0.5714; f1_dev 0.6214; loss_train 0.1141; loss_dev 0.1026
# Ep. 3/5; It. 1400/2608; Runtime 80.11 s; Remaining runtime 1h25min46s; f1_train 0.6780; f1_dev 0.6139; loss_train 0.0774; loss_dev 0.1019
# Ep. 3/5; It. 1500/2608; Runtime 80.43 s; Remaining runtime 1h24min46s; f1_train 0.6897; f1_dev 0.6337; loss_train 0.0795; loss_dev 0.1000
# Ep. 3/5; It. 1600/2608; Runtime 78.99 s; Remaining runtime 1h21min56s; f1_train 0.6316; f1_dev 0.6286; loss_train 0.0827; loss_dev 0.1003
# Ep. 3/5; It. 1700/2608; Runtime 79.98 s; Remaining runtime 1h21min38s; f1_train 0.6667; f1_dev 0.6019; loss_train 0.0848; loss_dev 0.0983
# Ep. 3/5; It. 1800/2608; Runtime 81.69 s; Remaining runtime 1h22min1s; f1_train 0.7037; f1_dev 0.6061; loss_train 0.0938; loss_dev 0.0970
# Ep. 3/5; It. 1900/2608; Runtime 80.15 s; Remaining runtime 1h19min8s; f1_train 0.7347; f1_dev 0.5714; loss_train 0.0732; loss_dev 0.1009
# Ep. 3/5; It. 2000/2608; Runtime 83.97 s; Remaining runtime 1h21min30s; f1_train 0.5652; f1_dev 0.6275; loss_train 0.0904; loss_dev 0.1015
# Ep. 3/5; It. 2100/2608; Runtime 82.15 s; Remaining runtime 1h18min22s; f1_train 0.7937; f1_dev 0.6214; loss_train 0.0682; loss_dev 0.0971
# Ep. 3/5; It. 2200/2608; Runtime 79.14 s; Remaining runtime 1h14min11s; f1_train 0.6780; f1_dev 0.6286; loss_train 0.1032; loss_dev 0.0950
# Ep. 3/5; It. 2300/2608; Runtime 79.42 s; Remaining runtime 1h13min7s; f1_train 0.8000; f1_dev 0.5773; loss_train 0.0676; loss_dev 0.0981
# Ep. 3/5; It. 2400/2608; Runtime 79.95 s; Remaining runtime 1h12min16s; f1_train 0.7273; f1_dev 0.5714; loss_train 0.0932; loss_dev 0.0984
# Ep. 3/5; It. 2500/2608; Runtime 81.02 s; Remaining runtime 1h11min53s; f1_train 0.7308; f1_dev 0.6214; loss_train 0.0730; loss_dev 0.0968
# Ep. 3/5; It. 2600/2608; Runtime 79.49 s; Remaining runtime 1h9min12s; f1_train 0.8136; f1_dev 0.6607; loss_train 0.0667; loss_dev 0.0963
# Ep. 4/5; It. 0/2608; Runtime 15.19 s; Remaining runtime 0h13min12s; f1_train 0.7119; f1_dev 0.5941; loss_train 0.0969; loss_dev 0.0975
# Ep. 4/5; It. 100/2608; Runtime 79.43 s; Remaining runtime 1h7min43s; f1_train 0.6415; f1_dev 0.5859; loss_train 0.0770; loss_dev 0.0986
# Ep. 4/5; It. 200/2608; Runtime 80.12 s; Remaining runtime 1h6min58s; f1_train 0.6829; f1_dev 0.6481; loss_train 0.0746; loss_dev 0.0957
# Ep. 4/5; It. 300/2608; Runtime 80.43 s; Remaining runtime 1h5min53s; f1_train 0.6275; f1_dev 0.6408; loss_train 0.0927; loss_dev 0.0944
# Ep. 4/5; It. 400/2608; Runtime 80.88 s; Remaining runtime 1h4min55s; f1_train 0.7018; f1_dev 0.5859; loss_train 0.0860; loss_dev 0.0965
# Ep. 4/5; It. 500/2608; Runtime 79.67 s; Remaining runtime 1h2min37s; f1_train 0.7429; f1_dev 0.5859; loss_train 0.1057; loss_dev 0.0958
# Ep. 4/5; It. 600/2608; Runtime 81.35 s; Remaining runtime 1h2min34s; f1_train 0.6349; f1_dev 0.5882; loss_train 0.1088; loss_dev 0.1007
# Ep. 4/5; It. 700/2608; Runtime 79.84 s; Remaining runtime 1h0min5s; f1_train 0.6667; f1_dev 0.6239; loss_train 0.0785; loss_dev 0.0954
# Ep. 4/5; It. 800/2608; Runtime 79.78 s; Remaining runtime 0h58min42s; f1_train 0.7931; f1_dev 0.5926; loss_train 0.0779; loss_dev 0.0970
# Ep. 4/5; It. 900/2608; Runtime 79.16 s; Remaining runtime 0h56min56s; f1_train 0.7761; f1_dev 0.6355; loss_train 0.0868; loss_dev 0.0941
# Ep. 4/5; It. 1000/2608; Runtime 85.19 s; Remaining runtime 0h59min51s; f1_train 0.7667; f1_dev 0.6019; loss_train 0.0794; loss_dev 0.0995
# Ep. 4/5; It. 1100/2608; Runtime 80.54 s; Remaining runtime 0h55min15s; f1_train 0.7547; f1_dev 0.5800; loss_train 0.0675; loss_dev 0.0972
# Ep. 4/5; It. 1200/2608; Runtime 80.06 s; Remaining runtime 0h53min35s; f1_train 0.6786; f1_dev 0.6226; loss_train 0.0746; loss_dev 0.0969
# Ep. 4/5; It. 1300/2608; Runtime 79.02 s; Remaining runtime 0h51min34s; f1_train 0.6866; f1_dev 0.5657; loss_train 0.1110; loss_dev 0.0992
# Ep. 4/5; It. 1400/2608; Runtime 78.52 s; Remaining runtime 0h49min56s; f1_train 0.7692; f1_dev 0.5794; loss_train 0.0985; loss_dev 0.1055
# Ep. 4/5; It. 1500/2608; Runtime 79.66 s; Remaining runtime 0h49min20s; f1_train 0.7778; f1_dev 0.6182; loss_train 0.0617; loss_dev 0.0992
# Ep. 4/5; It. 1600/2608; Runtime 80.14 s; Remaining runtime 0h48min17s; f1_train 0.6269; f1_dev 0.6066; loss_train 0.1126; loss_dev 0.1032
# Ep. 4/5; It. 1700/2608; Runtime 79.42 s; Remaining runtime 0h46min32s; f1_train 0.6765; f1_dev 0.6000; loss_train 0.1085; loss_dev 0.1040
# Ep. 4/5; It. 1800/2608; Runtime 79.84 s; Remaining runtime 0h45min27s; f1_train 0.7347; f1_dev 0.6355; loss_train 0.0649; loss_dev 0.1024
# Ep. 4/5; It. 1900/2608; Runtime 79.82 s; Remaining runtime 0h44min6s; f1_train 0.6538; f1_dev 0.6316; loss_train 0.0973; loss_dev 0.0966
# Ep. 4/5; It. 2000/2608; Runtime 83.16 s; Remaining runtime 0h44min34s; f1_train 0.7742; f1_dev 0.6250; loss_train 0.0739; loss_dev 0.1024
# Ep. 4/5; It. 2100/2608; Runtime 82.78 s; Remaining runtime 0h42min59s; f1_train 0.7059; f1_dev 0.6346; loss_train 0.1099; loss_dev 0.0989
# Ep. 4/5; It. 2200/2608; Runtime 79.40 s; Remaining runtime 0h39min54s; f1_train 0.7302; f1_dev 0.6296; loss_train 0.0768; loss_dev 0.1007
# Ep. 4/5; It. 2300/2608; Runtime 80.07 s; Remaining runtime 0h38min54s; f1_train 0.7097; f1_dev 0.6486; loss_train 0.0894; loss_dev 0.0978
# Ep. 4/5; It. 2400/2608; Runtime 80.96 s; Remaining runtime 0h37min59s; f1_train 0.5763; f1_dev 0.5833; loss_train 0.1157; loss_dev 0.1099
# Ep. 4/5; It. 2500/2608; Runtime 80.28 s; Remaining runtime 0h36min20s; f1_train 0.5714; f1_dev 0.6111; loss_train 0.0903; loss_dev 0.0986
# Ep. 4/5; It. 2600/2608; Runtime 79.73 s; Remaining runtime 0h34min45s; f1_train 0.7797; f1_dev 0.6387; loss_train 0.0883; loss_dev 0.0997
# Ep. 5/5; It. 0/2608; Runtime 14.70 s; Remaining runtime 0h6min23s; f1_train 0.5306; f1_dev 0.6122; loss_train 0.0985; loss_dev 0.1026
# Ep. 5/5; It. 100/2608; Runtime 79.57 s; Remaining runtime 0h33min15s; f1_train 0.7234; f1_dev 0.5825; loss_train 0.0596; loss_dev 0.1058
# Ep. 5/5; It. 200/2608; Runtime 81.57 s; Remaining runtime 0h32min44s; f1_train 0.7692; f1_dev 0.5981; loss_train 0.0832; loss_dev 0.1077
# Ep. 5/5; It. 300/2608; Runtime 79.88 s; Remaining runtime 0h30min43s; f1_train 0.7000; f1_dev 0.5926; loss_train 0.1023; loss_dev 0.0995
# Ep. 5/5; It. 400/2608; Runtime 80.07 s; Remaining runtime 0h29min27s; f1_train 0.6462; f1_dev 0.5600; loss_train 0.0899; loss_dev 0.1018
# Ep. 5/5; It. 500/2608; Runtime 79.21 s; Remaining runtime 0h27min49s; f1_train 0.6957; f1_dev 0.6538; loss_train 0.1053; loss_dev 0.0989
# Ep. 5/5; It. 600/2608; Runtime 81.85 s; Remaining runtime 0h27min23s; f1_train 0.5769; f1_dev 0.6182; loss_train 0.1070; loss_dev 0.1001
# Ep. 5/5; It. 700/2608; Runtime 79.04 s; Remaining runtime 0h25min8s; f1_train 0.8197; f1_dev 0.5893; loss_train 0.0686; loss_dev 0.0959
# Ep. 5/5; It. 800/2608; Runtime 80.49 s; Remaining runtime 0h24min15s; f1_train 0.6571; f1_dev 0.5872; loss_train 0.1148; loss_dev 0.1050
# Ep. 5/5; It. 900/2608; Runtime 80.18 s; Remaining runtime 0h22min49s; f1_train 0.7083; f1_dev 0.5918; loss_train 0.0691; loss_dev 0.1083
# Ep. 5/5; It. 1000/2608; Runtime 83.51 s; Remaining runtime 0h22min22s; f1_train 0.6364; f1_dev 0.5905; loss_train 0.1166; loss_dev 0.1024
# Ep. 5/5; It. 1100/2608; Runtime 79.64 s; Remaining runtime 0h20min1s; f1_train 0.7778; f1_dev 0.6000; loss_train 0.0839; loss_dev 0.0951
# Ep. 5/5; It. 1200/2608; Runtime 80.89 s; Remaining runtime 0h18min58s; f1_train 0.6866; f1_dev 0.5872; loss_train 0.0906; loss_dev 0.0992
# Ep. 5/5; It. 1300/2608; Runtime 80.04 s; Remaining runtime 0h17min26s; f1_train 0.8000; f1_dev 0.5825; loss_train 0.0794; loss_dev 0.0939
# Ep. 5/5; It. 1400/2608; Runtime 79.44 s; Remaining runtime 0h15min59s; f1_train 0.6780; f1_dev 0.6214; loss_train 0.0860; loss_dev 0.0952
# Ep. 5/5; It. 1500/2608; Runtime 79.77 s; Remaining runtime 0h14min43s; f1_train 0.7458; f1_dev 0.6429; loss_train 0.0620; loss_dev 0.0999
# Ep. 5/5; It. 1600/2608; Runtime 80.59 s; Remaining runtime 0h13min32s; f1_train 0.7170; f1_dev 0.6000; loss_train 0.0761; loss_dev 0.1001
# Ep. 5/5; It. 1700/2608; Runtime 78.96 s; Remaining runtime 0h11min56s; f1_train 0.6400; f1_dev 0.7059; loss_train 0.0856; loss_dev 0.0962
# Ep. 5/5; It. 1800/2608; Runtime 79.87 s; Remaining runtime 0h10min45s; f1_train 0.6512; f1_dev 0.6364; loss_train 0.0791; loss_dev 0.0960
# Ep. 5/5; It. 1900/2608; Runtime 81.25 s; Remaining runtime 0h9min35s; f1_train 0.7407; f1_dev 0.5905; loss_train 0.0662; loss_dev 0.0974
# Ep. 5/5; It. 2000/2608; Runtime 83.65 s; Remaining runtime 0h8min28s; f1_train 0.6780; f1_dev 0.6095; loss_train 0.0967; loss_dev 0.0978
# Ep. 5/5; It. 2100/2608; Runtime 81.35 s; Remaining runtime 0h6min53s; f1_train 0.7761; f1_dev 0.6346; loss_train 0.0879; loss_dev 0.0946
# Ep. 5/5; It. 2200/2608; Runtime 79.72 s; Remaining runtime 0h5min25s; f1_train 0.7037; f1_dev 0.6422; loss_train 0.0646; loss_dev 0.0953
# Ep. 5/5; It. 2300/2608; Runtime 79.59 s; Remaining runtime 0h4min5s; f1_train 0.5200; f1_dev 0.6214; loss_train 0.1046; loss_dev 0.0965
# Ep. 5/5; It. 2400/2608; Runtime 80.72 s; Remaining runtime 0h2min47s; f1_train 0.7200; f1_dev 0.6364; loss_train 0.0675; loss_dev 0.0944
# Ep. 5/5; It. 2500/2608; Runtime 80.12 s; Remaining runtime 0h1min26s; f1_train 0.8125; f1_dev 0.6486; loss_train 0.0664; loss_dev 0.0921
# Ep. 5/5; It. 2600/2608; Runtime 78.87 s; Remaining runtime 0h0min6s; f1_train 0.7213; f1_dev 0.6226; loss_train 0.0864; loss_dev 0.0974
# Total actual runtime: 2 hours 55 min 34 sec

# %%
MODELS_FILE = "models/model3.1/QIQC_model3.1.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set, seq_len: X_cv_lengths})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model3.1/QIQC_model3.1.ckpt
# cross val f1 65.55%, dev f1 62.26%
