# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
from functools import partial

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

def numpy_ewma_vectorized(data, alpha):
    alpha_ = 1-alpha
    D = pd.DataFrame(data)
    M = D.ewm(alpha=alpha_).mean()
    out = M.values
    return out

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_steps = 250
window_width = [3, 4, 5]
out_channels = [n_steps-window_width[0]+1, n_steps-window_width[1]+1, n_steps-window_width[2]+1]
embedding_dimensions = 300
n_fc1 = 300
n_fc2 = 300
n_fc3 = 300
n_fc4 = 200
n_fc5 = 100
n_output = 1
threshold = 1.
lambda_ = 0.05

activation_fn = tf.nn.elu
he_init = tf.variance_scaling_initializer()

init_W_CL_3 = np.random.randn(window_width[0],embedding_dimensions,1,out_channels[0]).astype(np.float32)
init_b_CL_3 = np.random.randn(1,1,1,out_channels[0]).astype(np.float32)
init_W_CL_4 = np.random.randn(window_width[1],embedding_dimensions,1,out_channels[1]).astype(np.float32)
init_b_CL_4 = np.random.randn(1,1,1,out_channels[1]).astype(np.float32)
init_W_CL_5 = np.random.randn(window_width[2],embedding_dimensions,1,out_channels[2]).astype(np.float32)
init_b_CL_5 = np.random.randn(1,1,1,out_channels[2]).astype(np.float32)


X = tf.placeholder(tf.int32, [None, n_steps], name="X") #m * n_steps
y = tf.placeholder(tf.float32, [None], name="y")
learning_rate = tf.placeholder(tf.float32)
#training = tf.placeholder_with_default(False, shape=(), name='training')

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)# n_words * embedding_dimensions
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X) # m * n_steps * embedding_dimensions

with tf.name_scope("CNN_3"):
    W_CL_3 = tf.Variable(initial_value=init_W_CL_3)
    b_CL_3 = tf.Variable(initial_value=init_b_CL_3)
    CL_3 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_3, strides=[1,1,1,1], padding="VALID")# m * n_steps - 3 + 1 *1 * out_channels 
    activated_CL_3 = activation_fn(tf.add(CL_3,b_CL_3)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_3 = tf.reshape(tf.math.reduce_max(activated_CL_3,axis=1),[-1,out_channels[0]]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_4"):
    W_CL_4 = tf.Variable(initial_value=init_W_CL_4)
    b_CL_4 = tf.Variable(initial_value=init_b_CL_4)
    CL_4 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_4, strides=[1,1,1,1], padding="VALID")# m * n_steps - 4 + 1 *1 * out_channels 
    activated_CL_4 = activation_fn(tf.add(CL_4,b_CL_4)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_4 = tf.reshape(tf.math.reduce_max(activated_CL_4,axis=1),[-1,out_channels[1]]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_5"):
    W_CL_5 = tf.Variable(initial_value=init_W_CL_5)
    b_CL_5 = tf.Variable(initial_value=init_b_CL_5)
    CL_5 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_5, strides=[1,1,1,1], padding="VALID")# m * n_steps - 5 + 1 *1 * out_channels 
    activated_CL_5 = activation_fn(tf.add(CL_5,b_CL_5)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_5 = tf.reshape(tf.math.reduce_max(activated_CL_5,axis=1),[-1,out_channels[2]]) # m * 1 * out_channels  --> m * out_channels

with tf.name_scope("Max_pool"):
    MAXPOOL = tf.concat([MAXPOOL_3,MAXPOOL_4,MAXPOOL_5], axis=1)
    
with tf.name_scope("fully_connected_layers"):
    fc_layer = partial(tf.layers.dense, activation=activation_fn, kernel_regularizer=tf.contrib.layers.l2_regularizer(lambda_), kernel_initializer=he_init)
    fc1 = fc_layer(MAXPOOL, n_fc1)
    fc2 = fc_layer(fc1, n_fc2)
    fc3 = fc_layer(fc2, n_fc3)
    fc4 = fc_layer(fc3, n_fc4)
    fc5 = fc_layer(fc4, n_fc5)


with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc5, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    base_loss = tf.reduce_mean(xentropy)
    reg_loss = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    loss = tf.add_n([base_loss] + reg_loss)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    grads_and_vars = optimizer.compute_gradients(loss)
    capped_gvs = [(tf.clip_by_value(grad, -threshold, threshold), var) for grad, var in grads_and_vars]
    l2_grads = tf.norm(grads_and_vars[0])
    l2_capped_grads = tf.norm(capped_gvs[0])
    training_op = optimizer.apply_gradients(capped_gvs)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 50

QIQC = data_split_and_batch(data_targets, cv=1000, dv=2000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
"""lengths, x_b, y_b = QIQC.next_batch()
item = x_b[26]
sentence = []
for i in range(lengths[26]):
  for word, key in words_ids.items():
    if item[i] == key:
      sentence.append(word)
sentence, y_b[26]"""
# Out:
# 'lengths, x_b, y_b = QIQC.next_batch()\nitem = x_b[26]\nsentence = []\nfor i in range(lengths[26]):\n  for word, key in words_ids.items():\n    if item[i] == key:\n      sentence.append(word)\nsentence, y_b[26]'

# %%
model_version = "4.2"

# %%
QIQC.reset()
n_epoch = 8
MODELS_FILE = "models/model{}/QIQC_model{}.ckpt".format(model_version,model_version)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)


t_init = time.time()
lr_stop = 1
lr_stack = []
loss_stack = []
step_stack = []
f1_stack = []
loss_train_stack = []
f1_train_stack = []
grads_train_stack = []
capped_grads_train_stack = []

lr = 0.004

with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        if epoch % 2 == 0 and epoch != 0 :
          lr = lr/2
        for iteration in range(QIQC.nr_batches):            
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            _,grads, capped_grads, f1_train, loss_train = sess.run([training_op, l2_grads, l2_capped_grads, f1, loss], feed_dict={X: X_batch, y: y_batch, learning_rate: lr})
            step = epoch * QIQC.nr_batches + iteration
            if step % 200 ==0:
              f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
              step_stack.append(step)
              loss_stack.append(loss_dev)
              f1_stack.append(f1_dev)
              loss_train_stack.append(loss_train)
              f1_train_stack.append(f1_train)
              grads_train_stack.append(grads)
              capped_grads_train_stack.append(capped_grads)

            if iteration % 10000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 1000 == 0:
                #f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch})
                #f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
                t_1 = time.time()
                t_delta = t_1 - t_0
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/1000
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/8; It. 0/26062; Runtime 11.01 s; Remaining runtime 0h38min15s; f1_train 0.1176; f1_dev nan; loss_train 30.6862; loss_dev 41.9695
# Ep. 1/8; It. 1000/26062; Runtime 41.96 s; Remaining runtime 2h25min7s; f1_train nan; f1_dev 0.5059; loss_train 0.3052; loss_dev 0.3009
# Ep. 1/8; It. 2000/26062; Runtime 41.88 s; Remaining runtime 2h24min7s; f1_train 0.4000; f1_dev 0.1176; loss_train 0.1605; loss_dev 0.1779
# Ep. 1/8; It. 3000/26062; Runtime 41.95 s; Remaining runtime 2h23min40s; f1_train nan; f1_dev 0.2083; loss_train 0.1441; loss_dev 0.1810
# Ep. 1/8; It. 4000/26062; Runtime 41.95 s; Remaining runtime 2h22min59s; f1_train 0.6667; f1_dev 0.4046; loss_train 0.1923; loss_dev 0.1626
# Ep. 1/8; It. 5000/26062; Runtime 41.92 s; Remaining runtime 2h22min9s; f1_train 0.6667; f1_dev 0.3057; loss_train 0.0922; loss_dev 0.1610
# Ep. 1/8; It. 6000/26062; Runtime 41.93 s; Remaining runtime 2h21min30s; f1_train 0.5714; f1_dev 0.5746; loss_train 0.2384; loss_dev 0.1920
# Ep. 1/8; It. 7000/26062; Runtime 41.99 s; Remaining runtime 2h21min0s; f1_train nan; f1_dev 0.5759; loss_train 0.1763; loss_dev 0.1690
# Ep. 1/8; It. 8000/26062; Runtime 41.94 s; Remaining runtime 2h20min8s; f1_train nan; f1_dev 0.5455; loss_train 0.1020; loss_dev 0.1439
# Ep. 1/8; It. 9000/26062; Runtime 41.85 s; Remaining runtime 2h19min7s; f1_train 0.6667; f1_dev 0.4318; loss_train 0.1288; loss_dev 0.1470
# Ep. 1/8; It. 10000/26062; Runtime 44.99 s; Remaining runtime 2h28min49s; f1_train 0.4000; f1_dev 0.1460; loss_train 0.1834; loss_dev 0.1782
# Ep. 1/8; It. 11000/26062; Runtime 42.06 s; Remaining runtime 2h18min26s; f1_train 0.6667; f1_dev 0.4520; loss_train 0.0686; loss_dev 0.1484
# Ep. 1/8; It. 12000/26062; Runtime 41.83 s; Remaining runtime 2h16min59s; f1_train 0.8889; f1_dev 0.5490; loss_train 0.1271; loss_dev 0.1809
# Ep. 1/8; It. 13000/26062; Runtime 41.85 s; Remaining runtime 2h16min21s; f1_train 0.5000; f1_dev 0.5361; loss_train 0.1387; loss_dev 0.1454
# Ep. 1/8; It. 14000/26062; Runtime 41.91 s; Remaining runtime 2h15min51s; f1_train nan; f1_dev 0.5222; loss_train 0.1256; loss_dev 0.1498
# Ep. 1/8; It. 15000/26062; Runtime 41.77 s; Remaining runtime 2h14min43s; f1_train nan; f1_dev 0.0781; loss_train 0.1829; loss_dev 0.1876
# Ep. 1/8; It. 16000/26062; Runtime 41.74 s; Remaining runtime 2h13min55s; f1_train nan; f1_dev 0.2222; loss_train 0.1508; loss_dev 0.1540
# Ep. 1/8; It. 17000/26062; Runtime 41.82 s; Remaining runtime 2h13min27s; f1_train 0.6667; f1_dev 0.4699; loss_train 0.1109; loss_dev 0.1476
# Ep. 1/8; It. 18000/26062; Runtime 41.78 s; Remaining runtime 2h12min38s; f1_train 0.3333; f1_dev 0.2313; loss_train 0.2086; loss_dev 0.1509
# Ep. 1/8; It. 19000/26062; Runtime 41.80 s; Remaining runtime 2h12min0s; f1_train nan; f1_dev 0.3681; loss_train 0.0778; loss_dev 0.1524
# Ep. 1/8; It. 20000/26062; Runtime 44.31 s; Remaining runtime 2h19min11s; f1_train nan; f1_dev 0.1343; loss_train 0.7296; loss_dev 0.7017
# Ep. 1/8; It. 21000/26062; Runtime 41.90 s; Remaining runtime 2h10min55s; f1_train nan; f1_dev 0.5926; loss_train 0.1908; loss_dev 0.1618
# Ep. 1/8; It. 22000/26062; Runtime 41.80 s; Remaining runtime 2h9min54s; f1_train 1.0000; f1_dev 0.4693; loss_train 0.0551; loss_dev 0.1502
# Ep. 1/8; It. 23000/26062; Runtime 41.76 s; Remaining runtime 2h9min5s; f1_train nan; f1_dev 0.5784; loss_train 0.1407; loss_dev 0.1451
# Ep. 1/8; It. 24000/26062; Runtime 41.79 s; Remaining runtime 2h8min30s; f1_train nan; f1_dev 0.5625; loss_train 0.1682; loss_dev 0.1395
# Ep. 1/8; It. 25000/26062; Runtime 41.80 s; Remaining runtime 2h7min50s; f1_train 0.6667; f1_dev 0.5856; loss_train 0.1517; loss_dev 0.1389
# Ep. 1/8; It. 26000/26062; Runtime 41.82 s; Remaining runtime 2h7min11s; f1_train nan; f1_dev 0.1884; loss_train 0.7029; loss_dev 0.7578
# Ep. 2/8; It. 0/26062; Runtime 9.53 s; Remaining runtime 0h28min58s; f1_train 0.6000; f1_dev 0.1884; loss_train 0.5836; loss_dev 0.7578
# Ep. 2/8; It. 1000/26062; Runtime 42.07 s; Remaining runtime 2h7min13s; f1_train nan; f1_dev 0.5258; loss_train 0.2863; loss_dev 0.1414
# Ep. 2/8; It. 2000/26062; Runtime 41.75 s; Remaining runtime 2h5min33s; f1_train 1.0000; f1_dev 0.5054; loss_train 0.0470; loss_dev 0.1406
# Ep. 2/8; It. 3000/26062; Runtime 41.84 s; Remaining runtime 2h5min6s; f1_train nan; f1_dev 0.4945; loss_train 0.0812; loss_dev 0.1354
# Ep. 2/8; It. 4000/26062; Runtime 41.81 s; Remaining runtime 2h4min20s; f1_train nan; f1_dev 0.5617; loss_train 0.1180; loss_dev 0.2071
# Ep. 2/8; It. 5000/26062; Runtime 41.81 s; Remaining runtime 2h3min37s; f1_train nan; f1_dev 0.3827; loss_train 0.0861; loss_dev 0.1468
# Ep. 2/8; It. 6000/26062; Runtime 41.78 s; Remaining runtime 2h2min50s; f1_train 0.6667; f1_dev 0.5319; loss_train 0.0803; loss_dev 0.1457
# Ep. 2/8; It. 7000/26062; Runtime 41.82 s; Remaining runtime 2h2min16s; f1_train 0.3333; f1_dev 0.5269; loss_train 0.1408; loss_dev 0.1364
# Ep. 2/8; It. 8000/26062; Runtime 41.78 s; Remaining runtime 2h1min27s; f1_train nan; f1_dev 0.5899; loss_train 0.1139; loss_dev 0.1332
# Ep. 2/8; It. 9000/26062; Runtime 41.76 s; Remaining runtime 2h0min43s; f1_train nan; f1_dev 0.6009; loss_train 0.0933; loss_dev 0.1362
# Ep. 2/8; It. 10000/26062; Runtime 45.24 s; Remaining runtime 2h10min1s; f1_train nan; f1_dev 0.5929; loss_train 0.0654; loss_dev 0.1364
# Ep. 2/8; It. 11000/26062; Runtime 41.97 s; Remaining runtime 1h59min55s; f1_train 1.0000; f1_dev 0.5823; loss_train 0.0550; loss_dev 0.1414
# Ep. 2/8; It. 12000/26062; Runtime 41.78 s; Remaining runtime 1h58min40s; f1_train nan; f1_dev 0.2483; loss_train 0.1151; loss_dev 0.1532
# Ep. 2/8; It. 13000/26062; Runtime 41.73 s; Remaining runtime 1h57min49s; f1_train 0.4444; f1_dev 0.1471; loss_train 19.2724; loss_dev 59.7953
# Ep. 2/8; It. 14000/26062; Runtime 41.77 s; Remaining runtime 1h57min15s; f1_train 0.3333; f1_dev 0.6141; loss_train 0.2021; loss_dev 0.1472
# Ep. 2/8; It. 15000/26062; Runtime 41.78 s; Remaining runtime 1h56min35s; f1_train 0.6667; f1_dev 0.4624; loss_train 0.1081; loss_dev 0.1376
# Ep. 2/8; It. 16000/26062; Runtime 41.78 s; Remaining runtime 1h55min52s; f1_train 0.5714; f1_dev 0.4740; loss_train 0.1249; loss_dev 0.1393
# Ep. 2/8; It. 17000/26062; Runtime 41.84 s; Remaining runtime 1h55min21s; f1_train 0.8571; f1_dev 0.5780; loss_train 0.1069; loss_dev 0.1327
# Ep. 2/8; It. 18000/26062; Runtime 41.76 s; Remaining runtime 1h54min27s; f1_train nan; f1_dev 0.5865; loss_train 0.2462; loss_dev 0.1360
# Ep. 2/8; It. 19000/26062; Runtime 41.72 s; Remaining runtime 1h53min38s; f1_train 0.5714; f1_dev 0.6126; loss_train 0.1680; loss_dev 0.1638
# Ep. 2/8; It. 20000/26062; Runtime 44.26 s; Remaining runtime 1h59min48s; f1_train 0.4000; f1_dev 0.6227; loss_train 0.1462; loss_dev 0.1531
# Ep. 2/8; It. 21000/26062; Runtime 41.85 s; Remaining runtime 1h52min35s; f1_train 0.2222; f1_dev 0.5054; loss_train 0.3306; loss_dev 0.1736
# Ep. 2/8; It. 22000/26062; Runtime 41.74 s; Remaining runtime 1h51min36s; f1_train 0.5714; f1_dev 0.6122; loss_train 0.1787; loss_dev 0.1367
# Ep. 2/8; It. 23000/26062; Runtime 41.78 s; Remaining runtime 1h51min1s; f1_train nan; f1_dev 0.5767; loss_train 0.0653; loss_dev 0.1325
# Ep. 2/8; It. 24000/26062; Runtime 41.78 s; Remaining runtime 1h50min19s; f1_train nan; f1_dev 0.6027; loss_train 0.0608; loss_dev 0.1315
# Ep. 2/8; It. 25000/26062; Runtime 41.79 s; Remaining runtime 1h49min39s; f1_train 0.4444; f1_dev 0.4000; loss_train 1.1866; loss_dev 2.3236
# Ep. 2/8; It. 26000/26062; Runtime 41.75 s; Remaining runtime 1h48min51s; f1_train 0.5000; f1_dev 0.5588; loss_train 0.2497; loss_dev 0.1308
# Ep. 3/8; It. 0/26062; Runtime 9.06 s; Remaining runtime 0h23min37s; f1_train 0.6667; f1_dev 0.5588; loss_train 0.1453; loss_dev 0.1308
# Ep. 3/8; It. 1000/26062; Runtime 42.03 s; Remaining runtime 1h48min49s; f1_train 1.0000; f1_dev 0.6128; loss_train 0.0467; loss_dev 0.1295
# Ep. 3/8; It. 2000/26062; Runtime 41.75 s; Remaining runtime 1h47min24s; f1_train 0.4444; f1_dev 0.5743; loss_train 0.2705; loss_dev 0.1286
# Ep. 3/8; It. 3000/26062; Runtime 41.77 s; Remaining runtime 1h46min46s; f1_train 0.3333; f1_dev 0.6091; loss_train 0.1487; loss_dev 0.1301
# Ep. 3/8; It. 4000/26062; Runtime 41.78 s; Remaining runtime 1h46min6s; f1_train 0.6667; f1_dev 0.4773; loss_train 0.1025; loss_dev 0.1350
# Ep. 3/8; It. 5000/26062; Runtime 41.80 s; Remaining runtime 1h45min27s; f1_train nan; f1_dev 0.4767; loss_train 0.1356; loss_dev 0.1376
# Ep. 3/8; It. 6000/26062; Runtime 41.81 s; Remaining runtime 1h44min46s; f1_train 0.5000; f1_dev 0.6194; loss_train 0.1955; loss_dev 0.1396
# Ep. 3/8; It. 7000/26062; Runtime 41.76 s; Remaining runtime 1h43min57s; f1_train 0.6667; f1_dev 0.5780; loss_train 0.0588; loss_dev 0.1278
# Ep. 3/8; It. 8000/26062; Runtime 41.77 s; Remaining runtime 1h43min17s; f1_train 1.0000; f1_dev 0.5600; loss_train 0.0765; loss_dev 0.1375
# Ep. 3/8; It. 9000/26062; Runtime 41.79 s; Remaining runtime 1h42min39s; f1_train 0.6667; f1_dev 0.6240; loss_train 0.1990; loss_dev 0.1549
# Ep. 3/8; It. 10000/26062; Runtime 45.65 s; Remaining runtime 1h51min21s; f1_train 0.6667; f1_dev 0.6340; loss_train 0.1309; loss_dev 0.1378
# Ep. 3/8; It. 11000/26062; Runtime 42.01 s; Remaining runtime 1h41min46s; f1_train 0.2857; f1_dev 0.5397; loss_train 0.2158; loss_dev 0.1292
# Ep. 3/8; It. 12000/26062; Runtime 41.78 s; Remaining runtime 1h40min31s; f1_train 1.0000; f1_dev 0.6244; loss_train 0.0830; loss_dev 0.1936
# Ep. 3/8; It. 13000/26062; Runtime 41.85 s; Remaining runtime 1h40min0s; f1_train nan; f1_dev 0.6131; loss_train 0.3205; loss_dev 0.1485
# Ep. 3/8; It. 14000/26062; Runtime 41.76 s; Remaining runtime 1h39min5s; f1_train nan; f1_dev 0.5905; loss_train 0.0576; loss_dev 0.1253
# Ep. 3/8; It. 15000/26062; Runtime 41.78 s; Remaining runtime 1h38min26s; f1_train 0.5000; f1_dev 0.6202; loss_train 0.0978; loss_dev 0.1383
# Ep. 3/8; It. 16000/26062; Runtime 41.77 s; Remaining runtime 1h37min43s; f1_train 0.5000; f1_dev 0.5657; loss_train 0.1658; loss_dev 0.1270
# Ep. 3/8; It. 17000/26062; Runtime 41.79 s; Remaining runtime 1h37min4s; f1_train 0.8571; f1_dev 0.6044; loss_train 0.1552; loss_dev 0.1267
# Ep. 3/8; It. 18000/26062; Runtime 41.79 s; Remaining runtime 1h36min23s; f1_train 0.7500; f1_dev 0.5872; loss_train 0.1195; loss_dev 0.1736
# Ep. 3/8; It. 19000/26062; Runtime 41.81 s; Remaining runtime 1h35min43s; f1_train 0.8000; f1_dev 0.5974; loss_train 0.0934; loss_dev 0.1267
# Ep. 3/8; It. 20000/26062; Runtime 44.41 s; Remaining runtime 1h40min55s; f1_train 1.0000; f1_dev 0.5911; loss_train 0.0680; loss_dev 0.1259
# Ep. 3/8; It. 21000/26062; Runtime 41.93 s; Remaining runtime 1h34min36s; f1_train 0.5714; f1_dev 0.6316; loss_train 0.1950; loss_dev 0.1412
# Ep. 3/8; It. 22000/26062; Runtime 41.75 s; Remaining runtime 1h33min29s; f1_train 0.5000; f1_dev 0.6207; loss_train 0.0822; loss_dev 0.1528
# Ep. 3/8; It. 23000/26062; Runtime 41.82 s; Remaining runtime 1h32min57s; f1_train 1.0000; f1_dev 0.6255; loss_train 0.0552; loss_dev 0.1300
# Ep. 3/8; It. 24000/26062; Runtime 41.77 s; Remaining runtime 1h32min8s; f1_train 0.5714; f1_dev 0.6161; loss_train 0.1192; loss_dev 0.1280
# Ep. 3/8; It. 25000/26062; Runtime 41.79 s; Remaining runtime 1h31min29s; f1_train 1.0000; f1_dev 0.5263; loss_train 0.0910; loss_dev 0.1297
# Ep. 3/8; It. 26000/26062; Runtime 41.79 s; Remaining runtime 1h30min48s; f1_train 0.8889; f1_dev 0.6180; loss_train 0.1206; loss_dev 0.1254
# Ep. 4/8; It. 0/26062; Runtime 8.53 s; Remaining runtime 0h18min31s; f1_train 0.5714; f1_dev 0.6180; loss_train 0.1161; loss_dev 0.1254
# Ep. 4/8; It. 1000/26062; Runtime 42.04 s; Remaining runtime 1h30min36s; f1_train 0.5000; f1_dev 0.6260; loss_train 0.1746; loss_dev 0.1347
# Ep. 4/8; It. 2000/26062; Runtime 41.81 s; Remaining runtime 1h29min24s; f1_train 0.7500; f1_dev 0.5417; loss_train 0.2019; loss_dev 0.1291
# Ep. 4/8; It. 3000/26062; Runtime 41.80 s; Remaining runtime 1h28min41s; f1_train 0.6667; f1_dev 0.4972; loss_train 0.1242; loss_dev 0.1636
# Ep. 4/8; It. 4000/26062; Runtime 41.76 s; Remaining runtime 1h27min54s; f1_train 0.4615; f1_dev 0.6083; loss_train 0.2285; loss_dev 0.1300
# Ep. 4/8; It. 5000/26062; Runtime 41.81 s; Remaining runtime 1h27min19s; f1_train 1.0000; f1_dev 0.5943; loss_train 0.0840; loss_dev 0.1287
# Ep. 4/8; It. 6000/26062; Runtime 41.82 s; Remaining runtime 1h26min38s; f1_train 0.6667; f1_dev 0.5800; loss_train 0.1144; loss_dev 0.1289
# Ep. 4/8; It. 7000/26062; Runtime 41.81 s; Remaining runtime 1h25min55s; f1_train 0.8000; f1_dev 0.5872; loss_train 0.1597; loss_dev 0.1249
# Ep. 4/8; It. 8000/26062; Runtime 41.80 s; Remaining runtime 1h25min13s; f1_train nan; f1_dev 0.6224; loss_train 0.0937; loss_dev 0.1287
# Ep. 4/8; It. 9000/26062; Runtime 41.79 s; Remaining runtime 1h24min29s; f1_train 0.4000; f1_dev 0.3694; loss_train 0.1505; loss_dev 0.1603
# Ep. 4/8; It. 10000/26062; Runtime 44.96 s; Remaining runtime 1h30min8s; f1_train 0.6667; f1_dev 0.5269; loss_train 0.0982; loss_dev 0.1266
# Ep. 4/8; It. 11000/26062; Runtime 42.05 s; Remaining runtime 1h23min37s; f1_train nan; f1_dev 0.6165; loss_train 0.0887; loss_dev 0.1477
# Ep. 4/8; It. 12000/26062; Runtime 41.79 s; Remaining runtime 1h22min24s; f1_train 0.8333; f1_dev 0.6099; loss_train 0.1176; loss_dev 0.1233
# Ep. 4/8; It. 13000/26062; Runtime 41.85 s; Remaining runtime 1h21min49s; f1_train 0.8000; f1_dev 0.5584; loss_train 0.0760; loss_dev 0.1264
# Ep. 4/8; It. 14000/26062; Runtime 41.82 s; Remaining runtime 1h21min4s; f1_train 0.8000; f1_dev 0.6356; loss_train 0.0786; loss_dev 0.1260
# Ep. 4/8; It. 15000/26062; Runtime 41.83 s; Remaining runtime 1h20min23s; f1_train nan; f1_dev 0.6303; loss_train 0.0536; loss_dev 0.1278
# Ep. 4/8; It. 16000/26062; Runtime 41.83 s; Remaining runtime 1h19min41s; f1_train 0.4000; f1_dev 0.4588; loss_train 0.1106; loss_dev 0.1305
# Ep. 4/8; It. 17000/26062; Runtime 41.89 s; Remaining runtime 1h19min6s; f1_train 0.5714; f1_dev 0.2603; loss_train 0.2166; loss_dev 0.5738
# Ep. 4/8; It. 18000/26062; Runtime 41.79 s; Remaining runtime 1h18min13s; f1_train 0.5714; f1_dev 0.6233; loss_train 0.1743; loss_dev 0.1260
# Ep. 4/8; It. 19000/26062; Runtime 41.82 s; Remaining runtime 1h17min35s; f1_train 0.4000; f1_dev 0.5951; loss_train 0.2344; loss_dev 0.1262
# Ep. 4/8; It. 20000/26062; Runtime 44.72 s; Remaining runtime 1h22min12s; f1_train 1.0000; f1_dev 0.5865; loss_train 0.0535; loss_dev 0.1224
# Ep. 4/8; It. 21000/26062; Runtime 42.02 s; Remaining runtime 1h16min33s; f1_train 1.0000; f1_dev 0.6261; loss_train 0.0569; loss_dev 0.1237
# Ep. 4/8; It. 22000/26062; Runtime 41.80 s; Remaining runtime 1h15min27s; f1_train nan; f1_dev 0.4651; loss_train 0.0466; loss_dev 0.1292
# Ep. 4/8; It. 23000/26062; Runtime 41.86 s; Remaining runtime 1h14min52s; f1_train 0.6667; f1_dev 0.5922; loss_train 0.1671; loss_dev 0.1342
# Ep. 4/8; It. 24000/26062; Runtime 41.84 s; Remaining runtime 1h14min7s; f1_train 0.6667; f1_dev 0.6009; loss_train 0.2812; loss_dev 0.2136
# Ep. 4/8; It. 25000/26062; Runtime 41.77 s; Remaining runtime 1h13min18s; f1_train 1.0000; f1_dev 0.6228; loss_train 0.0674; loss_dev 0.1245
# Ep. 4/8; It. 26000/26062; Runtime 41.79 s; Remaining runtime 1h12min38s; f1_train 0.8000; f1_dev 0.5829; loss_train 0.1084; loss_dev 0.1253
# Ep. 5/8; It. 0/26062; Runtime 9.18 s; Remaining runtime 0h15min57s; f1_train 0.5000; f1_dev 0.5911; loss_train 0.1030; loss_dev 0.1230
# Ep. 5/8; It. 1000/26062; Runtime 42.00 s; Remaining runtime 1h12min16s; f1_train 1.0000; f1_dev 0.5829; loss_train 0.0464; loss_dev 0.1228
# Ep. 5/8; It. 2000/26062; Runtime 41.79 s; Remaining runtime 1h11min12s; f1_train nan; f1_dev 0.6117; loss_train 0.0764; loss_dev 0.1206
# Ep. 5/8; It. 3000/26062; Runtime 41.81 s; Remaining runtime 1h10min32s; f1_train 0.6667; f1_dev 0.5951; loss_train 0.0882; loss_dev 0.1234
# Ep. 5/8; It. 4000/26062; Runtime 41.82 s; Remaining runtime 1h9min52s; f1_train 0.8000; f1_dev 0.6220; loss_train 0.0689; loss_dev 0.1225
# Ep. 5/8; It. 5000/26062; Runtime 41.84 s; Remaining runtime 1h9min12s; f1_train 0.5714; f1_dev 0.5960; loss_train 0.1289; loss_dev 0.1231
# Ep. 5/8; It. 6000/26062; Runtime 41.83 s; Remaining runtime 1h8min29s; f1_train 0.5000; f1_dev 0.6337; loss_train 0.1289; loss_dev 0.1249
# Ep. 5/8; It. 7000/26062; Runtime 41.83 s; Remaining runtime 1h7min48s; f1_train 0.8571; f1_dev 0.5876; loss_train 0.0932; loss_dev 0.1237
# Ep. 5/8; It. 8000/26062; Runtime 41.86 s; Remaining runtime 1h7min8s; f1_train nan; f1_dev 0.4678; loss_train 0.0494; loss_dev 0.1301
# Ep. 5/8; It. 9000/26062; Runtime 41.82 s; Remaining runtime 1h6min23s; f1_train 1.0000; f1_dev 0.5859; loss_train 0.0457; loss_dev 0.1216
# Ep. 5/8; It. 10000/26062; Runtime 45.28 s; Remaining runtime 1h11min7s; f1_train 0.5000; f1_dev 0.6250; loss_train 0.0866; loss_dev 0.1451
# Ep. 5/8; It. 11000/26062; Runtime 42.12 s; Remaining runtime 1h5min27s; f1_train 0.8000; f1_dev 0.6175; loss_train 0.1453; loss_dev 0.1200
# Ep. 5/8; It. 12000/26062; Runtime 41.86 s; Remaining runtime 1h4min21s; f1_train 0.5000; f1_dev 0.6267; loss_train 0.1024; loss_dev 0.1233
# Ep. 5/8; It. 13000/26062; Runtime 41.91 s; Remaining runtime 1h3min44s; f1_train nan; f1_dev 0.5532; loss_train 0.1813; loss_dev 0.1270
# Ep. 5/8; It. 14000/26062; Runtime 41.84 s; Remaining runtime 1h2min55s; f1_train 0.4000; f1_dev 0.6124; loss_train 0.1632; loss_dev 0.1215
# Ep. 5/8; It. 15000/26062; Runtime 41.84 s; Remaining runtime 1h2min14s; f1_train 0.8571; f1_dev 0.6356; loss_train 0.1136; loss_dev 0.1199
# Ep. 5/8; It. 16000/26062; Runtime 41.83 s; Remaining runtime 1h1min31s; f1_train nan; f1_dev 0.6195; loss_train 0.0261; loss_dev 0.1215
# Ep. 5/8; It. 17000/26062; Runtime 41.85 s; Remaining runtime 1h0min51s; f1_train 0.6667; f1_dev 0.6175; loss_train 0.0590; loss_dev 0.1228
# Ep. 5/8; It. 18000/26062; Runtime 41.89 s; Remaining runtime 1h0min13s; f1_train 1.0000; f1_dev 0.5905; loss_train 0.0562; loss_dev 0.1261
# Ep. 5/8; It. 19000/26062; Runtime 41.82 s; Remaining runtime 0h59min25s; f1_train 0.5000; f1_dev 0.5596; loss_train 0.0872; loss_dev 0.1225
# Ep. 5/8; It. 20000/26062; Runtime 44.45 s; Remaining runtime 1h2min24s; f1_train 0.6667; f1_dev 0.6119; loss_train 0.1916; loss_dev 0.1200
# Ep. 5/8; It. 21000/26062; Runtime 42.01 s; Remaining runtime 0h58min17s; f1_train 0.5000; f1_dev 0.6281; loss_train 0.1363; loss_dev 0.1230
# Ep. 5/8; It. 22000/26062; Runtime 41.84 s; Remaining runtime 0h57min21s; f1_train nan; f1_dev 0.6168; loss_train 0.1556; loss_dev 0.1196
# Ep. 5/8; It. 23000/26062; Runtime 41.87 s; Remaining runtime 0h56min41s; f1_train 0.8000; f1_dev 0.5773; loss_train 0.1255; loss_dev 0.1230
# Ep. 5/8; It. 24000/26062; Runtime 41.87 s; Remaining runtime 0h55min59s; f1_train 0.3333; f1_dev 0.5140; loss_train 0.2551; loss_dev 0.1268
# Ep. 5/8; It. 25000/26062; Runtime 41.89 s; Remaining runtime 0h55min19s; f1_train 0.5714; f1_dev 0.5612; loss_train 0.1109; loss_dev 0.1264
# Ep. 5/8; It. 26000/26062; Runtime 41.87 s; Remaining runtime 0h54min35s; f1_train nan; f1_dev 0.5684; loss_train 0.0927; loss_dev 0.1248
# Ep. 6/8; It. 0/26062; Runtime 9.22 s; Remaining runtime 0h12min0s; f1_train 1.0000; f1_dev 0.5684; loss_train 0.0638; loss_dev 0.1248
# Ep. 6/8; It. 1000/26062; Runtime 42.12 s; Remaining runtime 0h54min10s; f1_train nan; f1_dev 0.6216; loss_train 0.1295; loss_dev 0.1218
# Ep. 6/8; It. 2000/26062; Runtime 41.83 s; Remaining runtime 0h53min6s; f1_train 0.8000; f1_dev 0.6300; loss_train 0.0787; loss_dev 0.1218
# Ep. 6/8; It. 3000/26062; Runtime 41.86 s; Remaining runtime 0h52min27s; f1_train 0.8000; f1_dev 0.6307; loss_train 0.0905; loss_dev 0.1241
# Ep. 6/8; It. 4000/26062; Runtime 41.84 s; Remaining runtime 0h51min44s; f1_train 0.4444; f1_dev 0.6276; loss_train 0.1677; loss_dev 0.1228
# Ep. 6/8; It. 5000/26062; Runtime 41.85 s; Remaining runtime 0h51min2s; f1_train 0.4000; f1_dev 0.5972; loss_train 0.0740; loss_dev 0.1227
# Ep. 6/8; It. 6000/26062; Runtime 41.89 s; Remaining runtime 0h50min23s; f1_train 0.5000; f1_dev 0.6000; loss_train 0.1303; loss_dev 0.1409
# Ep. 6/8; It. 7000/26062; Runtime 41.88 s; Remaining runtime 0h49min41s; f1_train 0.7500; f1_dev 0.6299; loss_train 0.1420; loss_dev 0.1244
# Ep. 6/8; It. 8000/26062; Runtime 41.87 s; Remaining runtime 0h48min58s; f1_train 0.6000; f1_dev 0.6078; loss_train 0.1686; loss_dev 0.1190
# Ep. 6/8; It. 9000/26062; Runtime 41.85 s; Remaining runtime 0h48min15s; f1_train nan; f1_dev 0.6429; loss_train 0.0392; loss_dev 0.1198
# Ep. 6/8; It. 10000/26062; Runtime 45.18 s; Remaining runtime 0h51min20s; f1_train 0.6667; f1_dev 0.6040; loss_train 0.1018; loss_dev 0.1199
# Ep. 6/8; It. 11000/26062; Runtime 42.05 s; Remaining runtime 0h47min5s; f1_train 0.5000; f1_dev 0.5859; loss_train 0.1687; loss_dev 0.1262
# Ep. 6/8; It. 12000/26062; Runtime 41.80 s; Remaining runtime 0h46min6s; f1_train 0.5714; f1_dev 0.6393; loss_train 0.0918; loss_dev 0.1202
# Ep. 6/8; It. 13000/26062; Runtime 41.87 s; Remaining runtime 0h45min29s; f1_train 0.4000; f1_dev 0.6256; loss_train 0.1921; loss_dev 0.1191
# Ep. 6/8; It. 14000/26062; Runtime 41.90 s; Remaining runtime 0h44min49s; f1_train 1.0000; f1_dev 0.6204; loss_train 0.0552; loss_dev 0.1217
# Ep. 6/8; It. 15000/26062; Runtime 41.84 s; Remaining runtime 0h44min3s; f1_train nan; f1_dev 0.5918; loss_train 0.2553; loss_dev 0.1203
# Ep. 6/8; It. 16000/26062; Runtime 41.87 s; Remaining runtime 0h43min23s; f1_train 0.8889; f1_dev 0.5846; loss_train 0.0929; loss_dev 0.1305
# Ep. 6/8; It. 17000/26062; Runtime 41.86 s; Remaining runtime 0h42min41s; f1_train 0.4000; f1_dev 0.6320; loss_train 0.1187; loss_dev 0.1184
# Ep. 6/8; It. 18000/26062; Runtime 41.84 s; Remaining runtime 0h41min58s; f1_train 0.5000; f1_dev 0.6359; loss_train 0.0774; loss_dev 0.1183
# Ep. 6/8; It. 19000/26062; Runtime 41.86 s; Remaining runtime 0h41min17s; f1_train 0.7273; f1_dev 0.6360; loss_train 0.1535; loss_dev 0.1252
# Ep. 6/8; It. 20000/26062; Runtime 44.44 s; Remaining runtime 0h43min6s; f1_train 1.0000; f1_dev 0.6087; loss_train 0.0630; loss_dev 0.1193
# Ep. 6/8; It. 21000/26062; Runtime 41.96 s; Remaining runtime 0h39min59s; f1_train nan; f1_dev 0.6414; loss_train 0.0559; loss_dev 0.1188
# Ep. 6/8; It. 22000/26062; Runtime 41.87 s; Remaining runtime 0h39min12s; f1_train 0.8571; f1_dev 0.5854; loss_train 0.0668; loss_dev 0.1204
# Ep. 6/8; It. 23000/26062; Runtime 41.91 s; Remaining runtime 0h38min32s; f1_train 1.0000; f1_dev 0.6078; loss_train 0.0670; loss_dev 0.2601
# Ep. 6/8; It. 24000/26062; Runtime 41.88 s; Remaining runtime 0h37min49s; f1_train 1.0000; f1_dev 0.6000; loss_train 0.0708; loss_dev 0.1202
# Ep. 6/8; It. 25000/26062; Runtime 41.83 s; Remaining runtime 0h37min4s; f1_train nan; f1_dev 0.6547; loss_train 0.1029; loss_dev 0.1179
# Ep. 6/8; It. 26000/26062; Runtime 41.87 s; Remaining runtime 0h36min25s; f1_train 0.5000; f1_dev 0.6547; loss_train 0.0580; loss_dev 0.1182
# Ep. 7/8; It. 0/26062; Runtime 8.89 s; Remaining runtime 0h7min43s; f1_train nan; f1_dev 0.6547; loss_train 0.0463; loss_dev 0.1182
# Ep. 7/8; It. 1000/26062; Runtime 42.15 s; Remaining runtime 0h35min54s; f1_train nan; f1_dev 0.6184; loss_train 0.0378; loss_dev 0.1179
# Ep. 7/8; It. 2000/26062; Runtime 41.88 s; Remaining runtime 0h34min59s; f1_train 0.7500; f1_dev 0.6250; loss_train 0.0875; loss_dev 0.1204
# Ep. 7/8; It. 3000/26062; Runtime 41.85 s; Remaining runtime 0h34min16s; f1_train 1.0000; f1_dev 0.6429; loss_train 0.0304; loss_dev 0.1194
# Ep. 7/8; It. 4000/26062; Runtime 41.89 s; Remaining runtime 0h33min36s; f1_train 0.6667; f1_dev 0.6162; loss_train 0.1309; loss_dev 0.1176
# Ep. 7/8; It. 5000/26062; Runtime 41.86 s; Remaining runtime 0h32min52s; f1_train 0.8571; f1_dev 0.6333; loss_train 0.0841; loss_dev 0.1196
# Ep. 7/8; It. 6000/26062; Runtime 41.83 s; Remaining runtime 0h32min9s; f1_train nan; f1_dev 0.6415; loss_train 0.1040; loss_dev 0.1174
# Ep. 7/8; It. 7000/26062; Runtime 41.87 s; Remaining runtime 0h31min29s; f1_train 0.6154; f1_dev 0.6047; loss_train 0.3107; loss_dev 0.1192
# Ep. 7/8; It. 8000/26062; Runtime 41.89 s; Remaining runtime 0h30min48s; f1_train 0.6667; f1_dev 0.6169; loss_train 0.2188; loss_dev 0.1191
# Ep. 7/8; It. 9000/26062; Runtime 41.92 s; Remaining runtime 0h30min7s; f1_train 1.0000; f1_dev 0.6333; loss_train 0.0550; loss_dev 0.1196
# Ep. 7/8; It. 10000/26062; Runtime 45.92 s; Remaining runtime 0h32min14s; f1_train 0.5714; f1_dev 0.6276; loss_train 0.1609; loss_dev 0.1191
# Ep. 7/8; It. 11000/26062; Runtime 42.15 s; Remaining runtime 0h28min53s; f1_train 0.8000; f1_dev 0.6245; loss_train 0.0459; loss_dev 0.1177
# Ep. 7/8; It. 12000/26062; Runtime 41.96 s; Remaining runtime 0h28min3s; f1_train 0.8000; f1_dev 0.6348; loss_train 0.0881; loss_dev 0.1174
# Ep. 7/8; It. 13000/26062; Runtime 41.90 s; Remaining runtime 0h27min19s; f1_train 0.6667; f1_dev 0.6435; loss_train 0.1509; loss_dev 0.1211
# Ep. 7/8; It. 14000/26062; Runtime 41.91 s; Remaining runtime 0h26min37s; f1_train 0.7500; f1_dev 0.6000; loss_train 0.1156; loss_dev 0.1243
# Ep. 7/8; It. 15000/26062; Runtime 41.88 s; Remaining runtime 0h25min54s; f1_train 0.2857; f1_dev 0.6238; loss_train 0.1891; loss_dev 0.1191
# Ep. 7/8; It. 16000/26062; Runtime 41.87 s; Remaining runtime 0h25min12s; f1_train nan; f1_dev 0.6186; loss_train 0.0810; loss_dev 0.1208
# Ep. 7/8; It. 17000/26062; Runtime 41.96 s; Remaining runtime 0h24min33s; f1_train nan; f1_dev 0.6197; loss_train 0.0857; loss_dev 0.1186
# Ep. 7/8; It. 18000/26062; Runtime 41.88 s; Remaining runtime 0h23min49s; f1_train 1.0000; f1_dev 0.6311; loss_train 0.0647; loss_dev 0.1173
# Ep. 7/8; It. 19000/26062; Runtime 41.97 s; Remaining runtime 0h23min10s; f1_train 0.8000; f1_dev 0.6094; loss_train 0.1020; loss_dev 0.1201
# Ep. 7/8; It. 20000/26062; Runtime 44.57 s; Remaining runtime 0h23min51s; f1_train 0.8571; f1_dev 0.5789; loss_train 0.0944; loss_dev 0.1236
# Ep. 7/8; It. 21000/26062; Runtime 42.11 s; Remaining runtime 0h21min50s; f1_train 0.8571; f1_dev 0.6207; loss_train 0.0864; loss_dev 0.1197
# Ep. 7/8; It. 22000/26062; Runtime 41.87 s; Remaining runtime 0h21min1s; f1_train 0.6667; f1_dev 0.6275; loss_train 0.1123; loss_dev 0.1176
# Ep. 7/8; It. 23000/26062; Runtime 41.87 s; Remaining runtime 0h20min19s; f1_train 0.6667; f1_dev 0.5888; loss_train 0.2176; loss_dev 0.1220
# Ep. 7/8; It. 24000/26062; Runtime 41.91 s; Remaining runtime 0h19min38s; f1_train 0.8571; f1_dev 0.6261; loss_train 0.0838; loss_dev 0.1184
# Ep. 7/8; It. 25000/26062; Runtime 41.86 s; Remaining runtime 0h18min55s; f1_train 0.7692; f1_dev 0.6267; loss_train 0.1655; loss_dev 0.1184
# Ep. 7/8; It. 26000/26062; Runtime 41.91 s; Remaining runtime 0h18min14s; f1_train 0.5000; f1_dev 0.6066; loss_train 0.0902; loss_dev 0.1185
# Ep. 8/8; It. 0/26062; Runtime 9.73 s; Remaining runtime 0h4min13s; f1_train 0.6667; f1_dev 0.6271; loss_train 0.0678; loss_dev 0.1175
# Ep. 8/8; It. 1000/26062; Runtime 42.13 s; Remaining runtime 0h17min35s; f1_train 0.8889; f1_dev 0.6389; loss_train 0.0733; loss_dev 0.1171
# Ep. 8/8; It. 2000/26062; Runtime 41.86 s; Remaining runtime 0h16min47s; f1_train 0.8889; f1_dev 0.6299; loss_train 0.0879; loss_dev 0.1293
# Ep. 8/8; It. 3000/26062; Runtime 41.86 s; Remaining runtime 0h16min5s; f1_train 0.5000; f1_dev 0.6271; loss_train 0.1421; loss_dev 0.1165
# Ep. 8/8; It. 4000/26062; Runtime 41.88 s; Remaining runtime 0h15min23s; f1_train 0.6667; f1_dev 0.6201; loss_train 0.0473; loss_dev 0.1171
# Ep. 8/8; It. 5000/26062; Runtime 41.92 s; Remaining runtime 0h14min42s; f1_train 0.7692; f1_dev 0.6133; loss_train 0.1443; loss_dev 0.1246
# Ep. 8/8; It. 6000/26062; Runtime 41.94 s; Remaining runtime 0h14min1s; f1_train 0.8000; f1_dev 0.6226; loss_train 0.0651; loss_dev 0.1196
# Ep. 8/8; It. 7000/26062; Runtime 41.89 s; Remaining runtime 0h13min18s; f1_train 0.8000; f1_dev 0.6273; loss_train 0.1007; loss_dev 0.1186
# Ep. 8/8; It. 8000/26062; Runtime 41.90 s; Remaining runtime 0h12min36s; f1_train 0.8571; f1_dev 0.5789; loss_train 0.1621; loss_dev 0.1221
# Ep. 8/8; It. 9000/26062; Runtime 41.87 s; Remaining runtime 0h11min54s; f1_train 0.5714; f1_dev 0.6396; loss_train 0.1189; loss_dev 0.1162
# Ep. 8/8; It. 10000/26062; Runtime 44.92 s; Remaining runtime 0h12min1s; f1_train nan; f1_dev 0.6226; loss_train 0.1316; loss_dev 0.1181
# Ep. 8/8; It. 11000/26062; Runtime 42.11 s; Remaining runtime 0h10min34s; f1_train 0.5714; f1_dev 0.6176; loss_train 0.2057; loss_dev 0.1195
# Ep. 8/8; It. 12000/26062; Runtime 41.92 s; Remaining runtime 0h9min49s; f1_train 0.6667; f1_dev 0.6364; loss_train 0.1632; loss_dev 0.1209
# Ep. 8/8; It. 13000/26062; Runtime 41.89 s; Remaining runtime 0h9min7s; f1_train 0.8889; f1_dev 0.6261; loss_train 0.0876; loss_dev 0.1183
# Ep. 8/8; It. 14000/26062; Runtime 41.84 s; Remaining runtime 0h8min24s; f1_train 0.6667; f1_dev 0.6200; loss_train 0.1148; loss_dev 0.1191
# Ep. 8/8; It. 15000/26062; Runtime 41.94 s; Remaining runtime 0h7min43s; f1_train 0.4000; f1_dev 0.6140; loss_train 0.1130; loss_dev 0.1195
# Ep. 8/8; It. 16000/26062; Runtime 41.88 s; Remaining runtime 0h7min1s; f1_train 0.8000; f1_dev 0.6222; loss_train 0.1067; loss_dev 0.1181
# Ep. 8/8; It. 17000/26062; Runtime 41.87 s; Remaining runtime 0h6min19s; f1_train nan; f1_dev 0.6333; loss_train 0.1062; loss_dev 0.1199
# Ep. 8/8; It. 18000/26062; Runtime 41.91 s; Remaining runtime 0h5min37s; f1_train 0.4000; f1_dev 0.6188; loss_train 0.2369; loss_dev 0.1175
# Ep. 8/8; It. 19000/26062; Runtime 41.96 s; Remaining runtime 0h4min56s; f1_train 0.2857; f1_dev 0.6147; loss_train 0.2270; loss_dev 0.1205
# Ep. 8/8; It. 20000/26062; Runtime 44.50 s; Remaining runtime 0h4min29s; f1_train 0.6667; f1_dev 0.6301; loss_train 0.1273; loss_dev 0.1173
# Ep. 8/8; It. 21000/26062; Runtime 42.03 s; Remaining runtime 0h3min32s; f1_train 1.0000; f1_dev 0.6204; loss_train 0.0331; loss_dev 0.1177
# Ep. 8/8; It. 22000/26062; Runtime 41.96 s; Remaining runtime 0h2min50s; f1_train 0.5000; f1_dev 0.6051; loss_train 0.1012; loss_dev 0.1221
# Ep. 8/8; It. 23000/26062; Runtime 41.94 s; Remaining runtime 0h2min8s; f1_train 0.9091; f1_dev 0.6147; loss_train 0.1090; loss_dev 0.1175
# Ep. 8/8; It. 24000/26062; Runtime 41.94 s; Remaining runtime 0h1min26s; f1_train 0.5000; f1_dev 0.6269; loss_train 0.1100; loss_dev 0.1216
# Ep. 8/8; It. 25000/26062; Runtime 41.93 s; Remaining runtime 0h0min44s; f1_train 0.5714; f1_dev 0.6154; loss_train 0.1486; loss_dev 0.1203
# Ep. 8/8; It. 26000/26062; Runtime 41.98 s; Remaining runtime 0h0min2s; f1_train 0.5000; f1_dev 0.6228; loss_train 0.1521; loss_dev 0.1214
# Total actual runtime: 2 hours 27 min 22 sec

# %%
alpha = 0.1
ewma_loss_dev = numpy_ewma_vectorized(loss_stack, alpha)
ewma_f1_dev = numpy_ewma_vectorized(f1_stack, alpha)
ewma_loss_train = numpy_ewma_vectorized(loss_train_stack, alpha)
ewma_f1_train = numpy_ewma_vectorized(f1_train_stack, alpha)
ewma_grads_l2_norm = numpy_ewma_vectorized(grads_train_stack, alpha)
ewma_capped_grads_l2_norm = numpy_ewma_vectorized(capped_grads_train_stack, alpha)

plt.figure(figsize = (20, 16))
plt.subplot(321) 
plt.plot(step_stack, ewma_loss_dev)
plt.xlabel("Learning Rate")
plt.ylabel("Loss dev")
plt.ylim([0,.3])
plt.subplot(322)
plt.plot(step_stack, ewma_f1_dev)
plt.xlabel("Learning Rate")
plt.ylabel("F1 dev")

plt.subplot(323) 
plt.plot(step_stack, ewma_loss_train)
plt.xlabel("Learning Rate")
plt.ylabel("Loss Train")
plt.ylim([0,0.3])
plt.subplot(324)
plt.plot(step_stack, ewma_f1_train)
plt.xlabel("Learning Rate")
plt.ylabel("F1 Train")

plt.subplot(325)
plt.plot(step_stack,ewma_grads_l2_norm)
plt.xlabel("Learning Rate")
plt.ylabel("Train Gradient Norm")

plt.subplot(326)
plt.plot(step_stack,ewma_capped_grads_l2_norm)
plt.xlabel("Learning Rate")
plt.ylabel("Train Capped Gradient Norm")

plt.show()

# %%
MODELS_FILE = "models/model{}/QIQC_model{}.ckpt".format(model_version,model_version)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model4.2/QIQC_model4.2.ckpt
# cross val f1 47.83%, dev f1 64.39%
