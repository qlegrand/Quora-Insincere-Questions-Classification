# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

def numpy_ewma_vectorized(data, alpha):
    alpha_ = 1-alpha
    D = pd.DataFrame(data)
    M = D.ewm(alpha=alpha_).mean()
    out = M.values
    return out

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_steps = 250
window_width = [3, 4, 5]
out_channels = [n_steps-window_width[0]+1, n_steps-window_width[1]+1, n_steps-window_width[2]+1]
embedding_dimensions = 300
n_fc1 = 600
n_fc2 = 600
n_fc3 = 600
n_fc4 = 400
n_fc5 = 200
n_output = 1
threshold = 1.
dropout_rate = 0.
momentum = 0.9

activation_fn = tf.nn.elu
init_W_CL_3 = np.random.randn(window_width[0],embedding_dimensions,1,out_channels[0]).astype(np.float32)
init_b_CL_3 = np.random.randn(1,1,1,out_channels[0]).astype(np.float32)
init_W_CL_4 = np.random.randn(window_width[1],embedding_dimensions,1,out_channels[1]).astype(np.float32)
init_b_CL_4 = np.random.randn(1,1,1,out_channels[1]).astype(np.float32)
init_W_CL_5 = np.random.randn(window_width[2],embedding_dimensions,1,out_channels[2]).astype(np.float32)
init_b_CL_5 = np.random.randn(1,1,1,out_channels[2]).astype(np.float32)

learning_rate = tf.placeholder(tf.float32)

X = tf.placeholder(tf.int32, [None, n_steps], name="X") #m * n_steps
y = tf.placeholder(tf.float32, [None], name="y")
training = tf.placeholder_with_default(False, shape=(), name='training')

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)# n_words * embedding_dimensions
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X) # m * n_steps * embedding_dimensions

with tf.name_scope("CNN_3"):
    W_CL_3 = tf.Variable(initial_value=init_W_CL_3)
    b_CL_3 = tf.Variable(initial_value=init_b_CL_3)
    CL_3 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_3, strides=[1,1,1,1], padding="VALID")# m * n_steps - 3 + 1 *1 * out_channels 
    activated_CL_3 = activation_fn(tf.add(CL_3,b_CL_3)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_3 = tf.reshape(tf.math.reduce_max(activated_CL_3,axis=1),[-1,out_channels[0]]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_4"):
    W_CL_4 = tf.Variable(initial_value=init_W_CL_4)
    b_CL_4 = tf.Variable(initial_value=init_b_CL_4)
    CL_4 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_4, strides=[1,1,1,1], padding="VALID")# m * n_steps - 4 + 1 *1 * out_channels 
    activated_CL_4 = activation_fn(tf.add(CL_4,b_CL_4)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_4 = tf.reshape(tf.math.reduce_max(activated_CL_4,axis=1),[-1,out_channels[1]]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_5"):
    W_CL_5 = tf.Variable(initial_value=init_W_CL_5)
    b_CL_5 = tf.Variable(initial_value=init_b_CL_5)
    CL_5 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_5, strides=[1,1,1,1], padding="VALID")# m * n_steps - 5 + 1 *1 * out_channels 
    activated_CL_5 = activation_fn(tf.add(CL_5,b_CL_5)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_5 = tf.reshape(tf.math.reduce_max(activated_CL_5,axis=1),[-1,out_channels[2]]) # m * 1 * out_channels  --> m * out_channels

with tf.name_scope("Max_pool"):
    MAXPOOL = tf.concat([MAXPOOL_3,MAXPOOL_4,MAXPOOL_5], axis=1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(MAXPOOL, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2, n_fc3, activation_fn=activation_fn)
    fc4 = tf.contrib.layers.fully_connected(fc3, n_fc4, activation_fn=activation_fn)
    fc5 = tf.contrib.layers.fully_connected(fc4, n_fc5, activation_fn=activation_fn)


with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc5, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    grads_and_vars = optimizer.compute_gradients(loss)
    capped_gvs = [(tf.clip_by_value(grad, -threshold, threshold), var) for grad, var in grads_and_vars]
    training_op = optimizer.apply_gradients(capped_gvs)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
"""lengths, x_b, y_b = QIQC.next_batch()
item = x_b[26]
sentence = []
for i in range(lengths[26]):
  for word, key in words_ids.items():
    if item[i] == key:
      sentence.append(word)
sentence, y_b[26]"""
# Out:
# 'lengths, x_b, y_b = QIQC.next_batch()\nitem = x_b[26]\nsentence = []\nfor i in range(lengths[26]):\n  for word, key in words_ids.items():\n    if item[i] == key:\n      sentence.append(word)\nsentence, y_b[26]'

# %%
model_version = "4.0.2"

# %%
QIQC.reset()
n_epoch = 8
now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model{}/QIQC_model{}.ckpt".format(model_version,model_version)
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

#file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

t_init = time.time()
lr_stop = 1
lr_stack = []
loss_stack = []
step_stack = []
f1_stack = []
loss_train_stack = []
f1_train_stack = []

lr = 0.004

with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        if epoch % 2 == 0 and epoch != 0 :
          lr = lr/2
        for iteration in range(QIQC.nr_batches):            
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, learning_rate: lr, training: True})
            step = epoch * QIQC.nr_batches + iteration
            if step % 20 ==0:
              f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
              f1_train, loss_train = sess.run([f1, loss], feed_dict = {X : X_batch, y : y_batch})
              step_stack.append(step)
              loss_stack.append(loss_dev)
              f1_stack.append(f1_dev)
              loss_train_stack.append(loss_train)
              f1_train_stack.append(f1_train)
            """
            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)
            """
            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                #f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch})
                #f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
                t_1 = time.time()
                t_delta = t_1 - t_0
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/8; It. 0/2608; Runtime 11.59 s; Remaining runtime 0h40min17s; f1_train nan; f1_dev nan; loss_train 53.8755; loss_dev 47.5688
# Ep. 1/8; It. 100/2608; Runtime 36.47 s; Remaining runtime 2h6min12s; f1_train nan; f1_dev nan; loss_train 0.1771; loss_dev 0.1924
# Ep. 1/8; It. 200/2608; Runtime 36.54 s; Remaining runtime 2h5min50s; f1_train 0.3243; f1_dev 0.3000; loss_train 0.1419; loss_dev 0.1385
# Ep. 1/8; It. 300/2608; Runtime 36.58 s; Remaining runtime 2h5min22s; f1_train 0.2000; f1_dev 0.1471; loss_train 0.1293; loss_dev 0.1539
# Ep. 1/8; It. 400/2608; Runtime 36.63 s; Remaining runtime 2h4min56s; f1_train 0.5000; f1_dev 0.4800; loss_train 0.1456; loss_dev 0.1256
# Ep. 1/8; It. 500/2608; Runtime 36.57 s; Remaining runtime 2h4min7s; f1_train 0.5217; f1_dev 0.5294; loss_train 0.1294; loss_dev 0.1225
# Ep. 1/8; It. 600/2608; Runtime 36.67 s; Remaining runtime 2h3min50s; f1_train 0.5135; f1_dev 0.4731; loss_train 0.1728; loss_dev 0.1172
# Ep. 1/8; It. 700/2608; Runtime 36.69 s; Remaining runtime 2h3min17s; f1_train 0.4082; f1_dev 0.4524; loss_train 0.1406; loss_dev 0.1155
# Ep. 1/8; It. 800/2608; Runtime 36.63 s; Remaining runtime 2h2min29s; f1_train 0.6364; f1_dev 0.5600; loss_train 0.0917; loss_dev 0.1146
# Ep. 1/8; It. 900/2608; Runtime 36.78 s; Remaining runtime 2h2min23s; f1_train 0.5000; f1_dev 0.4889; loss_train 0.1095; loss_dev 0.1137
# Ep. 1/8; It. 1000/2608; Runtime 39.83 s; Remaining runtime 2h11min51s; f1_train 0.4348; f1_dev 0.4471; loss_train 0.1242; loss_dev 0.1144
# Ep. 1/8; It. 1100/2608; Runtime 36.94 s; Remaining runtime 2h1min40s; f1_train 0.4737; f1_dev 0.5106; loss_train 0.1037; loss_dev 0.1100
# Ep. 1/8; It. 1200/2608; Runtime 36.76 s; Remaining runtime 2h0min28s; f1_train 0.3529; f1_dev 0.4337; loss_train 0.1072; loss_dev 0.1157
# Ep. 1/8; It. 1300/2608; Runtime 36.78 s; Remaining runtime 1h59min54s; f1_train 0.6567; f1_dev 0.5965; loss_train 0.1185; loss_dev 0.1123
# Ep. 1/8; It. 1400/2608; Runtime 36.78 s; Remaining runtime 1h59min19s; f1_train 0.2581; f1_dev 0.0923; loss_train 0.1075; loss_dev 0.1372
# Ep. 1/8; It. 1500/2608; Runtime 36.79 s; Remaining runtime 1h58min43s; f1_train 0.4000; f1_dev 0.5962; loss_train 0.1173; loss_dev 0.1046
# Ep. 1/8; It. 1600/2608; Runtime 36.79 s; Remaining runtime 1h58min6s; f1_train 0.4615; f1_dev 0.4337; loss_train 0.1108; loss_dev 0.1142
# Ep. 1/8; It. 1700/2608; Runtime 36.76 s; Remaining runtime 1h57min24s; f1_train 0.4000; f1_dev 0.4884; loss_train 0.1273; loss_dev 0.1087
# Ep. 1/8; It. 1800/2608; Runtime 36.75 s; Remaining runtime 1h56min46s; f1_train 0.6571; f1_dev 0.5962; loss_train 0.1225; loss_dev 0.1054
# Ep. 1/8; It. 1900/2608; Runtime 36.72 s; Remaining runtime 1h56min3s; f1_train 0.3902; f1_dev 0.4578; loss_train 0.1216; loss_dev 0.1119
# Ep. 1/8; It. 2000/2608; Runtime 39.44 s; Remaining runtime 2h4min0s; f1_train 0.5882; f1_dev 0.6226; loss_train 0.1152; loss_dev 0.1015
# Ep. 1/8; It. 2100/2608; Runtime 36.89 s; Remaining runtime 1h55min22s; f1_train 0.6053; f1_dev 0.6379; loss_train 0.1270; loss_dev 0.1049
# Ep. 1/8; It. 2200/2608; Runtime 36.74 s; Remaining runtime 1h54min16s; f1_train 0.4000; f1_dev 0.5057; loss_train 0.0855; loss_dev 0.1059
# Ep. 1/8; It. 2300/2608; Runtime 36.78 s; Remaining runtime 1h53min48s; f1_train 0.7097; f1_dev 0.6078; loss_train 0.0961; loss_dev 0.1026
# Ep. 1/8; It. 2400/2608; Runtime 36.78 s; Remaining runtime 1h53min11s; f1_train 0.5455; f1_dev 0.5435; loss_train 0.1053; loss_dev 0.1051
# Ep. 1/8; It. 2500/2608; Runtime 36.76 s; Remaining runtime 1h52min29s; f1_train 0.5714; f1_dev 0.5657; loss_train 0.1009; loss_dev 0.1042
# Ep. 1/8; It. 2600/2608; Runtime 36.77 s; Remaining runtime 1h51min55s; f1_train 0.3478; f1_dev 0.2254; loss_train 0.1356; loss_dev 0.1167
# Ep. 2/8; It. 0/2608; Runtime 10.27 s; Remaining runtime 0h31min14s; f1_train 0.3478; f1_dev 0.2254; loss_train 0.1356; loss_dev 0.1167
# Ep. 2/8; It. 100/2608; Runtime 36.65 s; Remaining runtime 1h50min53s; f1_train 0.6667; f1_dev 0.6435; loss_train 0.1260; loss_dev 0.1017
# Ep. 2/8; It. 200/2608; Runtime 36.61 s; Remaining runtime 1h50min11s; f1_train 0.7097; f1_dev 0.6296; loss_train 0.1186; loss_dev 0.1016
# Ep. 2/8; It. 300/2608; Runtime 36.59 s; Remaining runtime 1h49min30s; f1_train 0.5000; f1_dev 0.3636; loss_train 0.1043; loss_dev 0.1195
# Ep. 2/8; It. 400/2608; Runtime 36.58 s; Remaining runtime 1h48min52s; f1_train 0.7941; f1_dev 0.6111; loss_train 0.0692; loss_dev 0.1036
# Ep. 2/8; It. 500/2608; Runtime 36.67 s; Remaining runtime 1h48min30s; f1_train 0.6377; f1_dev 0.6486; loss_train 0.1021; loss_dev 0.0981
# Ep. 2/8; It. 600/2608; Runtime 36.59 s; Remaining runtime 1h47min41s; f1_train 0.7059; f1_dev 0.6182; loss_train 0.1063; loss_dev 0.1002
# Ep. 2/8; It. 700/2608; Runtime 36.62 s; Remaining runtime 1h47min8s; f1_train 0.6897; f1_dev 0.6000; loss_train 0.1038; loss_dev 0.1010
# Ep. 2/8; It. 800/2608; Runtime 36.62 s; Remaining runtime 1h46min31s; f1_train 0.6087; f1_dev 0.6286; loss_train 0.1068; loss_dev 0.0989
# Ep. 2/8; It. 900/2608; Runtime 36.60 s; Remaining runtime 1h45min52s; f1_train 0.7391; f1_dev 0.6286; loss_train 0.0807; loss_dev 0.1022
# Ep. 2/8; It. 1000/2608; Runtime 40.24 s; Remaining runtime 1h55min43s; f1_train 0.7273; f1_dev 0.6486; loss_train 0.1046; loss_dev 0.0965
# Ep. 2/8; It. 1100/2608; Runtime 36.81 s; Remaining runtime 1h45min15s; f1_train 0.5862; f1_dev 0.6602; loss_train 0.1076; loss_dev 0.0947
# Ep. 2/8; It. 1200/2608; Runtime 36.61 s; Remaining runtime 1h44min3s; f1_train 0.7119; f1_dev 0.6471; loss_train 0.0835; loss_dev 0.0997
# Ep. 2/8; It. 1300/2608; Runtime 36.65 s; Remaining runtime 1h43min34s; f1_train 0.4000; f1_dev 0.5806; loss_train 0.1012; loss_dev 0.1018
# Ep. 2/8; It. 1400/2608; Runtime 36.61 s; Remaining runtime 1h42min50s; f1_train 0.7097; f1_dev 0.6341; loss_train 0.1079; loss_dev 0.1013
# Ep. 2/8; It. 1500/2608; Runtime 36.58 s; Remaining runtime 1h42min9s; f1_train 0.6129; f1_dev 0.6667; loss_train 0.1014; loss_dev 0.0938
# Ep. 2/8; It. 1600/2608; Runtime 36.63 s; Remaining runtime 1h41min41s; f1_train 0.6182; f1_dev 0.6337; loss_train 0.1064; loss_dev 0.0961
# Ep. 2/8; It. 1700/2608; Runtime 36.60 s; Remaining runtime 1h41min0s; f1_train 0.8182; f1_dev 0.6486; loss_train 0.0726; loss_dev 0.1000
# Ep. 2/8; It. 1800/2608; Runtime 36.61 s; Remaining runtime 1h40min23s; f1_train 0.5652; f1_dev 0.6087; loss_train 0.0855; loss_dev 0.1062
# Ep. 2/8; It. 1900/2608; Runtime 36.65 s; Remaining runtime 1h39min54s; f1_train 0.7500; f1_dev 0.6552; loss_train 0.0736; loss_dev 0.0979
# Ep. 2/8; It. 2000/2608; Runtime 39.44 s; Remaining runtime 1h46min51s; f1_train 0.5000; f1_dev 0.6000; loss_train 0.0951; loss_dev 0.1026
# Ep. 2/8; It. 2100/2608; Runtime 36.78 s; Remaining runtime 1h39min2s; f1_train 0.7246; f1_dev 0.6429; loss_train 0.1035; loss_dev 0.0962
# Ep. 2/8; It. 2200/2608; Runtime 36.63 s; Remaining runtime 1h38min1s; f1_train 0.5714; f1_dev 0.6422; loss_train 0.1178; loss_dev 0.0958
# Ep. 2/8; It. 2300/2608; Runtime 36.63 s; Remaining runtime 1h37min25s; f1_train 0.6441; f1_dev 0.6607; loss_train 0.0987; loss_dev 0.0967
# Ep. 2/8; It. 2400/2608; Runtime 36.61 s; Remaining runtime 1h36min44s; f1_train 0.6182; f1_dev 0.5773; loss_train 0.1000; loss_dev 0.1030
# Ep. 2/8; It. 2500/2608; Runtime 36.61 s; Remaining runtime 1h36min7s; f1_train 0.6939; f1_dev 0.6542; loss_train 0.0732; loss_dev 0.0965
# Ep. 2/8; It. 2600/2608; Runtime 36.61 s; Remaining runtime 1h35min32s; f1_train 0.5106; f1_dev 0.6122; loss_train 0.0986; loss_dev 0.1007
# Ep. 3/8; It. 0/2608; Runtime 9.96 s; Remaining runtime 0h25min58s; f1_train 0.5106; f1_dev 0.6122; loss_train 0.0986; loss_dev 0.1007
# Ep. 3/8; It. 100/2608; Runtime 36.65 s; Remaining runtime 1h34min58s; f1_train 0.7302; f1_dev 0.6496; loss_train 0.0775; loss_dev 0.0928
# Ep. 3/8; It. 200/2608; Runtime 36.61 s; Remaining runtime 1h34min15s; f1_train 0.7869; f1_dev 0.6542; loss_train 0.0628; loss_dev 0.0963
# Ep. 3/8; It. 300/2608; Runtime 36.63 s; Remaining runtime 1h33min41s; f1_train 0.6400; f1_dev 0.6600; loss_train 0.0775; loss_dev 0.0975
# Ep. 3/8; It. 400/2608; Runtime 36.65 s; Remaining runtime 1h33min7s; f1_train 0.6383; f1_dev 0.6476; loss_train 0.0832; loss_dev 0.0969
# Ep. 3/8; It. 500/2608; Runtime 36.67 s; Remaining runtime 1h32min34s; f1_train 0.6780; f1_dev 0.6606; loss_train 0.0889; loss_dev 0.0944
# Ep. 3/8; It. 600/2608; Runtime 36.61 s; Remaining runtime 1h31min48s; f1_train 0.6452; f1_dev 0.6042; loss_train 0.1241; loss_dev 0.1036
# Ep. 3/8; It. 700/2608; Runtime 36.63 s; Remaining runtime 1h31min15s; f1_train 0.5778; f1_dev 0.6538; loss_train 0.0867; loss_dev 0.0978
# Ep. 3/8; It. 800/2608; Runtime 36.61 s; Remaining runtime 1h30min35s; f1_train 0.6792; f1_dev 0.6535; loss_train 0.0700; loss_dev 0.1011
# Ep. 3/8; It. 900/2608; Runtime 36.66 s; Remaining runtime 1h30min6s; f1_train 0.5818; f1_dev 0.6549; loss_train 0.1119; loss_dev 0.0942
# Ep. 3/8; It. 1000/2608; Runtime 40.33 s; Remaining runtime 1h38min28s; f1_train 0.5882; f1_dev 0.5806; loss_train 0.0859; loss_dev 0.1096
# Ep. 3/8; It. 1100/2608; Runtime 36.80 s; Remaining runtime 1h29min14s; f1_train 0.8354; f1_dev 0.6729; loss_train 0.0891; loss_dev 0.0971
# Ep. 3/8; It. 1200/2608; Runtime 36.68 s; Remaining runtime 1h28min19s; f1_train 0.6829; f1_dev 0.6122; loss_train 0.0531; loss_dev 0.1158
# Ep. 3/8; It. 1300/2608; Runtime 36.65 s; Remaining runtime 1h27min38s; f1_train 0.7000; f1_dev 0.6667; loss_train 0.0692; loss_dev 0.0989
# Ep. 3/8; It. 1400/2608; Runtime 36.64 s; Remaining runtime 1h26min59s; f1_train 0.6933; f1_dev 0.6720; loss_train 0.1350; loss_dev 0.0999
# Ep. 3/8; It. 1500/2608; Runtime 36.63 s; Remaining runtime 1h26min22s; f1_train 0.6552; f1_dev 0.6847; loss_train 0.1028; loss_dev 0.0947
# Ep. 3/8; It. 1600/2608; Runtime 36.59 s; Remaining runtime 1h25min39s; f1_train 0.5714; f1_dev 0.6458; loss_train 0.0971; loss_dev 0.1001
# Ep. 3/8; It. 1700/2608; Runtime 36.64 s; Remaining runtime 1h25min10s; f1_train 0.7797; f1_dev 0.6122; loss_train 0.0772; loss_dev 0.0977
# Ep. 3/8; It. 1800/2608; Runtime 36.65 s; Remaining runtime 1h24min35s; f1_train 0.7200; f1_dev 0.6535; loss_train 0.0666; loss_dev 0.0998
# Ep. 3/8; It. 1900/2608; Runtime 36.69 s; Remaining runtime 1h24min4s; f1_train 0.6154; f1_dev 0.6400; loss_train 0.0840; loss_dev 0.1019
# Ep. 3/8; It. 2000/2608; Runtime 39.77 s; Remaining runtime 1h30min27s; f1_train 0.6531; f1_dev 0.5979; loss_train 0.0827; loss_dev 0.1055
# Ep. 3/8; It. 2100/2608; Runtime 36.85 s; Remaining runtime 1h23min12s; f1_train 0.7451; f1_dev 0.6535; loss_train 0.0917; loss_dev 0.1030
# Ep. 3/8; It. 2200/2608; Runtime 36.60 s; Remaining runtime 1h22min1s; f1_train 0.5312; f1_dev 0.6538; loss_train 0.1464; loss_dev 0.0957
# Ep. 3/8; It. 2300/2608; Runtime 36.62 s; Remaining runtime 1h21min27s; f1_train 0.8000; f1_dev 0.6504; loss_train 0.1111; loss_dev 0.0972
# Ep. 3/8; It. 2400/2608; Runtime 36.66 s; Remaining runtime 1h20min57s; f1_train 0.6809; f1_dev 0.6783; loss_train 0.0775; loss_dev 0.1000
# Ep. 3/8; It. 2500/2608; Runtime 36.70 s; Remaining runtime 1h20min25s; f1_train 0.7222; f1_dev 0.6504; loss_train 0.0923; loss_dev 0.1001
# Ep. 3/8; It. 2600/2608; Runtime 36.67 s; Remaining runtime 1h19min45s; f1_train 0.7000; f1_dev 0.6275; loss_train 0.0781; loss_dev 0.1061
# Ep. 4/8; It. 0/2608; Runtime 10.63 s; Remaining runtime 0h23min5s; f1_train 0.5000; f1_dev 0.4819; loss_train 0.0995; loss_dev 0.1220
# Ep. 4/8; It. 100/2608; Runtime 36.66 s; Remaining runtime 1h19min3s; f1_train 0.7857; f1_dev 0.6250; loss_train 0.0582; loss_dev 0.1062
# Ep. 4/8; It. 200/2608; Runtime 36.66 s; Remaining runtime 1h18min27s; f1_train 0.5366; f1_dev 0.5116; loss_train 0.0773; loss_dev 0.1439
# Ep. 4/8; It. 300/2608; Runtime 36.64 s; Remaining runtime 1h17min48s; f1_train 0.7000; f1_dev 0.6218; loss_train 0.0794; loss_dev 0.1083
# Ep. 4/8; It. 400/2608; Runtime 36.65 s; Remaining runtime 1h17min12s; f1_train 0.7778; f1_dev 0.6296; loss_train 0.0613; loss_dev 0.1118
# Ep. 4/8; It. 500/2608; Runtime 36.65 s; Remaining runtime 1h16min35s; f1_train 0.8101; f1_dev 0.6435; loss_train 0.0699; loss_dev 0.0996
# Ep. 4/8; It. 600/2608; Runtime 36.63 s; Remaining runtime 1h15min56s; f1_train 0.6545; f1_dev 0.6446; loss_train 0.0797; loss_dev 0.1032
# Ep. 4/8; It. 700/2608; Runtime 36.65 s; Remaining runtime 1h15min22s; f1_train 0.7353; f1_dev 0.6239; loss_train 0.0877; loss_dev 0.1050
# Ep. 4/8; It. 800/2608; Runtime 36.65 s; Remaining runtime 1h14min45s; f1_train 0.7568; f1_dev 0.6393; loss_train 0.0760; loss_dev 0.1033
# Ep. 4/8; It. 900/2608; Runtime 36.65 s; Remaining runtime 1h14min8s; f1_train 0.8364; f1_dev 0.6275; loss_train 0.0486; loss_dev 0.1082
# Ep. 4/8; It. 1000/2608; Runtime 40.03 s; Remaining runtime 1h20min19s; f1_train 0.7451; f1_dev 0.6486; loss_train 0.0668; loss_dev 0.1074
# Ep. 4/8; It. 1100/2608; Runtime 36.78 s; Remaining runtime 1h13min11s; f1_train 0.7778; f1_dev 0.6422; loss_train 0.0481; loss_dev 0.1141
# Ep. 4/8; It. 1200/2608; Runtime 36.68 s; Remaining runtime 1h12min22s; f1_train 0.8052; f1_dev 0.6357; loss_train 0.0707; loss_dev 0.1113
# Ep. 4/8; It. 1300/2608; Runtime 36.63 s; Remaining runtime 1h11min40s; f1_train 0.7547; f1_dev 0.6600; loss_train 0.0624; loss_dev 0.1106
# Ep. 4/8; It. 1400/2608; Runtime 36.68 s; Remaining runtime 1h11min10s; f1_train 0.7297; f1_dev 0.6612; loss_train 0.0856; loss_dev 0.1021
# Ep. 4/8; It. 1500/2608; Runtime 36.65 s; Remaining runtime 1h10min28s; f1_train 0.3684; f1_dev 0.4000; loss_train 0.1081; loss_dev 0.1332
# Ep. 4/8; It. 1600/2608; Runtime 36.66 s; Remaining runtime 1h9min53s; f1_train 0.7945; f1_dev 0.6719; loss_train 0.0648; loss_dev 0.1102
# Ep. 4/8; It. 1700/2608; Runtime 36.63 s; Remaining runtime 1h9min14s; f1_train 0.6923; f1_dev 0.6186; loss_train 0.0737; loss_dev 0.1214
# Ep. 4/8; It. 1800/2608; Runtime 36.62 s; Remaining runtime 1h8min36s; f1_train 0.8308; f1_dev 0.6346; loss_train 0.0531; loss_dev 0.1058
# Ep. 4/8; It. 1900/2608; Runtime 36.66 s; Remaining runtime 1h8min3s; f1_train 0.6296; f1_dev 0.6542; loss_train 0.1021; loss_dev 0.1074
# Ep. 4/8; It. 2000/2608; Runtime 39.55 s; Remaining runtime 1h12min46s; f1_train 0.8000; f1_dev 0.6325; loss_train 0.0514; loss_dev 0.1070
# Ep. 4/8; It. 2100/2608; Runtime 36.81 s; Remaining runtime 1h7min7s; f1_train 0.6769; f1_dev 0.6435; loss_train 0.0790; loss_dev 0.1033
# Ep. 4/8; It. 2200/2608; Runtime 36.64 s; Remaining runtime 1h6min12s; f1_train 0.7632; f1_dev 0.6355; loss_train 0.0825; loss_dev 0.1094
# Ep. 4/8; It. 2300/2608; Runtime 36.67 s; Remaining runtime 1h5min38s; f1_train 0.7143; f1_dev 0.6364; loss_train 0.0782; loss_dev 0.1028
# Ep. 4/8; It. 2400/2608; Runtime 36.62 s; Remaining runtime 1h4min56s; f1_train 0.7273; f1_dev 0.6491; loss_train 0.0949; loss_dev 0.1024
# Ep. 4/8; It. 2500/2608; Runtime 36.65 s; Remaining runtime 1h4min23s; f1_train 0.8101; f1_dev 0.6400; loss_train 0.0773; loss_dev 0.1079
# Ep. 4/8; It. 2600/2608; Runtime 36.66 s; Remaining runtime 1h3min47s; f1_train 0.7778; f1_dev 0.6491; loss_train 0.0786; loss_dev 0.1096
# Ep. 5/8; It. 0/2608; Runtime 9.84 s; Remaining runtime 0h17min6s; f1_train 0.7778; f1_dev 0.6491; loss_train 0.0786; loss_dev 0.1096
# Ep. 5/8; It. 100/2608; Runtime 36.67 s; Remaining runtime 1h3min9s; f1_train 0.8060; f1_dev 0.6387; loss_train 0.0624; loss_dev 0.1183
# Ep. 5/8; It. 200/2608; Runtime 36.63 s; Remaining runtime 1h2min27s; f1_train 0.8148; f1_dev 0.6000; loss_train 0.0559; loss_dev 0.1240
# Ep. 5/8; It. 300/2608; Runtime 36.66 s; Remaining runtime 1h1min54s; f1_train 0.7500; f1_dev 0.6126; loss_train 0.0641; loss_dev 0.1199
# Ep. 5/8; It. 400/2608; Runtime 36.61 s; Remaining runtime 1h1min12s; f1_train 0.9114; f1_dev 0.5905; loss_train 0.0486; loss_dev 0.1376
# Ep. 5/8; It. 500/2608; Runtime 36.67 s; Remaining runtime 1h0min41s; f1_train 0.7541; f1_dev 0.5979; loss_train 0.0739; loss_dev 0.1323
# Ep. 5/8; It. 600/2608; Runtime 36.68 s; Remaining runtime 1h0min5s; f1_train 0.8254; f1_dev 0.6441; loss_train 0.0590; loss_dev 0.1179
# Ep. 5/8; It. 700/2608; Runtime 36.64 s; Remaining runtime 0h59min25s; f1_train 0.7797; f1_dev 0.6182; loss_train 0.0669; loss_dev 0.1287
# Ep. 5/8; It. 800/2608; Runtime 36.62 s; Remaining runtime 0h58min47s; f1_train 0.8710; f1_dev 0.6780; loss_train 0.0470; loss_dev 0.1227
# Ep. 5/8; It. 900/2608; Runtime 36.65 s; Remaining runtime 0h58min13s; f1_train 0.8857; f1_dev 0.6504; loss_train 0.0527; loss_dev 0.1175
# Ep. 5/8; It. 1000/2608; Runtime 40.30 s; Remaining runtime 1h3min20s; f1_train 0.8219; f1_dev 0.6168; loss_train 0.0601; loss_dev 0.1281
# Ep. 5/8; It. 1100/2608; Runtime 36.79 s; Remaining runtime 0h57min12s; f1_train 0.8169; f1_dev 0.6200; loss_train 0.0611; loss_dev 0.1558
# Ep. 5/8; It. 1200/2608; Runtime 36.65 s; Remaining runtime 0h56min23s; f1_train 0.8571; f1_dev 0.6168; loss_train 0.0638; loss_dev 0.1427
# Ep. 5/8; It. 1300/2608; Runtime 36.65 s; Remaining runtime 0h55min47s; f1_train 0.8056; f1_dev 0.6230; loss_train 0.0724; loss_dev 0.1315
# Ep. 5/8; It. 1400/2608; Runtime 36.65 s; Remaining runtime 0h55min10s; f1_train 0.8966; f1_dev 0.6281; loss_train 0.0342; loss_dev 0.1192
# Ep. 5/8; It. 1500/2608; Runtime 36.66 s; Remaining runtime 0h54min34s; f1_train 0.8085; f1_dev 0.6316; loss_train 0.0533; loss_dev 0.1168
# Ep. 5/8; It. 1600/2608; Runtime 36.65 s; Remaining runtime 0h53min56s; f1_train 0.7761; f1_dev 0.5745; loss_train 0.0674; loss_dev 0.1409
# Ep. 5/8; It. 1700/2608; Runtime 36.64 s; Remaining runtime 0h53min19s; f1_train 0.8205; f1_dev 0.6496; loss_train 0.0489; loss_dev 0.1228
# Ep. 5/8; It. 1800/2608; Runtime 36.69 s; Remaining runtime 0h52min47s; f1_train 0.7059; f1_dev 0.6667; loss_train 0.0636; loss_dev 0.1253
# Ep. 5/8; It. 1900/2608; Runtime 36.64 s; Remaining runtime 0h52min6s; f1_train 0.7719; f1_dev 0.6019; loss_train 0.0816; loss_dev 0.1256
# Ep. 5/8; It. 2000/2608; Runtime 39.42 s; Remaining runtime 0h55min23s; f1_train 0.8929; f1_dev 0.6186; loss_train 0.0408; loss_dev 0.1232
# Ep. 5/8; It. 2100/2608; Runtime 36.79 s; Remaining runtime 0h51min5s; f1_train 0.8222; f1_dev 0.6491; loss_train 0.0796; loss_dev 0.1145
# Ep. 5/8; It. 2200/2608; Runtime 36.60 s; Remaining runtime 0h50min12s; f1_train 0.7500; f1_dev 0.6207; loss_train 0.0764; loss_dev 0.1305
# Ep. 5/8; It. 2300/2608; Runtime 36.61 s; Remaining runtime 0h49min37s; f1_train 0.7500; f1_dev 0.6508; loss_train 0.0767; loss_dev 0.1200
# Ep. 5/8; It. 2400/2608; Runtime 36.66 s; Remaining runtime 0h49min4s; f1_train 0.8182; f1_dev 0.6379; loss_train 0.0690; loss_dev 0.1228
# Ep. 5/8; It. 2500/2608; Runtime 36.63 s; Remaining runtime 0h48min25s; f1_train 0.8000; f1_dev 0.6441; loss_train 0.0632; loss_dev 0.1254
# Ep. 5/8; It. 2600/2608; Runtime 36.65 s; Remaining runtime 0h47min50s; f1_train 0.7586; f1_dev 0.6364; loss_train 0.0529; loss_dev 0.1191
# Ep. 6/8; It. 0/2608; Runtime 10.36 s; Remaining runtime 0h13min30s; f1_train 0.8485; f1_dev 0.6491; loss_train 0.0516; loss_dev 0.1153
# Ep. 6/8; It. 100/2608; Runtime 36.69 s; Remaining runtime 0h47min13s; f1_train 0.8846; f1_dev 0.6250; loss_train 0.0386; loss_dev 0.1376
# Ep. 6/8; It. 200/2608; Runtime 36.67 s; Remaining runtime 0h46min35s; f1_train 0.7937; f1_dev 0.6286; loss_train 0.0543; loss_dev 0.1487
# Ep. 6/8; It. 300/2608; Runtime 36.64 s; Remaining runtime 0h45min56s; f1_train 0.8065; f1_dev 0.6355; loss_train 0.0619; loss_dev 0.1433
# Ep. 6/8; It. 400/2608; Runtime 36.65 s; Remaining runtime 0h45min20s; f1_train 0.8718; f1_dev 0.6364; loss_train 0.0508; loss_dev 0.1475
# Ep. 6/8; It. 500/2608; Runtime 36.65 s; Remaining runtime 0h44min44s; f1_train 0.8250; f1_dev 0.6261; loss_train 0.0569; loss_dev 0.1478
# Ep. 6/8; It. 600/2608; Runtime 36.63 s; Remaining runtime 0h44min5s; f1_train 0.7458; f1_dev 0.6179; loss_train 0.0641; loss_dev 0.1406
# Ep. 6/8; It. 700/2608; Runtime 36.64 s; Remaining runtime 0h43min30s; f1_train 0.8750; f1_dev 0.6341; loss_train 0.0451; loss_dev 0.1408
# Ep. 6/8; It. 800/2608; Runtime 36.78 s; Remaining runtime 0h43min3s; f1_train 0.8974; f1_dev 0.6429; loss_train 0.0498; loss_dev 0.1433
# Ep. 6/8; It. 900/2608; Runtime 36.69 s; Remaining runtime 0h42min20s; f1_train 0.8627; f1_dev 0.6346; loss_train 0.0420; loss_dev 0.1462
# Ep. 6/8; It. 1000/2608; Runtime 39.95 s; Remaining runtime 0h45min26s; f1_train 0.8533; f1_dev 0.6491; loss_train 0.0647; loss_dev 0.1317
# Ep. 6/8; It. 1100/2608; Runtime 36.79 s; Remaining runtime 0h41min14s; f1_train 0.9143; f1_dev 0.6355; loss_train 0.0429; loss_dev 0.1491
# Ep. 6/8; It. 1200/2608; Runtime 36.65 s; Remaining runtime 0h40min27s; f1_train 0.9014; f1_dev 0.5905; loss_train 0.0439; loss_dev 0.1581
# Ep. 6/8; It. 1300/2608; Runtime 36.63 s; Remaining runtime 0h39min49s; f1_train 0.9851; f1_dev 0.6261; loss_train 0.0209; loss_dev 0.1468
# Ep. 6/8; It. 1400/2608; Runtime 36.61 s; Remaining runtime 0h39min12s; f1_train 0.8358; f1_dev 0.6226; loss_train 0.0545; loss_dev 0.1243
# Ep. 6/8; It. 1500/2608; Runtime 36.63 s; Remaining runtime 0h38min36s; f1_train 0.9000; f1_dev 0.6491; loss_train 0.0367; loss_dev 0.1220
# Ep. 6/8; It. 1600/2608; Runtime 36.60 s; Remaining runtime 0h37min57s; f1_train 0.8966; f1_dev 0.6154; loss_train 0.0321; loss_dev 0.1472
# Ep. 6/8; It. 1700/2608; Runtime 36.66 s; Remaining runtime 0h37min24s; f1_train 0.8261; f1_dev 0.6019; loss_train 0.0381; loss_dev 0.1457
# Ep. 6/8; It. 1800/2608; Runtime 36.64 s; Remaining runtime 0h36min47s; f1_train 0.7600; f1_dev 0.6116; loss_train 0.0496; loss_dev 0.1389
# Ep. 6/8; It. 1900/2608; Runtime 36.64 s; Remaining runtime 0h36min10s; f1_train 0.8923; f1_dev 0.5825; loss_train 0.0389; loss_dev 0.1436
# Ep. 6/8; It. 2000/2608; Runtime 39.29 s; Remaining runtime 0h38min8s; f1_train 0.9014; f1_dev 0.6195; loss_train 0.0368; loss_dev 0.1347
# Ep. 6/8; It. 2100/2608; Runtime 36.76 s; Remaining runtime 0h35min4s; f1_train 0.8889; f1_dev 0.6250; loss_train 0.0612; loss_dev 0.1229
# Ep. 6/8; It. 2200/2608; Runtime 36.62 s; Remaining runtime 0h34min19s; f1_train 0.8000; f1_dev 0.6296; loss_train 0.0361; loss_dev 0.1367
# Ep. 6/8; It. 2300/2608; Runtime 36.65 s; Remaining runtime 0h33min44s; f1_train 0.7500; f1_dev 0.6095; loss_train 0.0570; loss_dev 0.1370
# Ep. 6/8; It. 2400/2608; Runtime 36.62 s; Remaining runtime 0h33min6s; f1_train 0.8235; f1_dev 0.6095; loss_train 0.0445; loss_dev 0.1431
# Ep. 6/8; It. 2500/2608; Runtime 36.69 s; Remaining runtime 0h32min33s; f1_train 0.9062; f1_dev 0.6111; loss_train 0.0473; loss_dev 0.1612
# Ep. 6/8; It. 2600/2608; Runtime 36.63 s; Remaining runtime 0h31min53s; f1_train 0.8767; f1_dev 0.5794; loss_train 0.0532; loss_dev 0.1388
# Ep. 7/8; It. 0/2608; Runtime 10.37 s; Remaining runtime 0h9min1s; f1_train 0.8767; f1_dev 0.5794; loss_train 0.0532; loss_dev 0.1388
# Ep. 7/8; It. 100/2608; Runtime 36.64 s; Remaining runtime 0h31min14s; f1_train 0.7500; f1_dev 0.6087; loss_train 0.0533; loss_dev 0.1795
# Ep. 7/8; It. 200/2608; Runtime 36.61 s; Remaining runtime 0h30min36s; f1_train 0.8966; f1_dev 0.5794; loss_train 0.0352; loss_dev 0.1742
# Ep. 7/8; It. 300/2608; Runtime 36.68 s; Remaining runtime 0h30min3s; f1_train 0.8929; f1_dev 0.6034; loss_train 0.0319; loss_dev 0.1748
# Ep. 7/8; It. 400/2608; Runtime 36.65 s; Remaining runtime 0h29min25s; f1_train 0.9114; f1_dev 0.6129; loss_train 0.0426; loss_dev 0.1465
# Ep. 7/8; It. 500/2608; Runtime 36.65 s; Remaining runtime 0h28min48s; f1_train 0.8642; f1_dev 0.6218; loss_train 0.0484; loss_dev 0.1423
# Ep. 7/8; It. 600/2608; Runtime 36.66 s; Remaining runtime 0h28min12s; f1_train 0.9167; f1_dev 0.6087; loss_train 0.0381; loss_dev 0.1566
# Ep. 7/8; It. 700/2608; Runtime 36.68 s; Remaining runtime 0h27min36s; f1_train 0.8780; f1_dev 0.6372; loss_train 0.0523; loss_dev 0.1615
# Ep. 7/8; It. 800/2608; Runtime 36.73 s; Remaining runtime 0h27min2s; f1_train 0.8421; f1_dev 0.6071; loss_train 0.0415; loss_dev 0.1710
# Ep. 7/8; It. 900/2608; Runtime 36.69 s; Remaining runtime 0h26min23s; f1_train 0.8615; f1_dev 0.5941; loss_train 0.0652; loss_dev 0.1870
# Ep. 7/8; It. 1000/2608; Runtime 40.17 s; Remaining runtime 0h28min13s; f1_train 0.9000; f1_dev 0.6050; loss_train 0.0355; loss_dev 0.1528
# Ep. 7/8; It. 1100/2608; Runtime 36.78 s; Remaining runtime 0h25min13s; f1_train 0.9143; f1_dev 0.6429; loss_train 0.0429; loss_dev 0.1540
# Ep. 7/8; It. 1200/2608; Runtime 36.65 s; Remaining runtime 0h24min31s; f1_train 0.9333; f1_dev 0.5849; loss_train 0.0352; loss_dev 0.1760
# Ep. 7/8; It. 1300/2608; Runtime 36.61 s; Remaining runtime 0h23min53s; f1_train 0.9524; f1_dev 0.6140; loss_train 0.0200; loss_dev 0.1820
# Ep. 7/8; It. 1400/2608; Runtime 36.63 s; Remaining runtime 0h23min17s; f1_train 0.8772; f1_dev 0.6306; loss_train 0.0355; loss_dev 0.1653
# Ep. 7/8; It. 1500/2608; Runtime 36.65 s; Remaining runtime 0h22min41s; f1_train 0.9412; f1_dev 0.6372; loss_train 0.0274; loss_dev 0.1650
# Ep. 7/8; It. 1600/2608; Runtime 36.64 s; Remaining runtime 0h22min4s; f1_train 0.8750; f1_dev 0.6218; loss_train 0.0449; loss_dev 0.1618
# Ep. 7/8; It. 1700/2608; Runtime 36.67 s; Remaining runtime 0h21min29s; f1_train 0.9429; f1_dev 0.6271; loss_train 0.0231; loss_dev 0.1569
# Ep. 7/8; It. 1800/2608; Runtime 36.67 s; Remaining runtime 0h20min52s; f1_train 0.9275; f1_dev 0.6306; loss_train 0.0229; loss_dev 0.1560
# Ep. 7/8; It. 1900/2608; Runtime 36.61 s; Remaining runtime 0h20min14s; f1_train 0.8000; f1_dev 0.6364; loss_train 0.0405; loss_dev 0.1588
# Ep. 7/8; It. 2000/2608; Runtime 39.32 s; Remaining runtime 0h21min4s; f1_train 0.8846; f1_dev 0.6271; loss_train 0.0344; loss_dev 0.1566
# Ep. 7/8; It. 2100/2608; Runtime 36.79 s; Remaining runtime 0h19min6s; f1_train 0.8475; f1_dev 0.6140; loss_train 0.0472; loss_dev 0.1690
# Ep. 7/8; It. 2200/2608; Runtime 36.61 s; Remaining runtime 0h18min24s; f1_train 0.9268; f1_dev 0.6182; loss_train 0.0371; loss_dev 0.1725
# Ep. 7/8; It. 2300/2608; Runtime 36.67 s; Remaining runtime 0h17min49s; f1_train 0.8125; f1_dev 0.6095; loss_train 0.0451; loss_dev 0.1729
# Ep. 7/8; It. 2400/2608; Runtime 36.63 s; Remaining runtime 0h17min11s; f1_train 0.9130; f1_dev 0.6239; loss_train 0.0227; loss_dev 0.1670
# Ep. 7/8; It. 2500/2608; Runtime 36.64 s; Remaining runtime 0h16min35s; f1_train 0.9000; f1_dev 0.6126; loss_train 0.0342; loss_dev 0.1538
# Ep. 7/8; It. 2600/2608; Runtime 36.63 s; Remaining runtime 0h15min58s; f1_train 0.8980; f1_dev 0.6168; loss_train 0.0373; loss_dev 0.1627
# Ep. 8/8; It. 0/2608; Runtime 9.85 s; Remaining runtime 0h4min16s; f1_train 0.8980; f1_dev 0.6168; loss_train 0.0373; loss_dev 0.1627
# Ep. 8/8; It. 100/2608; Runtime 36.67 s; Remaining runtime 0h15min19s; f1_train 0.9118; f1_dev 0.6372; loss_train 0.0317; loss_dev 0.1789
# Ep. 8/8; It. 200/2608; Runtime 36.63 s; Remaining runtime 0h14min42s; f1_train 0.9231; f1_dev 0.6364; loss_train 0.0241; loss_dev 0.1825
# Ep. 8/8; It. 300/2608; Runtime 36.65 s; Remaining runtime 0h14min5s; f1_train 0.9524; f1_dev 0.6250; loss_train 0.0146; loss_dev 0.1932
# Ep. 8/8; It. 400/2608; Runtime 36.67 s; Remaining runtime 0h13min29s; f1_train 0.8696; f1_dev 0.6195; loss_train 0.0428; loss_dev 0.1764
# Ep. 8/8; It. 500/2608; Runtime 36.66 s; Remaining runtime 0h12min52s; f1_train 0.9123; f1_dev 0.6080; loss_train 0.0325; loss_dev 0.1701
# Ep. 8/8; It. 600/2608; Runtime 36.61 s; Remaining runtime 0h12min15s; f1_train 0.9180; f1_dev 0.6372; loss_train 0.0293; loss_dev 0.1874
# Ep. 8/8; It. 700/2608; Runtime 36.63 s; Remaining runtime 0h11min38s; f1_train 0.9310; f1_dev 0.6018; loss_train 0.0316; loss_dev 0.1805
# Ep. 8/8; It. 800/2608; Runtime 36.63 s; Remaining runtime 0h11min2s; f1_train 0.9375; f1_dev 0.6239; loss_train 0.0227; loss_dev 0.1719
# Ep. 8/8; It. 900/2608; Runtime 36.65 s; Remaining runtime 0h10min25s; f1_train 0.8696; f1_dev 0.6018; loss_train 0.0430; loss_dev 0.1942
# Ep. 8/8; It. 1000/2608; Runtime 40.02 s; Remaining runtime 0h10min43s; f1_train 0.9231; f1_dev 0.6018; loss_train 0.0262; loss_dev 0.1857
# Ep. 8/8; It. 1100/2608; Runtime 36.83 s; Remaining runtime 0h9min15s; f1_train 0.8657; f1_dev 0.6296; loss_train 0.0388; loss_dev 0.1968
# Ep. 8/8; It. 1200/2608; Runtime 36.61 s; Remaining runtime 0h8min35s; f1_train 0.8525; f1_dev 0.6154; loss_train 0.0427; loss_dev 0.1630
# Ep. 8/8; It. 1300/2608; Runtime 36.62 s; Remaining runtime 0h7min58s; f1_train 0.8788; f1_dev 0.6080; loss_train 0.0372; loss_dev 0.1853
# Ep. 8/8; It. 1400/2608; Runtime 36.64 s; Remaining runtime 0h7min22s; f1_train 0.9091; f1_dev 0.6154; loss_train 0.0329; loss_dev 0.1816
# Ep. 8/8; It. 1500/2608; Runtime 36.65 s; Remaining runtime 0h6min46s; f1_train 0.9254; f1_dev 0.6325; loss_train 0.0288; loss_dev 0.1637
# Ep. 8/8; It. 1600/2608; Runtime 36.75 s; Remaining runtime 0h6min10s; f1_train 0.9118; f1_dev 0.6050; loss_train 0.0428; loss_dev 0.1690
# Ep. 8/8; It. 1700/2608; Runtime 36.68 s; Remaining runtime 0h5min33s; f1_train 0.9677; f1_dev 0.5825; loss_train 0.0158; loss_dev 0.1936
# Ep. 8/8; It. 1800/2608; Runtime 36.61 s; Remaining runtime 0h4min55s; f1_train 0.9000; f1_dev 0.6038; loss_train 0.0409; loss_dev 0.2127
# Ep. 8/8; It. 1900/2608; Runtime 36.64 s; Remaining runtime 0h4min19s; f1_train 0.9067; f1_dev 0.5913; loss_train 0.0364; loss_dev 0.2024
# Ep. 8/8; It. 2000/2608; Runtime 39.23 s; Remaining runtime 0h3min58s; f1_train 0.9429; f1_dev 0.5926; loss_train 0.0229; loss_dev 0.1971
# Ep. 8/8; It. 2100/2608; Runtime 36.69 s; Remaining runtime 0h3min6s; f1_train 0.8276; f1_dev 0.6038; loss_train 0.0473; loss_dev 0.1943
# Ep. 8/8; It. 2200/2608; Runtime 36.68 s; Remaining runtime 0h2min29s; f1_train 0.8608; f1_dev 0.6167; loss_train 0.0578; loss_dev 0.1775
# Ep. 8/8; It. 2300/2608; Runtime 36.64 s; Remaining runtime 0h1min52s; f1_train 0.9020; f1_dev 0.5893; loss_train 0.0370; loss_dev 0.1664
# Ep. 8/8; It. 2400/2608; Runtime 36.67 s; Remaining runtime 0h1min16s; f1_train 0.8571; f1_dev 0.6387; loss_train 0.0389; loss_dev 0.1671
# Ep. 8/8; It. 2500/2608; Runtime 36.69 s; Remaining runtime 0h0min39s; f1_train 0.8571; f1_dev 0.6364; loss_train 0.0530; loss_dev 0.1836
# Ep. 8/8; It. 2600/2608; Runtime 36.60 s; Remaining runtime 0h0min2s; f1_train 0.9032; f1_dev 0.6250; loss_train 0.0318; loss_dev 0.1828
# Total actual runtime: 2 hours 9 min 30 sec

# %%
alpha = 0.1
ewma_loss_dev = numpy_ewma_vectorized(loss_stack, alpha)
ewma_f1_dev = numpy_ewma_vectorized(f1_stack, alpha)
ewma_loss_train = numpy_ewma_vectorized(loss_train_stack, alpha)
ewma_f1_train = numpy_ewma_vectorized(f1_train_stack, alpha)

plt.figure(figsize = (20, 16))
plt.subplot(221) 
plt.plot(step_stack, ewma_loss_dev)
plt.xlabel("Learning Rate")
plt.ylabel("Loss dev")
#plt.xlim([0.001,0.008])
plt.ylim([0,.3])
plt.subplot(222)
plt.plot(step_stack, ewma_f1_dev)
#plt.xlim([0.001,0.008])
#plt.ylim([0.55,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1 dev")

plt.subplot(223) 
plt.plot(step_stack, ewma_loss_train)
plt.xlabel("Learning Rate")
plt.ylabel("Loss Train")
#plt.xlim([0.001,0.008])
plt.ylim([0,0.3])
plt.subplot(224)
plt.plot(step_stack, ewma_f1_train)
#plt.xlim([0.001,0.008])
#plt.ylim([0.55,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1 Train")

plt.show()

# %%
MODELS_FILE = "models/model{}/QIQC_model{}.ckpt".format(model_version,model_version)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model4.0.2/QIQC_model4.0.2.ckpt
# cross val f1 62.12%, dev f1 61.26%

# %%
print(modfil)
# Out:
# /content/gdrive/My Drive/Colab Notebooks/models/model4.0.2/QIQC_model4.0.2.ckpt
