# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

n_neurons = [500, 500, 500, 500]
n_fc1 = 1500
n_fc2 = 600
n_fc3 = 200
n_output = 1
learning_rate = tf.placeholder(tf.float32)
activation_fn = tf.nn.elu

n_steps = 250
seq_len = tf.placeholder(tf.int32, [None], name="seq_len")

X = tf.placeholder(tf.int32, [None, n_steps], name="X")
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X)

with tf.name_scope("shallow_LSTM_layer"):
    lstm_cell = [tf.contrib.rnn.LSTMCell(num_units=n, name="LSTM") for n in n_neurons]
    multi_lstm_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell)
    h_states, out_states = tf.nn.dynamic_rnn(multi_lstm_cell, embedded_sentences, dtype = tf.float32, sequence_length=seq_len) #state = 3 * 2 * m * 500
    states = tf.concat([out_states[0][0],out_states[1][0],out_states[2][0]], axis = 1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(states, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)
    fc3 = tf.contrib.layers.fully_connected(fc2, n_fc3, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc3, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 500

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
"""
QIQC.reset()
with tf.Session() as sess:
    init.run()
    loss_hist = []
    lr_hist = []
    iter_hist = []
    lr = 0
    t_0 = time.time()
    for iteration in range(QIQC.nr_batches):  
        lr = (iteration + 1)/QIQC.nr_batches * 10 # 1.008188^85 = 2
        X_lengths, X_batch, y_batch = QIQC.next_batch()
        _, run_loss = sess.run([training_op, loss], feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate:lr})

        loss_hist.append(run_loss)
        iter_hist.append(iteration)
        lr_hist.append(lr)
        if iteration % 100 == 0:
            t_1 = time.time()
            t_delta = t_1 - t_0
            expected_runtime = t_delta * (QIQC.nr_batches - iteration)/100
            expected_runtime_h = int(expected_runtime//3600)
            expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
            expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
            t_0 = t_1
            print("It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s".format(iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec))
    
"""
# Out:
# '\nQIQC.reset()\nwith tf.Session() as sess:\n    init.run()\n    loss_hist = []\n    lr_hist = []\n    iter_hist = []\n    lr = 0\n    t_0 = time.time()\n    for iteration in range(QIQC.nr_batches):  \n        lr = (iteration + 1)/QIQC.nr_batches * 10 # 1.008188^85 = 2\n        X_lengths, X_batch, y_batch = QIQC.next_batch()\n        _, run_loss = sess.run([training_op, loss], feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate:lr})\n\n        loss_hist.append(run_loss)\n        iter_hist.append(iteration)\n        lr_hist.append(lr)\n        if iteration % 100 == 0:\n            t_1 = time.time()\n            t_delta = t_1 - t_0\n            expected_runtime = t_delta * (QIQC.nr_batches - iteration)/100\n            expected_runtime_h = int(expected_runtime//3600)\n            expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)\n            expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))\n            t_0 = t_1\n            print("It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s".format(iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec))\n    \n'

# %%
#plt.plot(np.log(lr_hist), loss_hist)
#plt.ylim((0,30))

# %%
QIQC.reset()
n_epoch = 5

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model3.2/QIQC_model3.2.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
total_deltas = 0
t_init = time.time()
min_lr = 0.0005
max_lr = 0.0015
with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    stepsize = QIQC.nr_batches
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):
            step = epoch * QIQC.nr_batches + iteration
            cycle = np.floor(1 + step/(2 * stepsize))
            pattern = np.absolute(step/stepsize - 2*cycle + 1)
            cycle_lr = min_lr + (max_lr - min_lr) * pattern
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_len: X_lengths, learning_rate: cycle_lr})

            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)

            if iteration % 1000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 100 == 0:
                f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                t_1 = time.time()
                t_delta = t_1 - t_0
                total_deltas += t_delta
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/100
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/5; It. 0/2608; Runtime 8.02 s; Remaining runtime 0h17min25s; f1_train nan; f1_dev nan; loss_train 1.2268; loss_dev 1.0514
# Ep. 1/5; It. 100/2608; Runtime 79.10 s; Remaining runtime 2h50min35s; f1_train 0.1875; f1_dev 0.2927; loss_train 0.1151; loss_dev 0.1390
# Ep. 1/5; It. 200/2608; Runtime 77.38 s; Remaining runtime 2h45min35s; f1_train 0.5581; f1_dev 0.4516; loss_train 0.1283; loss_dev 0.1221
# Ep. 1/5; It. 300/2608; Runtime 77.92 s; Remaining runtime 2h45min27s; f1_train 0.3636; f1_dev 0.2029; loss_train 0.1074; loss_dev 0.1360
# Ep. 1/5; It. 400/2608; Runtime 77.95 s; Remaining runtime 2h44min13s; f1_train 0.5424; f1_dev 0.5686; loss_train 0.1586; loss_dev 0.1230
# Ep. 1/5; It. 500/2608; Runtime 77.35 s; Remaining runtime 2h41min39s; f1_train 0.4000; f1_dev 0.2703; loss_train 0.1096; loss_dev 0.1214
# Ep. 1/5; It. 600/2608; Runtime 76.87 s; Remaining runtime 2h39min22s; f1_train 0.6437; f1_dev 0.5981; loss_train 0.1617; loss_dev 0.1053
# Ep. 1/5; It. 700/2608; Runtime 80.66 s; Remaining runtime 2h45min53s; f1_train 0.5634; f1_dev 0.6000; loss_train 0.1336; loss_dev 0.1115
# Ep. 1/5; It. 800/2608; Runtime 77.76 s; Remaining runtime 2h38min37s; f1_train 0.8000; f1_dev 0.6275; loss_train 0.0777; loss_dev 0.1055
# Ep. 1/5; It. 900/2608; Runtime 79.23 s; Remaining runtime 2h40min18s; f1_train 0.5517; f1_dev 0.6290; loss_train 0.1117; loss_dev 0.1072
# Ep. 1/5; It. 1000/2608; Runtime 82.48 s; Remaining runtime 2h45min30s; f1_train 0.6429; f1_dev 0.6154; loss_train 0.1025; loss_dev 0.1019
# Ep. 1/5; It. 1100/2608; Runtime 78.12 s; Remaining runtime 2h35min27s; f1_train 0.6939; f1_dev 0.6000; loss_train 0.0901; loss_dev 0.1018
# Ep. 1/5; It. 1200/2608; Runtime 78.98 s; Remaining runtime 2h35min50s; f1_train 0.5714; f1_dev 0.6154; loss_train 0.1014; loss_dev 0.1012
# Ep. 1/5; It. 1300/2608; Runtime 77.84 s; Remaining runtime 2h32min18s; f1_train 0.5957; f1_dev 0.5745; loss_train 0.1126; loss_dev 0.1029
# Ep. 1/5; It. 1400/2608; Runtime 77.02 s; Remaining runtime 2h29min24s; f1_train 0.6667; f1_dev 0.6337; loss_train 0.0861; loss_dev 0.0997
# Ep. 1/5; It. 1500/2608; Runtime 78.45 s; Remaining runtime 2h30min53s; f1_train 0.5385; f1_dev 0.6545; loss_train 0.1045; loss_dev 0.1015
# Ep. 1/5; It. 1600/2608; Runtime 78.19 s; Remaining runtime 2h29min4s; f1_train 0.8378; f1_dev 0.6491; loss_train 0.0796; loss_dev 0.0999
# Ep. 1/5; It. 1700/2608; Runtime 77.52 s; Remaining runtime 2h26min30s; f1_train 0.6349; f1_dev 0.5435; loss_train 0.0997; loss_dev 0.1018
# Ep. 1/5; It. 1800/2608; Runtime 78.21 s; Remaining runtime 2h26min30s; f1_train 0.6667; f1_dev 0.6122; loss_train 0.1094; loss_dev 0.1001
# Ep. 1/5; It. 1900/2608; Runtime 77.25 s; Remaining runtime 2h23min26s; f1_train 0.6765; f1_dev 0.6496; loss_train 0.1216; loss_dev 0.1065
# Ep. 1/5; It. 2000/2608; Runtime 79.60 s; Remaining runtime 2h26min27s; f1_train 0.6429; f1_dev 0.6783; loss_train 0.0994; loss_dev 0.0986
# Ep. 1/5; It. 2100/2608; Runtime 79.11 s; Remaining runtime 2h24min15s; f1_train 0.4314; f1_dev 0.5870; loss_train 0.1181; loss_dev 0.1062
# Ep. 1/5; It. 2200/2608; Runtime 80.15 s; Remaining runtime 2h24min48s; f1_train 0.5000; f1_dev 0.6214; loss_train 0.0877; loss_dev 0.0966
# Ep. 1/5; It. 2300/2608; Runtime 77.27 s; Remaining runtime 2h18min18s; f1_train 0.7273; f1_dev 0.6281; loss_train 0.1003; loss_dev 0.1026
# Ep. 1/5; It. 2400/2608; Runtime 78.46 s; Remaining runtime 2h19min7s; f1_train 0.6316; f1_dev 0.5794; loss_train 0.0974; loss_dev 0.0999
# Ep. 1/5; It. 2500/2608; Runtime 77.62 s; Remaining runtime 2h16min21s; f1_train 0.6383; f1_dev 0.6355; loss_train 0.0985; loss_dev 0.0988
# Ep. 1/5; It. 2600/2608; Runtime 77.49 s; Remaining runtime 2h14min50s; f1_train 0.6441; f1_dev 0.5806; loss_train 0.1016; loss_dev 0.1020
# Ep. 2/5; It. 0/2608; Runtime 14.78 s; Remaining runtime 0h25min41s; f1_train 0.7636; f1_dev 0.6346; loss_train 0.0807; loss_dev 0.0993
# Ep. 2/5; It. 100/2608; Runtime 78.18 s; Remaining runtime 2h14min37s; f1_train 0.5909; f1_dev 0.5926; loss_train 0.0815; loss_dev 0.0987
# Ep. 2/5; It. 200/2608; Runtime 78.09 s; Remaining runtime 2h13min10s; f1_train 0.7647; f1_dev 0.5941; loss_train 0.0928; loss_dev 0.1004
# Ep. 2/5; It. 300/2608; Runtime 78.95 s; Remaining runtime 2h13min19s; f1_train 0.4865; f1_dev 0.5714; loss_train 0.0869; loss_dev 0.0995
# Ep. 2/5; It. 400/2608; Runtime 78.15 s; Remaining runtime 2h10min39s; f1_train 0.6552; f1_dev 0.6111; loss_train 0.0969; loss_dev 0.1000
# Ep. 2/5; It. 500/2608; Runtime 77.63 s; Remaining runtime 2h8min29s; f1_train 0.7576; f1_dev 0.6126; loss_train 0.1030; loss_dev 0.0982
# Ep. 2/5; It. 600/2608; Runtime 78.39 s; Remaining runtime 2h8min27s; f1_train 0.7037; f1_dev 0.5979; loss_train 0.0876; loss_dev 0.1020
# Ep. 2/5; It. 700/2608; Runtime 77.39 s; Remaining runtime 2h5min31s; f1_train 0.6538; f1_dev 0.5631; loss_train 0.0808; loss_dev 0.1013
# Ep. 2/5; It. 800/2608; Runtime 78.11 s; Remaining runtime 2h5min23s; f1_train 0.5000; f1_dev 0.5745; loss_train 0.1252; loss_dev 0.1058
# Ep. 2/5; It. 900/2608; Runtime 80.07 s; Remaining runtime 2h7min12s; f1_train 0.7222; f1_dev 0.6429; loss_train 0.1089; loss_dev 0.1034
# Ep. 2/5; It. 1000/2608; Runtime 82.38 s; Remaining runtime 2h9min30s; f1_train 0.5366; f1_dev 0.5495; loss_train 0.1272; loss_dev 0.1054
# Ep. 2/5; It. 1100/2608; Runtime 76.79 s; Remaining runtime 1h59min26s; f1_train 0.8056; f1_dev 0.5965; loss_train 0.0763; loss_dev 0.1001
# Ep. 2/5; It. 1200/2608; Runtime 77.75 s; Remaining runtime 1h59min38s; f1_train 0.6667; f1_dev 0.6168; loss_train 0.1093; loss_dev 0.1005
# Ep. 2/5; It. 1300/2608; Runtime 77.65 s; Remaining runtime 1h58min11s; f1_train 0.6667; f1_dev 0.5859; loss_train 0.0846; loss_dev 0.0995
# Ep. 2/5; It. 1400/2608; Runtime 77.43 s; Remaining runtime 1h56min33s; f1_train 0.7576; f1_dev 0.6038; loss_train 0.0936; loss_dev 0.0988
# Ep. 2/5; It. 1500/2608; Runtime 77.16 s; Remaining runtime 1h54min51s; f1_train 0.5294; f1_dev 0.6355; loss_train 0.1603; loss_dev 0.0986
# Ep. 2/5; It. 1600/2608; Runtime 79.06 s; Remaining runtime 1h56min22s; f1_train 0.7105; f1_dev 0.6126; loss_train 0.1085; loss_dev 0.1017
# Ep. 2/5; It. 1700/2608; Runtime 78.92 s; Remaining runtime 1h54min51s; f1_train 0.7059; f1_dev 0.6078; loss_train 0.0869; loss_dev 0.0989
# Ep. 2/5; It. 1800/2608; Runtime 78.09 s; Remaining runtime 1h52min20s; f1_train 0.6377; f1_dev 0.6078; loss_train 0.1012; loss_dev 0.0970
# Ep. 2/5; It. 1900/2608; Runtime 79.80 s; Remaining runtime 1h53min28s; f1_train 0.6316; f1_dev 0.5652; loss_train 0.0974; loss_dev 0.1081
# Ep. 2/5; It. 2000/2608; Runtime 82.89 s; Remaining runtime 1h56min29s; f1_train 0.7119; f1_dev 0.6491; loss_train 0.0839; loss_dev 0.0989
# Ep. 2/5; It. 2100/2608; Runtime 77.73 s; Remaining runtime 1h47min56s; f1_train 0.5532; f1_dev 0.5275; loss_train 0.1028; loss_dev 0.0998
# Ep. 2/5; It. 2200/2608; Runtime 78.91 s; Remaining runtime 1h48min15s; f1_train 0.5970; f1_dev 0.6415; loss_train 0.1195; loss_dev 0.0938
# Ep. 2/5; It. 2300/2608; Runtime 77.04 s; Remaining runtime 1h44min24s; f1_train 0.5758; f1_dev 0.6379; loss_train 0.1414; loss_dev 0.0972
# Ep. 2/5; It. 2400/2608; Runtime 79.28 s; Remaining runtime 1h46min8s; f1_train 0.4762; f1_dev 0.6429; loss_train 0.1047; loss_dev 0.1075
# Ep. 2/5; It. 2500/2608; Runtime 78.06 s; Remaining runtime 1h43min11s; f1_train 0.6522; f1_dev 0.6250; loss_train 0.0766; loss_dev 0.1016
# Ep. 2/5; It. 2600/2608; Runtime 77.04 s; Remaining runtime 1h40min33s; f1_train 0.6061; f1_dev 0.6476; loss_train 0.1297; loss_dev 0.0951
# Ep. 3/5; It. 0/2608; Runtime 14.94 s; Remaining runtime 0h19min28s; f1_train 0.6441; f1_dev 0.6667; loss_train 0.0888; loss_dev 0.0946
# Ep. 3/5; It. 100/2608; Runtime 78.63 s; Remaining runtime 1h41min13s; f1_train 0.7213; f1_dev 0.6346; loss_train 0.0826; loss_dev 0.0917
# Ep. 3/5; It. 200/2608; Runtime 77.21 s; Remaining runtime 1h38min6s; f1_train 0.6567; f1_dev 0.6667; loss_train 0.1325; loss_dev 0.0915
# Ep. 3/5; It. 300/2608; Runtime 80.10 s; Remaining runtime 1h40min26s; f1_train 0.6000; f1_dev 0.6263; loss_train 0.0649; loss_dev 0.0979
# Ep. 3/5; It. 400/2608; Runtime 78.22 s; Remaining runtime 1h36min47s; f1_train 0.8197; f1_dev 0.6606; loss_train 0.0699; loss_dev 0.0977
# Ep. 3/5; It. 500/2608; Runtime 76.91 s; Remaining runtime 1h33min52s; f1_train 0.7097; f1_dev 0.6552; loss_train 0.0942; loss_dev 0.0953
# Ep. 3/5; It. 600/2608; Runtime 78.63 s; Remaining runtime 1h34min40s; f1_train 0.6538; f1_dev 0.6364; loss_train 0.0942; loss_dev 0.0998
# Ep. 3/5; It. 700/2608; Runtime 78.12 s; Remaining runtime 1h32min45s; f1_train 0.5909; f1_dev 0.6226; loss_train 0.0892; loss_dev 0.0975
# Ep. 3/5; It. 800/2608; Runtime 77.23 s; Remaining runtime 1h30min24s; f1_train 0.7241; f1_dev 0.6607; loss_train 0.0792; loss_dev 0.1039
# Ep. 3/5; It. 900/2608; Runtime 77.99 s; Remaining runtime 1h29min59s; f1_train 0.8000; f1_dev 0.6139; loss_train 0.0505; loss_dev 0.0958
# Ep. 3/5; It. 1000/2608; Runtime 83.03 s; Remaining runtime 1h34min25s; f1_train 0.5957; f1_dev 0.6078; loss_train 0.0861; loss_dev 0.0965
# Ep. 3/5; It. 1100/2608; Runtime 78.37 s; Remaining runtime 1h27min49s; f1_train 0.7536; f1_dev 0.6239; loss_train 0.0808; loss_dev 0.0980
# Ep. 3/5; It. 1200/2608; Runtime 78.89 s; Remaining runtime 1h27min5s; f1_train 0.7111; f1_dev 0.6337; loss_train 0.0687; loss_dev 0.0994
# Ep. 3/5; It. 1300/2608; Runtime 77.32 s; Remaining runtime 1h24min4s; f1_train 0.6230; f1_dev 0.6545; loss_train 0.0880; loss_dev 0.0979
# Ep. 3/5; It. 1400/2608; Runtime 78.04 s; Remaining runtime 1h23min33s; f1_train 0.5882; f1_dev 0.6545; loss_train 0.1107; loss_dev 0.0930
# Ep. 3/5; It. 1500/2608; Runtime 77.75 s; Remaining runtime 1h21min57s; f1_train 0.6296; f1_dev 0.6296; loss_train 0.0918; loss_dev 0.0954
# Ep. 3/5; It. 1600/2608; Runtime 77.90 s; Remaining runtime 1h20min48s; f1_train 0.6129; f1_dev 0.6364; loss_train 0.1096; loss_dev 0.0924
# Ep. 3/5; It. 1700/2608; Runtime 79.23 s; Remaining runtime 1h20min51s; f1_train 0.6809; f1_dev 0.6200; loss_train 0.0718; loss_dev 0.1028
# Ep. 3/5; It. 1800/2608; Runtime 78.08 s; Remaining runtime 1h18min23s; f1_train 0.5455; f1_dev 0.6346; loss_train 0.0807; loss_dev 0.0985
# Ep. 3/5; It. 1900/2608; Runtime 76.72 s; Remaining runtime 1h15min44s; f1_train 0.6531; f1_dev 0.6214; loss_train 0.0836; loss_dev 0.0973
# Ep. 3/5; It. 2000/2608; Runtime 82.92 s; Remaining runtime 1h20min29s; f1_train 0.5417; f1_dev 0.6726; loss_train 0.1036; loss_dev 0.0943
# Ep. 3/5; It. 2100/2608; Runtime 78.91 s; Remaining runtime 1h15min16s; f1_train 0.6452; f1_dev 0.6549; loss_train 0.1075; loss_dev 0.0933
# Ep. 3/5; It. 2200/2608; Runtime 78.59 s; Remaining runtime 1h13min39s; f1_train 0.5484; f1_dev 0.6486; loss_train 0.1224; loss_dev 0.0928
# Ep. 3/5; It. 2300/2608; Runtime 78.20 s; Remaining runtime 1h11min59s; f1_train 0.7568; f1_dev 0.6275; loss_train 0.0975; loss_dev 0.0960
# Ep. 3/5; It. 2400/2608; Runtime 79.25 s; Remaining runtime 1h11min38s; f1_train 0.7742; f1_dev 0.6786; loss_train 0.1047; loss_dev 0.0954
# Ep. 3/5; It. 2500/2608; Runtime 78.15 s; Remaining runtime 1h9min20s; f1_train 0.6250; f1_dev 0.6415; loss_train 0.0873; loss_dev 0.0964
# Ep. 3/5; It. 2600/2608; Runtime 77.79 s; Remaining runtime 1h7min43s; f1_train 0.7143; f1_dev 0.6604; loss_train 0.0705; loss_dev 0.0918
# Ep. 4/5; It. 0/2608; Runtime 15.15 s; Remaining runtime 0h13min10s; f1_train 0.7273; f1_dev 0.6061; loss_train 0.0841; loss_dev 0.0954
# Ep. 4/5; It. 100/2608; Runtime 77.24 s; Remaining runtime 1h5min51s; f1_train 0.6500; f1_dev 0.6154; loss_train 0.1100; loss_dev 0.1007
# Ep. 4/5; It. 200/2608; Runtime 78.57 s; Remaining runtime 1h5min41s; f1_train 0.7536; f1_dev 0.6214; loss_train 0.0783; loss_dev 0.0986
# Ep. 4/5; It. 300/2608; Runtime 79.80 s; Remaining runtime 1h5min23s; f1_train 0.6531; f1_dev 0.6727; loss_train 0.0843; loss_dev 0.0983
# Ep. 4/5; It. 400/2608; Runtime 77.54 s; Remaining runtime 1h2min14s; f1_train 0.8333; f1_dev 0.6346; loss_train 0.0520; loss_dev 0.0982
# Ep. 4/5; It. 500/2608; Runtime 77.87 s; Remaining runtime 1h1min12s; f1_train 0.6557; f1_dev 0.6545; loss_train 0.0972; loss_dev 0.0962
# Ep. 4/5; It. 600/2608; Runtime 78.73 s; Remaining runtime 1h0min34s; f1_train 0.7089; f1_dev 0.6496; loss_train 0.1140; loss_dev 0.0956
# Ep. 4/5; It. 700/2608; Runtime 76.28 s; Remaining runtime 0h57min24s; f1_train 0.7755; f1_dev 0.6486; loss_train 0.0540; loss_dev 0.0948
# Ep. 4/5; It. 800/2608; Runtime 77.74 s; Remaining runtime 0h57min13s; f1_train 0.7273; f1_dev 0.6789; loss_train 0.0722; loss_dev 0.0974
# Ep. 4/5; It. 900/2608; Runtime 78.68 s; Remaining runtime 0h56min35s; f1_train 0.6667; f1_dev 0.6727; loss_train 0.1095; loss_dev 0.0931
# Ep. 4/5; It. 1000/2608; Runtime 80.98 s; Remaining runtime 0h56min54s; f1_train 0.7059; f1_dev 0.6897; loss_train 0.0892; loss_dev 0.0938
# Ep. 4/5; It. 1100/2608; Runtime 78.62 s; Remaining runtime 0h53min56s; f1_train 0.7755; f1_dev 0.6612; loss_train 0.0524; loss_dev 0.0957
# Ep. 4/5; It. 1200/2608; Runtime 80.01 s; Remaining runtime 0h53min33s; f1_train 0.8308; f1_dev 0.6727; loss_train 0.0785; loss_dev 0.0983
# Ep. 4/5; It. 1300/2608; Runtime 78.41 s; Remaining runtime 0h51min10s; f1_train 0.6667; f1_dev 0.6542; loss_train 0.1031; loss_dev 0.0966
# Ep. 4/5; It. 1400/2608; Runtime 77.93 s; Remaining runtime 0h49min33s; f1_train 0.7302; f1_dev 0.6275; loss_train 0.0706; loss_dev 0.0985
# Ep. 4/5; It. 1500/2608; Runtime 78.32 s; Remaining runtime 0h48min30s; f1_train 0.7302; f1_dev 0.6667; loss_train 0.0721; loss_dev 0.0981
# Ep. 4/5; It. 1600/2608; Runtime 76.93 s; Remaining runtime 0h46min21s; f1_train 0.5789; f1_dev 0.6226; loss_train 0.0838; loss_dev 0.1027
# Ep. 4/5; It. 1700/2608; Runtime 77.95 s; Remaining runtime 0h45min40s; f1_train 0.7547; f1_dev 0.6226; loss_train 0.0741; loss_dev 0.0992
# Ep. 4/5; It. 1800/2608; Runtime 79.70 s; Remaining runtime 0h45min22s; f1_train 0.6667; f1_dev 0.5882; loss_train 0.0862; loss_dev 0.0980
# Ep. 4/5; It. 1900/2608; Runtime 78.17 s; Remaining runtime 0h43min12s; f1_train 0.7500; f1_dev 0.6286; loss_train 0.0665; loss_dev 0.0993
# Ep. 4/5; It. 2000/2608; Runtime 83.02 s; Remaining runtime 0h44min29s; f1_train 0.6400; f1_dev 0.6214; loss_train 0.0764; loss_dev 0.0985
# Ep. 4/5; It. 2100/2608; Runtime 80.23 s; Remaining runtime 0h41min40s; f1_train 0.7419; f1_dev 0.6000; loss_train 0.0703; loss_dev 0.0967
# Ep. 4/5; It. 2200/2608; Runtime 77.12 s; Remaining runtime 0h38min46s; f1_train 0.6552; f1_dev 0.6727; loss_train 0.0873; loss_dev 0.0941
# Ep. 4/5; It. 2300/2608; Runtime 77.41 s; Remaining runtime 0h37min37s; f1_train 0.8169; f1_dev 0.6667; loss_train 0.0690; loss_dev 0.0958
# Ep. 4/5; It. 2400/2608; Runtime 78.02 s; Remaining runtime 0h36min36s; f1_train 0.7250; f1_dev 0.6667; loss_train 0.0930; loss_dev 0.0952
# Ep. 4/5; It. 2500/2608; Runtime 78.98 s; Remaining runtime 0h35min45s; f1_train 0.7778; f1_dev 0.6306; loss_train 0.0687; loss_dev 0.0906
# Ep. 4/5; It. 2600/2608; Runtime 77.59 s; Remaining runtime 0h33min49s; f1_train 0.7308; f1_dev 0.6095; loss_train 0.0681; loss_dev 0.0989
# Ep. 5/5; It. 0/2608; Runtime 15.38 s; Remaining runtime 0h6min41s; f1_train 0.7018; f1_dev 0.6168; loss_train 0.0862; loss_dev 0.0982
# Ep. 5/5; It. 100/2608; Runtime 77.61 s; Remaining runtime 0h32min26s; f1_train 0.7241; f1_dev 0.6355; loss_train 0.0684; loss_dev 0.1007
# Ep. 5/5; It. 200/2608; Runtime 78.10 s; Remaining runtime 0h31min20s; f1_train 0.7556; f1_dev 0.6549; loss_train 0.0648; loss_dev 0.1072
# Ep. 5/5; It. 300/2608; Runtime 78.41 s; Remaining runtime 0h30min9s; f1_train 0.6909; f1_dev 0.6842; loss_train 0.0847; loss_dev 0.1016
# Ep. 5/5; It. 400/2608; Runtime 78.76 s; Remaining runtime 0h28min58s; f1_train 0.6909; f1_dev 0.6139; loss_train 0.0836; loss_dev 0.1073
# Ep. 5/5; It. 500/2608; Runtime 77.69 s; Remaining runtime 0h27min17s; f1_train 0.7949; f1_dev 0.6486; loss_train 0.0959; loss_dev 0.1083
# Ep. 5/5; It. 600/2608; Runtime 79.19 s; Remaining runtime 0h26min30s; f1_train 0.7077; f1_dev 0.6415; loss_train 0.0922; loss_dev 0.1091
# Ep. 5/5; It. 700/2608; Runtime 77.68 s; Remaining runtime 0h24min42s; f1_train 0.6800; f1_dev 0.6372; loss_train 0.0748; loss_dev 0.0981
# Ep. 5/5; It. 800/2608; Runtime 77.61 s; Remaining runtime 0h23min23s; f1_train 0.8214; f1_dev 0.6355; loss_train 0.0749; loss_dev 0.1040
# Ep. 5/5; It. 900/2608; Runtime 77.01 s; Remaining runtime 0h21min55s; f1_train 0.7647; f1_dev 0.6372; loss_train 0.0711; loss_dev 0.0991
# Ep. 5/5; It. 1000/2608; Runtime 82.83 s; Remaining runtime 0h22min11s; f1_train 0.7213; f1_dev 0.6486; loss_train 0.0703; loss_dev 0.1003
# Ep. 5/5; It. 1100/2608; Runtime 78.43 s; Remaining runtime 0h19min42s; f1_train 0.8148; f1_dev 0.6355; loss_train 0.0552; loss_dev 0.0974
# Ep. 5/5; It. 1200/2608; Runtime 78.04 s; Remaining runtime 0h18min18s; f1_train 0.6667; f1_dev 0.6239; loss_train 0.0728; loss_dev 0.1069
# Ep. 5/5; It. 1300/2608; Runtime 77.01 s; Remaining runtime 0h16min47s; f1_train 0.7671; f1_dev 0.6408; loss_train 0.0955; loss_dev 0.1002
# Ep. 5/5; It. 1400/2608; Runtime 76.64 s; Remaining runtime 0h15min25s; f1_train 0.6933; f1_dev 0.6296; loss_train 0.0913; loss_dev 0.1066
# Ep. 5/5; It. 1500/2608; Runtime 77.62 s; Remaining runtime 0h14min20s; f1_train 0.8000; f1_dev 0.6549; loss_train 0.0507; loss_dev 0.1031
# Ep. 5/5; It. 1600/2608; Runtime 78.12 s; Remaining runtime 0h13min7s; f1_train 0.6316; f1_dev 0.6250; loss_train 0.0993; loss_dev 0.1041
# Ep. 5/5; It. 1700/2608; Runtime 77.45 s; Remaining runtime 0h11min43s; f1_train 0.7123; f1_dev 0.6038; loss_train 0.0986; loss_dev 0.1036
# Ep. 5/5; It. 1800/2608; Runtime 77.89 s; Remaining runtime 0h10min29s; f1_train 0.8000; f1_dev 0.6422; loss_train 0.0554; loss_dev 0.1042
# Ep. 5/5; It. 1900/2608; Runtime 77.90 s; Remaining runtime 0h9min11s; f1_train 0.6538; f1_dev 0.6607; loss_train 0.0780; loss_dev 0.1012
# Ep. 5/5; It. 2000/2608; Runtime 82.14 s; Remaining runtime 0h8min19s; f1_train 0.8824; f1_dev 0.6610; loss_train 0.0664; loss_dev 0.1054
# Ep. 5/5; It. 2100/2608; Runtime 80.93 s; Remaining runtime 0h6min51s; f1_train 0.7500; f1_dev 0.6429; loss_train 0.0894; loss_dev 0.1051
# Ep. 5/5; It. 2200/2608; Runtime 77.58 s; Remaining runtime 0h5min16s; f1_train 0.7879; f1_dev 0.6372; loss_train 0.0675; loss_dev 0.1058
# Ep. 5/5; It. 2300/2608; Runtime 78.15 s; Remaining runtime 0h4min0s; f1_train 0.7812; f1_dev 0.6429; loss_train 0.0774; loss_dev 0.1057
# Ep. 5/5; It. 2400/2608; Runtime 78.98 s; Remaining runtime 0h2min44s; f1_train 0.6761; f1_dev 0.6168; loss_train 0.0954; loss_dev 0.1042
# Ep. 5/5; It. 2500/2608; Runtime 78.42 s; Remaining runtime 0h1min24s; f1_train 0.7059; f1_dev 0.6306; loss_train 0.0767; loss_dev 0.1041
# Ep. 5/5; It. 2600/2608; Runtime 77.90 s; Remaining runtime 0h0min6s; f1_train 0.7119; f1_dev 0.6271; loss_train 0.0756; loss_dev 0.1026

# %%
MODELS_FILE = "models/model3.2/QIQC_model3.2.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set, seq_len: X_cv_lengths})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model3.2/QIQC_model3.2.ckpt
# cross val f1 64.46%, dev f1 63.72%
