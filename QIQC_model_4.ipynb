# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime as dt
import time
import re
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

DRIVE_PATH = "/content/gdrive/My Drive/Colab Notebooks/"
TRAIN_FILE = "datasets/train.csv"
CORRECTED_TRAIN_FILE = "datasets/corrected_train.csv"
TEST_FILE = "datasets/test.csv"
GLOVE_FILE = "embeddings/glove.840B.300d/glove.840B.300d.txt"

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Toolbox

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

def load_data(path = DRIVE_PATH, file = CORRECTED_TRAIN_FILE):
    csv_path = os.path.join(path,file)
    return pd.read_csv(csv_path)

def tokenize(sentences_list):
    return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in sentences_list] 
    
def get_vocab(sentences):
    vocab={}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] +=1
            except KeyError:
                vocab[word] = 1
    return vocab

def glove_embeddings(vocabulary_in_set, drive = DRIVE_PATH, gloveFile = GLOVE_FILE ,extract = -1):

    glove_file = os.path.join(drive,gloveFile)
  
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

    embeddings = []
    words_id = {}
    f = open(glove_file,'r', encoding="utf8")
    increment = 0
    words_id[""]=0
    first = True
    i = 1
    
    for line in f:
        word, vect = get_coefs(*line.split(" "))
        if first:
            embeddings.append(np.zeros_like(vect))
            first = False
        if word in vocabulary_in_set:
            embeddings.append(vect)
            words_id[word] = i
            i += 1
            if increment == extract - 1:
                break
            elif extract != -1:
                increment += 1
    f.close()   
    return np.array(embeddings), words_id

def df_to_data_target(df, data_col = "corrected_question_text", target_col = "target"):
    data = df[data_col]
    target = df[target_col]
    return np.c_[data, target]

def embed_and_pad(X, embeddings, n_dims, width):
    padded_X = np.zeros((len(X),width,n_dims))
    i = 0
    for sentence in X:
        j = 0
        for word in sentence:
            padded_X[i,j,:] = embeddings[word]
            j += 1
        i +=1
    return padded_X

def numpy_ewma_vectorized(data, alpha):
    alpha_ = 1-alpha
    D = pd.DataFrame(data)
    M = D.ewm(alpha=alpha_).mean()
    out = M.values
    return out

# %%
class data_split_and_batch:
    def __init__(self, data_targets, dv=0, cv=0, batch_size=500, words_ids = None, seed=42):
        self.seed = seed
        np.random.seed(seed)
        self.batch_length = batch_size
        self.pointer = 0
        self.reshuffle_seed = 0
        self.__split__(data_targets=data_targets, dv=dv, cv=cv, words_ids=words_ids)
    
    def __split__(self, data_targets, dv, cv, words_ids):
        positive_data_targets = data_targets[data_targets[:,1]==1]
        negative_data_targets = data_targets[data_targets[:,1]==0]
        
        positive_length = len(positive_data_targets)
        negative_length = len(negative_data_targets)
  
        pos_data_targets = positive_data_targets[np.random.permutation(positive_length), :]
        neg_data_targets = negative_data_targets[np.random.permutation(negative_length), :]
        
        if dv != 0:
            dv_positive = int(dv * positive_length/(positive_length + negative_length))
            dv_negative = dv - dv_positive
            dv_data_targets = np.concatenate((positive_data_targets[0:dv_positive,:], negative_data_targets[0:dv_negative,:]))
            dv_data_targets = dv_data_targets[np.random.permutation(dv), :]
            self.dv_targets = dv_data_targets[:,1].astype(float)
            X_dev = self.__tokenize__(dv_data_targets[:,0])
            self.X_dv_lengths = np.array(list(map(len, X_dev)))
            if words_ids == None:
                self.dv_data = X_dev
            else:
                self.dv_data = self.__ids_and_pad__(X_dev,words_ids[0], words_ids[1])
        else:
            dv_positive = 0
            dv_negative = 0
            
        if cv != 0:
            cv_positive = int(cv * positive_length/(positive_length + negative_length))
            cv_negative = cv - cv_positive
            cv_data_targets = np.concatenate((positive_data_targets[dv_positive:dv_positive + cv_positive,:], negative_data_targets[dv_negative:dv_negative + cv_negative,:]))
            cv_data_targets = cv_data_targets[np.random.permutation(cv), :]
            self.cv_targets = cv_data_targets[:,1].astype(float)
            X_cross = self.__tokenize__(cv_data_targets[:,0])
            self.X_cv_lengths = np.array(list(map(len, X_cross)))
            if words_ids == None:
                self.cv_data = X_cross
            else:
                self.cv_data = self.__ids_and_pad__(X_cross,words_ids[0], words_ids[1])   
        else:
            cv_positive = 0
            cv_negative = 0
            
        train_data_targets = np.concatenate((positive_data_targets[dv_positive + cv_positive:,:], negative_data_targets[dv_negative + cv_negative:,:]))
        train_data_targets = train_data_targets[np.random.permutation(len(data_targets)-dv-cv), :]
        self.train_targets = train_data_targets[:,1].astype(float)
        X_train = self.__tokenize__(train_data_targets[:,0])
        self.X_train_lengths = np.array(list(map(len, X_train)))
        if words_ids == None:
            self.train_data = X_train
        else:
            self.train_data = self.__ids_and_pad__(X_train ,words_ids[0], words_ids[1])
        self.num_train_examples = len(self.train_targets)
        self.nr_batches = self.num_train_examples//self.batch_length
    
    def __tokenize__(self, X):
        return [re.findall(r"[\w]+|[']|[.,!?;]", str(x)) for x in X]
    
    def __ids_and_pad__(self, X, word_ids, width):
        padded_X = np.zeros((len(X),width))
        i = 0
        for sentence in X:
            j = 0
            for word in sentence:
                padded_X[i,j] = word_ids[word]
                j += 1
            i +=1
        return padded_X
    
    def cross_val_set(self):
        return self.X_cv_lengths, self.cv_data, self.cv_targets 
    
    def dev_set(self):
        return self.X_dv_lengths, self.dv_data, self.dv_targets
    
    def next_batch(self):
        self.pointer += 1
        X_batch = self.train_data[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        y_batch = self.train_targets[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        X_batch_lengths = self.X_train_lengths[(self.pointer - 1)*self.batch_length:self.pointer*self.batch_length]
        
        if self.pointer == self.nr_batches:
            self.pointer = 0
            self.reshuffle_seed += 1
            np.random.seed(self.seed + self.reshuffle_seed)
            permutations = np.random.permutation(self.num_train_examples)
            self.train_data = self.train_data[permutations]
            self.train_targets = self.train_targets[permutations]
            self.X_train_lengths = self.X_train_lengths[permutations]
            
        return X_batch_lengths, X_batch, y_batch
    
    def reset(self):
        self.pointer = 0

# %% [markdown]
# # Load and prepare data

# %%
train_data = load_data()
train_data.head()
# Out:
#                     qid  target  \
# 0  00002165364db923c7e6       0
# 1  000032939017120e6e44       0
# 2  0000412ca6e4628ce2cf       0
# 3  000042bf85aa498cd78e       0
# 4  0000455dfa3e01eae3af       0
#
#                              corrected_question_text
# 0  How did Quebec nationalists see their province...
# 1  Do you have an adopted dog , how would you enc...
# 2  Why does velocity affect time ? Does velocity ...
# 3  How did Otto von Guericke used the Magdeburg h...
# 4  Can I convert montra helicon D to a mountain b...

# %%
data_targets = df_to_data_target(train_data)

# %%
tokenized_questions = tokenize(train_data["corrected_question_text"].values)
vocabulary_in_set = get_vocab(tokenized_questions)

# %%
embeddings, words_ids = glove_embeddings(vocabulary_in_set=vocabulary_in_set)

# %% [markdown]
# # Construction phase

# %%
reset_graph()

out_channels = 100
window_width = [3, 4, 5]
embedding_dimensions = 300
n_steps = 250
n_fc1 = 300
n_fc2 = 100
n_output = 1

activation_fn = tf.nn.relu
init_W_CL_3 = np.random.randn(window_width[0],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_3 = np.random.randn(1,1,1,out_channels).astype(np.float32)
init_W_CL_4 = np.random.randn(window_width[1],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_4 = np.random.randn(1,1,1,out_channels).astype(np.float32)
init_W_CL_5 = np.random.randn(window_width[2],embedding_dimensions,1,out_channels).astype(np.float32)
init_b_CL_5 = np.random.randn(1,1,1,out_channels).astype(np.float32)

learning_rate = tf.placeholder(tf.float32)

X = tf.placeholder(tf.int32, [None, n_steps], name="X") #m * n_steps
y = tf.placeholder(tf.float32, [None], name="y")

with tf.name_scope("embedding_layer"):
    word_embeddings = tf.Variable(initial_value=embeddings, trainable=False)# n_words * embedding_dimensions
    embedded_sentences = tf.nn.embedding_lookup(word_embeddings, X) # m * n_steps * embedding_dimensions

with tf.name_scope("CNN_3"):
    W_CL_3 = tf.Variable(initial_value=init_W_CL_3)
    b_CL_3 = tf.Variable(initial_value=init_b_CL_3)
    CL_3 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_3, strides=[1,1,1,1], padding="VALID")# m * n_steps - 3 + 1 *1 * out_channels 
    activated_CL_3 = activation_fn(tf.add(CL_3,b_CL_3)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_3 = tf.reshape(tf.math.reduce_max(activated_CL_3,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_4"):
    W_CL_4 = tf.Variable(initial_value=init_W_CL_4)
    b_CL_4 = tf.Variable(initial_value=init_b_CL_4)
    CL_4 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_4, strides=[1,1,1,1], padding="VALID")# m * n_steps - 4 + 1 *1 * out_channels 
    activated_CL_4 = activation_fn(tf.add(CL_4,b_CL_4)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_4 = tf.reshape(tf.math.reduce_max(activated_CL_4,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels
    
with tf.name_scope("CNN_5"):
    W_CL_5 = tf.Variable(initial_value=init_W_CL_5)
    b_CL_5 = tf.Variable(initial_value=init_b_CL_5)
    CL_5 = tf.nn.conv2d(tf.reshape(embedded_sentences,[-1,n_steps,embedding_dimensions,1]), W_CL_5, strides=[1,1,1,1], padding="VALID")# m * n_steps - 5 + 1 *1 * out_channels 
    activated_CL_5 = activation_fn(tf.add(CL_5,b_CL_5)) # m * n_steps - 5 + 1 * 1 * out_channels
    MAXPOOL_5 = tf.reshape(tf.math.reduce_max(activated_CL_5,axis=1),[-1,out_channels]) # m * 1 * out_channels  --> m * out_channels

with tf.name_scope("Max_pool"):
    MAXPOOL = tf.concat([MAXPOOL_3,MAXPOOL_4,MAXPOOL_5], axis=1)
    
with tf.name_scope("fully_connected_layers"):
    fc1 = tf.contrib.layers.fully_connected(MAXPOOL, n_fc1, activation_fn=activation_fn)
    fc2 = tf.contrib.layers.fully_connected(fc1, n_fc2, activation_fn=activation_fn)

with tf.name_scope("logits_and_outputs"):
    logits = tf.reshape(tf.contrib.layers.fully_connected(fc2, n_output, activation_fn=None),shape=[-1])
    outputs = tf.sigmoid(logits)
    predictions = tf.round(outputs)

with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy)

with tf.name_scope("evaluation"):
    TP = tf.count_nonzero(predictions * y)
    TN = tf.count_nonzero((predictions - 1) * (y - 1))
    FP = tf.count_nonzero(predictions * (y - 1))
    FN = tf.count_nonzero((predictions - 1) * y)
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    f1 = 2 * precision * recall / (precision + recall)

with tf.name_scope("training_op"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

f1_train_summary = tf.summary.scalar('Train_F1_score', f1)
f1_dev_summary = tf.summary.scalar("Dev_F1_score", f1)
loss_train_summary = tf.summary.scalar("Train_loss", loss)
loss_dev_summary = tf.summary.scalar("Dev_loss", loss)

# %% [markdown]
# # Training phase

# %%
batch_size = 100

QIQC = data_split_and_batch(data_targets, cv=1000, dv=1000, batch_size=batch_size, words_ids=(words_ids,n_steps))
X_dev_lengths, X_dev_set, y_dev_set = QIQC.dev_set()

# %%
QIQC.reset()
n_epoch = 6

now = dt.utcnow().strftime("%Y%m%d%H%M%S")
LOGS_FOLDER = "logs/run-{}/".format(now)
MODELS_FILE = "models/model4/QIQC_model4.ckpt"
logdir = os.path.join(DRIVE_PATH,LOGS_FOLDER)
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)

#file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

t_init = time.time()
lr = 1e-12
lr_stop = 1
lr_stack = []
loss_stack = []
step_stack = []
f1_stack = []
loss_train_stack = []
f1_train_stack = []
min_lr = 0.003
max_lr = 0.008
lr = min_lr

with tf.Session() as sess:
    init.run()
    t_0 = time.time()
    for epoch in range(n_epoch):
        for iteration in range(QIQC.nr_batches):            
            X_lengths, X_batch, y_batch = QIQC.next_batch()
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, learning_rate: lr})
            
            step = epoch * QIQC.nr_batches + iteration
            cycle = np.floor(1 + step/(2 * QIQC.nr_batches))
            pattern = np.absolute(step/QIQC.nr_batches - 2*cycle + 1)
            lr = min_lr + (max_lr - min_lr) * (1-pattern)
            
            if step % 100 ==0:
              f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
              f1_train, loss_train = sess.run([f1, loss], feed_dict = {X : X_batch, y : y_batch})
              step_stack.append(step)
              loss_stack.append(loss_dev)
              f1_stack.append(f1_dev)
              loss_train_stack.append(loss_train)
              f1_train_stack.append(f1_train)
            """
            if iteration % 30 == 0 :
                f1_train_str, loss_train_str = sess.run([f1_train_summary, loss_train_summary],feed_dict = {X : X_batch, y : y_batch, seq_len: X_lengths})
                f1_dev_str, loss_dev_str = sess.run([f1_dev_summary, loss_dev_summary], feed_dict = {X : X_dev_set, y : y_dev_set, seq_len: X_dev_lengths})
                file_writer.add_summary(f1_train_str, step)
                file_writer.add_summary(f1_dev_str, step)
                file_writer.add_summary(loss_train_str, step)
                file_writer.add_summary(loss_dev_str, step)
            """
            if iteration % 10000 == 0:
                save_path = saver.save(sess,modfil)
            if iteration % 500 == 0:
                #f1_train, loss_train = sess.run([f1, loss],feed_dict = {X : X_batch, y : y_batch})
                #f1_dev, loss_dev = sess.run([f1, loss], feed_dict = {X : X_dev_set, y : y_dev_set})
                t_1 = time.time()
                t_delta = t_1 - t_0
                expected_runtime = t_delta * ((n_epoch - epoch - 1) * QIQC.nr_batches + (QIQC.nr_batches - iteration))/500
                expected_runtime_h = int(expected_runtime//3600)
                expected_runtime_min = int((expected_runtime - 3600 * expected_runtime_h)//60)
                expected_runtime_sec = int((expected_runtime - 3600 * expected_runtime_h - 60 * expected_runtime_min))
                t_0 = t_1
                print("Ep. {}/{}; It. {}/{}; Runtime {:.2f} s; Remaining runtime {}h{}min{}s; f1_train {:.4f}; f1_dev {:.4f}; loss_train {:.4f}; loss_dev {:.4f}".format(epoch + 1, n_epoch, iteration, QIQC.nr_batches, t_delta, expected_runtime_h,expected_runtime_min,expected_runtime_sec,f1_train,f1_dev,loss_train,loss_dev))
    save_path = saver.save(sess,modfil)
t_final = time.time()
actual_runtime_h = int((t_final - t_init)//3600)
actual_runtime_min = int((t_final - t_init - 3600 * actual_runtime_h)//60)
actual_runtime_sec = int((t_final - t_init - 3600 * actual_runtime_h - 60 * actual_runtime_min))

print("Total actual runtime: {} hours {} min {} sec".format(actual_runtime_h, actual_runtime_min, actual_runtime_sec))
# Out:
# Ep. 1/6; It. 0/13041; Runtime 9.12 s; Remaining runtime 0h23min47s; f1_train nan; f1_dev nan; loss_train 10.2213; loss_dev 8.0735
# Ep. 1/6; It. 500/13041; Runtime 20.75 s; Remaining runtime 0h53min47s; f1_train 0.5455; f1_dev 0.3956; loss_train 0.1040; loss_dev 0.1531
# Ep. 1/6; It. 1000/13041; Runtime 20.69 s; Remaining runtime 0h53min15s; f1_train 0.4000; f1_dev 0.0923; loss_train 0.0761; loss_dev 0.1707
# Ep. 1/6; It. 1500/13041; Runtime 20.69 s; Remaining runtime 0h52min56s; f1_train 0.2857; f1_dev 0.2500; loss_train 0.1145; loss_dev 0.1393
# Ep. 1/6; It. 2000/13041; Runtime 20.70 s; Remaining runtime 0h52min37s; f1_train 0.4444; f1_dev 0.4848; loss_train 0.0665; loss_dev 0.1195
# Ep. 1/6; It. 2500/13041; Runtime 20.73 s; Remaining runtime 0h52min19s; f1_train 0.5882; f1_dev 0.5437; loss_train 0.1400; loss_dev 0.1216
# Ep. 1/6; It. 3000/13041; Runtime 20.72 s; Remaining runtime 0h51min58s; f1_train 0.7692; f1_dev 0.4286; loss_train 0.1206; loss_dev 0.1312
# Ep. 1/6; It. 3500/13041; Runtime 20.74 s; Remaining runtime 0h51min40s; f1_train nan; f1_dev 0.5333; loss_train 0.1422; loss_dev 0.1078
# Ep. 1/6; It. 4000/13041; Runtime 20.73 s; Remaining runtime 0h51min18s; f1_train 0.8000; f1_dev 0.5472; loss_train 0.0542; loss_dev 0.1095
# Ep. 1/6; It. 4500/13041; Runtime 20.69 s; Remaining runtime 0h50min51s; f1_train 0.6667; f1_dev 0.5263; loss_train 0.0954; loss_dev 0.1101
# Ep. 1/6; It. 5000/13041; Runtime 20.72 s; Remaining runtime 0h50min35s; f1_train 0.4000; f1_dev 0.5055; loss_train 0.0763; loss_dev 0.1150
# Ep. 1/6; It. 5500/13041; Runtime 20.75 s; Remaining runtime 0h50min19s; f1_train 0.5000; f1_dev 0.5686; loss_train 0.0753; loss_dev 0.1049
# Ep. 1/6; It. 6000/13041; Runtime 20.73 s; Remaining runtime 0h49min54s; f1_train 0.4000; f1_dev 0.5000; loss_train 0.1308; loss_dev 0.1047
# Ep. 1/6; It. 6500/13041; Runtime 20.73 s; Remaining runtime 0h49min34s; f1_train 0.6000; f1_dev 0.5872; loss_train 0.1052; loss_dev 0.1027
# Ep. 1/6; It. 7000/13041; Runtime 20.71 s; Remaining runtime 0h49min11s; f1_train 0.6667; f1_dev 0.5000; loss_train 0.1260; loss_dev 0.1065
# Ep. 1/6; It. 7500/13041; Runtime 20.72 s; Remaining runtime 0h48min51s; f1_train 0.5455; f1_dev 0.6441; loss_train 0.1085; loss_dev 0.0996
# Ep. 1/6; It. 8000/13041; Runtime 20.74 s; Remaining runtime 0h48min33s; f1_train 0.8000; f1_dev 0.6316; loss_train 0.0355; loss_dev 0.1033
# Ep. 1/6; It. 8500/13041; Runtime 20.71 s; Remaining runtime 0h48min8s; f1_train 0.6667; f1_dev 0.5743; loss_train 0.0810; loss_dev 0.1042
# Ep. 1/6; It. 9000/13041; Runtime 20.70 s; Remaining runtime 0h47min46s; f1_train 0.7500; f1_dev 0.6422; loss_train 0.0663; loss_dev 0.1076
# Ep. 1/6; It. 9500/13041; Runtime 20.69 s; Remaining runtime 0h47min24s; f1_train 0.6000; f1_dev 0.5743; loss_train 0.0845; loss_dev 0.1039
# Ep. 1/6; It. 10000/13041; Runtime 23.71 s; Remaining runtime 0h53min56s; f1_train 0.6000; f1_dev 0.6154; loss_train 0.0968; loss_dev 0.1038
# Ep. 1/6; It. 10500/13041; Runtime 20.80 s; Remaining runtime 0h46min58s; f1_train 0.7143; f1_dev 0.6195; loss_train 0.1123; loss_dev 0.1091
# Ep. 1/6; It. 11000/13041; Runtime 20.66 s; Remaining runtime 0h46min19s; f1_train nan; f1_dev nan; loss_train 0.1104; loss_dev 0.1137
# Ep. 1/6; It. 11500/13041; Runtime 20.60 s; Remaining runtime 0h45min49s; f1_train 0.6000; f1_dev 0.6491; loss_train 0.1274; loss_dev 0.1076
# Ep. 1/6; It. 12000/13041; Runtime 20.61 s; Remaining runtime 0h45min30s; f1_train 0.2857; f1_dev 0.6019; loss_train 0.0884; loss_dev 0.1131
# Ep. 1/6; It. 12500/13041; Runtime 20.57 s; Remaining runtime 0h45min4s; f1_train 0.7273; f1_dev 0.6422; loss_train 0.1085; loss_dev 0.1039
# Ep. 1/6; It. 13000/13041; Runtime 20.58 s; Remaining runtime 0h44min45s; f1_train 0.7059; f1_dev 0.4944; loss_train 0.1223; loss_dev 0.1106
# Ep. 2/6; It. 0/13041; Runtime 7.45 s; Remaining runtime 0h16min12s; f1_train 0.7059; f1_dev 0.4944; loss_train 0.1223; loss_dev 0.1106
# Ep. 2/6; It. 500/13041; Runtime 20.70 s; Remaining runtime 0h44min38s; f1_train 0.4444; f1_dev 0.6071; loss_train 0.0883; loss_dev 0.1089
# Ep. 2/6; It. 1000/13041; Runtime 20.58 s; Remaining runtime 0h44min2s; f1_train 0.8000; f1_dev 0.5600; loss_train 0.0631; loss_dev 0.1038
# Ep. 2/6; It. 1500/13041; Runtime 20.61 s; Remaining runtime 0h43min45s; f1_train 0.6667; f1_dev 0.5567; loss_train 0.0942; loss_dev 0.1029
# Ep. 2/6; It. 2000/13041; Runtime 20.58 s; Remaining runtime 0h43min21s; f1_train 0.7500; f1_dev 0.5833; loss_train 0.1062; loss_dev 0.1077
# Ep. 2/6; It. 2500/13041; Runtime 20.58 s; Remaining runtime 0h43min1s; f1_train 0.6000; f1_dev 0.5474; loss_train 0.0836; loss_dev 0.1009
# Ep. 2/6; It. 3000/13041; Runtime 20.57 s; Remaining runtime 0h42min39s; f1_train 0.6667; f1_dev 0.6154; loss_train 0.1402; loss_dev 0.1057
# Ep. 2/6; It. 3500/13041; Runtime 20.55 s; Remaining runtime 0h42min16s; f1_train 0.6154; f1_dev 0.6542; loss_train 0.1191; loss_dev 0.0985
# Ep. 2/6; It. 4000/13041; Runtime 20.57 s; Remaining runtime 0h41min57s; f1_train 0.4444; f1_dev 0.6408; loss_train 0.0985; loss_dev 0.0987
# Ep. 2/6; It. 4500/13041; Runtime 20.58 s; Remaining runtime 0h41min38s; f1_train 0.3333; f1_dev 0.5769; loss_train 0.0801; loss_dev 0.1086
# Ep. 2/6; It. 5000/13041; Runtime 20.59 s; Remaining runtime 0h41min19s; f1_train 0.9412; f1_dev 0.6429; loss_train 0.0767; loss_dev 0.0954
# Ep. 2/6; It. 5500/13041; Runtime 20.59 s; Remaining runtime 0h40min58s; f1_train 0.5000; f1_dev 0.6154; loss_train 0.1003; loss_dev 0.0931
# Ep. 2/6; It. 6000/13041; Runtime 20.58 s; Remaining runtime 0h40min36s; f1_train 0.7143; f1_dev 0.6847; loss_train 0.0777; loss_dev 0.1020
# Ep. 2/6; It. 6500/13041; Runtime 20.59 s; Remaining runtime 0h40min17s; f1_train 0.4000; f1_dev 0.6275; loss_train 0.0858; loss_dev 0.1002
# Ep. 2/6; It. 7000/13041; Runtime 20.59 s; Remaining runtime 0h39min56s; f1_train 0.7692; f1_dev 0.6792; loss_train 0.1150; loss_dev 0.0992
# Ep. 2/6; It. 7500/13041; Runtime 20.61 s; Remaining runtime 0h39min38s; f1_train 0.7692; f1_dev 0.6552; loss_train 0.0934; loss_dev 0.0989
# Ep. 2/6; It. 8000/13041; Runtime 20.57 s; Remaining runtime 0h39min13s; f1_train 0.4000; f1_dev 0.5941; loss_train 0.1294; loss_dev 0.1012
# Ep. 2/6; It. 8500/13041; Runtime 20.58 s; Remaining runtime 0h38min54s; f1_train 0.6250; f1_dev 0.6724; loss_train 0.1230; loss_dev 0.1023
# Ep. 2/6; It. 9000/13041; Runtime 20.59 s; Remaining runtime 0h38min34s; f1_train 0.6667; f1_dev 0.6610; loss_train 0.0459; loss_dev 0.0985
# Ep. 2/6; It. 9500/13041; Runtime 20.59 s; Remaining runtime 0h38min14s; f1_train 0.6250; f1_dev 0.6491; loss_train 0.2000; loss_dev 0.1024
# Ep. 2/6; It. 10000/13041; Runtime 23.44 s; Remaining runtime 0h43min8s; f1_train 0.8000; f1_dev 0.5981; loss_train 0.0210; loss_dev 0.1024
# Ep. 2/6; It. 10500/13041; Runtime 20.70 s; Remaining runtime 0h37min44s; f1_train 0.6154; f1_dev 0.6000; loss_train 0.1021; loss_dev 0.0980
# Ep. 2/6; It. 11000/13041; Runtime 20.59 s; Remaining runtime 0h37min11s; f1_train 0.9333; f1_dev 0.6780; loss_train 0.0479; loss_dev 0.0996
# Ep. 2/6; It. 11500/13041; Runtime 20.58 s; Remaining runtime 0h36min50s; f1_train 0.3333; f1_dev 0.6552; loss_train 0.1343; loss_dev 0.0970
# Ep. 2/6; It. 12000/13041; Runtime 20.55 s; Remaining runtime 0h36min26s; f1_train 0.5714; f1_dev 0.6422; loss_train 0.1225; loss_dev 0.0959
# Ep. 2/6; It. 12500/13041; Runtime 20.59 s; Remaining runtime 0h36min10s; f1_train 0.5455; f1_dev 0.6275; loss_train 0.0998; loss_dev 0.0994
# Ep. 2/6; It. 13000/13041; Runtime 20.57 s; Remaining runtime 0h35min47s; f1_train 0.3333; f1_dev 0.6364; loss_train 0.2119; loss_dev 0.0961
# Ep. 3/6; It. 0/13041; Runtime 6.59 s; Remaining runtime 0h11min27s; f1_train 0.3333; f1_dev 0.6364; loss_train 0.2119; loss_dev 0.0961
# Ep. 3/6; It. 500/13041; Runtime 20.68 s; Remaining runtime 0h35min37s; f1_train 0.8000; f1_dev 0.6609; loss_train 0.0507; loss_dev 0.0960
# Ep. 3/6; It. 1000/13041; Runtime 20.56 s; Remaining runtime 0h35min3s; f1_train 0.5000; f1_dev 0.6275; loss_train 0.1654; loss_dev 0.0963
# Ep. 3/6; It. 1500/13041; Runtime 20.60 s; Remaining runtime 0h34min47s; f1_train 0.6667; f1_dev 0.6609; loss_train 0.0693; loss_dev 0.0959
# Ep. 3/6; It. 2000/13041; Runtime 20.56 s; Remaining runtime 0h34min22s; f1_train 0.6667; f1_dev 0.6435; loss_train 0.1028; loss_dev 0.0974
# Ep. 3/6; It. 2500/13041; Runtime 20.59 s; Remaining runtime 0h34min5s; f1_train 0.7500; f1_dev 0.6346; loss_train 0.0411; loss_dev 0.1040
# Ep. 3/6; It. 3000/13041; Runtime 20.60 s; Remaining runtime 0h33min45s; f1_train 0.6667; f1_dev 0.6275; loss_train 0.0977; loss_dev 0.1075
# Ep. 3/6; It. 3500/13041; Runtime 20.62 s; Remaining runtime 0h33min26s; f1_train 0.8333; f1_dev 0.6486; loss_train 0.0800; loss_dev 0.0983
# Ep. 3/6; It. 4000/13041; Runtime 20.59 s; Remaining runtime 0h33min3s; f1_train 0.7273; f1_dev 0.6441; loss_train 0.0762; loss_dev 0.1017
# Ep. 3/6; It. 4500/13041; Runtime 20.58 s; Remaining runtime 0h32min42s; f1_train 0.6154; f1_dev 0.6422; loss_train 0.1092; loss_dev 0.1015
# Ep. 3/6; It. 5000/13041; Runtime 20.61 s; Remaining runtime 0h32min23s; f1_train 0.7273; f1_dev 0.6286; loss_train 0.0689; loss_dev 0.0998
# Ep. 3/6; It. 5500/13041; Runtime 20.61 s; Remaining runtime 0h32min3s; f1_train 0.7500; f1_dev 0.5941; loss_train 0.0523; loss_dev 0.1008
# Ep. 3/6; It. 6000/13041; Runtime 20.66 s; Remaining runtime 0h31min47s; f1_train 0.9091; f1_dev 0.6341; loss_train 0.0831; loss_dev 0.1059
# Ep. 3/6; It. 6500/13041; Runtime 20.60 s; Remaining runtime 0h31min21s; f1_train 0.2857; f1_dev 0.6038; loss_train 0.1338; loss_dev 0.1042
# Ep. 3/6; It. 7000/13041; Runtime 20.62 s; Remaining runtime 0h31min2s; f1_train 0.5000; f1_dev 0.5882; loss_train 0.1098; loss_dev 0.1073
# Ep. 3/6; It. 7500/13041; Runtime 20.61 s; Remaining runtime 0h30min40s; f1_train 0.7692; f1_dev 0.6111; loss_train 0.0508; loss_dev 0.1065
# Ep. 3/6; It. 8000/13041; Runtime 20.57 s; Remaining runtime 0h30min17s; f1_train 0.2500; f1_dev 0.6481; loss_train 0.0996; loss_dev 0.1003
# Ep. 3/6; It. 8500/13041; Runtime 20.56 s; Remaining runtime 0h29min55s; f1_train 0.4444; f1_dev 0.6508; loss_train 0.1304; loss_dev 0.1046
# Ep. 3/6; It. 9000/13041; Runtime 20.60 s; Remaining runtime 0h29min37s; f1_train 0.7500; f1_dev 0.6140; loss_train 0.0941; loss_dev 0.1049
# Ep. 3/6; It. 9500/13041; Runtime 20.54 s; Remaining runtime 0h29min12s; f1_train 0.5714; f1_dev 0.6408; loss_train 0.1049; loss_dev 0.1037
# Ep. 3/6; It. 10000/13041; Runtime 22.94 s; Remaining runtime 0h32min14s; f1_train 0.5714; f1_dev 0.6549; loss_train 0.1596; loss_dev 0.1053
# Ep. 3/6; It. 10500/13041; Runtime 20.57 s; Remaining runtime 0h28min34s; f1_train 0.7273; f1_dev 0.6769; loss_train 0.1038; loss_dev 0.1047
# Ep. 3/6; It. 11000/13041; Runtime 20.61 s; Remaining runtime 0h28min16s; f1_train 0.8000; f1_dev 0.6168; loss_train 0.0753; loss_dev 0.1060
# Ep. 3/6; It. 11500/13041; Runtime 20.59 s; Remaining runtime 0h27min54s; f1_train 0.7273; f1_dev 0.6667; loss_train 0.0842; loss_dev 0.0973
# Ep. 3/6; It. 12000/13041; Runtime 20.56 s; Remaining runtime 0h27min31s; f1_train nan; f1_dev 0.4598; loss_train 0.1455; loss_dev 0.1309
# Ep. 3/6; It. 12500/13041; Runtime 20.57 s; Remaining runtime 0h27min11s; f1_train 0.9231; f1_dev 0.6281; loss_train 0.0482; loss_dev 0.1046
# Ep. 3/6; It. 13000/13041; Runtime 20.61 s; Remaining runtime 0h26min54s; f1_train 0.4706; f1_dev 0.6195; loss_train 0.1461; loss_dev 0.0994
# Ep. 4/6; It. 0/13041; Runtime 5.74 s; Remaining runtime 0h7min29s; f1_train 0.5714; f1_dev 0.4944; loss_train 0.1184; loss_dev 0.1104
# Ep. 4/6; It. 500/13041; Runtime 20.70 s; Remaining runtime 0h26min38s; f1_train 0.6667; f1_dev 0.5556; loss_train 0.0687; loss_dev 0.1085
# Ep. 4/6; It. 1000/13041; Runtime 20.59 s; Remaining runtime 0h26min9s; f1_train 0.7273; f1_dev 0.6140; loss_train 0.0704; loss_dev 0.1083
# Ep. 4/6; It. 1500/13041; Runtime 20.56 s; Remaining runtime 0h25min46s; f1_train 0.7500; f1_dev 0.6038; loss_train 0.0566; loss_dev 0.1083
# Ep. 4/6; It. 2000/13041; Runtime 20.55 s; Remaining runtime 0h25min25s; f1_train nan; f1_dev 0.1212; loss_train 0.1404; loss_dev 0.1596
# Ep. 4/6; It. 2500/13041; Runtime 20.56 s; Remaining runtime 0h25min6s; f1_train 0.6154; f1_dev 0.6111; loss_train 0.1868; loss_dev 0.1103
# Ep. 4/6; It. 3000/13041; Runtime 20.54 s; Remaining runtime 0h24min43s; f1_train 0.7273; f1_dev 0.5905; loss_train 0.0662; loss_dev 0.1109
# Ep. 4/6; It. 3500/13041; Runtime 20.58 s; Remaining runtime 0h24min26s; f1_train 0.6667; f1_dev 0.6239; loss_train 0.0495; loss_dev 0.1158
# Ep. 4/6; It. 4000/13041; Runtime 20.58 s; Remaining runtime 0h24min5s; f1_train 0.8000; f1_dev 0.6218; loss_train 0.0940; loss_dev 0.1119
# Ep. 4/6; It. 4500/13041; Runtime 20.58 s; Remaining runtime 0h23min45s; f1_train 0.6154; f1_dev 0.6552; loss_train 0.0994; loss_dev 0.1077
# Ep. 4/6; It. 5000/13041; Runtime 20.56 s; Remaining runtime 0h23min23s; f1_train 0.6667; f1_dev 0.5849; loss_train 0.0687; loss_dev 0.1130
# Ep. 4/6; It. 5500/13041; Runtime 20.59 s; Remaining runtime 0h23min4s; f1_train nan; f1_dev 0.5833; loss_train 0.1087; loss_dev 0.1281
# Ep. 4/6; It. 6000/13041; Runtime 20.58 s; Remaining runtime 0h22min43s; f1_train 0.6000; f1_dev 0.6372; loss_train 0.0720; loss_dev 0.1177
# Ep. 4/6; It. 6500/13041; Runtime 20.55 s; Remaining runtime 0h22min20s; f1_train 0.5714; f1_dev 0.5567; loss_train 0.1692; loss_dev 0.1255
# Ep. 4/6; It. 7000/13041; Runtime 20.58 s; Remaining runtime 0h22min2s; f1_train 0.8750; f1_dev 0.6055; loss_train 0.0731; loss_dev 0.1129
# Ep. 4/6; It. 7500/13041; Runtime 20.58 s; Remaining runtime 0h21min41s; f1_train 0.6667; f1_dev 0.5941; loss_train 0.0648; loss_dev 0.1230
# Ep. 4/6; It. 8000/13041; Runtime 20.55 s; Remaining runtime 0h21min19s; f1_train 0.5714; f1_dev 0.5946; loss_train 0.0961; loss_dev 0.1083
# Ep. 4/6; It. 8500/13041; Runtime 20.58 s; Remaining runtime 0h21min0s; f1_train 1.0000; f1_dev 0.6139; loss_train 0.0501; loss_dev 0.1107
# Ep. 4/6; It. 9000/13041; Runtime 20.59 s; Remaining runtime 0h20min40s; f1_train 0.6154; f1_dev 0.5946; loss_train 0.1412; loss_dev 0.1063
# Ep. 4/6; It. 9500/13041; Runtime 20.58 s; Remaining runtime 0h20min19s; f1_train 0.4444; f1_dev 0.6071; loss_train 0.0944; loss_dev 0.1061
# Ep. 4/6; It. 10000/13041; Runtime 22.78 s; Remaining runtime 0h22min6s; f1_train 0.7500; f1_dev 0.6261; loss_train 0.0854; loss_dev 0.1051
# Ep. 4/6; It. 10500/13041; Runtime 20.59 s; Remaining runtime 0h19min38s; f1_train 0.7778; f1_dev 0.6168; loss_train 0.1024; loss_dev 0.1062
# Ep. 4/6; It. 11000/13041; Runtime 20.60 s; Remaining runtime 0h19min18s; f1_train 0.7273; f1_dev 0.6306; loss_train 0.0516; loss_dev 0.1072
# Ep. 4/6; It. 11500/13041; Runtime 20.61 s; Remaining runtime 0h18min58s; f1_train 0.8235; f1_dev 0.5545; loss_train 0.0875; loss_dev 0.1059
# Ep. 4/6; It. 12000/13041; Runtime 20.57 s; Remaining runtime 0h18min36s; f1_train 0.4615; f1_dev 0.6182; loss_train 0.1190; loss_dev 0.1048
# Ep. 4/6; It. 12500/13041; Runtime 20.64 s; Remaining runtime 0h18min19s; f1_train 0.6667; f1_dev 0.6038; loss_train 0.1094; loss_dev 0.1067
# Ep. 4/6; It. 13000/13041; Runtime 20.58 s; Remaining runtime 0h17min55s; f1_train 0.5000; f1_dev 0.5825; loss_train 0.1448; loss_dev 0.1231
# Ep. 5/6; It. 0/13041; Runtime 5.58 s; Remaining runtime 0h4min51s; f1_train 0.5000; f1_dev 0.5825; loss_train 0.1448; loss_dev 0.1231
# Ep. 5/6; It. 500/13041; Runtime 20.64 s; Remaining runtime 0h17min35s; f1_train 1.0000; f1_dev 0.6500; loss_train 0.0215; loss_dev 0.1133
# Ep. 5/6; It. 1000/13041; Runtime 20.58 s; Remaining runtime 0h17min12s; f1_train 0.8000; f1_dev 0.6000; loss_train 0.0479; loss_dev 0.1200
# Ep. 5/6; It. 1500/13041; Runtime 20.56 s; Remaining runtime 0h16min50s; f1_train 0.6667; f1_dev 0.6387; loss_train 0.0884; loss_dev 0.1133
# Ep. 5/6; It. 2000/13041; Runtime 20.56 s; Remaining runtime 0h16min30s; f1_train 1.0000; f1_dev 0.5872; loss_train 0.0177; loss_dev 0.1131
# Ep. 5/6; It. 2500/13041; Runtime 20.56 s; Remaining runtime 0h16min9s; f1_train 0.7500; f1_dev 0.5766; loss_train 0.1544; loss_dev 0.1284
# Ep. 5/6; It. 3000/13041; Runtime 20.60 s; Remaining runtime 0h15min50s; f1_train 0.8235; f1_dev 0.5741; loss_train 0.0896; loss_dev 0.1191
# Ep. 5/6; It. 3500/13041; Runtime 20.57 s; Remaining runtime 0h15min29s; f1_train 0.9412; f1_dev 0.6179; loss_train 0.0507; loss_dev 0.1215
# Ep. 5/6; It. 4000/13041; Runtime 20.58 s; Remaining runtime 0h15min8s; f1_train 0.8421; f1_dev 0.5794; loss_train 0.1058; loss_dev 0.1304
# Ep. 5/6; It. 4500/13041; Runtime 20.58 s; Remaining runtime 0h14min48s; f1_train 0.7143; f1_dev 0.6179; loss_train 0.1029; loss_dev 0.1222
# Ep. 5/6; It. 5000/13041; Runtime 20.56 s; Remaining runtime 0h14min26s; f1_train 0.6667; f1_dev 0.6055; loss_train 0.0517; loss_dev 0.1085
# Ep. 5/6; It. 5500/13041; Runtime 20.57 s; Remaining runtime 0h14min6s; f1_train 1.0000; f1_dev 0.6000; loss_train 0.0206; loss_dev 0.1355
# Ep. 5/6; It. 6000/13041; Runtime 20.56 s; Remaining runtime 0h13min45s; f1_train 0.7273; f1_dev 0.5941; loss_train 0.0735; loss_dev 0.1324
# Ep. 5/6; It. 6500/13041; Runtime 20.58 s; Remaining runtime 0h13min25s; f1_train 0.8889; f1_dev 0.6207; loss_train 0.0315; loss_dev 0.1139
# Ep. 5/6; It. 7000/13041; Runtime 20.58 s; Remaining runtime 0h13min5s; f1_train 0.7143; f1_dev 0.6032; loss_train 0.0893; loss_dev 0.1138
# Ep. 5/6; It. 7500/13041; Runtime 20.55 s; Remaining runtime 0h12min43s; f1_train 0.8571; f1_dev 0.6140; loss_train 0.0623; loss_dev 0.1111
# Ep. 5/6; It. 8000/13041; Runtime 20.57 s; Remaining runtime 0h12min23s; f1_train 0.5000; f1_dev 0.5253; loss_train 0.0840; loss_dev 0.1348
# Ep. 5/6; It. 8500/13041; Runtime 20.56 s; Remaining runtime 0h12min3s; f1_train 0.7000; f1_dev 0.5760; loss_train 0.1152; loss_dev 0.1147
# Ep. 5/6; It. 9000/13041; Runtime 20.56 s; Remaining runtime 0h11min42s; f1_train 0.8000; f1_dev 0.6139; loss_train 0.0407; loss_dev 0.1172
# Ep. 5/6; It. 9500/13041; Runtime 20.55 s; Remaining runtime 0h11min21s; f1_train 0.6667; f1_dev 0.6239; loss_train 0.0890; loss_dev 0.1153
# Ep. 5/6; It. 10000/13041; Runtime 22.79 s; Remaining runtime 0h12min13s; f1_train 0.8750; f1_dev 0.5941; loss_train 0.1182; loss_dev 0.1178
# Ep. 5/6; It. 10500/13041; Runtime 20.58 s; Remaining runtime 0h10min41s; f1_train 0.8889; f1_dev 0.6612; loss_train 0.0402; loss_dev 0.1155
# Ep. 5/6; It. 11000/13041; Runtime 20.36 s; Remaining runtime 0h10min14s; f1_train 0.8421; f1_dev 0.6071; loss_train 0.0832; loss_dev 0.1190
# Ep. 5/6; It. 11500/13041; Runtime 20.33 s; Remaining runtime 0h9min53s; f1_train 0.7059; f1_dev 0.6422; loss_train 0.1156; loss_dev 0.1190
# Ep. 5/6; It. 12000/13041; Runtime 20.31 s; Remaining runtime 0h9min31s; f1_train 1.0000; f1_dev 0.6667; loss_train 0.0258; loss_dev 0.1210
# Ep. 5/6; It. 12500/13041; Runtime 20.28 s; Remaining runtime 0h9min10s; f1_train 0.7692; f1_dev 0.5760; loss_train 0.0582; loss_dev 0.1139
# Ep. 5/6; It. 13000/13041; Runtime 20.26 s; Remaining runtime 0h8min49s; f1_train 0.5000; f1_dev 0.6139; loss_train 0.1321; loss_dev 0.1270
# Ep. 6/6; It. 0/13041; Runtime 5.88 s; Remaining runtime 0h2min33s; f1_train 0.6000; f1_dev 0.6218; loss_train 0.0570; loss_dev 0.1171
# Ep. 6/6; It. 500/13041; Runtime 20.32 s; Remaining runtime 0h8min29s; f1_train 0.1667; f1_dev 0.4706; loss_train 0.2829; loss_dev 0.1660
# Ep. 6/6; It. 1000/13041; Runtime 20.23 s; Remaining runtime 0h8min7s; f1_train 0.4000; f1_dev 0.3951; loss_train 0.0966; loss_dev 0.1236
# Ep. 6/6; It. 1500/13041; Runtime 20.24 s; Remaining runtime 0h7min47s; f1_train 0.8571; f1_dev 0.6355; loss_train 0.0624; loss_dev 0.1135
# Ep. 6/6; It. 2000/13041; Runtime 20.24 s; Remaining runtime 0h7min27s; f1_train 0.7000; f1_dev 0.6139; loss_train 0.1875; loss_dev 0.1127
# Ep. 6/6; It. 2500/13041; Runtime 20.25 s; Remaining runtime 0h7min6s; f1_train 0.6000; f1_dev 0.6275; loss_train 0.0961; loss_dev 0.1189
# Ep. 6/6; It. 3000/13041; Runtime 20.25 s; Remaining runtime 0h6min46s; f1_train 0.8889; f1_dev 0.6230; loss_train 0.0589; loss_dev 0.1152
# Ep. 6/6; It. 3500/13041; Runtime 20.22 s; Remaining runtime 0h6min25s; f1_train 0.6000; f1_dev 0.5913; loss_train 0.0953; loss_dev 0.1137
# Ep. 6/6; It. 4000/13041; Runtime 20.25 s; Remaining runtime 0h6min6s; f1_train 0.1538; f1_dev 0.3591; loss_train 0.3646; loss_dev 0.3631
# Ep. 6/6; It. 4500/13041; Runtime 20.24 s; Remaining runtime 0h5min45s; f1_train 0.8333; f1_dev 0.6000; loss_train 0.0718; loss_dev 0.1126
# Ep. 6/6; It. 5000/13041; Runtime 20.24 s; Remaining runtime 0h5min25s; f1_train 0.6667; f1_dev 0.6034; loss_train 0.1017; loss_dev 0.1158
# Ep. 6/6; It. 5500/13041; Runtime 20.24 s; Remaining runtime 0h5min5s; f1_train 0.6667; f1_dev 0.5849; loss_train 0.0699; loss_dev 0.1285
# Ep. 6/6; It. 6000/13041; Runtime 20.22 s; Remaining runtime 0h4min44s; f1_train 0.7143; f1_dev 0.6055; loss_train 0.0758; loss_dev 0.1321
# Ep. 6/6; It. 6500/13041; Runtime 20.23 s; Remaining runtime 0h4min24s; f1_train 0.4000; f1_dev 0.6667; loss_train 0.0543; loss_dev 0.1122
# Ep. 6/6; It. 7000/13041; Runtime 20.24 s; Remaining runtime 0h4min4s; f1_train 0.8750; f1_dev 0.6549; loss_train 0.0648; loss_dev 0.1220
# Ep. 6/6; It. 7500/13041; Runtime 20.24 s; Remaining runtime 0h3min44s; f1_train 0.6667; f1_dev 0.6724; loss_train 0.0265; loss_dev 0.1129
# Ep. 6/6; It. 8000/13041; Runtime 20.23 s; Remaining runtime 0h3min23s; f1_train 0.7059; f1_dev 0.6261; loss_train 0.0883; loss_dev 0.1250
# Ep. 6/6; It. 8500/13041; Runtime 20.24 s; Remaining runtime 0h3min3s; f1_train 0.5000; f1_dev 0.5349; loss_train 0.0777; loss_dev 0.1185
# Ep. 6/6; It. 9000/13041; Runtime 20.22 s; Remaining runtime 0h2min43s; f1_train 0.7273; f1_dev 0.6000; loss_train 0.1615; loss_dev 0.1216
# Ep. 6/6; It. 9500/13041; Runtime 20.23 s; Remaining runtime 0h2min23s; f1_train 0.7143; f1_dev 0.5741; loss_train 0.0897; loss_dev 0.1208
# Ep. 6/6; It. 10000/13041; Runtime 22.64 s; Remaining runtime 0h2min17s; f1_train 0.6667; f1_dev 0.5905; loss_train 0.0799; loss_dev 0.1233
# Ep. 6/6; It. 10500/13041; Runtime 20.27 s; Remaining runtime 0h1min43s; f1_train 0.6667; f1_dev 0.6038; loss_train 0.0609; loss_dev 0.1104
# Ep. 6/6; It. 11000/13041; Runtime 20.22 s; Remaining runtime 0h1min22s; f1_train 0.8000; f1_dev 0.6486; loss_train 0.0398; loss_dev 0.1164
# Ep. 6/6; It. 11500/13041; Runtime 20.25 s; Remaining runtime 0h1min2s; f1_train 0.5000; f1_dev 0.6095; loss_train 0.0551; loss_dev 0.1256
# Ep. 6/6; It. 12000/13041; Runtime 20.26 s; Remaining runtime 0h0min42s; f1_train 0.5455; f1_dev 0.6182; loss_train 0.1836; loss_dev 0.1169
# Ep. 6/6; It. 12500/13041; Runtime 20.23 s; Remaining runtime 0h0min21s; f1_train 0.5000; f1_dev 0.4792; loss_train 0.0308; loss_dev 0.1408
# Ep. 6/6; It. 13000/13041; Runtime 20.24 s; Remaining runtime 0h0min1s; f1_train 0.4444; f1_dev 0.6182; loss_train 0.1408; loss_dev 0.1149
# Total actual runtime: 0 hours 54 min 28 sec

# %%
alpha = 0.9
ewma_loss_dev = numpy_ewma_vectorized(loss_stack, alpha)
ewma_f1_dev = numpy_ewma_vectorized(f1_stack, alpha)
ewma_loss_train = numpy_ewma_vectorized(loss_train_stack, alpha)
ewma_f1_train = numpy_ewma_vectorized(f1_train_stack, alpha)

plt.figure(figsize = (20, 16))
plt.subplot(221) 
plt.plot(step_stack, ewma_loss_dev)
plt.xlabel("Learning Rate")
plt.ylabel("Loss dev")
#plt.xlim([0.001,0.008])
plt.ylim([0,0.2])
plt.subplot(222)
plt.plot(step_stack, ewma_f1_dev)
#plt.xlim([0.001,0.008])
#plt.ylim([0.55,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1 dev")

plt.subplot(223) 
plt.plot(step_stack, ewma_loss_train)
plt.xlabel("Learning Rate")
plt.ylabel("Loss Train")
#plt.xlim([0.001,0.008])
plt.ylim([0,0.2])
plt.subplot(224)
plt.plot(step_stack, ewma_f1_train)
#plt.xlim([0.001,0.008])
#plt.ylim([0.55,0.75])
plt.xlabel("Learning Rate")
plt.ylabel("F1 Train")

plt.show()

# %%
MODELS_FILE = "models/model4/QIQC_model4.ckpt"
modfil = os.path.join(DRIVE_PATH,MODELS_FILE)
X_cv_lengths, X_cv_set, y_cv_set = QIQC.cross_val_set()

with tf.Session() as sess: 
    saver.restore(sess, modfil)
    f1_cv = f1.eval(feed_dict = {X : X_cv_set, y : y_cv_set})
    f1_dev = f1.eval(feed_dict = {X : X_dev_set, y : y_dev_set})

f1_cv_pc = f1_cv * 100
f1_dev_pc = f1_dev * 100
print("cross val f1 {:.2f}%, dev f1 {:.2f}%".format(f1_cv_pc, f1_dev_pc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/models/model4/QIQC_model4.ckpt
# cross val f1 63.79%, dev f1 62.96%
